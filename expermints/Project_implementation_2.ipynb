# %% [markdown]
# # Project Implementation

# %% [markdown]
# ## Install and import the required libraries
#
# <br>
# In the implementation part, we will start by importing the required libraries for our work. We will work mainly with yfinance for data collection, Pandas and Numpy for data processing, and TensorFlow for machine learning.
#
# <br>
# Other relevant libraries are keras_tuner for hyperparameter optimization, scikit-learn for data scaling and model evaluation, pandas-ta for calculating technical indicators based on the data from yfinance, and matplotlib for visualization.

# %%
# install Dependencies and import libraries
# !pip install yfinance pandas numpy tensorflow scikit-learn pandas-ta matplotlib IPython
# Out:
# Requirement already satisfied: yfinance in c:\users\ammaroasus\anaconda3\envs\stockpred\lib\site-packages (0.2.40)
# Requirement already satisfied: pandas in c:\users\ammaroasus\anaconda3\envs\stockpred\lib\site-packages (1.3.5)
# Requirement already satisfied: numpy in c:\users\ammaroasus\anaconda3\envs\stockpred\lib\site-packages (1.21.6)
# Requirement already satisfied: tensorflow in c:\users\ammaroasus\anaconda3\envs\stockpred\lib\site-packages (2.11.0)
# Requirement already satisfied: scikit-learn in c:\users\ammaroasus\anaconda3\envs\stockpred\lib\site-packages (1.0.2)
# Requirement already satisfied: pandas-ta in c:\users\ammaroasus\anaconda3\envs\stockpred\lib\site-packages (0.3.14b0)
# Requirement already satisfied: matplotlib in c:\users\ammaroasus\anaconda3\envs\stockpred\lib\site-packages (3.5.3)
# Requirement already satisfied: requests>=2.31 in c:\users\ammaroasus\anaconda3\envs\stockpred\lib\site-packages (from yfinance) (2.31.0)
# Requirement already satisfied: peewee>=3.16.2 in c:\users\ammaroasus\anaconda3\envs\stockpred\lib\site-packages (from yfinance) (3.17.5)
# Requirement already satisfied: frozendict>=2.3.4 in c:\users\ammaroasus\anaconda3\envs\stockpred\lib\site-packages (from yfinance) (2.4.4)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\ammaroasus\anaconda3\envs\stockpred\lib\site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: platformdirs>=2.0.0 in c:\users\ammaroasus\anaconda3\envs\stockpred\lib\site-packages (from yfinance) (4.0.0)
# Requirement already satisfied: pytz>=2022.5 in c:\users\ammaroasus\anaconda3\envs\stockpred\lib\site-packages (from yfinance) (2024.1)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\ammaroasus\anaconda3\envs\stockpred\lib\site-packages (from yfinance) (4.12.3)
# Requirement already satisfied: html5lib>=1.1 in c:\users\ammaroasus\anaconda3\envs\stockpred\lib\site-packages (from yfinance) (1.1)
# Requirement already satisfied: lxml>=4.9.1 in c:\users\ammaroasus\anaconda3\envs\stockpred\lib\site-packages (from yfinance) (5.2.2)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\ammaroasus\anaconda3\envs\stockpred\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tensorflow-intel==2.11.0 in c:\users\ammaroasus\anaconda3\envs\stockpred\lib\site-packages (from tensorflow) (2.11.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\ammaroasus\anaconda3\envs\stockpred\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (3.8.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\ammaroasus\anaconda3\envs\stockpred\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.6.3)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\ammaroasus\anaconda3\envs\stockpred\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (2.3.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\ammaroasus\anaconda3\envs\stockpred\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.16.0)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\ammaroasus\anaconda3\envs\stockpred\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (24.3.25)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in c:\users\ammaroasus\anaconda3\envs\stockpred\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (3.19.6)
# Requirement already satisfied: tensorflow-estimator<2.12,>=2.11.0 in c:\users\ammaroasus\anaconda3\envs\stockpred\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (2.11.0)
# Requirement already satisfied: setuptools in c:\users\ammaroasus\anaconda3\envs\stockpred\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (65.6.3)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\ammaroasus\anaconda3\envs\stockpred\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (0.31.0)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\ammaroasus\anaconda3\envs\stockpred\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (0.4.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\ammaroasus\anaconda3\envs\stockpred\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.16.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\ammaroasus\anaconda3\envs\stockpred\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (3.3.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\ammaroasus\anaconda3\envs\stockpred\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (4.7.1)
# Requirement already satisfied: packaging in c:\users\ammaroasus\anaconda3\envs\stockpred\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (24.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\ammaroasus\anaconda3\envs\stockpred\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.62.2)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\ammaroasus\anaconda3\envs\stockpred\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (18.1.1)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\ammaroasus\anaconda3\envs\stockpred\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (0.2.0)
# Requirement already satisfied: tensorboard<2.12,>=2.11 in c:\users\ammaroasus\anaconda3\envs\stockpred\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (2.11.2)
# Requirement already satisfied: keras<2.12,>=2.11.0 in c:\users\ammaroasus\anaconda3\envs\stockpred\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (2.11.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\ammaroasus\anaconda3\envs\stockpred\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (2.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\ammaroasus\anaconda3\envs\stockpred\lib\site-packages (from scikit-learn) (3.1.0)
# Requirement already satisfied: scipy>=1.1.0 in c:\users\ammaroasus\anaconda3\envs\stockpred\lib\site-packages (from scikit-learn) (1.7.3)
# Requirement already satisfied: joblib>=0.11 in c:\users\ammaroasus\anaconda3\envs\stockpred\lib\site-packages (from scikit-learn) (1.3.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\ammaroasus\anaconda3\envs\stockpred\lib\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\ammaroasus\anaconda3\envs\stockpred\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\ammaroasus\anaconda3\envs\stockpred\lib\site-packages (from matplotlib) (9.5.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\ammaroasus\anaconda3\envs\stockpred\lib\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ammaroasus\anaconda3\envs\stockpred\lib\site-packages (from matplotlib) (4.38.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\ammaroasus\anaconda3\envs\stockpred\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.4.1)
# Requirement already satisfied: webencodings in c:\users\ammaroasus\anaconda3\envs\stockpred\lib\site-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ammaroasus\anaconda3\envs\stockpred\lib\site-packages (from requests>=2.31->yfinance) (1.26.19)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ammaroasus\anaconda3\envs\stockpred\lib\site-packages (from requests>=2.31->yfinance) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ammaroasus\anaconda3\envs\stockpred\lib\site-packages (from requests>=2.31->yfinance) (2022.12.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\ammaroasus\anaconda3\envs\stockpred\lib\site-packages (from requests>=2.31->yfinance) (3.3.2)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\ammaroasus\anaconda3\envs\stockpred\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.11.0->tensorflow) (0.38.4)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\ammaroasus\anaconda3\envs\stockpred\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (1.8.1)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\ammaroasus\anaconda3\envs\stockpred\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2.2.3)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\ammaroasus\anaconda3\envs\stockpred\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (0.6.1)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\ammaroasus\anaconda3\envs\stockpred\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (3.4.4)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\ammaroasus\anaconda3\envs\stockpred\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (0.4.6)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\ammaroasus\anaconda3\envs\stockpred\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2.29.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\ammaroasus\anaconda3\envs\stockpred\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (4.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\ammaroasus\anaconda3\envs\stockpred\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\ammaroasus\anaconda3\envs\stockpred\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (0.3.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\ammaroasus\anaconda3\envs\stockpred\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2.0.0)
# Requirement already satisfied: importlib-metadata>=4.4 in c:\users\ammaroasus\anaconda3\envs\stockpred\lib\site-packages (from markdown>=2.6.8->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (6.7.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\ammaroasus\anaconda3\envs\stockpred\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2.1.5)
# Requirement already satisfied: zipp>=0.5 in c:\users\ammaroasus\anaconda3\envs\stockpred\lib\site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (3.15.0)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in c:\users\ammaroasus\anaconda3\envs\stockpred\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (0.5.1)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\ammaroasus\anaconda3\envs\stockpred\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (3.2.2)

# %%
# https://pypi.org/project/yfinance/ (""" it's an open-source tool that uses Yahoo's publicly available APIs, and is intended for research and educational purposes. """)
# import yfinance, our data source
import yfinance as yf

# import pandas and numpy
import pandas as pd 
import numpy as np

# import from tensorflow
from tensorflow.keras.models import Sequential, load_model, Model
from tensorflow.keras.layers import SimpleRNN, Dense, LSTM, Input, GRU, SeparableConv1D, BatchNormalization, MaxPooling1D, add, Layer, concatenate
from tensorflow.keras.utils import to_categorical, plot_model
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
from tensorflow.keras.optimizers import Adam, RMSprop, SGD
from tensorflow.keras.saving import register_keras_serializable

# import from keras_tuner
from keras_tuner import HyperModel, Hyperband, RandomSearch, Tuner, Oracle

# import from scikit-learn
from sklearn.preprocessing import MinMaxScaler, StandardScaler, RobustScaler
from sklearn.metrics import precision_recall_fscore_support, accuracy_score, r2_score, confusion_matrix, ConfusionMatrixDisplay

# https://pypi.org/project/pandas-ta/ ("""An easy to use Python 3 Pandas Extension with 130+ Technical Analysis Indicators. Can be called from a Pandas DataFrame or standalone""")
# import pandas-ta
import pandas_ta as ta

# import matplotlib for data visualisation
import matplotlib.pyplot as plt

# import from IPython library to be able to display images
from IPython.display import Image, display


# this library allow us to calculate how long a process would take 
from datetime import datetime

# %% [markdown]
# ## Load Data
#
#
# <br>
# In this implementation, we will work with 5 different stocks from the S&P500(1) list. The 5 stocks we will work with are chosen based on their ranking in this list from most valuable to least valuable, and each one is relatively distant from the other and belongs to a different industry. This will ensure a diverse sample and that our model evaluation results generalize relatively well, reducing the possibility of bias and overfitting.
#
# Check out our stock list for this project (2).
#
# <br>
# The yfinance API allows us to request the stock data for a company's given period and interval values. For the period value, we will set it to 10 years or max value which will be sufficient for all of our experiments, for the interval value however, which determines the frequency of the data rows, we will experiment with many options to see if our approach generalizes better with specific interval values as different intervals are relevant to other groups of financial analysts and traders in the real world, therefore we must try to create the best model relevant to each of these groups.
#
# That's why we will define a function that allows us to download any number of stock data at any period or interval, save the data as a CSV file to local storage, load it from storage, split it into different data frames based on the stock, and organize the data frames in a dictionary so it's easy to work with for the rest of the project.
#
# Check out the loadData function (3).

# %%
# insert the stock symbols into a list
symbols_list = ['PFE', 'ROP', 'XYL', 'CPAY', 'INCY']

# %%
# define a function to load the data from source (yfinance API), and save it as a csv to local storage
def loadData(symbols=symbols_list, period='10y', interval='1wk'):
    
    try:
        # load the the dataframe from the csv file if it already exist
        df = pd.read_csv(f'{period}_{interval}_stocks_data.csv').set_index(['Date', 'Ticker'])
        
        print("Data loaded from directory")
        
    except FileNotFoundError:
        # print a message stating the data does not already exists and need to be downloaded from yfinance
        print(f"There is no {period}_{interval}_stocks_data.csv. Data will be downloaded from yfinance.")
        
        # download the data from source and store it in the stock_data variable which will hold the data as a pandas dataframe
        stocks_data =  yf.download(symbols, period=period, interval=interval)

        # reshape the dataframe as a multi-level index dataframe
        stocks_data = stocks_data.stack()

        # source: https://www.statology.org/pandas-change-column-names-to-lowercase/
        # convert column names to lowercase
        stocks_data.columns = stocks_data.columns.str.lower()

        # save the dataframe to a csv file (Save the data to a CSV so we don't have to make any extra unnecessary requests to the API every time we reload the notebook)
        stocks_data.to_csv(f'{period}_{interval}_stocks_data.csv', index=True)

        # load the the dataframe from the csv file
        df = pd.read_csv(f'{period}_{interval}_stocks_data.csv').set_index(['Date', 'Ticker'])

    finally: 
        # create a dict to store the dataframe of each unique symbol where keys are symbol, values are dataframes
        df_dict = {}

        # iterate over the symbols
        for symbol in symbols:

            # source of inspiration https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.xs.html [11]
            # extract the specific stock data at the 'Ticker' level of this multi index dataframe and save it as a dataframe
            symbol_df = df.xs(symbol, axis=0, level='Ticker', drop_level=True)

            # store the datafram into the df_dict
            df_dict[symbol] = symbol_df

        # return the dictionary
        return df_dict

# %% [markdown]
# Load the data of the 5 selected stocks for the last 10 years on a weekly intrevals.

# %%
# load the stock data for the 5 companies into a dictionary
dfs = loadData(symbols=symbols_list, period='10y', interval='1wk')
# Out:
# Data loaded from directory

# %% [markdown]
# ## Perform simple exploritory data analysis
#
# <br>
# Now that we have a dictionary of dataframes, we can analyze the data and make some observations.

# %% [markdown]
# 1. We can get the shape of the data for any stock

# %%
# the data shape
for symbol in dfs.keys():
    print(f"Symbol: {symbol}, Shape: {dfs[symbol].shape} ")
# Out:
# Symbol: PFE, Shape: (523, 6)
# Symbol: ROP, Shape: (523, 6)
# Symbol: XYL, Shape: (523, 6)
# Symbol: CPAY, Shape: (523, 6)
# Symbol: INCY, Shape: (523, 6)

# %% [markdown]
# 2. We can get the basic stats for any stock

# %%
# data basic stats
dfs["PFE"].describe()
# Out:
#         adj close       close        high         low        open  \
# count  523.000000  523.000000  523.000000  523.000000  523.000000
# mean    29.870774   36.269160   37.066481   35.423588   36.250718
# std      7.594988    6.862873    7.114429    6.536369    6.851178
# min     17.923565   25.400000   26.170000   25.200001   25.580000
# 25%     23.773307   31.555978   32.129982   30.858634   31.555977
# 50%     28.344492   34.478176   34.914612   33.785580   34.487667
# 75%     33.093800   40.028976   40.682581   39.165085   40.033976
# max     52.740730   59.480000   61.709999   57.160000   60.599998
#
#              volume
# count  5.230000e+02
# mean   1.373323e+08
# std    6.265050e+07
# min    3.922725e+07
# 25%    9.714320e+07
# 50%    1.215046e+08
# 75%    1.583856e+08
# max    6.333997e+08

# %% [markdown]
# 3. We can check how many missing values each column have for a any stock dataframe

# %%
# how many null values in each column
dfs['PFE'].isnull().sum()
# Out:
# adj close    0
# close        0
# high         0
# low          0
# open         0
# volume       0
# dtype: int64

# %% [markdown]
# #### Columns breakdown
#
# <br>
# Date: The index is the date on which the information on the rest of the columns takes place.
#
# <br>
# Adjusted close: is the closing price after adjustments for all applicable splits and dividend distributions which represents the true closing price.
#
# <br>
# Close: is the historical closing price of the stock.
#
# <br>
# High: is the highest point a stock has reached.
#
# <br>
# Low: is the lowest point of a stock.
#
# <br>
# Open: the opening price of the stock.
#
# <br>
# Volume: the volume of stocks traded in that timeframe.
#
# <br>
# Usually for this type of model we would only keep either Adjusted close or close, we are going to keep the adjusted close for now but it worth mentiong that most of the technical indicators we are utilizing are dependent on the none adjusted close.

# %% [markdown]
# ## Adding Targets
#
# <br>
# To predict stock trends based on past data, we'll create two new columns:
#
# - 'next_close': Represents the next closing price, serving as the target for the regression model.
#
# - 'trend': Indicates whether the next close is higher '1' or lower '0' than the current close, serving as the target for the classification model.
#
# So we will train the model on to the current closing price and make it predict the next closing price/trend for any given timestep.
#
# <br>
# To do that we define the add_targets(4) function which takes a data frame as input, adds the 'next_close' and 'trend' columns to it, and returns it as an output.

# %%
# create a function that takes a dataframe and create 'next_close' column based on its 'close' column
def get_next_close(_df):
    
    # create the 'next_close' column to be equal to the next closing price
    # this can be accomplished easily by shifting the close column backward by 1
    return _df['close'].shift(-1)

# create a function that returns 1 if the the next closing price is higher than current closing price and 0 otherwise.
def assign_trend(row):
    if row['next_close'] > row['close']:
        return 1
    elif row['next_close'] < row['close']:
        return 0
    else: # if the next value is missing then return NaN
        return np.nan

# create a function that add the target columns to the dataframe
def add_targets(_df):
    
    # add the next_close column to the dataframe
    _df['next_close'] = get_next_close(_df)
    
    # add the trend column to the dataframe
    _df['trend'] = _df.apply(assign_trend, axis=1)
    
    # drop the NaN values
    _df.dropna(inplace=True)
    
    # fix the 'trend' data type to be int
    _df = _df.astype({'trend': int})
    
    return _df

# %% [markdown]
# ## Feature Engineering
#
# <br>
# Adding indicators to the dataframe is important for enhancing model performance and accuracy.
#
# <br>
# We can either manually calculate technical indicators, which is time-consuming and prone to errors, or we can utilize an existing library designed for this purpose. pandas-ta is a library that includes a wide set of technical indicators and is designed to work seamlessly with pandas dataframes.

# %% [markdown]
# To explore the available indicators in pandas-ta, you can use the following:

# %%
# list available technical indicators
help(dfs['PFE'].ta.indicators())
# Out:
# Pandas TA - Technical Analysis Indicators - v0.3.14b0
# Total Indicators & Utilities: 205
# Abbreviations:
#     aberration, above, above_value, accbands, ad, adosc, adx, alma, amat, ao, aobv, apo, aroon, atr, bbands, below, below_value, bias, bop, brar, cci, cdl_pattern, cdl_z, cfo, cg, chop, cksp, cmf, cmo, coppock, cross, cross_value, cti, decay, decreasing, dema, dm, donchian, dpo, ebsw, efi, ema, entropy, eom, er, eri, fisher, fwma, ha, hilo, hl2, hlc3, hma, hwc, hwma, ichimoku, increasing, inertia, jma, kama, kc, kdj, kst, kurtosis, kvo, linreg, log_return, long_run, macd, mad, massi, mcgd, median, mfi, midpoint, midprice, mom, natr, nvi, obv, ohlc4, pdist, percent_return, pgo, ppo, psar, psl, pvi, pvo, pvol, pvr, pvt, pwma, qqe, qstick, quantile, rma, roc, rsi, rsx, rvgi, rvi, short_run, sinwma, skew, slope, sma, smi, squeeze, squeeze_pro, ssf, stc, stdev, stoch, stochrsi, supertrend, swma, t3, td_seq, tema, thermo, tos_stdevall, trima, trix, true_range, tsi, tsignals, ttm_trend, ui, uo, variance, vhf, vidya, vortex, vp, vwap, vwma, wcp, willr, wma, xsignals, zlma, zscore
#
# Candle Patterns:
#     2crows, 3blackcrows, 3inside, 3linestrike, 3outside, 3starsinsouth, 3whitesoldiers, abandonedbaby, advanceblock, belthold, breakaway, closingmarubozu, concealbabyswall, counterattack, darkcloudcover, doji, dojistar, dragonflydoji, engulfing, eveningdojistar, eveningstar, gapsidesidewhite, gravestonedoji, hammer, hangingman, harami, haramicross, highwave, hikkake, hikkakemod, homingpigeon, identical3crows, inneck, inside, invertedhammer, kicking, kickingbylength, ladderbottom, longleggeddoji, longline, marubozu, matchinglow, mathold, morningdojistar, morningstar, onneck, piercing, rickshawman, risefall3methods, separatinglines, shootingstar, shortline, spinningtop, stalledpattern, sticksandwich, takuri, tasukigap, thrusting, tristar, unique3river, upsidegap2crows, xsidegap3methods
# Help on NoneType object:
#
# class NoneType(object)
#  |  Methods defined here:
#  |
#  |  __bool__(self, /)
#  |      True if self else False
#  |
#  |  __repr__(self, /)
#  |      Return repr(self).
#  |
#  |  ----------------------------------------------------------------------
#  |  Static methods defined here:
#  |
#  |  __new__(*args, **kwargs) from builtins.type
#  |      Create and return a new object.  See help(type) for accurate signature.

# %% [markdown]
# For this project, we added a total of 66 technical indicators. Each feature is carefully selected based on the technical indicator's definition and description.
#
# Check the full list of the selected indicators and the implementation of the add_technical_indicators function which take a dataframe as input and add these indicators to it (5).
#
# We can also get detailed information on specific indicators:

# %%
# examine the MACD indicator
help(ta.macd)
# Out:
# Help on function macd in module pandas_ta.momentum.macd:
#
# macd(close, fast=None, slow=None, signal=None, talib=None, offset=None, **kwargs)
#     Moving Average Convergence Divergence (MACD)
#
#     The MACD is a popular indicator to that is used to identify a security's trend.
#     While APO and MACD are the same calculation, MACD also returns two more series
#     called Signal and Histogram. The Signal is an EMA of MACD and the Histogram is
#     the difference of MACD and Signal.
#
#     Sources:
#         https://www.tradingview.com/wiki/MACD_(Moving_Average_Convergence/Divergence)
#         AS Mode: https://tr.tradingview.com/script/YFlKXHnP/
#
#     Calculation:
#         Default Inputs:
#             fast=12, slow=26, signal=9
#         EMA = Exponential Moving Average
#         MACD = EMA(close, fast) - EMA(close, slow)
#         Signal = EMA(MACD, signal)
#         Histogram = MACD - Signal
#
#         if asmode:
#             MACD = MACD - Signal
#             Signal = EMA(MACD, signal)
#             Histogram = MACD - Signal
#
#     Args:
#         close (pd.Series): Series of 'close's
#         fast (int): The short period. Default: 12
#         slow (int): The long period. Default: 26
#         signal (int): The signal period. Default: 9
#         talib (bool): If TA Lib is installed and talib is True, Returns the TA Lib
#             version. Default: True
#         offset (int): How many periods to offset the result. Default: 0
#
#     Kwargs:
#         asmode (value, optional): When True, enables AS version of MACD.
#             Default: False
#         fillna (value, optional): pd.DataFrame.fillna(value)
#         fill_method (value, optional): Type of fill method
#
#     Returns:
#         pd.DataFrame: macd, histogram, signal columns.

# %% [markdown]
# Then, we’ll group the features into four categories:
# 1. Base Features: Original features from yfinance (6 features).
# 2. Technical Indicators based on Closing Price: (30 features).
# 3. Technical Indicators based on Highs and Lows: (31 features).
# 4. Technical Indicators based on Volume: (5 features).
# This grouping will enable us to create more sophisticated models, such as multi-output or inception models, which we will explore later.

# %%
# for the time being let's create a function that add all the technical indicators we want to a df
def add_technical_indicators(_df):
    
    ##### indicators based on the closing price ##### index range: 6:36
    # apply macd on the close column in a df and add it to the dataframe    
    macd = ta.macd(_df['close'])
    # The MACD (Moving Average Convergence/Divergence) is a popular indicator to that is used to identify a trend
    _df.insert(6, 'macd', macd.iloc[:,0])
    # Histogram is the difference of MACD and Signal
    _df.insert(7, 'macd_histogram', macd.iloc[:,1])
    # Signal is an EMA (exponential moving average) of MACD
    _df.insert(8, 'macd_signal', macd.iloc[:,2])
    
    # apply RSI on the Close column in a df and add it to the dataframe    
    # RSI (Relative Strength Index) is popular momentum oscillator. Measures velocity and magnitude a trend
    rsi = ta.rsi(_df['close'])
    _df.insert(9, 'rsi', rsi)

    # apply SMA on the Close column in a df and add it to the dataframe    
    # SMA (Simple Moving Average) is the classic moving average that is the equally weighted average over n periods.
    sma = ta.sma(_df['close'])
    _df.insert(10, 'sma', sma)

    # apply EMA on the Close column in a df and add it to the dataframe    
    # EMA (Exponential Moving Average). The weights are determined by alpha which is proportional to it's length.
    ema = ta.ema(_df['close'])
    _df.insert(11, 'ema', ema)
    
    ######## repeat the same proccess for all the technical indicators we want to include ##########
    # bbands: A popular volatility indicator by John Bollinger.
    bbands = ta.bbands(_df['close'])
    _df.insert(12, 'bbands_lower', bbands.iloc[:,0])
    _df.insert(13, 'bbands_mid', bbands.iloc[:,1])
    _df.insert(14, 'bbands_upper', bbands.iloc[:,2])
    _df.insert(15, 'bbands_bandwidth', bbands.iloc[:,3])
    _df.insert(16, 'bbands_percent', bbands.iloc[:,4])
    
    # dema: The Double Exponential Moving Average attempts to a smoother average with less lag than the normal Exponential Moving Average (EMA).
    dema = ta.dema(_df['close'])
    _df.insert(17, 'dema', dema)
    
    # tema: A less laggy Exponential Moving Average.
    tema = ta.tema(_df['close'])
    _df.insert(18, 'tema', tema)

    # roc: Rate of Change is an indicator is also referred to as Momentum. It is a pure momentum oscillator that measures the percent change in price with the previous price 'n' (or length) periods ago.
    roc = ta.roc(_df['close'])
    _df.insert(19, 'roc', roc)
    
    # mom: Momentum is an indicator used to measure a security's speed (or strength) of movement.  Or simply the change in price.
    mom = ta.mom(_df['close'])
    _df.insert(20, 'mom', mom)
    
    # kama: Developed by Perry Kaufman, Kaufman's Adaptive Moving Average (KAMA) is a moving average designed to account for market noise or volatility. KAMA will closely follow prices when the price swings are relatively small and the noise is low. KAMA will adjust when the price swings widen and follow prices from a greater distance. This trend-following indicator can be used to identify the overall trend, time turning points and filter price movements.
    kama = ta.kama(_df['close'])
    _df.insert(21, 'kama', kama)
                       
    # trix: is a momentum oscillator to identify divergences.
    trix = ta.trix(_df['close'])
    _df.insert(22, 'trix', trix.iloc[:,0])
    _df.insert(23, 'trixs', trix.iloc[:,1])
    
    # hma: The Hull Exponential Moving Average attempts to reduce or remove lag in moving averages.
    hma = ta.hma(_df['close'])
    _df.insert(24, 'hma', hma)
    
    # alma: The ALMA moving average uses the curve of the Normal (Gauss) distribution, which can be shifted from 0 to 1. This allows regulating the smoothness and high sensitivity of the indicator. Sigma is another parameter that is responsible for the shape of the curve coefficients. This moving average reduces lag of the data in conjunction with smoothing to reduce noise.
    alma = ta.alma(_df['close'])
    _df.insert(25, 'alma', alma)
    
    # apo: The Absolute Price Oscillator is an indicator used to measure a security's momentum.  It is simply the difference of two Exponential Moving Averages (EMA) of two different periods. Note: APO and MACD lines are equivalent.
    apo = ta.apo(_df['close'])
    _df.insert(26, 'apo', apo)
    
    # cfo: The Forecast Oscillator calculates the percentage difference between the actualprice and the Time Series Forecast (the endpoint of a linear regression line).
    cfo = ta.cfo(_df['close'])
    _df.insert(27, 'cfo', cfo)
    
    # cg: The Center of Gravity Indicator by John Ehlers attempts to identify turning points while exhibiting zero lag and smoothing.
    cg = ta.cg(_df['close'])
    _df.insert(28, 'cg', cg)
    
    # cmo: Attempts to capture the momentum of an asset with overbought at 50 and oversold at -50.
    cmo = ta.cmo(_df['close'])
    _df.insert(29, 'cmo', cmo)
    
    # coppock: Coppock Curve (originally called the "Trendex Model") is a momentum indicator is designed for use on a monthly time scale.  Although designed for monthly use, a daily calculation over the same period can be made, converting the periods to 294-day and 231-day rate of changes, and a 210-day weighted moving average.
    coppock = ta.coppock(_df['close'])
    _df.insert(30, 'coppock', coppock)
    
    # cti: The Correlation Trend Indicator is an oscillator created by John Ehler in 2020. It assigns a value depending on how close prices in that range are to following a positively- or negatively-sloping straight line. Values range from -1 to 1. This is a wrapper for ta.linreg(close, r=True).
    cti = ta.cti(_df['close'])
    _df.insert(31, 'cti', cti)
    
    # decay: Creates a decay moving forward from prior signals like crosses. The default is "linear". Exponential is optional as "exponential" or "exp".
    decay = ta.decay(_df['close'])
    _df.insert(32, 'decay', decay)
    
    # decreasing: Returns True if the series is decreasing over a period, False otherwise. If the kwarg 'strict' is True, it returns True if it is continuously decreasing over the period. When using the kwarg 'asint', then it returns 1 for True or 0 for False.
    decreasing = ta.decreasing(_df['close'])
    _df.insert(33, 'decreasing', decreasing)
    
    # ebsw: This indicator measures market cycles and uses a low pass filter to remove noise. Its output is bound signal between -1 and 1 and the maximum length of a detected trend is limited by its length input.
    ebsw = ta.ebsw(_df['close'])
    _df.insert(34, 'ebsw', ebsw)
    
    # entropy: Introduced by Claude Shannon in 1948, entropy measures the unpredictability of the data, or equivalently, of its average information. A die has higher entropy (p=1/6) versus a coin (p=1/2).
    entropy = ta.entropy(_df['close'])
    _df.insert(35, 'entropy', entropy)
    
    
    ##### indicators based on the high and lows of the price ##### range= 36:67
    
    # aberration: A volatility indicator
    aberration = ta.aberration(_df['high'], _df['low'], _df['close'])
    _df.insert(36, 'aberration_zg', aberration.iloc[:,0])
    _df.insert(37, 'aberration_sg', aberration.iloc[:,1])
    _df.insert(38, 'aberration_xg', aberration.iloc[:,2])
    _df.insert(39, 'aberration_atr', aberration.iloc[:,3])
    
    # adx:  Average Directional Movement is meant to quantify trend strength by measuring the amount of movement in a single direction.    
    adx = ta.adx(_df['high'], _df['low'], _df['close'])
    _df.insert(40, 'adx_adx', adx.iloc[:,0])
    _df.insert(41, 'adx_dmp', adx.iloc[:,1])
    _df.insert(42, 'adx_dmn', adx.iloc[:,2])

    # atr: Averge True Range is used to measure volatility, especially volatility caused by gaps or limit moves.
    atr = ta.atr(_df['high'], _df['low'], _df['close'])
    _df.insert(43, 'atr', atr)
    
    # stoch: The Stochastic Oscillator (STOCH) was developed by George Lane in the 1950's. He believed this indicator was a good way to measure momentum because changes in momentum precede changes in price.
    stoch = ta.stoch(_df['high'], _df['low'], _df['close'])
    _df.insert(44, 'stoch_k', stoch.iloc[:,0])
    _df.insert(45, 'stoch_d', stoch.iloc[:,1])
    
    # Supertrend: is an overlap indicator. It is used to help identify trend direction, setting stop loss, identify support and resistance, and/or generate buy & sell signals.
    supertrend = ta.supertrend(_df['high'], _df['low'], _df['close'])
    _df.insert(46, 'supertrend_trend', supertrend.iloc[:,0])
    _df.insert(47, 'supertrend_direction', supertrend.iloc[:,1])
    
    # cci: Commodity Channel Index is a momentum oscillator used to primarily identify overbought and oversold levels relative to a mean.
    cci = ta.cci(_df['high'], _df['low'], _df['close'])
    _df.insert(48, 'cci', cci)
    
    # aroon: attempts to identify if a security is trending and how strong.
    aroon = ta.aroon(_df['high'], _df['low'])
    _df.insert(49, 'aroon_up', aroon.iloc[:,0])
    _df.insert(50, 'aroon_down', aroon.iloc[:,1])
    _df.insert(51, 'aroon_osc', aroon.iloc[:,2])
    
    # natr: Normalized Average True Range attempt to normalize the average true range.
    natr = ta.natr(_df['high'], _df['low'], _df['close'])
    _df.insert(52, 'natr', natr)
    
    # William's Percent R is a momentum oscillator similar to the RSI that attempts to identify overbought and oversold conditions.
    willr = ta.willr(_df['high'], _df['low'], _df['close'])
    _df.insert(53, 'willr', willr)
    
    # vortex: Two oscillators that capture positive and negative trend movement.
    vortex = ta.vortex(_df['high'], _df['low'], _df['close'])
    _df.insert(54, 'vortex_vip', vortex.iloc[:,0])
    _df.insert(55, 'vortex_vim', vortex.iloc[:,1])
    
    # hlc3: the average of high, low, and close prices
    hlc3 = ta.hlc3(_df['high'], _df['low'], _df['close'])
    _df.insert(56, 'hlc3', hlc3)
    
    # ohlc4: the average of open, high, low, and close prices
    ohlc4 = ta.ohlc4(_df['open'], _df['high'], _df['low'], _df['close'])
    _df.insert(57, 'ohlc4', ohlc4)
    
    # accbands: Acceleration Bands created by Price Headley plots upper and lower envelope bands around a simple moving average.
    accbands = ta.accbands(_df['high'], _df['low'], _df['close'])
    _df.insert(58, 'accbands_lower', accbands.iloc[:,0])
    _df.insert(59, 'accbands_mid', accbands.iloc[:,1])
    _df.insert(60, 'accbands_upper', accbands.iloc[:,2])

    # chop: The Choppiness Index was created by Australian commodity trader E.W. Dreiss and is designed to determine if the market is choppy (trading sideways) or not choppy (trading within a trend in either direction). Values closer to 100 implies the underlying is choppier whereas values closer to 0 implies the underlying is trending.
    chop = ta.chop(_df['high'], _df['low'], _df['close'])
    _df.insert(61, 'chop', chop)
    
    # dm: The Directional Movement was developed by J. Welles Wilder in 1978 attempts to determine which direction the price of an asset is moving. It compares prior highs and lows to yield to two series +DM and -DM.
    dm = ta.dm(_df['high'], _df['low'])
    _df.insert(62, 'dm_positive', dm.iloc[:,0])
    _df.insert(63, 'dm_negative', dm.iloc[:,1])

    # donchian: Donchian Channels are used to measure volatility, similar to Bollinger Bands and Keltner Channels.
    donchian = ta.donchian(_df['high'], _df['low'])
    _df.insert(64, 'donchian_lower', donchian.iloc[:,0])
    _df.insert(65, 'donchian_mid', donchian.iloc[:,1])
    _df.insert(66, 'donchian_upper', donchian.iloc[:,2])
    
    
    ##### indicators based on the volume of the price ##### range= 67:72
    
    # obv: On Balance Volume is a cumulative indicator to measure buying and selling pressure.
    obv = ta.obv(_df['close'], _df['volume'])
    _df.insert(67, 'obv', obv)
    
    # vwma: Volume Weighted Moving Average.
    vwma = ta.vwma(_df['close'], _df['volume'])
    _df.insert(68, 'vwma', vwma)
    
    # adosc: Accumulation/Distribution Oscillator indicator utilizes Accumulation/Distribution and treats it similarily to MACD or APO.
    adosc = ta.adosc(_df['high'], _df['low'], _df['close'], _df['volume'])
    _df.insert(69, 'adosc', adosc)
    
    # cmf: Chailin Money Flow measures the amount of money flow volume over a specific period in conjunction with Accumulation/Distribution.
    cmf = ta.cmf(_df['high'], _df['low'], _df['close'], _df['volume'])
    _df.insert(70, 'cmf', cmf)
    
    # efi: Elder's Force Index measures the power behind a price movement using price and volume as well as potential reversals and price corrections.
    efi = ta.efi(_df['close'], _df['volume'])
    _df.insert(71, 'efi', efi)


    #### we can add more technical indicators if we want using the same process ####
    
    # remove the NaN values and return the new dataframe
    _df.dropna(inplace=True)
    
    return _df

# %% [markdown]
# Finally we will create add_targets_and_indicators (6), a helper functions to add the targets and indicators to all dataframes in a dictionary.

# %%
# create a function that takes a dictionary of dataframes as input and add the targets and features to them 
def add_targets_and_indicators(_dfs):
    
    # iterate over the dataframes in the dictionary
    for symbol in _dfs.keys():
        
        # copy the dataframe
        _df = _dfs[symbol].copy(deep=True)
        
        # add target columns to the copied dataframe
        _df = add_targets(_df)
        
        # add technical indicators to the copied dataframe
        _df = add_technical_indicators(_df)
        
        # replace the original dataframe with the new dataframe
        _dfs[symbol] = _df
    
    # return the new dataframes dictionary
    return _dfs

# %%
# add the targets and technical indicators to each dataframe in the dictionary
full_dfs = add_targets_and_indicators(dfs.copy())

# %%
# check the shape of the new dataframes
full_dfs['PFE'].shape
# Out:
# (479, 74)

# %% [markdown]
# ## Data balance and common sense baseline
#
# <br>
# With the target column added, we can now assess the balance of our dataset from a classification perspective. An unbalanced dataset may skew the model's predictions. The trend column indicates whether the stock will rise or fall. By calculating the ratio of (trend = 1) to the total number of samples, we can evaluate the data balance.
#
# To acomplish that, we'll create calculate_data_balance (6), a function that computes the ratio of trend = 1 for each individual dataframe in our dictionary and the overall ratio across all dataframes.

# %%
# create a function to computes the ratio of trend = 1 for each individual dataframe in a dictionary 
def calculate_data_balance(_dfs):
    
    # store the total ratio of trend 1 of all the dataframes
    total = 0
    
    # iterate over the dataframes in the dictionary
    for symbol in _dfs.keys():
        
        # get the number of values where trend = 1
        trend_1 = _dfs[symbol]['trend'].value_counts()[1]
        
        # get the total number of rows in the dataframe
        row_num = _dfs[symbol].shape[0]
        
        # percentage of 'trend up' to the whole column
        trend_1_ratio = trend_1/row_num
        
        # print the ratio to the screen
        print(f"The Trend up ratio of {symbol} is: {trend_1_ratio}")
        
        # add the ratio to total
        total += trend_1_ratio
        
    # get the average trend up ratio
    average = total / len(_dfs.keys())
    
    # print the average ratio
    print(f"The Average Trend up ratio is: {average}")

# %%
# get the trend up ratio of all the dataframes in the dictionary to get a sense of how balanced the data is
calculate_data_balance(full_dfs)
# Out:
# The Trend up ratio of PFE is: 0.5177453027139874
# The Trend up ratio of ROP is: 0.578838174273859
# The Trend up ratio of XYL is: 0.5912863070539419
# The Trend up ratio of CPAY is: 0.556935817805383
# The Trend up ratio of INCY is: 0.463768115942029
# The Average Trend up ratio is: 0.5417147435578401

# %% [markdown]
# Based on these results, the data appears well-balanced.
#
# #### Common Sense Baseline
#
# Establishing a common sense baseline is crucial in machine learning to ensure that our model performs at least as well as basic logical assumptions. In stock prediction, a reasonable baseline assumes that the future trend will mirror the current trend; if a stock is rising, it’s expected to continue rising, and vice versa. This baseline is realistic and aligns with principles from behavioral finance[12], however, it's outside the scope of this project.
#
# To acheive that we will create calculate_common_sense_baseline (7), a function that calculates this common sense score for each stock in the dictionary, as well as the average overall score.

# %%
def calculate_common_sense_baseline(_dfs):
    
    # store the total common_sense_score for all the dataframes
    total = 0
    
    # iterate over the dataframes in the dictionary
    for symbol in _dfs.keys():
        
        # since the common sense will be to assume the trend next is going to be the same as the trend now, we will shift the trend
        # forward by one, this will give us a column that matches the common sense assumption we set
        common_sense = _dfs[symbol]['trend'].shift(1)

        # measure the average of when the common sense (naive) prediction matches the actual 'trend'
        common_sense_score = (common_sense == _dfs[symbol]['trend']).mean()
        
        # print the score to the screen
        print(f"The common sense score of {symbol} is: {common_sense_score}")
        
        # add the score to the total
        total += common_sense_score
       
    
    # get the average score
    average = total / len(_dfs.keys())
    
    # print the average score
    print(f"The Average common sense score is: {average}")

# %%
# get the common sense baseline for each dataframe in the dictionary
calculate_common_sense_baseline(full_dfs)
# Out:
# The common sense score of PFE is: 0.534446764091858
# The common sense score of ROP is: 0.520746887966805
# The common sense score of XYL is: 0.5124481327800829
# The common sense score of CPAY is: 0.505175983436853
# The common sense score of INCY is: 0.494824016563147
# The Average common sense score is: 0.5135283569677492

# %% [markdown]
# ## Prepare the data for training
#
# #### Features scaling
#
# To prepare the data for training, we first need to scale the features to a specific range. This scaling process enhances the model's ability to learn patterns effectively and efficiently.
#
# We'll test three different scalers from the scikit-learn library: MinMaxScaler, StandardScaler, and RobustScaler.
#
# 1. MinMaxScaler Transform features by scaling each feature to a given range. (0-1 in our case) [https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.MinMaxScaler.html]
# 2. StandardScaler Standardize features by removing the mean and scaling to unit variance. [https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.StandardScaler.html]
# 3. RobustScaler Scale features using statistics that are robust to outliers by removing the median and scaling the data according to the quantile range. [https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.RobustScaler.html]
#
# Given the continuous pattern shifts in financial data, no single scaler is guaranteed to consistently outperform the others. Therefore, we'll implement apply_scaler(8), a function that applies any given scaler to a set of features. This approach allows us to experiment with different scalers to achieve the best improvement to model performance.
#
# It's important to note that apply_scaler scales the training set independently from the test set to prevent data leakage, thereby reducing the risk of overfitting.
#
# #### Data Sequences
#
# To predict the stock trend for the next timestep, we look back at the last x timesteps and make a prediction based on that sequence. This requires reshaping the data into sequences of x timesteps, a necessary step for RNNs, which require input data in the shape of (samples, timesteps, and number of features). We achieve this by using the create_seqs(9) function, which takes features and the number of timesteps of each sequence and then reshapes the data based on the given timesteps.
#
# #### Train-Validation-Test Split
#
# We'll split the data into 70% for training, 20% for validation, and 10% for testing. This 70-20-10 split maximizes model accuracy while reducing the likelihood of overfitting that might occur with different ratios.
#
# create_train_vald_test_sets(11) function is where all these three processes will be applied in order to the data, making it ready for training.
#
# To apply these steps on each dataframe in the dictionary we will use the prepare_data_to_train(12), a function that converts the dictionary of dataframes into a dictionary of train-validation-test sets.

# %%
# create a function to apply a given scaler to the features
def apply_scaler(scaler, features):
    
    # set the training and test ratio to be 70-30
    training_ratio = int(len(features) * 0.7)

    # devide the feature set into training and test set
    X_train, X_test = features[:training_ratio], features[training_ratio:]
    
    # apply a scaler on the training and test sets in isolation so we don't allow the test set to influence the scaling process, which reduces the likelihood of overfitting 
    X_train_scaled = scaler.fit_transform(X_train)
    X_test_scaled = scaler.transform(X_test)
    
    # concat the two scaled sets into one
    X = np.concatenate((X_train_scaled, X_test_scaled), axis=0)

    # return the scaled features
    return X


# source of isnpiration: https://stackoverflow.com/questions/47945512/how-to-reshape-input-for-keras-lstm?rq=4 [13]
# create a function to reshape X and y into sequences of x timesteps
def create_seqs(features, target, num_rows):
    # create 2 empty lists to store the newly shaped features and target lists
    X, y = [], []
    
    # iterate over the features
    for i in range(len(features) - num_rows):
        # create indexes of the start and end of each sequence
        seq_s = i
        seq_e = i + num_rows
        
        # the ith sequence will be a slice of the features between the indexes, create it and add it to X
        xi = features[seq_s : seq_e]
        X.append(xi)
        
        # do the same for the target and add it to y
        yi = target[seq_e]
        y.append(yi)
    
    # return the X and y as numpy arraies
    return np.array(X), np.array(y)


# create a function to convert a dataframe into training, validation and test sets
def create_train_vald_test_sets(_df, scaler, target="classification", timesteps=6):

    # reset the index
    _df.reset_index(inplace = True)
    
    # drop the Date column as it's not necessary for now
    _df.drop(['Date'], axis=1, inplace=True)

    # set the features set
    X = _df.iloc[:, :-2]
    
    # set the target 
    if (target == "classification"):
        # trend is the target for classification
        y = _df.iloc[:, -1]
    else:
        # next_close is the target for regression
        y = _df.iloc[:, -2]

    # apply a scaler on the features set
    X = apply_scaler(scaler, X)
    
    # create sequences
    X_seq, y_seq = create_seqs(X, y, timesteps)
    
    # source of inspiration: https://www.tensorflow.org/api_docs/python/tf/keras/utils/to_categorical [14]
    # use to_categorical from tf to converts the target (trend) to binary class matrix, this will help us assign confidences to the classification prediction
    if (target == "classification"):
        y_seq = to_categorical(y_seq)

    # devide the data into a training set and a test set in 70-30 ratio
    training_ratio = int(len(X) * 0.7)
    
    # add a vaidation ratio at 20% of the data, this will leave 10% as test
    validation_ratio = int(len(X) * 0.2)
    
    X_train, X_vald, X_test = X_seq[:training_ratio], X_seq[training_ratio:training_ratio + validation_ratio], X_seq[training_ratio + validation_ratio:]
    y_train, y_vald, y_test = y_seq[:training_ratio], y_seq[training_ratio:training_ratio + validation_ratio], y_seq[training_ratio + validation_ratio:]

#     X_train, X_test = X_seq[:training_ratio], X_seq[training_ratio:]
#     y_train, y_test = y_seq[:training_ratio], y_seq[training_ratio:]

    # return the sets and the last_date
    return X_train, X_vald, X_test, y_train, y_vald, y_test


# create a function that takes a dict of dataframes, and return a dict of training, validation and testing datasets
def prepare_data_to_train(dfs_dict, scaler, target, timesteps):
    
    # create a dict of dicts to store training, validation and test sets for each stock
    sets_dict = {}
    
    # iterate over each dataframe in the dictionary
    for symbol in dfs_dict.keys():
        
        # convert the dataframe into training, validation and test sets
        X_train, X_vald, X_test, y_train, y_vald, y_test = create_train_vald_test_sets(dfs_dict[symbol].copy(deep=True), scaler, target, timesteps)
        
        # create a dict of the sets and add it to the sets_dict
        sets_dict[symbol] = {
            'X_train': X_train, 'X_vald': X_vald, 'X_test': X_test, 
            'y_train': y_train, 'y_vald': y_vald, 'y_test': y_test
        }
    
    # return the sets
    return sets_dict

# %%
# initialize a MinMaxScaler instance for a range between 0 and 1
min_max_scaler = MinMaxScaler(feature_range=(0, 1))

# initialize a StandardScaler instance
standard_scaler = StandardScaler()

# initialize a RobustScaler instance
robust_scaler = RobustScaler()

# %%
# apply the 3 steps of preparing data for training on each dataframe in the dictionary
target = 'classification' # set the target
timesteps = 10 # set the timesteps
data_sets = prepare_data_to_train(full_dfs.copy(), min_max_scaler, target, timesteps)

# %%
print(data_sets['PFE']['X_train'].shape)
print(data_sets['PFE']['X_vald'].shape)
print(data_sets['PFE']['X_test'].shape)
# Out:
# (335, 10, 72)
# (95, 10, 72)
# (39, 10, 72)

# %% [markdown]
# ## Models archive
#
# For this section, we created create_models_archive(13), a function to train and save individual models for each dataset within a dictionary. This setup is crucial for scenarios where multiple stock choices are analyzed and assessed simultaneously. The function accepts a dictionary of datasets and a model creation function or class instance, then trains the model on each dataset separately. It stores the trained models, evaluation data, and hyperparameters (if applicable) in a dictionary associated with each stock.
#
# This implementation supports classification and regression-type models, so we can easily switch between the two prediction approaches.
#
# Additionally, this function incorporates EarlyStopping[] and ReduceLROnPlateau[] callbacks to enhance the training process. These callbacks help prevent overfitting by stopping training early if the model's performance stops improving and reducing the learning rate when necessary.
#
# [source: 7.2. Inspecting and monitoring deep-learning models using Keras callba- acks and TensorBoard,
# source: EarlyStopping, https://keras.io/api/callbacks/early_stopping/]
#
# [source: ReduceLROnPlateau, https://keras.io/api/callbacks/reduce_lr_on_plateau/]
#
# Optionally, it enables hyperparameter optimization during training, so if a hyperparameter tuner is passed, the function will fine-tune the model's hyperparameters to achieve the best possible performance before saving the final model.

# %%
# helper function to measure how long a process would take
def get_time():
    return datetime.now()

# source of inspiration: Introduction to the Keras Tuner, https://www.tensorflow.org/tutorials/keras/keras_tuner
# create a function to train static and hyperparameters optimized models on multiple datasets and archive them
def create_models_archive(_create_model, _datasets_dict, _model_type='classification', _tuner=None, _epochs=50, _model_name='model', _project_name='proj'):
    
    # get time before the training
    start = get_time()
    
    # create the models archive dictionary
    archive = {}
    
    # iterate over the symbols in the dictionary
    for symbol in _datasets_dict.keys():
        
        # initiate a dict for the symbol
        archive[symbol] = {}
        
        # setup the data to be passed to the model
        X_train, y_train = _datasets_dict[symbol]['X_train'], _datasets_dict[symbol]['y_train']
        X_vald, y_vald = _datasets_dict[symbol]['X_vald'], _datasets_dict[symbol]['y_vald']
        X_test, y_test = _datasets_dict[symbol]['X_test'], _datasets_dict[symbol]['y_test']

        # source: 7.2. Inspecting and monitoring deep-learning models using Keras callba- acks and TensorBoard
        # source: EarlyStopping, https://keras.io/api/callbacks/early_stopping/
        # Stop training when a monitored metric has stopped improving.
        # monitor: Quantity to be monitored.
        # min_delta: Minimum change in the monitored quantity to qualify as an improvement (we will use the default value)
        # patience: Number of epochs with no improvement after which training will be stopped.
        stop_early = EarlyStopping(monitor='val_loss', 
                                   min_delta=0, 
                                   patience=5)
        
        # source: ReduceLROnPlateau, https://keras.io/api/callbacks/reduce_lr_on_plateau/
        # Reduce learning rate when a metric has stopped improving.
        reduce_lr =  ReduceLROnPlateau(monitor='val_loss', 
                                       factor=0.1, 
                                       patience=10)
        
        # initialize the model
#         model = _create_model(X_train.shape)   
        model = _create_model        
        
        # source: Hyperband Tuner, https://keras.io/api/keras_tuner/tuners/hyperband/
        ### Instantiate the tuner and perform hypertuning
        # pass the model which is an Instance of HyperModel class (or callable that takes hyperparameters and returns a Model instance)
        # objective is the direction of the optimization
        # max_epochs is the maximum number of epochs to train one model, it is recommended to set this to a value slightly higher than expected then use early stopping callback during training (we will use the default value)
        # factor: the reduction factor for the number of epochs and number of models for each bracket (we will use the default value)
        # hyperband_iterations: the number of times to iterate over the full Hyperband algorithm. One iteration will run approximately max_epochs * (math.log(max_epochs, factor) ** 2) cumulative epochs across all trials. (we will use the default value)
        # we will set the seed to make our work easier to replicate by others 
        # directory is and project name is the path where it will store the trails data results, this will make it much faster to rerun the training process if we need to
        if _tuner:
            tuner = _tuner(model, 
                        objective='val_accuracy', 
                        max_epochs=10, 
                        factor=3, 
                        hyperband_iterations=1, 
                        seed=101, 
                        directory='keras_tuner_models', 
                        project_name=f'{_project_name}/{symbol}')

            # Run the hyperparameter search. The arguments for the search method are the same as those used for tf.keras.model.fit in addition to the callback above.
            tuner.search(X_train, y_train, 
                         epochs=_epochs, 
                         validation_data=(X_vald, y_vald), 
                         callbacks=[stop_early, reduce_lr], 
                        verbose=0)

            # source: The base Tuner class, https://keras.io/api/keras_tuner/tuners/base_tuner/
            # get_best_hyperparameters Returns the best hyperparameters, as determined by the objective as a list sorted from the best to the worst.
            # Get the optimal hyperparameters
            best_hps=tuner.get_best_hyperparameters(num_trials=1)[0]

            # Display tuning results summary. prints a summary of the search results including the hyperparameter values and evaluation results for each trial.
            results_summary = tuner.results_summary()
        
            # Build the model with the optimal hyperparameters and train it on the data for 50 epochs
            model = tuner.hypermodel.build(best_hps)
                    
        
        # fit the model
        history = model.fit(X_train, y_train, 
                            epochs=_epochs, 
                            batch_size=32, 
                            validation_data=(X_vald, y_vald), 
                            callbacks=[stop_early, reduce_lr], 
                            verbose=0)
        
        # get the history of accuracy during training as a list
        if _model_type == "classification":
            val_prec_per_epoch = history.history['val_accuracy']
        else:
            val_prec_per_epoch = history.history['val_loss']

        # get the index of the highest val_precision from this list, we will use this index to set the epochs values during the training
        best_epoch = val_prec_per_epoch.index(max(val_prec_per_epoch)) + 1
        print('Best epoch: %d' % (best_epoch,))

        ### train the model based on the results of the hyperparameter optimization process 
        # Re-instantiate the hypermodel and train it with the optimal number of epochs from above.
        if _tuner:
            hypermodel = tuner.hypermodel.build(best_hps)
        else:
#             hypermodel = _create_model(X_train.shape)
            hypermodel = model

        # Retrain the model
        hypermodel_history = hypermodel.fit(X_train, y_train, 
                                            validation_data=(X_vald, y_vald), 
                                            epochs=best_epoch, 
                                            verbose=0)

        # evaluate the model
        model_evaluation = hypermodel.evaluate(X_test, y_test, verbose=0)
            
        # get predictions from the model given the test set
        y_pred = hypermodel.predict(X_test)

        # evaluate the model whether the model type is classification or regression
        if _model_type == "classification":     
            # convert the predictions and test set to be in the shape of a vector of labels
            y_pred_labels = np.argmax(y_pred, axis=1)
            y_test_labels = np.argmax(y_test, axis=1)
        else:
            # get the R2 of the model
            r2 = r2_score(y_test, y_pred)
        
        # source of inspiration: https://www.tensorflow.org/tutorials/keras/save_and_load
        # save model to device
        hypermodel.save(f'models/{_model_name}_{symbol}.keras')        
        
        # store the model in the associated symbol dict
        archive[symbol]['model'] = load_model(f'models/{_model_name}_{symbol}.keras')
        
        # evaluate the model on the test_set and store it in the associated symbol dict
        archive[symbol]['evaluation'] = model_evaluation
        
        # store the best model hyperparameters in the associated symbol dict
        archive[symbol]['hyperparameters'] = best_hps if _tuner else None
        
        # store the the best model training and validation accuracy history
        archive[symbol]['training_history'] = hypermodel_history
        
        # store the the best model prediction labels and true labels
        archive[symbol]['y_pred_labels'] = y_pred_labels if _model_type == "classification" else None
        archive[symbol]['y_test_labels'] = y_test_labels if _model_type == "classification" else None
        
        # store the R2 score for regression model
        archive[symbol]['r2'] = r2 if _model_type == "regression" else None
        
        # store the the tunning proccess results_summary
        archive[symbol]['results_summary'] = results_summary if _tuner else None
        
        # get time after the training
        end = get_time()
        
        # print the trainig duration
        print(f"training for the {symbol} model was done in: {end - start}")
        
    return archive

# %% [markdown]
# ## Models Evaluation
#
# To evaluate the models in the created models archive we will create evaluate_models_archive(14), a function that takes the model archive and for each model in it:
# 1. Calculate and print accuracy, precision, recall, F-score, and any other relevant evaluation metric.
# 2. Create a confusion matrix.
# 3. Plot Training vs. validation loss to assess model performance over epochs.
#
# Finally, the function calculates and prints the average metrics across all models.

# %%
# create a function to calculate the precision, recall, and accuracy of a model
def calculate_precision_recall_fscore(y_test, y_pred):
    # source of inspiration: https://stackoverflow.com/questions/48987959/classification-metrics-cant-handle-a-mix-of-continuous-multioutput-and-multi-la [15]
    # get precision, recall, and fscore and return them
    precision, recall, fscore, support = precision_recall_fscore_support(y_test, y_pred, average='weighted', zero_division=0)
    return precision, recall, fscore

# create a function that produce a confusion matrix of a model
def create_confusion_matrix(y_test, y_pred):
    # source of inspiration: https://scikit-learn.org/stable/modules/generated/sklearn.metrics.ConfusionMatrixDisplay.html [16]
    conf_mat = confusion_matrix(y_test, y_pred)
    disp = ConfusionMatrixDisplay(conf_mat)
    disp.plot()
    plt.show()
       
# create a function that graph the traing vs validation loss
def create_train_vald_graph(training_history): 
    # source of the code snippet[17]
    # get the training and validation loss
    loss = training_history['loss']
    val_loss = training_history['val_loss']
    
    # we can get the number of epochs simply from the length of the loss list
    epochs = range(1, len(loss) + 1)
    
    ### plot
    plt.figure()
    
    # plot the training loss against the epochs
    plt.plot(epochs, loss, 'bo', label='Training loss')
    
    # plot the validation loss against the epochs
    plt.plot(epochs, val_loss, 'b', label='Validation loss')
    
    # add title and legend
    plt.title('Training and validation loss')
    plt.legend()
    plt.show()


# create a function that evaluate a dictionary of models
def evaluate_models_archive(_models_archive):
    
    # initialize the total metrics variables set them to 0
    total_precision = 0
    total_recall = 0
    total_fscore = 0
    total_accuracy = 0
    
    # iterate over the symbols of the dictionary
    for symbol in _models_archive.keys():
        
        # get the model y_test and y_pred
        y_test = _models_archive[symbol]['y_test_labels']
        y_pred = _models_archive[symbol]['y_pred_labels']
        
        # model summary
        _models_archive[symbol]['model'].summary()
        
        # plot the model and save it to an image
        plot_path = f"{symbol}_model_plot.png"
        plot_model(_models_archive[symbol]['model'], show_shapes=True, dpi=80, to_file=plot_path)
        # disply the saved plot image
        display(Image(plot_path))
        
        # classification model metrics
        accuracy = accuracy_score(y_test, y_pred)
        precision, recall, fscore = calculate_precision_recall_fscore(y_test, y_pred)
        
        # print the metrics for each model
        print(f"The {symbol} Model Classification Metrics:")
        print(f"Accuracy: {accuracy}")
        print(f"Precision: {precision}")
        print(f"Recall: {recall}")
        print(f"F-Score: {fscore}")
        print("--------------------------------------------------------------")
        
        # add the scores for this model to the total scores
        total_precision += precision
        total_recall += recall
        total_fscore += fscore
        total_accuracy += accuracy
        
        # create confusion matrix
        create_confusion_matrix(y_test, y_pred)
        
        # plot training vs validation loss
        create_train_vald_graph(_models_archive[symbol]['training_history'].history)
        
    # calculate average metrics
    models_num = len(_models_archive.keys())
    average_precision = total_precision / models_num
    average_recall = total_recall / models_num
    average_fscore = total_fscore / models_num
    average_accuracy = total_accuracy / models_num

    # print the average metrics
    print(f"Average Classification Metrics for All Models:")
    print(f"Average Accuracy: {average_accuracy}")
    print(f"Average Precision: {average_precision}")
    print(f"Average Recall: {average_recall}")
    print(f"Average F-Score: {average_fscore}")

# %% [markdown]
# ## Machine Learning Models and RNNs
#
# For this type of problem, we can't simply rely on feedforward models such as densely connected networks or convolutional networks, since they are designed to process each input independently without retaining the state between inputs which is suitable when dealing with discrete data.
#
# However, when dealing with continuous data such as stock data, handling them as sequences would be more appropriate and this is where RNNs come into play.
#
# RNNs (recurrent neural networks) were designed specifically to process continuous data such as time series. As they can retain information over time allows them to identify patterns, making them powerful tools for forecasting.
#
# For this project, we will consider the three available types of RNNS in TensorFlow:
#
# SimpleRNN: The basic RNN, processes sequences by maintaining a hidden state that is updated at each timestep. However, it suffers from the vanishing gradient problem, as adding more layers, the network eventually becomes untrainable.
#
# LSTM (Long Short-Term Memory): an improvement over SimpleRNN as it addresses the vanishing gradient issue by incorporating three gates (input, forget, and output). These gates regulate the flow of information, allowing LSTMs to capture long-term dependencies effectively. However, LSTM is more computationally expensive than SimpleRNN.
#
# GRU (Gated Recurrent Unit):  a simplified implementation of LSTMs with only two gates (reset and update). They are computationally more efficient while still theoretically countering the vanishing gradient problem.
#
# [][][]
# [deep learning with python, chapter 6, 6.2. Understanding recurrent neural networks]
# [What is LSTM – Long Short Term Memory?, https://www.geeksforgeeks.org/deep-learning-introduction-to-long-short-term-memory/]
# [Gated Recurrent Unit Networks, https://www.geeksforgeeks.org/gated-recurrent-unit-networks/]
#
#
# RNNModel(15) is a class we created that enables us to instantiate a classification or regression model, where the layers consist of either SimpleRNN, LSTM, or GRU. RNNModel will allow us to create a compare a wide range of models easily and fairly.

# %%
### create the baseline model
# source of inspiration: François Chollet (11, 2017), “Deep Learning with Python” chapter 6 [8]
# define a model class that allow us to build SimpleRNN, LSTM, or GRU models for classification or regression approches
class RNNModel:
    def __init__(self, X_train_shape, model_type='classification', layer_type='SimpleRNN'):
        self.X_train_shape = X_train_shape
        self.model_type = model_type
        self.layer_type = layer_type

    def build(self):
        # initialize a sequential model
        model = Sequential()

        # add the model layers
        # input layer
        model.add(Input(shape=(self.X_train_shape[1], self.X_train_shape[2])))

        # RNN layers
        # set the layer type
        if self.layer_type == 'SimpleRNN':
            RNN_layer = SimpleRNN
        elif self.layer_type == 'LSTM':
            RNN_layer = LSTM
        elif self.layer_type == 'GRU':
            RNN_layer = GRU
        else:
            raise ValueError('Wrong layer type provided!!! only support (SimpleRNN, LSTM, GRU)')

        # add the selected layers to the model
        model.add(RNN_layer(64, return_sequences=True))
        model.add(RNN_layer(64, return_sequences=False))

        # set the model type and compile it
        if self.model_type == 'classification':
            model.add(Dense(2, activation='softmax')) # output layer
            model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy']) # compile the model
        elif self.model_type == 'regression':
            model.add(Dense(1)) # output layer
            model.compile(optimizer='adam', loss='mean_squared_error', metrics=['mae']) # compile the model
        else:
            raise ValueError('Wrong model type provided!!! only support (classification, regression)')

        return model

# %% [markdown]
# ## SimpleRNN vs LSTM vs GRU

# %% [markdown]
# ### SimpleRNN

# %%
# set the model initialization inputs
X_train_shape = data_sets['PFE']['X_train'].shape
model_type='classification'
layer_type='SimpleRNN'

# create the model
simpleRNN_model = RNNModel(X_train_shape, model_type, layer_type)
simpleRNN_model = simpleRNN_model.build()

# create models archive for simpleRNN classification approach
simpleRNN_models_archive = create_models_archive(simpleRNN_model, 
                                                 data_sets, 
                                                 _model_type=model_type, 
                                                 _tuner=None, 
                                                 _epochs=50, 
                                                 _model_name='simpleRNN_class', 
                                                 _project_name='proj')

# %%
# evaluate the models in the archive
evaluate_models_archive(simpleRNN_models_archive)

# %% [markdown]
# ### LSTM

# %%
# set the model initialization inputs
X_train_shape = data_sets['PFE']['X_train'].shape
model_type='classification'
layer_type='LSTM'

# create the model
lstm_model = RNNModel(X_train_shape, model_type, layer_type)
lstm_model = lstm_model.build()

# create models archive for lstm classification approach
lstm_models_archive = create_models_archive(lstm_model, 
                                                 data_sets, 
                                                 _model_type=model_type, 
                                                 _tuner=None, 
                                                 _epochs=50, 
                                                 _model_name='lstm_class', 
                                                 _project_name='proj')

# %%
# evaluate the models in the archive
evaluate_models_archive(lstm_models_archive)

# %% [markdown]
# ### GRU

# %%
# set the model initialization inputs
X_train_shape = data_sets['PFE']['X_train'].shape
model_type='classification'
layer_type='GRU'

# create the model
gru_model = RNNModel(X_train_shape, model_type, layer_type)
gru_model = gru_model.build()

# create models archive for gru classification approach
gru_models_archive = create_models_archive(gru_model, 
                                                 data_sets, 
                                                 _model_type=model_type, 
                                                 _tuner=None, 
                                                 _epochs=50, 
                                                 _model_name='gru_class', 
                                                 _project_name='proj')

# %%
# evaluate the models in the archive
evaluate_models_archive(gru_models_archive)

# %% [markdown]
# ## Classification vs Regression approach
#
# As we stated before regression models could be more beneficial for predicting the actual future closing prices in the stock market since it would enable us to perform more advanced tasks such as portfolio optimization. Therefore before proceeding we will create a baseline regression model and compare it with our baseline classification model. If the regression model sounds promising, we will be improving it for the rest of the project, otherwise will proceed with the classification approach.

# %%
# apply the 3 steps of preparing data for training on each dataframe in the dictionary
target = 'regression' # set the target
timesteps = 10 # set the timesteps
data_sets_reg = prepare_data_to_train(full_dfs.copy(), min_max_scaler, target, timesteps)

# set the model initialization inputs
X_train_shape = data_sets_reg['PFE']['X_train'].shape
model_type='regression'
layer_type='SimpleRNN'

# create the model
simpleRNN_model_reg = RNNModel(X_train_shape, model_type, layer_type)
simpleRNN_model_reg = simpleRNN_model_reg.build()

# create models archive for simpleRNN regression approach
simpleRNN_models_reg_archive = create_models_archive(simpleRNN_model_reg, 
                                                 data_sets_reg, 
                                                 _model_type=model_type, 
                                                 _tuner=None, 
                                                 _epochs=50, 
                                                 _model_name='simpleRNN_reg', 
                                                 _project_name='proj')

# %%
### evaluate the model
# get the mean absolute error
mae = simpleRNN_models_reg_archive['PFE']['model'].evaluate(data_sets_reg['PFE']['X_test'], data_sets_reg['PFE']['y_test'])[1]

# devide the mae by the average next_closing price
mae/data_sets_reg['PFE']['y_test'].mean()

# %% [markdown]
# The model's predictions are, on average, 16.5% off, which is significant for stock prediction. Hence, the regression approach is unsuitable with the current data, and we should focus on the classification approach.

# %% [markdown]
# ## BatchNormalization
#
# BatchNormalization is a tensorflow layer type that adaptively normalize data as the mean and variance changes while training. It helps with gradient propagation allowing for deeper networks.
#
# We will add one BatchNormalization layer after each RNN layer and see if there are any improvements.
#
# Check RNNModelNorm(16)

# %%
### create the baseline model
# source of inspiration: François Chollet (11, 2017), “Deep Learning with Python” chapter 6 [8]
# define a model class that allow us to build SimpleRNN, LSTM, or GRU models for classification or regression approches
class RNNModelNorm:
    def __init__(self, X_train_shape, model_type='classification', layer_type='SimpleRNN'):
        self.X_train_shape = X_train_shape
        self.model_type = model_type
        self.layer_type = layer_type

    def build(self):
        # initialize a sequential model
        model = Sequential()

        # add the model layers
        # input layer
        model.add(Input(shape=(self.X_train_shape[1], self.X_train_shape[2])))

        # RNN layers
        # set the layer type
        if self.layer_type == 'SimpleRNN':
            RNN_layer = SimpleRNN
        elif self.layer_type == 'LSTM':
            RNN_layer = LSTM
        elif self.layer_type == 'GRU':
            RNN_layer = GRU
        else:
            raise ValueError('Wrong layer type provided!!! only support (SimpleRNN, LSTM, GRU)')

        # add the selected layers to the model
        model.add(RNN_layer(64, return_sequences=True))
        model.add(BatchNormalization())
        model.add(RNN_layer(64, return_sequences=False))
        model.add(BatchNormalization())

        # set the model type and compile it
        if self.model_type == 'classification':
            model.add(Dense(2, activation='softmax')) # output layer
            model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy']) # compile the model
        elif self.model_type == 'regression':
            model.add(Dense(1)) # output layer
            model.compile(optimizer='adam', loss='mean_squared_error', metrics=['mae']) # compile the model
        else:
            raise ValueError('Wrong model type provided!!! only support (classification, regression)')

        return model

# %%
# set the model initialization inputs
X_train_shape = data_sets['PFE']['X_train'].shape
model_type='classification'
layer_type='SimpleRNN'

# create the model
simpleRNN_norm_model = RNNModelNorm(X_train_shape, model_type, layer_type)
simpleRNN_norm_model = simpleRNN_norm_model.build()

# create models archive for simpleRNN_norm_model classification approach
simpleRNN_norm_models_archive = create_models_archive(simpleRNN_norm_model, 
                                                 data_sets, 
                                                 _model_type=model_type, 
                                                 _tuner=None, 
                                                 _epochs=50, 
                                                 _model_name='simpleRNN_norm_class', 
                                                 _project_name='proj')
# Out:
# Best epoch: 2
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 342ms/step
# training for the PFE model was done in: 0:00:06.154113
# Best epoch: 7
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# training for the ROP model was done in: 0:00:08.286218
# Best epoch: 10
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# training for the XYL model was done in: 0:00:11.022854
# Best epoch: 6
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# training for the CPAY model was done in: 0:00:13.093260
# Best epoch: 3
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# training for the INCY model was done in: 0:00:14.850722

# %%
# evaluate the models in the archive
evaluate_models_archive(simpleRNN_norm_models_archive)
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ simple_rnn_4 (SimpleRNN)             │ (None, 10, 64)              │           8,768 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 10, 64)              │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ simple_rnn_5 (SimpleRNN)             │ (None, 64)                  │           8,256 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 64)                  │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 2)                   │             130 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 52,488 (205.04 KB)
#  Trainable params: 17,410 (68.01 KB)
#  Non-trainable params: 256 (1.00 KB)
#  Optimizer params: 34,822 (136.03 KB)
# The PFE Model Classification Metrics:
# Accuracy: 0.5384615384615384
# Precision: 0.5260545905707196
# Recall: 0.5384615384615384
# F-Score: 0.4940828402366864
# --------------------------------------------------------------
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ simple_rnn_4 (SimpleRNN)             │ (None, 10, 64)              │           8,768 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 10, 64)              │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ simple_rnn_5 (SimpleRNN)             │ (None, 64)                  │           8,256 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 64)                  │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 2)                   │             130 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 52,488 (205.04 KB)
#  Trainable params: 17,410 (68.01 KB)
#  Non-trainable params: 256 (1.00 KB)
#  Optimizer params: 34,822 (136.03 KB)
# The ROP Model Classification Metrics:
# Accuracy: 0.5641025641025641
# Precision: 0.569088319088319
# Recall: 0.5641025641025641
# F-Score: 0.547348784823047
# --------------------------------------------------------------
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ simple_rnn_4 (SimpleRNN)             │ (None, 10, 64)              │           8,768 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 10, 64)              │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ simple_rnn_5 (SimpleRNN)             │ (None, 64)                  │           8,256 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 64)                  │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 2)                   │             130 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 52,488 (205.04 KB)
#  Trainable params: 17,410 (68.01 KB)
#  Non-trainable params: 256 (1.00 KB)
#  Optimizer params: 34,822 (136.03 KB)
# The XYL Model Classification Metrics:
# Accuracy: 0.48717948717948717
# Precision: 0.4341880341880342
# Recall: 0.48717948717948717
# F-Score: 0.45156695156695154
# --------------------------------------------------------------
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ simple_rnn_4 (SimpleRNN)             │ (None, 10, 64)              │           8,768 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 10, 64)              │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ simple_rnn_5 (SimpleRNN)             │ (None, 64)                  │           8,256 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 64)                  │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 2)                   │             130 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 52,488 (205.04 KB)
#  Trainable params: 17,410 (68.01 KB)
#  Non-trainable params: 256 (1.00 KB)
#  Optimizer params: 34,822 (136.03 KB)
# The CPAY Model Classification Metrics:
# Accuracy: 0.5128205128205128
# Precision: 0.507051282051282
# Recall: 0.5128205128205128
# F-Score: 0.506915306915307
# --------------------------------------------------------------
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ simple_rnn_4 (SimpleRNN)             │ (None, 10, 64)              │           8,768 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 10, 64)              │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ simple_rnn_5 (SimpleRNN)             │ (None, 64)                  │           8,256 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 64)                  │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 2)                   │             130 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 52,488 (205.04 KB)
#  Trainable params: 17,410 (68.01 KB)
#  Non-trainable params: 256 (1.00 KB)
#  Optimizer params: 34,822 (136.03 KB)
# The INCY Model Classification Metrics:
# Accuracy: 0.4358974358974359
# Precision: 0.4337035513506102
# Recall: 0.4358974358974359
# F-Score: 0.4336589336589336
# --------------------------------------------------------------
# Average Classification Metrics for All Models:
# Average Accuracy: 0.5076923076923077
# Average Precision: 0.49401715544979297
# Average Recall: 0.5076923076923077
# Average F-Score: 0.4867145634401851

# %% [markdown]
# On average we see worst performance.

# %% [markdown]
# ## Hyperparameter Optimization
#
# We implemented hyperparameter optimization using keras_tuner library. HP_RNNModel(17), a class we created, inherates from keras_tuner's HyperModel class. HP_RNNModel allows us to optimize:
#
# 1. Model hyperparameters:
# - Number of RNN layers (2-4)
# - Layer type (SimpleRNN, LSTM, GRU)
# - Units per layer (64-128)
# - Recurrent dropout (0.0-0.5)
# 2. Algorithm hyperparameters:
# - Optimizer type (Adam, RMSprop, SGD)
# - Learning rate (0.0001-0.01)
# 3. training  hyperparameters:
# - Batch size (32, 64)
#
# Hyperband[] is the tuner we used as it's computationally efficient, making it suitable for tuning multiple models quickly.
#
# create_models_archive was created to be compatible with this approach by being able to use the passed tuner for optimization. create_models_archive also optimizes the number of epochs.
#
# [https://www.tensorflow.org/tutorials/keras/keras_tuner]

# %%
# source of inspiration: Introduction to the Keras Tuner, https://www.tensorflow.org/tutorials/keras/keras_tuner
# constuct the model which will perform hyperparameter optimization to choose layers count, neurons counts, recurrent_dropout, optimizer_type, optimizer learning rate
class HP_RNNModel(HyperModel):

    # initialize the model upon creating a class instance
    # using a class structure instead of a function to construct the model will allow us to pass variables to it before passing it to keras tuner
    # source of inspiration on how to pass variables to the model before passing the model to keras tuner: https://github.com/JulieProst/keras-tuner-tutorial/blob/master/hypermodels.py
    def __init__(self, X_train_shape):
        self.X_train_shape = X_train_shape
    
    # build the model
    def build(self, hp):
        # initialize a sequential model
        model = Sequential()

        ### add the model layers (Model hyperparameters optimization)
        # input layer
        model.add(Input(shape=(self.X_train_shape[1], self.X_train_shape[2])))

        # source: Int method, https://keras.io/api/keras_tuner/hyperparameters/
        # dynamically optimize the number of layers
        hp_layers = hp.Int(name='hp_layers', 
                           min_value=2, 
                           max_value=4, 
                           step=2)

        # for each optimized layer
        for i in range(hp_layers):
            
            # optimize the layer type
            hp_layer_type = hp.Choice(f'RNN_layer_{i}_type', values=['SimpleRNN', 'LSTM', 'GRU'])
            if hp_layer_type == 'SimpleRNN':
                layer_type = SimpleRNN
            elif hp_layer_type == 'LSTM':
                layer_type = LSTM
            else:
                layer_type = GRU

            # dynamically tune the number of units in each layer, select a value between 64-128
            hp_units = hp.Int(name=f'hp_units_at_hp_layer_{i}', 
                              min_value=64, 
                              max_value=128, 
                              step=64)
            
            # source: SimpleRNN layer, https://keras.io/api/layers/recurrent_layers/simple_rnn/
            # return_sequences: Boolean. Whether to return the last output in the output sequence, or the full sequence. Default: False.
            # set the return_sequences parameter to true unless it's the last layer, set it to false
            return_sequences_boolean = i != (hp_layers - 1)

            # source: Float method, https://keras.io/api/keras_tuner/hyperparameters/
            # source: SimpleRNN layer, https://keras.io/api/layers/recurrent_layers/simple_rnn/
            # recurrent_dropout: Float between 0 and 1. Fraction of the units to drop for the linear transformation of the recurrent state.
            # dynamically tune the recurrent_dropout float value
            recurrent_dropout = hp.Float(name=f'recurrent_dropout_{i}', 
                                         min_value=0.0, 
                                         max_value=0.5, 
                                         step=0.1)

            # add a simpleRNN layer and pass the optimized number of unites, recurrent_dropout, and the return_sequences boolean
            layer = layer_type(units=hp_units, 
                              return_sequences=return_sequences_boolean, 
                              recurrent_dropout=recurrent_dropout)
            model.add(layer)


        # add the output layer
        model.add(Dense(2, activation='softmax'))

        ### the model compiler (Algorithm hyperparameters optimization)
        # source: Choice method, https://keras.io/api/keras_tuner/hyperparameters/
        # dynamically optimize the optimizer type
        hp_optimizer_type = hp.Choice('optimizer_type', values=['Adam', 'RMSprop', 'SGD'])
        if hp_optimizer_type == 'Adam':
            optimizer = Adam
        elif hp_optimizer_type == 'RMSprop':
            optimizer = RMSprop
        else:
            optimizer = SGD

        # dynamically tune the learning rate for the optimizer
        # When sampling="log", the step is multiplied between samples.
        hp_lr = hp.Float('learning_rate', 
                         min_value=0.0001, 
                         max_value=0.01, 
                         sampling='LOG')
        hp_optimizer = optimizer(learning_rate=hp_lr)

        # compile the model
        model.compile(optimizer=hp_optimizer, 
                      loss='categorical_crossentropy', # this is the most suitable one for predictions of one-hot encoded labels
                      metrics=['accuracy'])

        # return the model
        return model
    
    # source: omalleyt12, https://github.com/keras-team/keras-tuner/issues/122
    # define a fit function which will allow us to pass an optimized value for batch_size
    # *args and **kwargs are the ones we pass through tuner.search()
    def fit(self, hp, model, *args, **kwargs):
        
        # dynamically optimize the batch_size for the training process
        hp_batch_size = hp.Choice("batch_size", [32, 64])
        return model.fit(
            *args,
            batch_size=hp_batch_size,
            **kwargs,
        )

# %%
# set the model initialization inputs
X_train_shape = data_sets['PFE']['X_train'].shape
model_type='classification'
tuner = Hyperband

# create the model
hp_RNN_model = HP_RNNModel(X_train_shape)
# hp_RNN_model = hp_RNN_model.build()

# create models archive for HP_RNNModel classification approach
hp_RNN_models_archive = create_models_archive(hp_RNN_model, 
                                                 data_sets, 
                                                 _model_type=model_type, 
                                                 _tuner=tuner, 
                                                 _epochs=50, 
                                                 _model_name='hp_RNN_model', 
                                                 _project_name='hp_RNN_models_archive')
# Out:
# Reloading Tuner from keras_tuner_models\hp_RNN_models_archive/PFE\tuner0.json
# Results summary
# Results in keras_tuner_models\hp_RNN_models_archive/PFE
# Showing 10 best trials
# Objective(name="val_accuracy", direction="max")
#
# Trial 0002 summary
# Hyperparameters:
# hp_layers: 4
# RNN_layer_0_type: SimpleRNN
# hp_units_at_hp_layer_0: 128
# recurrent_dropout_0: 0.2
# RNN_layer_1_type: LSTM
# hp_units_at_hp_layer_1: 64
# recurrent_dropout_1: 0.2
# optimizer_type: RMSprop
# learning_rate: 0.0009294745699713808
# RNN_layer_2_type: GRU
# hp_units_at_hp_layer_2: 128
# recurrent_dropout_2: 0.0
# RNN_layer_3_type: SimpleRNN
# hp_units_at_hp_layer_3: 64
# recurrent_dropout_3: 0.30000000000000004
# batch_size: 64
# tuner/epochs: 2
# tuner/initial_epoch: 0
# tuner/bracket: 2
# tuner/round: 0
# Score: 0.6000000238418579
#
# Trial 0028 summary
# Hyperparameters:
# hp_layers: 2
# RNN_layer_0_type: GRU
# hp_units_at_hp_layer_0: 64
# recurrent_dropout_0: 0.4
# RNN_layer_1_type: SimpleRNN
# hp_units_at_hp_layer_1: 128
# recurrent_dropout_1: 0.0
# optimizer_type: RMSprop
# learning_rate: 0.0005914405187452458
# RNN_layer_2_type: SimpleRNN
# hp_units_at_hp_layer_2: 128
# recurrent_dropout_2: 0.2
# RNN_layer_3_type: SimpleRNN
# hp_units_at_hp_layer_3: 64
# recurrent_dropout_3: 0.1
# batch_size: 64
# tuner/epochs: 10
# tuner/initial_epoch: 0
# tuner/bracket: 0
# tuner/round: 0
# Score: 0.6000000238418579
#
# Trial 0009 summary
# Hyperparameters:
# hp_layers: 4
# RNN_layer_0_type: SimpleRNN
# hp_units_at_hp_layer_0: 128
# recurrent_dropout_0: 0.30000000000000004
# RNN_layer_1_type: LSTM
# hp_units_at_hp_layer_1: 128
# recurrent_dropout_1: 0.4
# optimizer_type: Adam
# learning_rate: 0.007147424082020044
# RNN_layer_2_type: LSTM
# hp_units_at_hp_layer_2: 128
# recurrent_dropout_2: 0.1
# RNN_layer_3_type: LSTM
# hp_units_at_hp_layer_3: 64
# recurrent_dropout_3: 0.30000000000000004
# batch_size: 64
# tuner/epochs: 2
# tuner/initial_epoch: 0
# tuner/bracket: 2
# tuner/round: 0
# Score: 0.5894736647605896
#
# Trial 0001 summary
# Hyperparameters:
# hp_layers: 4
# RNN_layer_0_type: GRU
# hp_units_at_hp_layer_0: 64
# recurrent_dropout_0: 0.0
# RNN_layer_1_type: SimpleRNN
# hp_units_at_hp_layer_1: 128
# recurrent_dropout_1: 0.4
# optimizer_type: Adam
# learning_rate: 0.0026421929875193183
# RNN_layer_2_type: GRU
# hp_units_at_hp_layer_2: 128
# recurrent_dropout_2: 0.0
# RNN_layer_3_type: LSTM
# hp_units_at_hp_layer_3: 64
# recurrent_dropout_3: 0.4
# batch_size: 64
# tuner/epochs: 2
# tuner/initial_epoch: 0
# tuner/bracket: 2
# tuner/round: 0
# Score: 0.5894736647605896
#
# Trial 0008 summary
# Hyperparameters:
# hp_layers: 4
# RNN_layer_0_type: SimpleRNN
# hp_units_at_hp_layer_0: 64
# recurrent_dropout_0: 0.30000000000000004
# RNN_layer_1_type: LSTM
# hp_units_at_hp_layer_1: 64
# recurrent_dropout_1: 0.4
# optimizer_type: RMSprop
# learning_rate: 0.002570345329777908
# RNN_layer_2_type: GRU
# hp_units_at_hp_layer_2: 64
# recurrent_dropout_2: 0.30000000000000004
# RNN_layer_3_type: LSTM
# hp_units_at_hp_layer_3: 64
# recurrent_dropout_3: 0.30000000000000004
# batch_size: 64
# tuner/epochs: 2
# tuner/initial_epoch: 0
# tuner/bracket: 2
# tuner/round: 0
# Score: 0.5894736647605896
#
# Trial 0024 summary
# Hyperparameters:
# hp_layers: 4
# RNN_layer_0_type: GRU
# hp_units_at_hp_layer_0: 128
# recurrent_dropout_0: 0.0
# RNN_layer_1_type: SimpleRNN
# hp_units_at_hp_layer_1: 64
# recurrent_dropout_1: 0.30000000000000004
# optimizer_type: Adam
# learning_rate: 0.0033851182385612262
# RNN_layer_2_type: SimpleRNN
# hp_units_at_hp_layer_2: 128
# recurrent_dropout_2: 0.4
# RNN_layer_3_type: GRU
# hp_units_at_hp_layer_3: 128
# recurrent_dropout_3: 0.30000000000000004
# batch_size: 64
# tuner/epochs: 10
# tuner/initial_epoch: 4
# tuner/bracket: 1
# tuner/round: 1
# tuner/trial_id: 0022
# Score: 0.5894736647605896
#
# Trial 0022 summary
# Hyperparameters:
# hp_layers: 4
# RNN_layer_0_type: GRU
# hp_units_at_hp_layer_0: 128
# recurrent_dropout_0: 0.0
# RNN_layer_1_type: SimpleRNN
# hp_units_at_hp_layer_1: 64
# recurrent_dropout_1: 0.30000000000000004
# optimizer_type: Adam
# learning_rate: 0.0033851182385612262
# RNN_layer_2_type: SimpleRNN
# hp_units_at_hp_layer_2: 128
# recurrent_dropout_2: 0.4
# RNN_layer_3_type: GRU
# hp_units_at_hp_layer_3: 128
# recurrent_dropout_3: 0.30000000000000004
# batch_size: 64
# tuner/epochs: 4
# tuner/initial_epoch: 0
# tuner/bracket: 1
# tuner/round: 0
# Score: 0.5894736647605896
#
# Trial 0018 summary
# Hyperparameters:
# hp_layers: 2
# RNN_layer_0_type: LSTM
# hp_units_at_hp_layer_0: 128
# recurrent_dropout_0: 0.4
# RNN_layer_1_type: LSTM
# hp_units_at_hp_layer_1: 128
# recurrent_dropout_1: 0.30000000000000004
# optimizer_type: RMSprop
# learning_rate: 0.0002249755313619729
# RNN_layer_2_type: GRU
# hp_units_at_hp_layer_2: 64
# recurrent_dropout_2: 0.2
# RNN_layer_3_type: SimpleRNN
# hp_units_at_hp_layer_3: 64
# recurrent_dropout_3: 0.2
# batch_size: 32
# tuner/epochs: 4
# tuner/initial_epoch: 0
# tuner/bracket: 1
# tuner/round: 0
# Score: 0.5684210658073425
#
# Trial 0020 summary
# Hyperparameters:
# hp_layers: 4
# RNN_layer_0_type: SimpleRNN
# hp_units_at_hp_layer_0: 64
# recurrent_dropout_0: 0.1
# RNN_layer_1_type: GRU
# hp_units_at_hp_layer_1: 128
# recurrent_dropout_1: 0.2
# optimizer_type: RMSprop
# learning_rate: 0.00016176530973716871
# RNN_layer_2_type: GRU
# hp_units_at_hp_layer_2: 128
# recurrent_dropout_2: 0.4
# RNN_layer_3_type: GRU
# hp_units_at_hp_layer_3: 128
# recurrent_dropout_3: 0.1
# batch_size: 64
# tuner/epochs: 4
# tuner/initial_epoch: 0
# tuner/bracket: 1
# tuner/round: 0
# Score: 0.5684210658073425
#
# Trial 0029 summary
# Hyperparameters:
# hp_layers: 2
# RNN_layer_0_type: GRU
# hp_units_at_hp_layer_0: 128
# recurrent_dropout_0: 0.0
# RNN_layer_1_type: LSTM
# hp_units_at_hp_layer_1: 128
# recurrent_dropout_1: 0.1
# optimizer_type: RMSprop
# learning_rate: 0.00026068410258675275
# RNN_layer_2_type: LSTM
# hp_units_at_hp_layer_2: 64
# recurrent_dropout_2: 0.0
# RNN_layer_3_type: LSTM
# hp_units_at_hp_layer_3: 128
# recurrent_dropout_3: 0.1
# batch_size: 64
# tuner/epochs: 10
# tuner/initial_epoch: 0
# tuner/bracket: 0
# tuner/round: 0
# Score: 0.5263158082962036
# Best epoch: 3
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 683ms/step
# training for the PFE model was done in: 0:00:18.462121
# Reloading Tuner from keras_tuner_models\hp_RNN_models_archive/ROP\tuner0.json
# Results summary
# Results in keras_tuner_models\hp_RNN_models_archive/ROP
# Showing 10 best trials
# Objective(name="val_accuracy", direction="max")
#
# Trial 0009 summary
# Hyperparameters:
# hp_layers: 4
# RNN_layer_0_type: SimpleRNN
# hp_units_at_hp_layer_0: 128
# recurrent_dropout_0: 0.30000000000000004
# RNN_layer_1_type: LSTM
# hp_units_at_hp_layer_1: 128
# recurrent_dropout_1: 0.4
# optimizer_type: Adam
# learning_rate: 0.007147424082020044
# RNN_layer_2_type: LSTM
# hp_units_at_hp_layer_2: 128
# recurrent_dropout_2: 0.1
# RNN_layer_3_type: LSTM
# hp_units_at_hp_layer_3: 64
# recurrent_dropout_3: 0.30000000000000004
# batch_size: 64
# tuner/epochs: 2
# tuner/initial_epoch: 0
# tuner/bracket: 2
# tuner/round: 0
# Score: 0.5520833134651184
#
# Trial 0002 summary
# Hyperparameters:
# hp_layers: 4
# RNN_layer_0_type: SimpleRNN
# hp_units_at_hp_layer_0: 128
# recurrent_dropout_0: 0.2
# RNN_layer_1_type: LSTM
# hp_units_at_hp_layer_1: 64
# recurrent_dropout_1: 0.2
# optimizer_type: RMSprop
# learning_rate: 0.0009294745699713808
# RNN_layer_2_type: GRU
# hp_units_at_hp_layer_2: 128
# recurrent_dropout_2: 0.0
# RNN_layer_3_type: SimpleRNN
# hp_units_at_hp_layer_3: 64
# recurrent_dropout_3: 0.30000000000000004
# batch_size: 64
# tuner/epochs: 2
# tuner/initial_epoch: 0
# tuner/bracket: 2
# tuner/round: 0
# Score: 0.5520833134651184
#
# Trial 0001 summary
# Hyperparameters:
# hp_layers: 4
# RNN_layer_0_type: GRU
# hp_units_at_hp_layer_0: 64
# recurrent_dropout_0: 0.0
# RNN_layer_1_type: SimpleRNN
# hp_units_at_hp_layer_1: 128
# recurrent_dropout_1: 0.4
# optimizer_type: Adam
# learning_rate: 0.0026421929875193183
# RNN_layer_2_type: GRU
# hp_units_at_hp_layer_2: 128
# recurrent_dropout_2: 0.0
# RNN_layer_3_type: LSTM
# hp_units_at_hp_layer_3: 64
# recurrent_dropout_3: 0.4
# batch_size: 64
# tuner/epochs: 2
# tuner/initial_epoch: 0
# tuner/bracket: 2
# tuner/round: 0
# Score: 0.5520833134651184
#
# Trial 0008 summary
# Hyperparameters:
# hp_layers: 4
# RNN_layer_0_type: SimpleRNN
# hp_units_at_hp_layer_0: 64
# recurrent_dropout_0: 0.30000000000000004
# RNN_layer_1_type: LSTM
# hp_units_at_hp_layer_1: 64
# recurrent_dropout_1: 0.4
# optimizer_type: RMSprop
# learning_rate: 0.002570345329777908
# RNN_layer_2_type: GRU
# hp_units_at_hp_layer_2: 64
# recurrent_dropout_2: 0.30000000000000004
# RNN_layer_3_type: LSTM
# hp_units_at_hp_layer_3: 64
# recurrent_dropout_3: 0.30000000000000004
# batch_size: 64
# tuner/epochs: 2
# tuner/initial_epoch: 0
# tuner/bracket: 2
# tuner/round: 0
# Score: 0.5520833134651184
#
# Trial 0007 summary
# Hyperparameters:
# hp_layers: 2
# RNN_layer_0_type: LSTM
# hp_units_at_hp_layer_0: 64
# recurrent_dropout_0: 0.2
# RNN_layer_1_type: LSTM
# hp_units_at_hp_layer_1: 128
# recurrent_dropout_1: 0.1
# optimizer_type: Adam
# learning_rate: 0.0010828465568378522
# RNN_layer_2_type: SimpleRNN
# hp_units_at_hp_layer_2: 128
# recurrent_dropout_2: 0.4
# RNN_layer_3_type: SimpleRNN
# hp_units_at_hp_layer_3: 128
# recurrent_dropout_3: 0.30000000000000004
# batch_size: 32
# tuner/epochs: 2
# tuner/initial_epoch: 0
# tuner/bracket: 2
# tuner/round: 0
# Score: 0.5520833134651184
#
# Trial 0000 summary
# Hyperparameters:
# hp_layers: 4
# RNN_layer_0_type: SimpleRNN
# hp_units_at_hp_layer_0: 128
# recurrent_dropout_0: 0.4
# RNN_layer_1_type: GRU
# hp_units_at_hp_layer_1: 128
# recurrent_dropout_1: 0.1
# optimizer_type: Adam
# learning_rate: 0.0003623815491328145
# tuner/epochs: 2
# tuner/initial_epoch: 0
# tuner/bracket: 2
# tuner/round: 0
# RNN_layer_2_type: SimpleRNN
# hp_units_at_hp_layer_2: 64
# recurrent_dropout_2: 0.0
# RNN_layer_3_type: SimpleRNN
# hp_units_at_hp_layer_3: 64
# recurrent_dropout_3: 0.0
# batch_size: 32
# Score: 0.5520833134651184
#
# Trial 0016 summary
# Hyperparameters:
# hp_layers: 4
# RNN_layer_0_type: SimpleRNN
# hp_units_at_hp_layer_0: 128
# recurrent_dropout_0: 0.2
# RNN_layer_1_type: LSTM
# hp_units_at_hp_layer_1: 64
# recurrent_dropout_1: 0.2
# optimizer_type: RMSprop
# learning_rate: 0.0009294745699713808
# RNN_layer_2_type: GRU
# hp_units_at_hp_layer_2: 128
# recurrent_dropout_2: 0.0
# RNN_layer_3_type: SimpleRNN
# hp_units_at_hp_layer_3: 64
# recurrent_dropout_3: 0.30000000000000004
# batch_size: 64
# tuner/epochs: 10
# tuner/initial_epoch: 4
# tuner/bracket: 2
# tuner/round: 2
# tuner/trial_id: 0014
# Score: 0.5520833134651184
#
# Trial 0024 summary
# Hyperparameters:
# hp_layers: 2
# RNN_layer_0_type: LSTM
# hp_units_at_hp_layer_0: 128
# recurrent_dropout_0: 0.4
# RNN_layer_1_type: LSTM
# hp_units_at_hp_layer_1: 128
# recurrent_dropout_1: 0.30000000000000004
# optimizer_type: RMSprop
# learning_rate: 0.0002249755313619729
# RNN_layer_2_type: GRU
# hp_units_at_hp_layer_2: 64
# recurrent_dropout_2: 0.2
# RNN_layer_3_type: SimpleRNN
# hp_units_at_hp_layer_3: 64
# recurrent_dropout_3: 0.2
# batch_size: 32
# tuner/epochs: 10
# tuner/initial_epoch: 4
# tuner/bracket: 1
# tuner/round: 1
# tuner/trial_id: 0018
# Score: 0.5520833134651184
#
# Trial 0029 summary
# Hyperparameters:
# hp_layers: 2
# RNN_layer_0_type: GRU
# hp_units_at_hp_layer_0: 128
# recurrent_dropout_0: 0.0
# RNN_layer_1_type: LSTM
# hp_units_at_hp_layer_1: 128
# recurrent_dropout_1: 0.1
# optimizer_type: RMSprop
# learning_rate: 0.00026068410258675275
# RNN_layer_2_type: LSTM
# hp_units_at_hp_layer_2: 64
# recurrent_dropout_2: 0.0
# RNN_layer_3_type: LSTM
# hp_units_at_hp_layer_3: 128
# recurrent_dropout_3: 0.1
# batch_size: 64
# tuner/epochs: 10
# tuner/initial_epoch: 0
# tuner/bracket: 0
# tuner/round: 0
# Score: 0.5520833134651184
#
# Trial 0004 summary
# Hyperparameters:
# hp_layers: 4
# RNN_layer_0_type: LSTM
# hp_units_at_hp_layer_0: 64
# recurrent_dropout_0: 0.2
# RNN_layer_1_type: SimpleRNN
# hp_units_at_hp_layer_1: 128
# recurrent_dropout_1: 0.0
# optimizer_type: Adam
# learning_rate: 0.00022773443777239995
# RNN_layer_2_type: SimpleRNN
# hp_units_at_hp_layer_2: 128
# recurrent_dropout_2: 0.1
# RNN_layer_3_type: GRU
# hp_units_at_hp_layer_3: 128
# recurrent_dropout_3: 0.1
# batch_size: 32
# tuner/epochs: 2
# tuner/initial_epoch: 0
# tuner/bracket: 2
# tuner/round: 0
# Score: 0.5520833134651184
# Best epoch: 2
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 744ms/stepWARNING:tensorflow:5 out of the last 13 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x00000203C49FF060> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 593ms/step
# training for the ROP model was done in: 0:00:40.843584
# Reloading Tuner from keras_tuner_models\hp_RNN_models_archive/XYL\tuner0.json
# Results summary
# Results in keras_tuner_models\hp_RNN_models_archive/XYL
# Showing 10 best trials
# Objective(name="val_accuracy", direction="max")
#
# Trial 0014 summary
# Hyperparameters:
# hp_layers: 4
# RNN_layer_0_type: SimpleRNN
# hp_units_at_hp_layer_0: 128
# recurrent_dropout_0: 0.4
# RNN_layer_1_type: GRU
# hp_units_at_hp_layer_1: 128
# recurrent_dropout_1: 0.1
# optimizer_type: Adam
# learning_rate: 0.0003623815491328145
# tuner/epochs: 4
# tuner/initial_epoch: 2
# tuner/bracket: 2
# tuner/round: 1
# RNN_layer_2_type: SimpleRNN
# hp_units_at_hp_layer_2: 64
# recurrent_dropout_2: 0.0
# RNN_layer_3_type: SimpleRNN
# hp_units_at_hp_layer_3: 64
# recurrent_dropout_3: 0.0
# batch_size: 32
# tuner/trial_id: 0000
# Score: 0.5520833134651184
#
# Trial 0026 summary
# Hyperparameters:
# hp_layers: 2
# RNN_layer_0_type: LSTM
# hp_units_at_hp_layer_0: 128
# recurrent_dropout_0: 0.4
# RNN_layer_1_type: LSTM
# hp_units_at_hp_layer_1: 64
# recurrent_dropout_1: 0.4
# optimizer_type: SGD
# learning_rate: 0.0013638404825740366
# RNN_layer_2_type: LSTM
# hp_units_at_hp_layer_2: 128
# recurrent_dropout_2: 0.1
# RNN_layer_3_type: GRU
# hp_units_at_hp_layer_3: 64
# recurrent_dropout_3: 0.0
# batch_size: 32
# tuner/epochs: 10
# tuner/initial_epoch: 0
# tuner/bracket: 0
# tuner/round: 0
# Score: 0.5520833134651184
#
# Trial 0024 summary
# Hyperparameters:
# hp_layers: 4
# RNN_layer_0_type: SimpleRNN
# hp_units_at_hp_layer_0: 64
# recurrent_dropout_0: 0.0
# RNN_layer_1_type: LSTM
# hp_units_at_hp_layer_1: 128
# recurrent_dropout_1: 0.0
# optimizer_type: Adam
# learning_rate: 0.0012650614556534965
# RNN_layer_2_type: GRU
# hp_units_at_hp_layer_2: 128
# recurrent_dropout_2: 0.2
# RNN_layer_3_type: SimpleRNN
# hp_units_at_hp_layer_3: 64
# recurrent_dropout_3: 0.0
# batch_size: 32
# tuner/epochs: 10
# tuner/initial_epoch: 4
# tuner/bracket: 1
# tuner/round: 1
# tuner/trial_id: 0019
# Score: 0.5520833134651184
#
# Trial 0011 summary
# Hyperparameters:
# hp_layers: 4
# RNN_layer_0_type: LSTM
# hp_units_at_hp_layer_0: 128
# recurrent_dropout_0: 0.0
# RNN_layer_1_type: SimpleRNN
# hp_units_at_hp_layer_1: 128
# recurrent_dropout_1: 0.1
# optimizer_type: SGD
# learning_rate: 0.0065117874801730825
# RNN_layer_2_type: LSTM
# hp_units_at_hp_layer_2: 64
# recurrent_dropout_2: 0.0
# RNN_layer_3_type: GRU
# hp_units_at_hp_layer_3: 128
# recurrent_dropout_3: 0.0
# batch_size: 64
# tuner/epochs: 2
# tuner/initial_epoch: 0
# tuner/bracket: 2
# tuner/round: 0
# Score: 0.5416666865348816
#
# Trial 0017 summary
# Hyperparameters:
# hp_layers: 2
# RNN_layer_0_type: LSTM
# hp_units_at_hp_layer_0: 64
# recurrent_dropout_0: 0.2
# RNN_layer_1_type: LSTM
# hp_units_at_hp_layer_1: 128
# recurrent_dropout_1: 0.1
# optimizer_type: Adam
# learning_rate: 0.0010828465568378522
# RNN_layer_2_type: SimpleRNN
# hp_units_at_hp_layer_2: 128
# recurrent_dropout_2: 0.4
# RNN_layer_3_type: SimpleRNN
# hp_units_at_hp_layer_3: 128
# recurrent_dropout_3: 0.30000000000000004
# batch_size: 32
# tuner/epochs: 10
# tuner/initial_epoch: 4
# tuner/bracket: 2
# tuner/round: 2
# tuner/trial_id: 0013
# Score: 0.5416666865348816
#
# Trial 0016 summary
# Hyperparameters:
# hp_layers: 4
# RNN_layer_0_type: SimpleRNN
# hp_units_at_hp_layer_0: 128
# recurrent_dropout_0: 0.4
# RNN_layer_1_type: GRU
# hp_units_at_hp_layer_1: 128
# recurrent_dropout_1: 0.1
# optimizer_type: Adam
# learning_rate: 0.0003623815491328145
# tuner/epochs: 10
# tuner/initial_epoch: 4
# tuner/bracket: 2
# tuner/round: 2
# RNN_layer_2_type: SimpleRNN
# hp_units_at_hp_layer_2: 64
# recurrent_dropout_2: 0.0
# RNN_layer_3_type: SimpleRNN
# hp_units_at_hp_layer_3: 64
# recurrent_dropout_3: 0.0
# batch_size: 32
# tuner/trial_id: 0014
# Score: 0.5416666865348816
#
# Trial 0029 summary
# Hyperparameters:
# hp_layers: 2
# RNN_layer_0_type: GRU
# hp_units_at_hp_layer_0: 128
# recurrent_dropout_0: 0.0
# RNN_layer_1_type: LSTM
# hp_units_at_hp_layer_1: 128
# recurrent_dropout_1: 0.1
# optimizer_type: RMSprop
# learning_rate: 0.00026068410258675275
# RNN_layer_2_type: LSTM
# hp_units_at_hp_layer_2: 64
# recurrent_dropout_2: 0.0
# RNN_layer_3_type: LSTM
# hp_units_at_hp_layer_3: 128
# recurrent_dropout_3: 0.1
# batch_size: 64
# tuner/epochs: 10
# tuner/initial_epoch: 0
# tuner/bracket: 0
# tuner/round: 0
# Score: 0.53125
#
# Trial 0019 summary
# Hyperparameters:
# hp_layers: 4
# RNN_layer_0_type: SimpleRNN
# hp_units_at_hp_layer_0: 64
# recurrent_dropout_0: 0.0
# RNN_layer_1_type: LSTM
# hp_units_at_hp_layer_1: 128
# recurrent_dropout_1: 0.0
# optimizer_type: Adam
# learning_rate: 0.0012650614556534965
# RNN_layer_2_type: GRU
# hp_units_at_hp_layer_2: 128
# recurrent_dropout_2: 0.2
# RNN_layer_3_type: SimpleRNN
# hp_units_at_hp_layer_3: 64
# recurrent_dropout_3: 0.0
# batch_size: 32
# tuner/epochs: 4
# tuner/initial_epoch: 0
# tuner/bracket: 1
# tuner/round: 0
# Score: 0.53125
#
# Trial 0013 summary
# Hyperparameters:
# hp_layers: 2
# RNN_layer_0_type: LSTM
# hp_units_at_hp_layer_0: 64
# recurrent_dropout_0: 0.2
# RNN_layer_1_type: LSTM
# hp_units_at_hp_layer_1: 128
# recurrent_dropout_1: 0.1
# optimizer_type: Adam
# learning_rate: 0.0010828465568378522
# RNN_layer_2_type: SimpleRNN
# hp_units_at_hp_layer_2: 128
# recurrent_dropout_2: 0.4
# RNN_layer_3_type: SimpleRNN
# hp_units_at_hp_layer_3: 128
# recurrent_dropout_3: 0.30000000000000004
# batch_size: 32
# tuner/epochs: 4
# tuner/initial_epoch: 2
# tuner/bracket: 2
# tuner/round: 1
# tuner/trial_id: 0007
# Score: 0.53125
#
# Trial 0007 summary
# Hyperparameters:
# hp_layers: 2
# RNN_layer_0_type: LSTM
# hp_units_at_hp_layer_0: 64
# recurrent_dropout_0: 0.2
# RNN_layer_1_type: LSTM
# hp_units_at_hp_layer_1: 128
# recurrent_dropout_1: 0.1
# optimizer_type: Adam
# learning_rate: 0.0010828465568378522
# RNN_layer_2_type: SimpleRNN
# hp_units_at_hp_layer_2: 128
# recurrent_dropout_2: 0.4
# RNN_layer_3_type: SimpleRNN
# hp_units_at_hp_layer_3: 128
# recurrent_dropout_3: 0.30000000000000004
# batch_size: 32
# tuner/epochs: 2
# tuner/initial_epoch: 0
# tuner/bracket: 2
# tuner/round: 0
# Score: 0.5208333134651184
# Best epoch: 2
# WARNING:tensorflow:6 out of the last 14 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x00000203CF8BA3E0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 501ms/step
# training for the XYL model was done in: 0:00:59.415096
# Reloading Tuner from keras_tuner_models\hp_RNN_models_archive/CPAY\tuner0.json
# Results summary
# Results in keras_tuner_models\hp_RNN_models_archive/CPAY
# Showing 10 best trials
# Objective(name="val_accuracy", direction="max")
#
# Trial 0007 summary
# Hyperparameters:
# hp_layers: 2
# RNN_layer_0_type: LSTM
# hp_units_at_hp_layer_0: 64
# recurrent_dropout_0: 0.2
# RNN_layer_1_type: LSTM
# hp_units_at_hp_layer_1: 128
# recurrent_dropout_1: 0.1
# optimizer_type: Adam
# learning_rate: 0.0010828465568378522
# RNN_layer_2_type: SimpleRNN
# hp_units_at_hp_layer_2: 128
# recurrent_dropout_2: 0.4
# RNN_layer_3_type: SimpleRNN
# hp_units_at_hp_layer_3: 128
# recurrent_dropout_3: 0.30000000000000004
# batch_size: 32
# tuner/epochs: 2
# tuner/initial_epoch: 0
# tuner/bracket: 2
# tuner/round: 0
# Score: 0.59375
#
# Trial 0017 summary
# Hyperparameters:
# hp_layers: 2
# RNN_layer_0_type: LSTM
# hp_units_at_hp_layer_0: 64
# recurrent_dropout_0: 0.2
# RNN_layer_1_type: LSTM
# hp_units_at_hp_layer_1: 128
# recurrent_dropout_1: 0.1
# optimizer_type: Adam
# learning_rate: 0.0010828465568378522
# RNN_layer_2_type: SimpleRNN
# hp_units_at_hp_layer_2: 128
# recurrent_dropout_2: 0.4
# RNN_layer_3_type: SimpleRNN
# hp_units_at_hp_layer_3: 128
# recurrent_dropout_3: 0.30000000000000004
# batch_size: 32
# tuner/epochs: 10
# tuner/initial_epoch: 4
# tuner/bracket: 2
# tuner/round: 2
# tuner/trial_id: 0012
# Score: 0.59375
#
# Trial 0004 summary
# Hyperparameters:
# hp_layers: 4
# RNN_layer_0_type: LSTM
# hp_units_at_hp_layer_0: 64
# recurrent_dropout_0: 0.2
# RNN_layer_1_type: SimpleRNN
# hp_units_at_hp_layer_1: 128
# recurrent_dropout_1: 0.0
# optimizer_type: Adam
# learning_rate: 0.00022773443777239995
# RNN_layer_2_type: SimpleRNN
# hp_units_at_hp_layer_2: 128
# recurrent_dropout_2: 0.1
# RNN_layer_3_type: GRU
# hp_units_at_hp_layer_3: 128
# recurrent_dropout_3: 0.1
# batch_size: 32
# tuner/epochs: 2
# tuner/initial_epoch: 0
# tuner/bracket: 2
# tuner/round: 0
# Score: 0.5833333134651184
#
# Trial 0013 summary
# Hyperparameters:
# hp_layers: 4
# RNN_layer_0_type: LSTM
# hp_units_at_hp_layer_0: 64
# recurrent_dropout_0: 0.2
# RNN_layer_1_type: SimpleRNN
# hp_units_at_hp_layer_1: 128
# recurrent_dropout_1: 0.0
# optimizer_type: Adam
# learning_rate: 0.00022773443777239995
# RNN_layer_2_type: SimpleRNN
# hp_units_at_hp_layer_2: 128
# recurrent_dropout_2: 0.1
# RNN_layer_3_type: GRU
# hp_units_at_hp_layer_3: 128
# recurrent_dropout_3: 0.1
# batch_size: 32
# tuner/epochs: 4
# tuner/initial_epoch: 2
# tuner/bracket: 2
# tuner/round: 1
# tuner/trial_id: 0004
# Score: 0.5833333134651184
#
# Trial 0027 summary
# Hyperparameters:
# hp_layers: 4
# RNN_layer_0_type: SimpleRNN
# hp_units_at_hp_layer_0: 64
# recurrent_dropout_0: 0.2
# RNN_layer_1_type: GRU
# hp_units_at_hp_layer_1: 64
# recurrent_dropout_1: 0.0
# optimizer_type: Adam
# learning_rate: 0.0006950772468507907
# RNN_layer_2_type: LSTM
# hp_units_at_hp_layer_2: 128
# recurrent_dropout_2: 0.4
# RNN_layer_3_type: SimpleRNN
# hp_units_at_hp_layer_3: 64
# recurrent_dropout_3: 0.1
# batch_size: 64
# tuner/epochs: 10
# tuner/initial_epoch: 0
# tuner/bracket: 0
# tuner/round: 0
# Score: 0.5833333134651184
#
# Trial 0000 summary
# Hyperparameters:
# hp_layers: 4
# RNN_layer_0_type: SimpleRNN
# hp_units_at_hp_layer_0: 128
# recurrent_dropout_0: 0.4
# RNN_layer_1_type: GRU
# hp_units_at_hp_layer_1: 128
# recurrent_dropout_1: 0.1
# optimizer_type: Adam
# learning_rate: 0.0003623815491328145
# tuner/epochs: 2
# tuner/initial_epoch: 0
# tuner/bracket: 2
# tuner/round: 0
# RNN_layer_2_type: SimpleRNN
# hp_units_at_hp_layer_2: 64
# recurrent_dropout_2: 0.0
# RNN_layer_3_type: SimpleRNN
# hp_units_at_hp_layer_3: 64
# recurrent_dropout_3: 0.0
# batch_size: 32
# Score: 0.5729166865348816
#
# Trial 0018 summary
# Hyperparameters:
# hp_layers: 2
# RNN_layer_0_type: LSTM
# hp_units_at_hp_layer_0: 128
# recurrent_dropout_0: 0.4
# RNN_layer_1_type: LSTM
# hp_units_at_hp_layer_1: 128
# recurrent_dropout_1: 0.30000000000000004
# optimizer_type: RMSprop
# learning_rate: 0.0002249755313619729
# RNN_layer_2_type: GRU
# hp_units_at_hp_layer_2: 64
# recurrent_dropout_2: 0.2
# RNN_layer_3_type: SimpleRNN
# hp_units_at_hp_layer_3: 64
# recurrent_dropout_3: 0.2
# batch_size: 32
# tuner/epochs: 4
# tuner/initial_epoch: 0
# tuner/bracket: 1
# tuner/round: 0
# Score: 0.5729166865348816
#
# Trial 0021 summary
# Hyperparameters:
# hp_layers: 4
# RNN_layer_0_type: SimpleRNN
# hp_units_at_hp_layer_0: 64
# recurrent_dropout_0: 0.1
# RNN_layer_1_type: SimpleRNN
# hp_units_at_hp_layer_1: 64
# recurrent_dropout_1: 0.1
# optimizer_type: RMSprop
# learning_rate: 0.0001744074458486059
# RNN_layer_2_type: SimpleRNN
# hp_units_at_hp_layer_2: 64
# recurrent_dropout_2: 0.30000000000000004
# RNN_layer_3_type: LSTM
# hp_units_at_hp_layer_3: 64
# recurrent_dropout_3: 0.4
# batch_size: 32
# tuner/epochs: 4
# tuner/initial_epoch: 0
# tuner/bracket: 1
# tuner/round: 0
# Score: 0.5729166865348816
#
# Trial 0026 summary
# Hyperparameters:
# hp_layers: 2
# RNN_layer_0_type: LSTM
# hp_units_at_hp_layer_0: 128
# recurrent_dropout_0: 0.4
# RNN_layer_1_type: LSTM
# hp_units_at_hp_layer_1: 64
# recurrent_dropout_1: 0.4
# optimizer_type: SGD
# learning_rate: 0.0013638404825740366
# RNN_layer_2_type: LSTM
# hp_units_at_hp_layer_2: 128
# recurrent_dropout_2: 0.1
# RNN_layer_3_type: GRU
# hp_units_at_hp_layer_3: 64
# recurrent_dropout_3: 0.0
# batch_size: 32
# tuner/epochs: 10
# tuner/initial_epoch: 0
# tuner/bracket: 0
# tuner/round: 0
# Score: 0.5625
#
# Trial 0029 summary
# Hyperparameters:
# hp_layers: 2
# RNN_layer_0_type: GRU
# hp_units_at_hp_layer_0: 128
# recurrent_dropout_0: 0.0
# RNN_layer_1_type: LSTM
# hp_units_at_hp_layer_1: 128
# recurrent_dropout_1: 0.1
# optimizer_type: RMSprop
# learning_rate: 0.00026068410258675275
# RNN_layer_2_type: LSTM
# hp_units_at_hp_layer_2: 64
# recurrent_dropout_2: 0.0
# RNN_layer_3_type: LSTM
# hp_units_at_hp_layer_3: 128
# recurrent_dropout_3: 0.1
# batch_size: 64
# tuner/epochs: 10
# tuner/initial_epoch: 0
# tuner/bracket: 0
# tuner/round: 0
# Score: 0.5625
# Best epoch: 12
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 961ms/step
# training for the CPAY model was done in: 0:01:13.906432
# Reloading Tuner from keras_tuner_models\hp_RNN_models_archive/INCY\tuner0.json
# Results summary
# Results in keras_tuner_models\hp_RNN_models_archive/INCY
# Showing 10 best trials
# Objective(name="val_accuracy", direction="max")
#
# Trial 0016 summary
# Hyperparameters:
# hp_layers: 4
# RNN_layer_0_type: SimpleRNN
# hp_units_at_hp_layer_0: 64
# recurrent_dropout_0: 0.30000000000000004
# RNN_layer_1_type: LSTM
# hp_units_at_hp_layer_1: 64
# recurrent_dropout_1: 0.4
# optimizer_type: RMSprop
# learning_rate: 0.002570345329777908
# RNN_layer_2_type: GRU
# hp_units_at_hp_layer_2: 64
# recurrent_dropout_2: 0.30000000000000004
# RNN_layer_3_type: LSTM
# hp_units_at_hp_layer_3: 64
# recurrent_dropout_3: 0.30000000000000004
# batch_size: 64
# tuner/epochs: 10
# tuner/initial_epoch: 4
# tuner/bracket: 2
# tuner/round: 2
# tuner/trial_id: 0015
# Score: 0.6145833134651184
#
# Trial 0004 summary
# Hyperparameters:
# hp_layers: 4
# RNN_layer_0_type: LSTM
# hp_units_at_hp_layer_0: 64
# recurrent_dropout_0: 0.2
# RNN_layer_1_type: SimpleRNN
# hp_units_at_hp_layer_1: 128
# recurrent_dropout_1: 0.0
# optimizer_type: Adam
# learning_rate: 0.00022773443777239995
# RNN_layer_2_type: SimpleRNN
# hp_units_at_hp_layer_2: 128
# recurrent_dropout_2: 0.1
# RNN_layer_3_type: GRU
# hp_units_at_hp_layer_3: 128
# recurrent_dropout_3: 0.1
# batch_size: 32
# tuner/epochs: 2
# tuner/initial_epoch: 0
# tuner/bracket: 2
# tuner/round: 0
# Score: 0.59375
#
# Trial 0027 summary
# Hyperparameters:
# hp_layers: 4
# RNN_layer_0_type: SimpleRNN
# hp_units_at_hp_layer_0: 64
# recurrent_dropout_0: 0.2
# RNN_layer_1_type: GRU
# hp_units_at_hp_layer_1: 64
# recurrent_dropout_1: 0.0
# optimizer_type: Adam
# learning_rate: 0.0006950772468507907
# RNN_layer_2_type: LSTM
# hp_units_at_hp_layer_2: 128
# recurrent_dropout_2: 0.4
# RNN_layer_3_type: SimpleRNN
# hp_units_at_hp_layer_3: 64
# recurrent_dropout_3: 0.1
# batch_size: 64
# tuner/epochs: 10
# tuner/initial_epoch: 0
# tuner/bracket: 0
# tuner/round: 0
# Score: 0.59375
#
# Trial 0015 summary
# Hyperparameters:
# hp_layers: 4
# RNN_layer_0_type: SimpleRNN
# hp_units_at_hp_layer_0: 64
# recurrent_dropout_0: 0.30000000000000004
# RNN_layer_1_type: LSTM
# hp_units_at_hp_layer_1: 64
# recurrent_dropout_1: 0.4
# optimizer_type: RMSprop
# learning_rate: 0.002570345329777908
# RNN_layer_2_type: GRU
# hp_units_at_hp_layer_2: 64
# recurrent_dropout_2: 0.30000000000000004
# RNN_layer_3_type: LSTM
# hp_units_at_hp_layer_3: 64
# recurrent_dropout_3: 0.30000000000000004
# batch_size: 64
# tuner/epochs: 4
# tuner/initial_epoch: 2
# tuner/bracket: 2
# tuner/round: 1
# tuner/trial_id: 0008
# Score: 0.5833333134651184
#
# Trial 0028 summary
# Hyperparameters:
# hp_layers: 2
# RNN_layer_0_type: GRU
# hp_units_at_hp_layer_0: 64
# recurrent_dropout_0: 0.4
# RNN_layer_1_type: SimpleRNN
# hp_units_at_hp_layer_1: 128
# recurrent_dropout_1: 0.0
# optimizer_type: RMSprop
# learning_rate: 0.0005914405187452458
# RNN_layer_2_type: SimpleRNN
# hp_units_at_hp_layer_2: 128
# recurrent_dropout_2: 0.2
# RNN_layer_3_type: SimpleRNN
# hp_units_at_hp_layer_3: 64
# recurrent_dropout_3: 0.1
# batch_size: 64
# tuner/epochs: 10
# tuner/initial_epoch: 0
# tuner/bracket: 0
# tuner/round: 0
# Score: 0.5833333134651184
#
# Trial 0029 summary
# Hyperparameters:
# hp_layers: 2
# RNN_layer_0_type: GRU
# hp_units_at_hp_layer_0: 128
# recurrent_dropout_0: 0.0
# RNN_layer_1_type: LSTM
# hp_units_at_hp_layer_1: 128
# recurrent_dropout_1: 0.1
# optimizer_type: RMSprop
# learning_rate: 0.00026068410258675275
# RNN_layer_2_type: LSTM
# hp_units_at_hp_layer_2: 64
# recurrent_dropout_2: 0.0
# RNN_layer_3_type: LSTM
# hp_units_at_hp_layer_3: 128
# recurrent_dropout_3: 0.1
# batch_size: 64
# tuner/epochs: 10
# tuner/initial_epoch: 0
# tuner/bracket: 0
# tuner/round: 0
# Score: 0.5729166865348816
#
# Trial 0003 summary
# Hyperparameters:
# hp_layers: 4
# RNN_layer_0_type: GRU
# hp_units_at_hp_layer_0: 64
# recurrent_dropout_0: 0.4
# RNN_layer_1_type: SimpleRNN
# hp_units_at_hp_layer_1: 128
# recurrent_dropout_1: 0.2
# optimizer_type: Adam
# learning_rate: 0.004442367507315909
# RNN_layer_2_type: GRU
# hp_units_at_hp_layer_2: 128
# recurrent_dropout_2: 0.4
# RNN_layer_3_type: SimpleRNN
# hp_units_at_hp_layer_3: 128
# recurrent_dropout_3: 0.2
# batch_size: 64
# tuner/epochs: 2
# tuner/initial_epoch: 0
# tuner/bracket: 2
# tuner/round: 0
# Score: 0.5729166865348816
#
# Trial 0024 summary
# Hyperparameters:
# hp_layers: 2
# RNN_layer_0_type: LSTM
# hp_units_at_hp_layer_0: 128
# recurrent_dropout_0: 0.4
# RNN_layer_1_type: LSTM
# hp_units_at_hp_layer_1: 128
# recurrent_dropout_1: 0.30000000000000004
# optimizer_type: RMSprop
# learning_rate: 0.0002249755313619729
# RNN_layer_2_type: GRU
# hp_units_at_hp_layer_2: 64
# recurrent_dropout_2: 0.2
# RNN_layer_3_type: SimpleRNN
# hp_units_at_hp_layer_3: 64
# recurrent_dropout_3: 0.2
# batch_size: 32
# tuner/epochs: 10
# tuner/initial_epoch: 4
# tuner/bracket: 1
# tuner/round: 1
# tuner/trial_id: 0018
# Score: 0.5729166865348816
#
# Trial 0005 summary
# Hyperparameters:
# hp_layers: 4
# RNN_layer_0_type: LSTM
# hp_units_at_hp_layer_0: 64
# recurrent_dropout_0: 0.4
# RNN_layer_1_type: GRU
# hp_units_at_hp_layer_1: 128
# recurrent_dropout_1: 0.0
# optimizer_type: RMSprop
# learning_rate: 0.0008019212661756024
# RNN_layer_2_type: SimpleRNN
# hp_units_at_hp_layer_2: 64
# recurrent_dropout_2: 0.4
# RNN_layer_3_type: LSTM
# hp_units_at_hp_layer_3: 64
# recurrent_dropout_3: 0.30000000000000004
# batch_size: 32
# tuner/epochs: 2
# tuner/initial_epoch: 0
# tuner/bracket: 2
# tuner/round: 0
# Score: 0.5729166865348816
#
# Trial 0010 summary
# Hyperparameters:
# hp_layers: 2
# RNN_layer_0_type: SimpleRNN
# hp_units_at_hp_layer_0: 64
# recurrent_dropout_0: 0.1
# RNN_layer_1_type: LSTM
# hp_units_at_hp_layer_1: 64
# recurrent_dropout_1: 0.1
# optimizer_type: RMSprop
# learning_rate: 0.0004230507459568269
# RNN_layer_2_type: GRU
# hp_units_at_hp_layer_2: 128
# recurrent_dropout_2: 0.4
# RNN_layer_3_type: GRU
# hp_units_at_hp_layer_3: 64
# recurrent_dropout_3: 0.30000000000000004
# batch_size: 32
# tuner/epochs: 2
# tuner/initial_epoch: 0
# tuner/bracket: 2
# tuner/round: 0
# Score: 0.5729166865348816
# Best epoch: 6
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 738ms/step
# training for the INCY model was done in: 0:01:36.123022

# %%
# evaluate the models in the archive
evaluate_models_archive(hp_RNN_models_archive)
# Out:
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ simple_rnn_8 (SimpleRNN)             │ (None, 10, 128)             │          25,728 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_1 (LSTM)                        │ (None, 10, 64)              │          49,408 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ gru_1 (GRU)                          │ (None, 10, 128)             │          74,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ simple_rnn_9 (SimpleRNN)             │ (None, 64)                  │          12,352 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 2)                   │             130 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 324,230 (1.24 MB)
#  Trainable params: 162,114 (633.26 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 162,116 (633.27 KB)
# The PFE Model Classification Metrics:
# Accuracy: 0.46153846153846156
# Precision: 0.21301775147928995
# Recall: 0.46153846153846156
# F-Score: 0.291497975708502
# --------------------------------------------------------------
# C:\Users\ammaroAsus\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Model: "sequential_6"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ simple_rnn_11 (SimpleRNN)            │ (None, 10, 128)             │          25,728 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_5 (LSTM)                        │ (None, 10, 128)             │         131,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_6 (LSTM)                        │ (None, 10, 128)             │         131,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_7 (LSTM)                        │ (None, 64)                  │          49,408 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_6 (Dense)                      │ (None, 2)                   │             130 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 1,015,304 (3.87 MB)
#  Trainable params: 338,434 (1.29 MB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 676,870 (2.58 MB)
# The ROP Model Classification Metrics:
# Accuracy: 0.5128205128205128
# Precision: 0.26298487836949375
# Recall: 0.5128205128205128
# F-Score: 0.3476749239461104
# --------------------------------------------------------------
# C:\Users\ammaroAsus\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Model: "sequential_8"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ simple_rnn_15 (SimpleRNN)            │ (None, 10, 128)             │          25,728 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ gru_3 (GRU)                          │ (None, 10, 128)             │          99,072 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ simple_rnn_16 (SimpleRNN)            │ (None, 10, 64)              │          12,352 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ simple_rnn_17 (SimpleRNN)            │ (None, 64)                  │           8,256 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_8 (Dense)                      │ (None, 2)                   │             130 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 436,616 (1.67 MB)
#  Trainable params: 145,538 (568.51 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 291,078 (1.11 MB)
# The XYL Model Classification Metrics:
# Accuracy: 0.6153846153846154
# Precision: 0.37869822485207105
# Recall: 0.6153846153846154
# F-Score: 0.46886446886446886
# --------------------------------------------------------------
# C:\Users\ammaroAsus\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Model: "sequential_10"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ lstm_10 (LSTM)                       │ (None, 10, 64)              │          35,072 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_11 (LSTM)                       │ (None, 128)                 │          98,816 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_10 (Dense)                     │ (None, 2)                   │             258 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 402,440 (1.54 MB)
#  Trainable params: 134,146 (524.01 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 268,294 (1.02 MB)
# The CPAY Model Classification Metrics:
# Accuracy: 0.6410256410256411
# Precision: 0.710955710955711
# Recall: 0.6410256410256411
# F-Score: 0.5911680911680912
# --------------------------------------------------------------
# Model: "sequential_12"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ simple_rnn_19 (SimpleRNN)            │ (None, 10, 64)              │           8,768 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_14 (LSTM)                       │ (None, 10, 64)              │          33,024 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ gru_5 (GRU)                          │ (None, 10, 64)              │          24,960 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_15 (LSTM)                       │ (None, 64)                  │          33,024 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_12 (Dense)                     │ (None, 2)                   │             130 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 199,814 (780.53 KB)
#  Trainable params: 99,906 (390.26 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 99,908 (390.27 KB)
# The INCY Model Classification Metrics:
# Accuracy: 0.5128205128205128
# Precision: 0.26298487836949375
# Recall: 0.5128205128205128
# F-Score: 0.3476749239461104
# --------------------------------------------------------------
# C:\Users\ammaroAsus\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Average Classification Metrics for All Models:
# Average Accuracy: 0.5487179487179488
# Average Precision: 0.3657282888052119
# Average Recall: 0.5487179487179488
# Average F-Score: 0.40937607672665666

# %%
# # set the model initialization inputs
# X_train_shape = data_sets['PFE']['X_train'].shape
# model_type='classification'
# tuner = RandomSearch

# # create the model
# hp_RNN_model2 = HP_RNNModel(X_train_shape)

# # create models archive for simpleRNN classification approach
# hp_RNN_models2_archive = create_models_archive(hp_RNN_model2, 
#                                                  data_sets, 
#                                                  _model_type=model_type, 
#                                                  _tuner=tuner, 
#                                                  _epochs=50, 
#                                                  _model_name='hp_RNN_model2', 
#                                                  _project_name='hp_RNN_models2_archive')

# %% [markdown]
# ## Inception Model
#
# Inception models are designed to process input data through multiple parallel branches.
# They help the network separately learn features from different groups, which is more efficient than learning them jointly.
#
# In my implementation:
# 1. I created an InputSplitLayer(18) a custom layer to divide the input features into 4 groups.
# 2. Each feature group is passed through a separate HP_Hollow_RNN_Branch(19) class instance which is similar to the hp_RNN_model but without an output layer.
# 3. These branches are then combined in the HP_Hollow_RNN_Inception_Model, which merges the outputs from all the different branches before passing them to the output layer.
#
# The hyperparameter optimization process within HP_Hollow_RNN_Branch ensures the best possible configurations for each branch in the inception model.

# %%
# source of inspiration: The base Layer class, "class ComputeSum(Layer)", https://keras.io/2.15/api/layers/base_layer/
# create a custom layer to split the features into groups (4 groups)
# TypeError: Could not locate class 'InputSpiltLayer'. Make sure custom classes are decorated with `@keras.saving.register_keras_serializable()
@register_keras_serializable()
class InputSpiltLayer(Layer):
    def __init__(self, split_indices=[6, 36, 67, 72], **kwargs):
        super(InputSpiltLayer, self).__init__(**kwargs)
        
        # set the split indices
        self.split_indices = split_indices
    
    def call(self, inputs): # Defines the computation from inputs to outputs
        
        # initialize a list to store the input branches 
        data_set_branches = []
    
        # set the start index to be 0
        start_index = 0

        # iterates over the split_indices list
        for i in self.split_indices:
            
            # take a slice of the data features that is between the start index and the ith value in the split_indices
            branch = inputs[:, :, start_index:i]

            # add the slice to the data_set_branches list
            data_set_branches.append(branch)

            # update the start_index to be equal to the ith value in the split_indices
            start_index = i

        # return the data_set_branches
        return data_set_branches

class HP_Hollow_RNN_Branch(HyperModel):

    # initialize the model upon creating a class instance
    # using a class structure instead of a function to construct the model will allow us to pass variables to it before passing it to keras tuner
    # source of inspiration on how to pass variables to the model before passing the model to keras tuner: https://github.com/JulieProst/keras-tuner-tutorial/blob/master/hypermodels.py
    def __init__(self, _data_set_branch, _branch_name):
        self.data_set_branch = _data_set_branch
        self.branch_name = _branch_name
    
    # build the model
    def build(self, hp):

        layer = self.data_set_branch
        
        # source: Int method, https://keras.io/api/keras_tuner/hyperparameters/
        # dynamically optimize the number of layers
        hp_layers = hp.Int(name=f'{self.branch_name}_hp_layers', 
                           min_value=2, 
                           max_value=4, 
                           step=2)

        # for each optimized layer
        for i in range(hp_layers):
            
#             # dynamically tune the number of units in each layer, select a value between 32-256
#             hp_units = hp.Choice(f'{self.branch_name}_hp_units_at_hp_layer_{i}', [32, 64, 128, 256])

            # optimize the layer type
            hp_layer_type = hp.Choice(f'{self.branch_name}_RNN_layer_{i}_type', values=['SimpleRNN', 'LSTM', 'GRU'])
            if hp_layer_type == 'SimpleRNN':
                layer_type = SimpleRNN
            elif hp_layer_type == 'LSTM':
                layer_type = LSTM
            else:
                layer_type = GRU
            
            # dynamically tune the number of units in each layer, select a value between 64-128
            hp_units = hp.Int(name=f'{self.branch_name}_hp_units_at_hp_layer_{i}', 
                              min_value=64, 
                              max_value=128, 
                              step=64)

            # source: SimpleRNN layer, https://keras.io/api/layers/recurrent_layers/simple_rnn/
            # return_sequences: Boolean. Whether to return the last output in the output sequence, or the full sequence. Default: False.
            # set the return_sequences parameter to true unless it's the last layer, set it to false
            return_sequences_boolean = i != (hp_layers - 1)

            # source: Float method, https://keras.io/api/keras_tuner/hyperparameters/
            # source: SimpleRNN layer, https://keras.io/api/layers/recurrent_layers/simple_rnn/
            # recurrent_dropout: Float between 0 and 1. Fraction of the units to drop for the linear transformation of the recurrent state.
            # dynamically tune the recurrent_dropout float value
            recurrent_dropout = hp.Float(name=f'{self.branch_name}_recurrent_dropout_{i}', 
                                         min_value=0.0, 
                                         max_value=0.5, 
                                         step=0.1)

            # add a simpleRNN layer and pass the optimized number of unites, recurrent_dropout, and the return_sequences boolean
            layer = layer_type(units=hp_units, 
                              return_sequences=return_sequences_boolean, 
                              recurrent_dropout=recurrent_dropout)(layer)
            
#             layer = BatchNormalization()(layer)
            
            
        return layer
        
        

# source of inspiration: Introduction to the Keras Tuner, https://www.tensorflow.org/tutorials/keras/keras_tuner
# constuct the model which will perform hyperparameter optimization to choose layer type, layers count, neurons counts, recurrent_dropout, optimizer_type, optimizer learning rate
class HP_Hollow_RNN_Inception_Model(HyperModel):

    # initialize the model upon creating a class instance
    # using a class structure instead of a function to construct the model will allow us to pass variables to it before passing it to keras tuner
    # source of inspiration on how to pass variables to the model before passing the model to keras tuner: https://github.com/JulieProst/keras-tuner-tutorial/blob/master/hypermodels.py
    def __init__(self, X_train_shape):
        self.X_train_shape = X_train_shape
    
    # build the model
    def build(self, hp):
        ### add the model layers (Model hyperparameters optimization)
        # input layer
        input_data = Input(shape=(self.X_train_shape[1], self.X_train_shape[2]))

        all_features_branch = HP_Hollow_RNN_Branch(input_data, "all_features_branch").build(hp)
        
        
        # source of inspiration: deep learning with python, 7.1.4. Directed acyclic graphs of layers, Inception modules, https://www.manning.com/books/deep-learning-with-python
        data_set_branches = InputSpiltLayer([6, 36, 67, 72])(input_data)

        base_features_branch = HP_Hollow_RNN_Branch(data_set_branches[0], "base_features_branch").build(hp)
        close_features_branch = HP_Hollow_RNN_Branch(data_set_branches[1], "close_features_branch").build(hp)
        high_low_features_branch = HP_Hollow_RNN_Branch(data_set_branches[2], "high_low_features_branch").build(hp)
        volume_features_branch = HP_Hollow_RNN_Branch(data_set_branches[3], "volume_features_branch").build(hp)

        branches_merged = concatenate([base_features_branch, 
                                       close_features_branch, 
                                       high_low_features_branch, 
                                       volume_features_branch, 
                                       all_features_branch], axis=-1)    
    
        output = Dense(2, activation='softmax')(branches_merged)

        # create the model
        model = Model(input_data, output)

        ### the model compiler (Algorithm hyperparameters optimization)
        # source: Choice method, https://keras.io/api/keras_tuner/hyperparameters/
        # dynamically optimize the optimizer type
        hp_optimizer_type = hp.Choice('optimizer_type', values=['Adam', 'RMSprop', 'SGD'])
        if hp_optimizer_type == 'Adam':
            optimizer = Adam
        elif hp_optimizer_type == 'RMSprop':
            optimizer = RMSprop
        else:
            optimizer = SGD

        # dynamically tune the learning rate for the optimizer
        # When sampling="log", the step is multiplied between samples.
        hp_lr = hp.Float('learning_rate', 
                         min_value=0.0001, 
                         max_value=0.01, 
                         sampling='LOG')
        hp_optimizer = optimizer(learning_rate=hp_lr)

        # compile the model
        model.compile(optimizer=hp_optimizer, 
                      loss='categorical_crossentropy', # this is the most suitable one for predictions of one-hot encoded labels
                      metrics=['accuracy'])

        # return the model
        return model
    
    # source: omalleyt12, https://github.com/keras-team/keras-tuner/issues/122
    # define a fit function which will allow us to pass an optimized value for batch_size
    # *args and **kwargs are the ones we pass through tuner.search()
    def fit(self, hp, model, *args, **kwargs):
        
        # dynamically optimize the batch_size for the training process
        hp_batch_size = hp.Choice("batch_size", [32, 64])
        return model.fit(
            *args,
            batch_size=hp_batch_size,
            **kwargs,
        )

# %%
# set the model initialization inputs
X_train_shape = data_sets['PFE']['X_train'].shape
model_type='classification'
tuner = Hyperband

# create the model
hp_RNN_inception_model = HP_Hollow_RNN_Inception_Model(X_train_shape)
# hp_RNN_model = hp_RNN_model.build()

# create models archive for simpleRNN classification approach
hp_RNN_inception_models_archive = create_models_archive(hp_RNN_inception_model, 
                                                 data_sets, 
                                                 _model_type=model_type, 
                                                 _tuner=tuner, 
                                                 _epochs=50, 
                                                 _model_name='hp_RNN_inception_model', 
                                                 _project_name='hp_RNN_inception_model_archive3')
# Out:
# C:\Users\ammaroAsus\anaconda3\Lib\site-packages\keras\src\saving\saving_lib.py:415: UserWarning: Skipping variable loading for optimizer 'rmsprop', because it has 2 variables whereas the saved optimizer has 34 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# C:\Users\ammaroAsus\anaconda3\Lib\site-packages\keras\src\saving\saving_lib.py:415: UserWarning: Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 90 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# C:\Users\ammaroAsus\anaconda3\Lib\site-packages\keras\src\saving\saving_lib.py:415: UserWarning: Skipping variable loading for optimizer 'rmsprop', because it has 2 variables whereas the saved optimizer has 58 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# C:\Users\ammaroAsus\anaconda3\Lib\site-packages\keras\src\saving\saving_lib.py:415: UserWarning: Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 102 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# Results summary
# Results in keras_tuner_models\hp_RNN_inception_model_archive3/PFE
# Showing 10 best trials
# Objective(name="val_accuracy", direction="max")
#
# Trial 0008 summary
# Hyperparameters:
# all_features_branch_hp_layers: 2
# all_features_branch_RNN_layer_0_type: LSTM
# all_features_branch_hp_units_at_hp_layer_0: 64
# all_features_branch_recurrent_dropout_0: 0.2
# all_features_branch_RNN_layer_1_type: GRU
# all_features_branch_hp_units_at_hp_layer_1: 64
# all_features_branch_recurrent_dropout_1: 0.1
# base_features_branch_hp_layers: 2
# base_features_branch_RNN_layer_0_type: SimpleRNN
# base_features_branch_hp_units_at_hp_layer_0: 128
# base_features_branch_recurrent_dropout_0: 0.2
# base_features_branch_RNN_layer_1_type: LSTM
# base_features_branch_hp_units_at_hp_layer_1: 64
# base_features_branch_recurrent_dropout_1: 0.1
# close_features_branch_hp_layers: 2
# close_features_branch_RNN_layer_0_type: SimpleRNN
# close_features_branch_hp_units_at_hp_layer_0: 64
# close_features_branch_recurrent_dropout_0: 0.4
# close_features_branch_RNN_layer_1_type: LSTM
# close_features_branch_hp_units_at_hp_layer_1: 128
# close_features_branch_recurrent_dropout_1: 0.4
# high_low_features_branch_hp_layers: 2
# high_low_features_branch_RNN_layer_0_type: GRU
# high_low_features_branch_hp_units_at_hp_layer_0: 128
# high_low_features_branch_recurrent_dropout_0: 0.1
# high_low_features_branch_RNN_layer_1_type: SimpleRNN
# high_low_features_branch_hp_units_at_hp_layer_1: 64
# high_low_features_branch_recurrent_dropout_1: 0.1
# volume_features_branch_hp_layers: 2
# volume_features_branch_RNN_layer_0_type: LSTM
# volume_features_branch_hp_units_at_hp_layer_0: 128
# volume_features_branch_recurrent_dropout_0: 0.30000000000000004
# volume_features_branch_RNN_layer_1_type: SimpleRNN
# volume_features_branch_hp_units_at_hp_layer_1: 64
# volume_features_branch_recurrent_dropout_1: 0.30000000000000004
# optimizer_type: RMSprop
# learning_rate: 0.0009358636959100566
# all_features_branch_RNN_layer_2_type: SimpleRNN
# all_features_branch_hp_units_at_hp_layer_2: 128
# all_features_branch_recurrent_dropout_2: 0.4
# all_features_branch_RNN_layer_3_type: LSTM
# all_features_branch_hp_units_at_hp_layer_3: 64
# all_features_branch_recurrent_dropout_3: 0.1
# close_features_branch_RNN_layer_2_type: SimpleRNN
# close_features_branch_hp_units_at_hp_layer_2: 64
# close_features_branch_recurrent_dropout_2: 0.30000000000000004
# close_features_branch_RNN_layer_3_type: LSTM
# close_features_branch_hp_units_at_hp_layer_3: 128
# close_features_branch_recurrent_dropout_3: 0.30000000000000004
# high_low_features_branch_RNN_layer_2_type: LSTM
# high_low_features_branch_hp_units_at_hp_layer_2: 64
# high_low_features_branch_recurrent_dropout_2: 0.30000000000000004
# high_low_features_branch_RNN_layer_3_type: SimpleRNN
# high_low_features_branch_hp_units_at_hp_layer_3: 128
# high_low_features_branch_recurrent_dropout_3: 0.30000000000000004
# volume_features_branch_RNN_layer_2_type: GRU
# volume_features_branch_hp_units_at_hp_layer_2: 128
# volume_features_branch_recurrent_dropout_2: 0.2
# volume_features_branch_RNN_layer_3_type: LSTM
# volume_features_branch_hp_units_at_hp_layer_3: 64
# volume_features_branch_recurrent_dropout_3: 0.2
# batch_size: 32
# base_features_branch_RNN_layer_2_type: LSTM
# base_features_branch_hp_units_at_hp_layer_2: 128
# base_features_branch_recurrent_dropout_2: 0.0
# base_features_branch_RNN_layer_3_type: LSTM
# base_features_branch_hp_units_at_hp_layer_3: 64
# base_features_branch_recurrent_dropout_3: 0.1
# tuner/epochs: 2
# tuner/initial_epoch: 0
# tuner/bracket: 2
# tuner/round: 0
# Score: 0.621052622795105
#
# Trial 0029 summary
# Hyperparameters:
# all_features_branch_hp_layers: 4
# all_features_branch_RNN_layer_0_type: GRU
# all_features_branch_hp_units_at_hp_layer_0: 64
# all_features_branch_recurrent_dropout_0: 0.2
# all_features_branch_RNN_layer_1_type: GRU
# all_features_branch_hp_units_at_hp_layer_1: 64
# all_features_branch_recurrent_dropout_1: 0.0
# base_features_branch_hp_layers: 2
# base_features_branch_RNN_layer_0_type: SimpleRNN
# base_features_branch_hp_units_at_hp_layer_0: 128
# base_features_branch_recurrent_dropout_0: 0.0
# base_features_branch_RNN_layer_1_type: LSTM
# base_features_branch_hp_units_at_hp_layer_1: 128
# base_features_branch_recurrent_dropout_1: 0.0
# close_features_branch_hp_layers: 2
# close_features_branch_RNN_layer_0_type: SimpleRNN
# close_features_branch_hp_units_at_hp_layer_0: 64
# close_features_branch_recurrent_dropout_0: 0.4
# close_features_branch_RNN_layer_1_type: LSTM
# close_features_branch_hp_units_at_hp_layer_1: 64
# close_features_branch_recurrent_dropout_1: 0.2
# high_low_features_branch_hp_layers: 4
# high_low_features_branch_RNN_layer_0_type: SimpleRNN
# high_low_features_branch_hp_units_at_hp_layer_0: 128
# high_low_features_branch_recurrent_dropout_0: 0.1
# high_low_features_branch_RNN_layer_1_type: LSTM
# high_low_features_branch_hp_units_at_hp_layer_1: 64
# high_low_features_branch_recurrent_dropout_1: 0.1
# volume_features_branch_hp_layers: 2
# volume_features_branch_RNN_layer_0_type: SimpleRNN
# volume_features_branch_hp_units_at_hp_layer_0: 128
# volume_features_branch_recurrent_dropout_0: 0.0
# volume_features_branch_RNN_layer_1_type: SimpleRNN
# volume_features_branch_hp_units_at_hp_layer_1: 128
# volume_features_branch_recurrent_dropout_1: 0.30000000000000004
# optimizer_type: RMSprop
# learning_rate: 0.0005061117544320517
# all_features_branch_RNN_layer_2_type: SimpleRNN
# all_features_branch_hp_units_at_hp_layer_2: 64
# all_features_branch_recurrent_dropout_2: 0.30000000000000004
# all_features_branch_RNN_layer_3_type: GRU
# all_features_branch_hp_units_at_hp_layer_3: 128
# all_features_branch_recurrent_dropout_3: 0.1
# close_features_branch_RNN_layer_2_type: SimpleRNN
# close_features_branch_hp_units_at_hp_layer_2: 128
# close_features_branch_recurrent_dropout_2: 0.1
# close_features_branch_RNN_layer_3_type: SimpleRNN
# close_features_branch_hp_units_at_hp_layer_3: 64
# close_features_branch_recurrent_dropout_3: 0.0
# high_low_features_branch_RNN_layer_2_type: SimpleRNN
# high_low_features_branch_hp_units_at_hp_layer_2: 64
# high_low_features_branch_recurrent_dropout_2: 0.0
# high_low_features_branch_RNN_layer_3_type: SimpleRNN
# high_low_features_branch_hp_units_at_hp_layer_3: 64
# high_low_features_branch_recurrent_dropout_3: 0.0
# volume_features_branch_RNN_layer_2_type: GRU
# volume_features_branch_hp_units_at_hp_layer_2: 64
# volume_features_branch_recurrent_dropout_2: 0.2
# volume_features_branch_RNN_layer_3_type: LSTM
# volume_features_branch_hp_units_at_hp_layer_3: 128
# volume_features_branch_recurrent_dropout_3: 0.0
# batch_size: 64
# base_features_branch_RNN_layer_2_type: LSTM
# base_features_branch_hp_units_at_hp_layer_2: 64
# base_features_branch_recurrent_dropout_2: 0.1
# base_features_branch_RNN_layer_3_type: SimpleRNN
# base_features_branch_hp_units_at_hp_layer_3: 128
# base_features_branch_recurrent_dropout_3: 0.30000000000000004
# tuner/epochs: 10
# tuner/initial_epoch: 0
# tuner/bracket: 0
# tuner/round: 0
# Score: 0.621052622795105
#
# Trial 0001 summary
# Hyperparameters:
# all_features_branch_hp_layers: 2
# all_features_branch_RNN_layer_0_type: SimpleRNN
# all_features_branch_hp_units_at_hp_layer_0: 128
# all_features_branch_recurrent_dropout_0: 0.2
# all_features_branch_RNN_layer_1_type: LSTM
# all_features_branch_hp_units_at_hp_layer_1: 128
# all_features_branch_recurrent_dropout_1: 0.2
# base_features_branch_hp_layers: 4
# base_features_branch_RNN_layer_0_type: SimpleRNN
# base_features_branch_hp_units_at_hp_layer_0: 128
# base_features_branch_recurrent_dropout_0: 0.2
# base_features_branch_RNN_layer_1_type: SimpleRNN
# base_features_branch_hp_units_at_hp_layer_1: 128
# base_features_branch_recurrent_dropout_1: 0.30000000000000004
# close_features_branch_hp_layers: 4
# close_features_branch_RNN_layer_0_type: GRU
# close_features_branch_hp_units_at_hp_layer_0: 64
# close_features_branch_recurrent_dropout_0: 0.2
# close_features_branch_RNN_layer_1_type: LSTM
# close_features_branch_hp_units_at_hp_layer_1: 128
# close_features_branch_recurrent_dropout_1: 0.30000000000000004
# high_low_features_branch_hp_layers: 2
# high_low_features_branch_RNN_layer_0_type: SimpleRNN
# high_low_features_branch_hp_units_at_hp_layer_0: 128
# high_low_features_branch_recurrent_dropout_0: 0.0
# high_low_features_branch_RNN_layer_1_type: LSTM
# high_low_features_branch_hp_units_at_hp_layer_1: 64
# high_low_features_branch_recurrent_dropout_1: 0.0
# volume_features_branch_hp_layers: 2
# volume_features_branch_RNN_layer_0_type: SimpleRNN
# volume_features_branch_hp_units_at_hp_layer_0: 128
# volume_features_branch_recurrent_dropout_0: 0.1
# volume_features_branch_RNN_layer_1_type: GRU
# volume_features_branch_hp_units_at_hp_layer_1: 128
# volume_features_branch_recurrent_dropout_1: 0.1
# optimizer_type: Adam
# learning_rate: 0.00405701014195834
# all_features_branch_RNN_layer_2_type: LSTM
# all_features_branch_hp_units_at_hp_layer_2: 64
# all_features_branch_recurrent_dropout_2: 0.4
# all_features_branch_RNN_layer_3_type: GRU
# all_features_branch_hp_units_at_hp_layer_3: 128
# all_features_branch_recurrent_dropout_3: 0.0
# close_features_branch_RNN_layer_2_type: LSTM
# close_features_branch_hp_units_at_hp_layer_2: 64
# close_features_branch_recurrent_dropout_2: 0.0
# close_features_branch_RNN_layer_3_type: SimpleRNN
# close_features_branch_hp_units_at_hp_layer_3: 128
# close_features_branch_recurrent_dropout_3: 0.1
# high_low_features_branch_RNN_layer_2_type: LSTM
# high_low_features_branch_hp_units_at_hp_layer_2: 128
# high_low_features_branch_recurrent_dropout_2: 0.2
# high_low_features_branch_RNN_layer_3_type: SimpleRNN
# high_low_features_branch_hp_units_at_hp_layer_3: 128
# high_low_features_branch_recurrent_dropout_3: 0.1
# volume_features_branch_RNN_layer_2_type: LSTM
# volume_features_branch_hp_units_at_hp_layer_2: 128
# volume_features_branch_recurrent_dropout_2: 0.2
# volume_features_branch_RNN_layer_3_type: LSTM
# volume_features_branch_hp_units_at_hp_layer_3: 128
# volume_features_branch_recurrent_dropout_3: 0.0
# batch_size: 32
# tuner/epochs: 2
# tuner/initial_epoch: 0
# tuner/bracket: 2
# tuner/round: 0
# base_features_branch_RNN_layer_2_type: SimpleRNN
# base_features_branch_hp_units_at_hp_layer_2: 64
# base_features_branch_recurrent_dropout_2: 0.0
# base_features_branch_RNN_layer_3_type: SimpleRNN
# base_features_branch_hp_units_at_hp_layer_3: 64
# base_features_branch_recurrent_dropout_3: 0.0
# Score: 0.6000000238418579
#
# Trial 0022 summary
# Hyperparameters:
# all_features_branch_hp_layers: 4
# all_features_branch_RNN_layer_0_type: SimpleRNN
# all_features_branch_hp_units_at_hp_layer_0: 128
# all_features_branch_recurrent_dropout_0: 0.0
# all_features_branch_RNN_layer_1_type: LSTM
# all_features_branch_hp_units_at_hp_layer_1: 128
# all_features_branch_recurrent_dropout_1: 0.30000000000000004
# base_features_branch_hp_layers: 2
# base_features_branch_RNN_layer_0_type: LSTM
# base_features_branch_hp_units_at_hp_layer_0: 128
# base_features_branch_recurrent_dropout_0: 0.2
# base_features_branch_RNN_layer_1_type: SimpleRNN
# base_features_branch_hp_units_at_hp_layer_1: 64
# base_features_branch_recurrent_dropout_1: 0.4
# close_features_branch_hp_layers: 4
# close_features_branch_RNN_layer_0_type: GRU
# close_features_branch_hp_units_at_hp_layer_0: 128
# close_features_branch_recurrent_dropout_0: 0.4
# close_features_branch_RNN_layer_1_type: SimpleRNN
# close_features_branch_hp_units_at_hp_layer_1: 128
# close_features_branch_recurrent_dropout_1: 0.2
# high_low_features_branch_hp_layers: 2
# high_low_features_branch_RNN_layer_0_type: SimpleRNN
# high_low_features_branch_hp_units_at_hp_layer_0: 64
# high_low_features_branch_recurrent_dropout_0: 0.30000000000000004
# high_low_features_branch_RNN_layer_1_type: LSTM
# high_low_features_branch_hp_units_at_hp_layer_1: 128
# high_low_features_branch_recurrent_dropout_1: 0.2
# volume_features_branch_hp_layers: 2
# volume_features_branch_RNN_layer_0_type: LSTM
# volume_features_branch_hp_units_at_hp_layer_0: 128
# volume_features_branch_recurrent_dropout_0: 0.1
# volume_features_branch_RNN_layer_1_type: LSTM
# volume_features_branch_hp_units_at_hp_layer_1: 64
# volume_features_branch_recurrent_dropout_1: 0.1
# optimizer_type: SGD
# learning_rate: 0.0014635819274432475
# all_features_branch_RNN_layer_2_type: LSTM
# all_features_branch_hp_units_at_hp_layer_2: 64
# all_features_branch_recurrent_dropout_2: 0.2
# all_features_branch_RNN_layer_3_type: GRU
# all_features_branch_hp_units_at_hp_layer_3: 64
# all_features_branch_recurrent_dropout_3: 0.30000000000000004
# close_features_branch_RNN_layer_2_type: SimpleRNN
# close_features_branch_hp_units_at_hp_layer_2: 64
# close_features_branch_recurrent_dropout_2: 0.4
# close_features_branch_RNN_layer_3_type: SimpleRNN
# close_features_branch_hp_units_at_hp_layer_3: 128
# close_features_branch_recurrent_dropout_3: 0.4
# high_low_features_branch_RNN_layer_2_type: SimpleRNN
# high_low_features_branch_hp_units_at_hp_layer_2: 64
# high_low_features_branch_recurrent_dropout_2: 0.4
# high_low_features_branch_RNN_layer_3_type: LSTM
# high_low_features_branch_hp_units_at_hp_layer_3: 128
# high_low_features_branch_recurrent_dropout_3: 0.1
# volume_features_branch_RNN_layer_2_type: GRU
# volume_features_branch_hp_units_at_hp_layer_2: 64
# volume_features_branch_recurrent_dropout_2: 0.4
# volume_features_branch_RNN_layer_3_type: SimpleRNN
# volume_features_branch_hp_units_at_hp_layer_3: 64
# volume_features_branch_recurrent_dropout_3: 0.30000000000000004
# batch_size: 64
# base_features_branch_RNN_layer_2_type: GRU
# base_features_branch_hp_units_at_hp_layer_2: 64
# base_features_branch_recurrent_dropout_2: 0.2
# base_features_branch_RNN_layer_3_type: GRU
# base_features_branch_hp_units_at_hp_layer_3: 128
# base_features_branch_recurrent_dropout_3: 0.4
# tuner/epochs: 4
# tuner/initial_epoch: 0
# tuner/bracket: 1
# tuner/round: 0
# Score: 0.6000000238418579
#
# Trial 0028 summary
# Hyperparameters:
# all_features_branch_hp_layers: 2
# all_features_branch_RNN_layer_0_type: SimpleRNN
# all_features_branch_hp_units_at_hp_layer_0: 128
# all_features_branch_recurrent_dropout_0: 0.30000000000000004
# all_features_branch_RNN_layer_1_type: LSTM
# all_features_branch_hp_units_at_hp_layer_1: 64
# all_features_branch_recurrent_dropout_1: 0.4
# base_features_branch_hp_layers: 4
# base_features_branch_RNN_layer_0_type: LSTM
# base_features_branch_hp_units_at_hp_layer_0: 128
# base_features_branch_recurrent_dropout_0: 0.0
# base_features_branch_RNN_layer_1_type: GRU
# base_features_branch_hp_units_at_hp_layer_1: 128
# base_features_branch_recurrent_dropout_1: 0.1
# close_features_branch_hp_layers: 4
# close_features_branch_RNN_layer_0_type: LSTM
# close_features_branch_hp_units_at_hp_layer_0: 64
# close_features_branch_recurrent_dropout_0: 0.30000000000000004
# close_features_branch_RNN_layer_1_type: GRU
# close_features_branch_hp_units_at_hp_layer_1: 64
# close_features_branch_recurrent_dropout_1: 0.30000000000000004
# high_low_features_branch_hp_layers: 2
# high_low_features_branch_RNN_layer_0_type: LSTM
# high_low_features_branch_hp_units_at_hp_layer_0: 64
# high_low_features_branch_recurrent_dropout_0: 0.2
# high_low_features_branch_RNN_layer_1_type: SimpleRNN
# high_low_features_branch_hp_units_at_hp_layer_1: 128
# high_low_features_branch_recurrent_dropout_1: 0.1
# volume_features_branch_hp_layers: 2
# volume_features_branch_RNN_layer_0_type: SimpleRNN
# volume_features_branch_hp_units_at_hp_layer_0: 128
# volume_features_branch_recurrent_dropout_0: 0.2
# volume_features_branch_RNN_layer_1_type: LSTM
# volume_features_branch_hp_units_at_hp_layer_1: 64
# volume_features_branch_recurrent_dropout_1: 0.0
# optimizer_type: RMSprop
# learning_rate: 0.002254230657048051
# all_features_branch_RNN_layer_2_type: SimpleRNN
# all_features_branch_hp_units_at_hp_layer_2: 64
# all_features_branch_recurrent_dropout_2: 0.30000000000000004
# all_features_branch_RNN_layer_3_type: SimpleRNN
# all_features_branch_hp_units_at_hp_layer_3: 64
# all_features_branch_recurrent_dropout_3: 0.30000000000000004
# close_features_branch_RNN_layer_2_type: GRU
# close_features_branch_hp_units_at_hp_layer_2: 128
# close_features_branch_recurrent_dropout_2: 0.0
# close_features_branch_RNN_layer_3_type: GRU
# close_features_branch_hp_units_at_hp_layer_3: 64
# close_features_branch_recurrent_dropout_3: 0.1
# high_low_features_branch_RNN_layer_2_type: SimpleRNN
# high_low_features_branch_hp_units_at_hp_layer_2: 64
# high_low_features_branch_recurrent_dropout_2: 0.0
# high_low_features_branch_RNN_layer_3_type: LSTM
# high_low_features_branch_hp_units_at_hp_layer_3: 128
# high_low_features_branch_recurrent_dropout_3: 0.2
# volume_features_branch_RNN_layer_2_type: SimpleRNN
# volume_features_branch_hp_units_at_hp_layer_2: 128
# volume_features_branch_recurrent_dropout_2: 0.0
# volume_features_branch_RNN_layer_3_type: SimpleRNN
# volume_features_branch_hp_units_at_hp_layer_3: 128
# volume_features_branch_recurrent_dropout_3: 0.0
# batch_size: 32
# base_features_branch_RNN_layer_2_type: GRU
# base_features_branch_hp_units_at_hp_layer_2: 128
# base_features_branch_recurrent_dropout_2: 0.1
# base_features_branch_RNN_layer_3_type: LSTM
# base_features_branch_hp_units_at_hp_layer_3: 128
# base_features_branch_recurrent_dropout_3: 0.1
# tuner/epochs: 10
# tuner/initial_epoch: 0
# tuner/bracket: 0
# tuner/round: 0
# Score: 0.6000000238418579
#
# Trial 0006 summary
# Hyperparameters:
# all_features_branch_hp_layers: 4
# all_features_branch_RNN_layer_0_type: LSTM
# all_features_branch_hp_units_at_hp_layer_0: 64
# all_features_branch_recurrent_dropout_0: 0.4
# all_features_branch_RNN_layer_1_type: LSTM
# all_features_branch_hp_units_at_hp_layer_1: 128
# all_features_branch_recurrent_dropout_1: 0.4
# base_features_branch_hp_layers: 4
# base_features_branch_RNN_layer_0_type: LSTM
# base_features_branch_hp_units_at_hp_layer_0: 128
# base_features_branch_recurrent_dropout_0: 0.2
# base_features_branch_RNN_layer_1_type: LSTM
# base_features_branch_hp_units_at_hp_layer_1: 128
# base_features_branch_recurrent_dropout_1: 0.0
# close_features_branch_hp_layers: 2
# close_features_branch_RNN_layer_0_type: GRU
# close_features_branch_hp_units_at_hp_layer_0: 64
# close_features_branch_recurrent_dropout_0: 0.4
# close_features_branch_RNN_layer_1_type: GRU
# close_features_branch_hp_units_at_hp_layer_1: 64
# close_features_branch_recurrent_dropout_1: 0.4
# high_low_features_branch_hp_layers: 4
# high_low_features_branch_RNN_layer_0_type: LSTM
# high_low_features_branch_hp_units_at_hp_layer_0: 128
# high_low_features_branch_recurrent_dropout_0: 0.30000000000000004
# high_low_features_branch_RNN_layer_1_type: SimpleRNN
# high_low_features_branch_hp_units_at_hp_layer_1: 64
# high_low_features_branch_recurrent_dropout_1: 0.0
# volume_features_branch_hp_layers: 4
# volume_features_branch_RNN_layer_0_type: LSTM
# volume_features_branch_hp_units_at_hp_layer_0: 128
# volume_features_branch_recurrent_dropout_0: 0.0
# volume_features_branch_RNN_layer_1_type: LSTM
# volume_features_branch_hp_units_at_hp_layer_1: 64
# volume_features_branch_recurrent_dropout_1: 0.30000000000000004
# optimizer_type: RMSprop
# learning_rate: 0.0012124065560207727
# all_features_branch_RNN_layer_2_type: GRU
# all_features_branch_hp_units_at_hp_layer_2: 128
# all_features_branch_recurrent_dropout_2: 0.0
# all_features_branch_RNN_layer_3_type: SimpleRNN
# all_features_branch_hp_units_at_hp_layer_3: 64
# all_features_branch_recurrent_dropout_3: 0.1
# close_features_branch_RNN_layer_2_type: SimpleRNN
# close_features_branch_hp_units_at_hp_layer_2: 128
# close_features_branch_recurrent_dropout_2: 0.4
# close_features_branch_RNN_layer_3_type: GRU
# close_features_branch_hp_units_at_hp_layer_3: 128
# close_features_branch_recurrent_dropout_3: 0.4
# high_low_features_branch_RNN_layer_2_type: SimpleRNN
# high_low_features_branch_hp_units_at_hp_layer_2: 64
# high_low_features_branch_recurrent_dropout_2: 0.4
# high_low_features_branch_RNN_layer_3_type: SimpleRNN
# high_low_features_branch_hp_units_at_hp_layer_3: 128
# high_low_features_branch_recurrent_dropout_3: 0.4
# volume_features_branch_RNN_layer_2_type: GRU
# volume_features_branch_hp_units_at_hp_layer_2: 128
# volume_features_branch_recurrent_dropout_2: 0.30000000000000004
# volume_features_branch_RNN_layer_3_type: GRU
# volume_features_branch_hp_units_at_hp_layer_3: 128
# volume_features_branch_recurrent_dropout_3: 0.1
# batch_size: 32
# base_features_branch_RNN_layer_2_type: LSTM
# base_features_branch_hp_units_at_hp_layer_2: 64
# base_features_branch_recurrent_dropout_2: 0.30000000000000004
# base_features_branch_RNN_layer_3_type: GRU
# base_features_branch_hp_units_at_hp_layer_3: 64
# base_features_branch_recurrent_dropout_3: 0.1
# tuner/epochs: 2
# tuner/initial_epoch: 0
# tuner/bracket: 2
# tuner/round: 0
# Score: 0.5894736647605896
#
# Trial 0007 summary
# Hyperparameters:
# all_features_branch_hp_layers: 4
# all_features_branch_RNN_layer_0_type: LSTM
# all_features_branch_hp_units_at_hp_layer_0: 64
# all_features_branch_recurrent_dropout_0: 0.4
# all_features_branch_RNN_layer_1_type: LSTM
# all_features_branch_hp_units_at_hp_layer_1: 64
# all_features_branch_recurrent_dropout_1: 0.0
# base_features_branch_hp_layers: 2
# base_features_branch_RNN_layer_0_type: GRU
# base_features_branch_hp_units_at_hp_layer_0: 128
# base_features_branch_recurrent_dropout_0: 0.4
# base_features_branch_RNN_layer_1_type: LSTM
# base_features_branch_hp_units_at_hp_layer_1: 64
# base_features_branch_recurrent_dropout_1: 0.2
# close_features_branch_hp_layers: 4
# close_features_branch_RNN_layer_0_type: SimpleRNN
# close_features_branch_hp_units_at_hp_layer_0: 128
# close_features_branch_recurrent_dropout_0: 0.0
# close_features_branch_RNN_layer_1_type: GRU
# close_features_branch_hp_units_at_hp_layer_1: 64
# close_features_branch_recurrent_dropout_1: 0.30000000000000004
# high_low_features_branch_hp_layers: 4
# high_low_features_branch_RNN_layer_0_type: GRU
# high_low_features_branch_hp_units_at_hp_layer_0: 128
# high_low_features_branch_recurrent_dropout_0: 0.4
# high_low_features_branch_RNN_layer_1_type: GRU
# high_low_features_branch_hp_units_at_hp_layer_1: 128
# high_low_features_branch_recurrent_dropout_1: 0.0
# volume_features_branch_hp_layers: 2
# volume_features_branch_RNN_layer_0_type: LSTM
# volume_features_branch_hp_units_at_hp_layer_0: 64
# volume_features_branch_recurrent_dropout_0: 0.0
# volume_features_branch_RNN_layer_1_type: GRU
# volume_features_branch_hp_units_at_hp_layer_1: 128
# volume_features_branch_recurrent_dropout_1: 0.1
# optimizer_type: Adam
# learning_rate: 0.003378131836989523
# all_features_branch_RNN_layer_2_type: LSTM
# all_features_branch_hp_units_at_hp_layer_2: 128
# all_features_branch_recurrent_dropout_2: 0.1
# all_features_branch_RNN_layer_3_type: LSTM
# all_features_branch_hp_units_at_hp_layer_3: 128
# all_features_branch_recurrent_dropout_3: 0.1
# close_features_branch_RNN_layer_2_type: LSTM
# close_features_branch_hp_units_at_hp_layer_2: 128
# close_features_branch_recurrent_dropout_2: 0.0
# close_features_branch_RNN_layer_3_type: GRU
# close_features_branch_hp_units_at_hp_layer_3: 128
# close_features_branch_recurrent_dropout_3: 0.30000000000000004
# high_low_features_branch_RNN_layer_2_type: SimpleRNN
# high_low_features_branch_hp_units_at_hp_layer_2: 64
# high_low_features_branch_recurrent_dropout_2: 0.2
# high_low_features_branch_RNN_layer_3_type: SimpleRNN
# high_low_features_branch_hp_units_at_hp_layer_3: 128
# high_low_features_branch_recurrent_dropout_3: 0.0
# volume_features_branch_RNN_layer_2_type: GRU
# volume_features_branch_hp_units_at_hp_layer_2: 64
# volume_features_branch_recurrent_dropout_2: 0.0
# volume_features_branch_RNN_layer_3_type: GRU
# volume_features_branch_hp_units_at_hp_layer_3: 128
# volume_features_branch_recurrent_dropout_3: 0.4
# batch_size: 32
# base_features_branch_RNN_layer_2_type: LSTM
# base_features_branch_hp_units_at_hp_layer_2: 64
# base_features_branch_recurrent_dropout_2: 0.0
# base_features_branch_RNN_layer_3_type: SimpleRNN
# base_features_branch_hp_units_at_hp_layer_3: 128
# base_features_branch_recurrent_dropout_3: 0.30000000000000004
# tuner/epochs: 2
# tuner/initial_epoch: 0
# tuner/bracket: 2
# tuner/round: 0
# Score: 0.5894736647605896
#
# Trial 0011 summary
# Hyperparameters:
# all_features_branch_hp_layers: 2
# all_features_branch_RNN_layer_0_type: GRU
# all_features_branch_hp_units_at_hp_layer_0: 128
# all_features_branch_recurrent_dropout_0: 0.4
# all_features_branch_RNN_layer_1_type: SimpleRNN
# all_features_branch_hp_units_at_hp_layer_1: 64
# all_features_branch_recurrent_dropout_1: 0.2
# base_features_branch_hp_layers: 2
# base_features_branch_RNN_layer_0_type: SimpleRNN
# base_features_branch_hp_units_at_hp_layer_0: 128
# base_features_branch_recurrent_dropout_0: 0.4
# base_features_branch_RNN_layer_1_type: LSTM
# base_features_branch_hp_units_at_hp_layer_1: 128
# base_features_branch_recurrent_dropout_1: 0.1
# close_features_branch_hp_layers: 4
# close_features_branch_RNN_layer_0_type: LSTM
# close_features_branch_hp_units_at_hp_layer_0: 64
# close_features_branch_recurrent_dropout_0: 0.1
# close_features_branch_RNN_layer_1_type: SimpleRNN
# close_features_branch_hp_units_at_hp_layer_1: 64
# close_features_branch_recurrent_dropout_1: 0.30000000000000004
# high_low_features_branch_hp_layers: 4
# high_low_features_branch_RNN_layer_0_type: SimpleRNN
# high_low_features_branch_hp_units_at_hp_layer_0: 128
# high_low_features_branch_recurrent_dropout_0: 0.2
# high_low_features_branch_RNN_layer_1_type: LSTM
# high_low_features_branch_hp_units_at_hp_layer_1: 128
# high_low_features_branch_recurrent_dropout_1: 0.30000000000000004
# volume_features_branch_hp_layers: 2
# volume_features_branch_RNN_layer_0_type: LSTM
# volume_features_branch_hp_units_at_hp_layer_0: 128
# volume_features_branch_recurrent_dropout_0: 0.30000000000000004
# volume_features_branch_RNN_layer_1_type: LSTM
# volume_features_branch_hp_units_at_hp_layer_1: 64
# volume_features_branch_recurrent_dropout_1: 0.0
# optimizer_type: RMSprop
# learning_rate: 0.004787239377037189
# all_features_branch_RNN_layer_2_type: SimpleRNN
# all_features_branch_hp_units_at_hp_layer_2: 128
# all_features_branch_recurrent_dropout_2: 0.2
# all_features_branch_RNN_layer_3_type: GRU
# all_features_branch_hp_units_at_hp_layer_3: 64
# all_features_branch_recurrent_dropout_3: 0.4
# close_features_branch_RNN_layer_2_type: SimpleRNN
# close_features_branch_hp_units_at_hp_layer_2: 64
# close_features_branch_recurrent_dropout_2: 0.4
# close_features_branch_RNN_layer_3_type: LSTM
# close_features_branch_hp_units_at_hp_layer_3: 128
# close_features_branch_recurrent_dropout_3: 0.0
# high_low_features_branch_RNN_layer_2_type: GRU
# high_low_features_branch_hp_units_at_hp_layer_2: 128
# high_low_features_branch_recurrent_dropout_2: 0.2
# high_low_features_branch_RNN_layer_3_type: SimpleRNN
# high_low_features_branch_hp_units_at_hp_layer_3: 64
# high_low_features_branch_recurrent_dropout_3: 0.4
# volume_features_branch_RNN_layer_2_type: GRU
# volume_features_branch_hp_units_at_hp_layer_2: 64
# volume_features_branch_recurrent_dropout_2: 0.2
# volume_features_branch_RNN_layer_3_type: SimpleRNN
# volume_features_branch_hp_units_at_hp_layer_3: 64
# volume_features_branch_recurrent_dropout_3: 0.2
# batch_size: 32
# base_features_branch_RNN_layer_2_type: LSTM
# base_features_branch_hp_units_at_hp_layer_2: 128
# base_features_branch_recurrent_dropout_2: 0.30000000000000004
# base_features_branch_RNN_layer_3_type: SimpleRNN
# base_features_branch_hp_units_at_hp_layer_3: 128
# base_features_branch_recurrent_dropout_3: 0.0
# tuner/epochs: 2
# tuner/initial_epoch: 0
# tuner/bracket: 2
# tuner/round: 0
# Score: 0.5894736647605896
#
# Trial 0015 summary
# Hyperparameters:
# all_features_branch_hp_layers: 4
# all_features_branch_RNN_layer_0_type: LSTM
# all_features_branch_hp_units_at_hp_layer_0: 64
# all_features_branch_recurrent_dropout_0: 0.4
# all_features_branch_RNN_layer_1_type: LSTM
# all_features_branch_hp_units_at_hp_layer_1: 64
# all_features_branch_recurrent_dropout_1: 0.0
# base_features_branch_hp_layers: 2
# base_features_branch_RNN_layer_0_type: GRU
# base_features_branch_hp_units_at_hp_layer_0: 128
# base_features_branch_recurrent_dropout_0: 0.4
# base_features_branch_RNN_layer_1_type: LSTM
# base_features_branch_hp_units_at_hp_layer_1: 64
# base_features_branch_recurrent_dropout_1: 0.2
# close_features_branch_hp_layers: 4
# close_features_branch_RNN_layer_0_type: SimpleRNN
# close_features_branch_hp_units_at_hp_layer_0: 128
# close_features_branch_recurrent_dropout_0: 0.0
# close_features_branch_RNN_layer_1_type: GRU
# close_features_branch_hp_units_at_hp_layer_1: 64
# close_features_branch_recurrent_dropout_1: 0.30000000000000004
# high_low_features_branch_hp_layers: 4
# high_low_features_branch_RNN_layer_0_type: GRU
# high_low_features_branch_hp_units_at_hp_layer_0: 128
# high_low_features_branch_recurrent_dropout_0: 0.4
# high_low_features_branch_RNN_layer_1_type: GRU
# high_low_features_branch_hp_units_at_hp_layer_1: 128
# high_low_features_branch_recurrent_dropout_1: 0.0
# volume_features_branch_hp_layers: 2
# volume_features_branch_RNN_layer_0_type: LSTM
# volume_features_branch_hp_units_at_hp_layer_0: 64
# volume_features_branch_recurrent_dropout_0: 0.0
# volume_features_branch_RNN_layer_1_type: GRU
# volume_features_branch_hp_units_at_hp_layer_1: 128
# volume_features_branch_recurrent_dropout_1: 0.1
# optimizer_type: Adam
# learning_rate: 0.003378131836989523
# all_features_branch_RNN_layer_2_type: LSTM
# all_features_branch_hp_units_at_hp_layer_2: 128
# all_features_branch_recurrent_dropout_2: 0.1
# all_features_branch_RNN_layer_3_type: LSTM
# all_features_branch_hp_units_at_hp_layer_3: 128
# all_features_branch_recurrent_dropout_3: 0.1
# close_features_branch_RNN_layer_2_type: LSTM
# close_features_branch_hp_units_at_hp_layer_2: 128
# close_features_branch_recurrent_dropout_2: 0.0
# close_features_branch_RNN_layer_3_type: GRU
# close_features_branch_hp_units_at_hp_layer_3: 128
# close_features_branch_recurrent_dropout_3: 0.30000000000000004
# high_low_features_branch_RNN_layer_2_type: SimpleRNN
# high_low_features_branch_hp_units_at_hp_layer_2: 64
# high_low_features_branch_recurrent_dropout_2: 0.2
# high_low_features_branch_RNN_layer_3_type: SimpleRNN
# high_low_features_branch_hp_units_at_hp_layer_3: 128
# high_low_features_branch_recurrent_dropout_3: 0.0
# volume_features_branch_RNN_layer_2_type: GRU
# volume_features_branch_hp_units_at_hp_layer_2: 64
# volume_features_branch_recurrent_dropout_2: 0.0
# volume_features_branch_RNN_layer_3_type: GRU
# volume_features_branch_hp_units_at_hp_layer_3: 128
# volume_features_branch_recurrent_dropout_3: 0.4
# batch_size: 32
# base_features_branch_RNN_layer_2_type: LSTM
# base_features_branch_hp_units_at_hp_layer_2: 64
# base_features_branch_recurrent_dropout_2: 0.0
# base_features_branch_RNN_layer_3_type: SimpleRNN
# base_features_branch_hp_units_at_hp_layer_3: 128
# base_features_branch_recurrent_dropout_3: 0.30000000000000004
# tuner/epochs: 4
# tuner/initial_epoch: 2
# tuner/bracket: 2
# tuner/round: 1
# tuner/trial_id: 0007
# Score: 0.5894736647605896
#
# Trial 0017 summary
# Hyperparameters:
# all_features_branch_hp_layers: 2
# all_features_branch_RNN_layer_0_type: SimpleRNN
# all_features_branch_hp_units_at_hp_layer_0: 128
# all_features_branch_recurrent_dropout_0: 0.2
# all_features_branch_RNN_layer_1_type: LSTM
# all_features_branch_hp_units_at_hp_layer_1: 128
# all_features_branch_recurrent_dropout_1: 0.2
# base_features_branch_hp_layers: 4
# base_features_branch_RNN_layer_0_type: SimpleRNN
# base_features_branch_hp_units_at_hp_layer_0: 128
# base_features_branch_recurrent_dropout_0: 0.2
# base_features_branch_RNN_layer_1_type: SimpleRNN
# base_features_branch_hp_units_at_hp_layer_1: 128
# base_features_branch_recurrent_dropout_1: 0.30000000000000004
# close_features_branch_hp_layers: 4
# close_features_branch_RNN_layer_0_type: GRU
# close_features_branch_hp_units_at_hp_layer_0: 64
# close_features_branch_recurrent_dropout_0: 0.2
# close_features_branch_RNN_layer_1_type: LSTM
# close_features_branch_hp_units_at_hp_layer_1: 128
# close_features_branch_recurrent_dropout_1: 0.30000000000000004
# high_low_features_branch_hp_layers: 2
# high_low_features_branch_RNN_layer_0_type: SimpleRNN
# high_low_features_branch_hp_units_at_hp_layer_0: 128
# high_low_features_branch_recurrent_dropout_0: 0.0
# high_low_features_branch_RNN_layer_1_type: LSTM
# high_low_features_branch_hp_units_at_hp_layer_1: 64
# high_low_features_branch_recurrent_dropout_1: 0.0
# volume_features_branch_hp_layers: 2
# volume_features_branch_RNN_layer_0_type: SimpleRNN
# volume_features_branch_hp_units_at_hp_layer_0: 128
# volume_features_branch_recurrent_dropout_0: 0.1
# volume_features_branch_RNN_layer_1_type: GRU
# volume_features_branch_hp_units_at_hp_layer_1: 128
# volume_features_branch_recurrent_dropout_1: 0.1
# optimizer_type: Adam
# learning_rate: 0.00405701014195834
# all_features_branch_RNN_layer_2_type: LSTM
# all_features_branch_hp_units_at_hp_layer_2: 64
# all_features_branch_recurrent_dropout_2: 0.4
# all_features_branch_RNN_layer_3_type: GRU
# all_features_branch_hp_units_at_hp_layer_3: 128
# all_features_branch_recurrent_dropout_3: 0.0
# close_features_branch_RNN_layer_2_type: LSTM
# close_features_branch_hp_units_at_hp_layer_2: 64
# close_features_branch_recurrent_dropout_2: 0.0
# close_features_branch_RNN_layer_3_type: SimpleRNN
# close_features_branch_hp_units_at_hp_layer_3: 128
# close_features_branch_recurrent_dropout_3: 0.1
# high_low_features_branch_RNN_layer_2_type: LSTM
# high_low_features_branch_hp_units_at_hp_layer_2: 128
# high_low_features_branch_recurrent_dropout_2: 0.2
# high_low_features_branch_RNN_layer_3_type: SimpleRNN
# high_low_features_branch_hp_units_at_hp_layer_3: 128
# high_low_features_branch_recurrent_dropout_3: 0.1
# volume_features_branch_RNN_layer_2_type: LSTM
# volume_features_branch_hp_units_at_hp_layer_2: 128
# volume_features_branch_recurrent_dropout_2: 0.2
# volume_features_branch_RNN_layer_3_type: LSTM
# volume_features_branch_hp_units_at_hp_layer_3: 128
# volume_features_branch_recurrent_dropout_3: 0.0
# batch_size: 32
# tuner/epochs: 10
# tuner/initial_epoch: 4
# tuner/bracket: 2
# tuner/round: 2
# base_features_branch_RNN_layer_2_type: SimpleRNN
# base_features_branch_hp_units_at_hp_layer_2: 64
# base_features_branch_recurrent_dropout_2: 0.0
# base_features_branch_RNN_layer_3_type: SimpleRNN
# base_features_branch_hp_units_at_hp_layer_3: 64
# base_features_branch_recurrent_dropout_3: 0.0
# tuner/trial_id: 0013
# Score: 0.5894736647605896
# Best epoch: 10
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step
# training for the PFE model was done in: 0:20:21.498720
# C:\Users\ammaroAsus\anaconda3\Lib\site-packages\keras\src\saving\saving_lib.py:415: UserWarning: Skipping variable loading for optimizer 'rmsprop', because it has 2 variables whereas the saved optimizer has 52 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# C:\Users\ammaroAsus\anaconda3\Lib\site-packages\keras\src\saving\saving_lib.py:415: UserWarning: Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 114 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# Results summary
# Results in keras_tuner_models\hp_RNN_inception_model_archive3/ROP
# Showing 10 best trials
# Objective(name="val_accuracy", direction="max")
#
# Trial 0018 summary
# Hyperparameters:
# all_features_branch_hp_layers: 4
# all_features_branch_RNN_layer_0_type: GRU
# all_features_branch_hp_units_at_hp_layer_0: 128
# all_features_branch_recurrent_dropout_0: 0.2
# all_features_branch_RNN_layer_1_type: GRU
# all_features_branch_hp_units_at_hp_layer_1: 64
# all_features_branch_recurrent_dropout_1: 0.0
# base_features_branch_hp_layers: 2
# base_features_branch_RNN_layer_0_type: SimpleRNN
# base_features_branch_hp_units_at_hp_layer_0: 128
# base_features_branch_recurrent_dropout_0: 0.0
# base_features_branch_RNN_layer_1_type: GRU
# base_features_branch_hp_units_at_hp_layer_1: 64
# base_features_branch_recurrent_dropout_1: 0.2
# close_features_branch_hp_layers: 2
# close_features_branch_RNN_layer_0_type: LSTM
# close_features_branch_hp_units_at_hp_layer_0: 64
# close_features_branch_recurrent_dropout_0: 0.0
# close_features_branch_RNN_layer_1_type: LSTM
# close_features_branch_hp_units_at_hp_layer_1: 128
# close_features_branch_recurrent_dropout_1: 0.4
# high_low_features_branch_hp_layers: 2
# high_low_features_branch_RNN_layer_0_type: GRU
# high_low_features_branch_hp_units_at_hp_layer_0: 64
# high_low_features_branch_recurrent_dropout_0: 0.30000000000000004
# high_low_features_branch_RNN_layer_1_type: GRU
# high_low_features_branch_hp_units_at_hp_layer_1: 64
# high_low_features_branch_recurrent_dropout_1: 0.30000000000000004
# volume_features_branch_hp_layers: 4
# volume_features_branch_RNN_layer_0_type: SimpleRNN
# volume_features_branch_hp_units_at_hp_layer_0: 128
# volume_features_branch_recurrent_dropout_0: 0.2
# volume_features_branch_RNN_layer_1_type: LSTM
# volume_features_branch_hp_units_at_hp_layer_1: 64
# volume_features_branch_recurrent_dropout_1: 0.0
# optimizer_type: Adam
# learning_rate: 0.0023397247740777317
# all_features_branch_RNN_layer_2_type: GRU
# all_features_branch_hp_units_at_hp_layer_2: 128
# all_features_branch_recurrent_dropout_2: 0.30000000000000004
# all_features_branch_RNN_layer_3_type: LSTM
# all_features_branch_hp_units_at_hp_layer_3: 128
# all_features_branch_recurrent_dropout_3: 0.0
# close_features_branch_RNN_layer_2_type: GRU
# close_features_branch_hp_units_at_hp_layer_2: 128
# close_features_branch_recurrent_dropout_2: 0.4
# close_features_branch_RNN_layer_3_type: LSTM
# close_features_branch_hp_units_at_hp_layer_3: 128
# close_features_branch_recurrent_dropout_3: 0.1
# high_low_features_branch_RNN_layer_2_type: SimpleRNN
# high_low_features_branch_hp_units_at_hp_layer_2: 128
# high_low_features_branch_recurrent_dropout_2: 0.4
# high_low_features_branch_RNN_layer_3_type: LSTM
# high_low_features_branch_hp_units_at_hp_layer_3: 128
# high_low_features_branch_recurrent_dropout_3: 0.2
# volume_features_branch_RNN_layer_2_type: GRU
# volume_features_branch_hp_units_at_hp_layer_2: 64
# volume_features_branch_recurrent_dropout_2: 0.2
# volume_features_branch_RNN_layer_3_type: LSTM
# volume_features_branch_hp_units_at_hp_layer_3: 128
# volume_features_branch_recurrent_dropout_3: 0.1
# batch_size: 32
# base_features_branch_RNN_layer_2_type: GRU
# base_features_branch_hp_units_at_hp_layer_2: 128
# base_features_branch_recurrent_dropout_2: 0.0
# base_features_branch_RNN_layer_3_type: LSTM
# base_features_branch_hp_units_at_hp_layer_3: 64
# base_features_branch_recurrent_dropout_3: 0.0
# tuner/epochs: 4
# tuner/initial_epoch: 0
# tuner/bracket: 1
# tuner/round: 0
# Score: 0.5729166865348816
#
# Trial 0027 summary
# Hyperparameters:
# all_features_branch_hp_layers: 2
# all_features_branch_RNN_layer_0_type: GRU
# all_features_branch_hp_units_at_hp_layer_0: 64
# all_features_branch_recurrent_dropout_0: 0.4
# all_features_branch_RNN_layer_1_type: GRU
# all_features_branch_hp_units_at_hp_layer_1: 64
# all_features_branch_recurrent_dropout_1: 0.4
# base_features_branch_hp_layers: 2
# base_features_branch_RNN_layer_0_type: GRU
# base_features_branch_hp_units_at_hp_layer_0: 128
# base_features_branch_recurrent_dropout_0: 0.2
# base_features_branch_RNN_layer_1_type: LSTM
# base_features_branch_hp_units_at_hp_layer_1: 64
# base_features_branch_recurrent_dropout_1: 0.2
# close_features_branch_hp_layers: 4
# close_features_branch_RNN_layer_0_type: GRU
# close_features_branch_hp_units_at_hp_layer_0: 128
# close_features_branch_recurrent_dropout_0: 0.0
# close_features_branch_RNN_layer_1_type: SimpleRNN
# close_features_branch_hp_units_at_hp_layer_1: 64
# close_features_branch_recurrent_dropout_1: 0.2
# high_low_features_branch_hp_layers: 2
# high_low_features_branch_RNN_layer_0_type: SimpleRNN
# high_low_features_branch_hp_units_at_hp_layer_0: 128
# high_low_features_branch_recurrent_dropout_0: 0.30000000000000004
# high_low_features_branch_RNN_layer_1_type: GRU
# high_low_features_branch_hp_units_at_hp_layer_1: 128
# high_low_features_branch_recurrent_dropout_1: 0.0
# volume_features_branch_hp_layers: 4
# volume_features_branch_RNN_layer_0_type: SimpleRNN
# volume_features_branch_hp_units_at_hp_layer_0: 128
# volume_features_branch_recurrent_dropout_0: 0.4
# volume_features_branch_RNN_layer_1_type: LSTM
# volume_features_branch_hp_units_at_hp_layer_1: 64
# volume_features_branch_recurrent_dropout_1: 0.0
# optimizer_type: Adam
# learning_rate: 0.00033280672177041687
# all_features_branch_RNN_layer_2_type: LSTM
# all_features_branch_hp_units_at_hp_layer_2: 64
# all_features_branch_recurrent_dropout_2: 0.30000000000000004
# all_features_branch_RNN_layer_3_type: SimpleRNN
# all_features_branch_hp_units_at_hp_layer_3: 64
# all_features_branch_recurrent_dropout_3: 0.1
# close_features_branch_RNN_layer_2_type: LSTM
# close_features_branch_hp_units_at_hp_layer_2: 64
# close_features_branch_recurrent_dropout_2: 0.30000000000000004
# close_features_branch_RNN_layer_3_type: LSTM
# close_features_branch_hp_units_at_hp_layer_3: 64
# close_features_branch_recurrent_dropout_3: 0.30000000000000004
# high_low_features_branch_RNN_layer_2_type: LSTM
# high_low_features_branch_hp_units_at_hp_layer_2: 128
# high_low_features_branch_recurrent_dropout_2: 0.0
# high_low_features_branch_RNN_layer_3_type: LSTM
# high_low_features_branch_hp_units_at_hp_layer_3: 64
# high_low_features_branch_recurrent_dropout_3: 0.1
# volume_features_branch_RNN_layer_2_type: GRU
# volume_features_branch_hp_units_at_hp_layer_2: 128
# volume_features_branch_recurrent_dropout_2: 0.2
# volume_features_branch_RNN_layer_3_type: GRU
# volume_features_branch_hp_units_at_hp_layer_3: 128
# volume_features_branch_recurrent_dropout_3: 0.0
# batch_size: 32
# base_features_branch_RNN_layer_2_type: GRU
# base_features_branch_hp_units_at_hp_layer_2: 128
# base_features_branch_recurrent_dropout_2: 0.4
# base_features_branch_RNN_layer_3_type: SimpleRNN
# base_features_branch_hp_units_at_hp_layer_3: 64
# base_features_branch_recurrent_dropout_3: 0.4
# tuner/epochs: 10
# tuner/initial_epoch: 0
# tuner/bracket: 0
# tuner/round: 0
# Score: 0.5625
#
# Trial 0001 summary
# Hyperparameters:
# all_features_branch_hp_layers: 2
# all_features_branch_RNN_layer_0_type: SimpleRNN
# all_features_branch_hp_units_at_hp_layer_0: 128
# all_features_branch_recurrent_dropout_0: 0.2
# all_features_branch_RNN_layer_1_type: LSTM
# all_features_branch_hp_units_at_hp_layer_1: 128
# all_features_branch_recurrent_dropout_1: 0.2
# base_features_branch_hp_layers: 4
# base_features_branch_RNN_layer_0_type: SimpleRNN
# base_features_branch_hp_units_at_hp_layer_0: 128
# base_features_branch_recurrent_dropout_0: 0.2
# base_features_branch_RNN_layer_1_type: SimpleRNN
# base_features_branch_hp_units_at_hp_layer_1: 128
# base_features_branch_recurrent_dropout_1: 0.30000000000000004
# close_features_branch_hp_layers: 4
# close_features_branch_RNN_layer_0_type: GRU
# close_features_branch_hp_units_at_hp_layer_0: 64
# close_features_branch_recurrent_dropout_0: 0.2
# close_features_branch_RNN_layer_1_type: LSTM
# close_features_branch_hp_units_at_hp_layer_1: 128
# close_features_branch_recurrent_dropout_1: 0.30000000000000004
# high_low_features_branch_hp_layers: 2
# high_low_features_branch_RNN_layer_0_type: SimpleRNN
# high_low_features_branch_hp_units_at_hp_layer_0: 128
# high_low_features_branch_recurrent_dropout_0: 0.0
# high_low_features_branch_RNN_layer_1_type: LSTM
# high_low_features_branch_hp_units_at_hp_layer_1: 64
# high_low_features_branch_recurrent_dropout_1: 0.0
# volume_features_branch_hp_layers: 2
# volume_features_branch_RNN_layer_0_type: SimpleRNN
# volume_features_branch_hp_units_at_hp_layer_0: 128
# volume_features_branch_recurrent_dropout_0: 0.1
# volume_features_branch_RNN_layer_1_type: GRU
# volume_features_branch_hp_units_at_hp_layer_1: 128
# volume_features_branch_recurrent_dropout_1: 0.1
# optimizer_type: Adam
# learning_rate: 0.00405701014195834
# all_features_branch_RNN_layer_2_type: LSTM
# all_features_branch_hp_units_at_hp_layer_2: 64
# all_features_branch_recurrent_dropout_2: 0.4
# all_features_branch_RNN_layer_3_type: GRU
# all_features_branch_hp_units_at_hp_layer_3: 128
# all_features_branch_recurrent_dropout_3: 0.0
# close_features_branch_RNN_layer_2_type: LSTM
# close_features_branch_hp_units_at_hp_layer_2: 64
# close_features_branch_recurrent_dropout_2: 0.0
# close_features_branch_RNN_layer_3_type: SimpleRNN
# close_features_branch_hp_units_at_hp_layer_3: 128
# close_features_branch_recurrent_dropout_3: 0.1
# high_low_features_branch_RNN_layer_2_type: LSTM
# high_low_features_branch_hp_units_at_hp_layer_2: 128
# high_low_features_branch_recurrent_dropout_2: 0.2
# high_low_features_branch_RNN_layer_3_type: SimpleRNN
# high_low_features_branch_hp_units_at_hp_layer_3: 128
# high_low_features_branch_recurrent_dropout_3: 0.1
# volume_features_branch_RNN_layer_2_type: LSTM
# volume_features_branch_hp_units_at_hp_layer_2: 128
# volume_features_branch_recurrent_dropout_2: 0.2
# volume_features_branch_RNN_layer_3_type: LSTM
# volume_features_branch_hp_units_at_hp_layer_3: 128
# volume_features_branch_recurrent_dropout_3: 0.0
# batch_size: 32
# tuner/epochs: 2
# tuner/initial_epoch: 0
# tuner/bracket: 2
# tuner/round: 0
# base_features_branch_RNN_layer_2_type: SimpleRNN
# base_features_branch_hp_units_at_hp_layer_2: 64
# base_features_branch_recurrent_dropout_2: 0.0
# base_features_branch_RNN_layer_3_type: SimpleRNN
# base_features_branch_hp_units_at_hp_layer_3: 64
# base_features_branch_recurrent_dropout_3: 0.0
# Score: 0.5520833134651184
#
# Trial 0002 summary
# Hyperparameters:
# all_features_branch_hp_layers: 2
# all_features_branch_RNN_layer_0_type: SimpleRNN
# all_features_branch_hp_units_at_hp_layer_0: 128
# all_features_branch_recurrent_dropout_0: 0.0
# all_features_branch_RNN_layer_1_type: LSTM
# all_features_branch_hp_units_at_hp_layer_1: 64
# all_features_branch_recurrent_dropout_1: 0.0
# base_features_branch_hp_layers: 4
# base_features_branch_RNN_layer_0_type: SimpleRNN
# base_features_branch_hp_units_at_hp_layer_0: 128
# base_features_branch_recurrent_dropout_0: 0.1
# base_features_branch_RNN_layer_1_type: LSTM
# base_features_branch_hp_units_at_hp_layer_1: 64
# base_features_branch_recurrent_dropout_1: 0.0
# close_features_branch_hp_layers: 4
# close_features_branch_RNN_layer_0_type: SimpleRNN
# close_features_branch_hp_units_at_hp_layer_0: 128
# close_features_branch_recurrent_dropout_0: 0.4
# close_features_branch_RNN_layer_1_type: SimpleRNN
# close_features_branch_hp_units_at_hp_layer_1: 128
# close_features_branch_recurrent_dropout_1: 0.30000000000000004
# high_low_features_branch_hp_layers: 2
# high_low_features_branch_RNN_layer_0_type: GRU
# high_low_features_branch_hp_units_at_hp_layer_0: 64
# high_low_features_branch_recurrent_dropout_0: 0.0
# high_low_features_branch_RNN_layer_1_type: GRU
# high_low_features_branch_hp_units_at_hp_layer_1: 64
# high_low_features_branch_recurrent_dropout_1: 0.1
# volume_features_branch_hp_layers: 4
# volume_features_branch_RNN_layer_0_type: LSTM
# volume_features_branch_hp_units_at_hp_layer_0: 128
# volume_features_branch_recurrent_dropout_0: 0.4
# volume_features_branch_RNN_layer_1_type: SimpleRNN
# volume_features_branch_hp_units_at_hp_layer_1: 128
# volume_features_branch_recurrent_dropout_1: 0.1
# optimizer_type: RMSprop
# learning_rate: 0.002220709089529535
# all_features_branch_RNN_layer_2_type: LSTM
# all_features_branch_hp_units_at_hp_layer_2: 128
# all_features_branch_recurrent_dropout_2: 0.0
# all_features_branch_RNN_layer_3_type: GRU
# all_features_branch_hp_units_at_hp_layer_3: 128
# all_features_branch_recurrent_dropout_3: 0.1
# close_features_branch_RNN_layer_2_type: GRU
# close_features_branch_hp_units_at_hp_layer_2: 128
# close_features_branch_recurrent_dropout_2: 0.0
# close_features_branch_RNN_layer_3_type: GRU
# close_features_branch_hp_units_at_hp_layer_3: 64
# close_features_branch_recurrent_dropout_3: 0.4
# high_low_features_branch_RNN_layer_2_type: SimpleRNN
# high_low_features_branch_hp_units_at_hp_layer_2: 64
# high_low_features_branch_recurrent_dropout_2: 0.2
# high_low_features_branch_RNN_layer_3_type: GRU
# high_low_features_branch_hp_units_at_hp_layer_3: 128
# high_low_features_branch_recurrent_dropout_3: 0.1
# volume_features_branch_RNN_layer_2_type: SimpleRNN
# volume_features_branch_hp_units_at_hp_layer_2: 64
# volume_features_branch_recurrent_dropout_2: 0.1
# volume_features_branch_RNN_layer_3_type: LSTM
# ...
# base_features_branch_hp_units_at_hp_layer_1: 128
# base_features_branch_recurrent_dropout_1: 0.2
# close_features_branch_hp_layers: 2
# close_features_branch_RNN_layer_0_type: LSTM
# close_features_branch_hp_units_at_hp_layer_0: 128
# close_features_branch_recurrent_dropout_0: 0.1
# close_features_branch_RNN_layer_1_type: GRU
# close_features_branch_hp_units_at_hp_layer_1: 64
# close_features_branch_recurrent_dropout_1: 0.1
# high_low_features_branch_hp_layers: 4
# high_low_features_branch_RNN_layer_0_type: LSTM
# high_low_features_branch_hp_units_at_hp_layer_0: 128
# high_low_features_branch_recurrent_dropout_0: 0.1
# high_low_features_branch_RNN_layer_1_type: LSTM
# high_low_features_branch_hp_units_at_hp_layer_1: 64
# high_low_features_branch_recurrent_dropout_1: 0.1
# volume_features_branch_hp_layers: 2
# volume_features_branch_RNN_layer_0_type: SimpleRNN
# volume_features_branch_hp_units_at_hp_layer_0: 128
# volume_features_branch_recurrent_dropout_0: 0.1
# volume_features_branch_RNN_layer_1_type: GRU
# volume_features_branch_hp_units_at_hp_layer_1: 64
# volume_features_branch_recurrent_dropout_1: 0.1
# optimizer_type: Adam
# learning_rate: 0.0015603766129866545
# all_features_branch_RNN_layer_2_type: LSTM
# all_features_branch_hp_units_at_hp_layer_2: 64
# all_features_branch_recurrent_dropout_2: 0.1
# all_features_branch_RNN_layer_3_type: GRU
# all_features_branch_hp_units_at_hp_layer_3: 64
# all_features_branch_recurrent_dropout_3: 0.1
# close_features_branch_RNN_layer_2_type: LSTM
# close_features_branch_hp_units_at_hp_layer_2: 64
# close_features_branch_recurrent_dropout_2: 0.4
# close_features_branch_RNN_layer_3_type: LSTM
# close_features_branch_hp_units_at_hp_layer_3: 128
# close_features_branch_recurrent_dropout_3: 0.2
# high_low_features_branch_RNN_layer_2_type: LSTM
# high_low_features_branch_hp_units_at_hp_layer_2: 128
# high_low_features_branch_recurrent_dropout_2: 0.2
# high_low_features_branch_RNN_layer_3_type: SimpleRNN
# high_low_features_branch_hp_units_at_hp_layer_3: 64
# high_low_features_branch_recurrent_dropout_3: 0.1
# volume_features_branch_RNN_layer_2_type: GRU
# volume_features_branch_hp_units_at_hp_layer_2: 128
# volume_features_branch_recurrent_dropout_2: 0.2
# volume_features_branch_RNN_layer_3_type: SimpleRNN
# volume_features_branch_hp_units_at_hp_layer_3: 128
# volume_features_branch_recurrent_dropout_3: 0.2
# batch_size: 32
# base_features_branch_RNN_layer_2_type: GRU
# base_features_branch_hp_units_at_hp_layer_2: 128
# base_features_branch_recurrent_dropout_2: 0.2
# base_features_branch_RNN_layer_3_type: LSTM
# base_features_branch_hp_units_at_hp_layer_3: 64
# base_features_branch_recurrent_dropout_3: 0.0
# tuner/epochs: 4
# tuner/initial_epoch: 0
# tuner/bracket: 1
# tuner/round: 0
# Score: 0.5833333134651184
#
# Trial 0025 summary
# Hyperparameters:
# all_features_branch_hp_layers: 4
# all_features_branch_RNN_layer_0_type: LSTM
# all_features_branch_hp_units_at_hp_layer_0: 128
# all_features_branch_recurrent_dropout_0: 0.0
# all_features_branch_RNN_layer_1_type: LSTM
# all_features_branch_hp_units_at_hp_layer_1: 64
# all_features_branch_recurrent_dropout_1: 0.2
# base_features_branch_hp_layers: 2
# base_features_branch_RNN_layer_0_type: LSTM
# base_features_branch_hp_units_at_hp_layer_0: 64
# base_features_branch_recurrent_dropout_0: 0.2
# base_features_branch_RNN_layer_1_type: SimpleRNN
# base_features_branch_hp_units_at_hp_layer_1: 128
# base_features_branch_recurrent_dropout_1: 0.2
# close_features_branch_hp_layers: 2
# close_features_branch_RNN_layer_0_type: LSTM
# close_features_branch_hp_units_at_hp_layer_0: 128
# close_features_branch_recurrent_dropout_0: 0.1
# close_features_branch_RNN_layer_1_type: GRU
# close_features_branch_hp_units_at_hp_layer_1: 64
# close_features_branch_recurrent_dropout_1: 0.1
# high_low_features_branch_hp_layers: 4
# high_low_features_branch_RNN_layer_0_type: LSTM
# high_low_features_branch_hp_units_at_hp_layer_0: 128
# high_low_features_branch_recurrent_dropout_0: 0.1
# high_low_features_branch_RNN_layer_1_type: LSTM
# high_low_features_branch_hp_units_at_hp_layer_1: 64
# high_low_features_branch_recurrent_dropout_1: 0.1
# volume_features_branch_hp_layers: 2
# volume_features_branch_RNN_layer_0_type: SimpleRNN
# volume_features_branch_hp_units_at_hp_layer_0: 128
# volume_features_branch_recurrent_dropout_0: 0.1
# volume_features_branch_RNN_layer_1_type: GRU
# volume_features_branch_hp_units_at_hp_layer_1: 64
# volume_features_branch_recurrent_dropout_1: 0.1
# optimizer_type: Adam
# learning_rate: 0.0015603766129866545
# all_features_branch_RNN_layer_2_type: LSTM
# all_features_branch_hp_units_at_hp_layer_2: 64
# all_features_branch_recurrent_dropout_2: 0.1
# all_features_branch_RNN_layer_3_type: GRU
# all_features_branch_hp_units_at_hp_layer_3: 64
# all_features_branch_recurrent_dropout_3: 0.1
# close_features_branch_RNN_layer_2_type: LSTM
# close_features_branch_hp_units_at_hp_layer_2: 64
# close_features_branch_recurrent_dropout_2: 0.4
# close_features_branch_RNN_layer_3_type: LSTM
# close_features_branch_hp_units_at_hp_layer_3: 128
# close_features_branch_recurrent_dropout_3: 0.2
# high_low_features_branch_RNN_layer_2_type: LSTM
# high_low_features_branch_hp_units_at_hp_layer_2: 128
# high_low_features_branch_recurrent_dropout_2: 0.2
# high_low_features_branch_RNN_layer_3_type: SimpleRNN
# high_low_features_branch_hp_units_at_hp_layer_3: 64
# high_low_features_branch_recurrent_dropout_3: 0.1
# volume_features_branch_RNN_layer_2_type: GRU
# volume_features_branch_hp_units_at_hp_layer_2: 128
# volume_features_branch_recurrent_dropout_2: 0.2
# volume_features_branch_RNN_layer_3_type: SimpleRNN
# volume_features_branch_hp_units_at_hp_layer_3: 128
# volume_features_branch_recurrent_dropout_3: 0.2
# batch_size: 32
# base_features_branch_RNN_layer_2_type: GRU
# base_features_branch_hp_units_at_hp_layer_2: 128
# base_features_branch_recurrent_dropout_2: 0.2
# base_features_branch_RNN_layer_3_type: LSTM
# base_features_branch_hp_units_at_hp_layer_3: 64
# base_features_branch_recurrent_dropout_3: 0.0
# tuner/epochs: 10
# tuner/initial_epoch: 4
# tuner/bracket: 1
# tuner/round: 1
# tuner/trial_id: 0021
# Score: 0.5833333134651184
#
# Trial 0027 summary
# Hyperparameters:
# all_features_branch_hp_layers: 2
# all_features_branch_RNN_layer_0_type: GRU
# all_features_branch_hp_units_at_hp_layer_0: 64
# all_features_branch_recurrent_dropout_0: 0.4
# all_features_branch_RNN_layer_1_type: GRU
# all_features_branch_hp_units_at_hp_layer_1: 64
# all_features_branch_recurrent_dropout_1: 0.4
# base_features_branch_hp_layers: 2
# base_features_branch_RNN_layer_0_type: GRU
# base_features_branch_hp_units_at_hp_layer_0: 128
# base_features_branch_recurrent_dropout_0: 0.2
# base_features_branch_RNN_layer_1_type: LSTM
# base_features_branch_hp_units_at_hp_layer_1: 64
# base_features_branch_recurrent_dropout_1: 0.2
# close_features_branch_hp_layers: 4
# close_features_branch_RNN_layer_0_type: GRU
# close_features_branch_hp_units_at_hp_layer_0: 128
# close_features_branch_recurrent_dropout_0: 0.0
# close_features_branch_RNN_layer_1_type: SimpleRNN
# close_features_branch_hp_units_at_hp_layer_1: 64
# close_features_branch_recurrent_dropout_1: 0.2
# high_low_features_branch_hp_layers: 2
# high_low_features_branch_RNN_layer_0_type: SimpleRNN
# high_low_features_branch_hp_units_at_hp_layer_0: 128
# high_low_features_branch_recurrent_dropout_0: 0.30000000000000004
# high_low_features_branch_RNN_layer_1_type: GRU
# high_low_features_branch_hp_units_at_hp_layer_1: 128
# high_low_features_branch_recurrent_dropout_1: 0.0
# volume_features_branch_hp_layers: 4
# volume_features_branch_RNN_layer_0_type: SimpleRNN
# volume_features_branch_hp_units_at_hp_layer_0: 128
# volume_features_branch_recurrent_dropout_0: 0.4
# volume_features_branch_RNN_layer_1_type: LSTM
# volume_features_branch_hp_units_at_hp_layer_1: 64
# volume_features_branch_recurrent_dropout_1: 0.0
# optimizer_type: Adam
# learning_rate: 0.00033280672177041687
# all_features_branch_RNN_layer_2_type: LSTM
# all_features_branch_hp_units_at_hp_layer_2: 64
# all_features_branch_recurrent_dropout_2: 0.30000000000000004
# all_features_branch_RNN_layer_3_type: SimpleRNN
# all_features_branch_hp_units_at_hp_layer_3: 64
# all_features_branch_recurrent_dropout_3: 0.1
# close_features_branch_RNN_layer_2_type: LSTM
# close_features_branch_hp_units_at_hp_layer_2: 64
# close_features_branch_recurrent_dropout_2: 0.30000000000000004
# close_features_branch_RNN_layer_3_type: LSTM
# close_features_branch_hp_units_at_hp_layer_3: 64
# close_features_branch_recurrent_dropout_3: 0.30000000000000004
# high_low_features_branch_RNN_layer_2_type: LSTM
# high_low_features_branch_hp_units_at_hp_layer_2: 128
# high_low_features_branch_recurrent_dropout_2: 0.0
# high_low_features_branch_RNN_layer_3_type: LSTM
# high_low_features_branch_hp_units_at_hp_layer_3: 64
# high_low_features_branch_recurrent_dropout_3: 0.1
# volume_features_branch_RNN_layer_2_type: GRU
# volume_features_branch_hp_units_at_hp_layer_2: 128
# volume_features_branch_recurrent_dropout_2: 0.2
# volume_features_branch_RNN_layer_3_type: GRU
# volume_features_branch_hp_units_at_hp_layer_3: 128
# volume_features_branch_recurrent_dropout_3: 0.0
# batch_size: 32
# base_features_branch_RNN_layer_2_type: GRU
# base_features_branch_hp_units_at_hp_layer_2: 128
# base_features_branch_recurrent_dropout_2: 0.4
# base_features_branch_RNN_layer_3_type: SimpleRNN
# base_features_branch_hp_units_at_hp_layer_3: 64
# base_features_branch_recurrent_dropout_3: 0.4
# tuner/epochs: 10
# tuner/initial_epoch: 0
# tuner/bracket: 0
# tuner/round: 0
# Score: 0.5833333134651184
#
# Trial 0029 summary
# Hyperparameters:
# all_features_branch_hp_layers: 4
# all_features_branch_RNN_layer_0_type: GRU
# all_features_branch_hp_units_at_hp_layer_0: 64
# all_features_branch_recurrent_dropout_0: 0.2
# all_features_branch_RNN_layer_1_type: GRU
# all_features_branch_hp_units_at_hp_layer_1: 64
# all_features_branch_recurrent_dropout_1: 0.0
# base_features_branch_hp_layers: 2
# base_features_branch_RNN_layer_0_type: SimpleRNN
# base_features_branch_hp_units_at_hp_layer_0: 128
# base_features_branch_recurrent_dropout_0: 0.0
# base_features_branch_RNN_layer_1_type: LSTM
# base_features_branch_hp_units_at_hp_layer_1: 128
# base_features_branch_recurrent_dropout_1: 0.0
# close_features_branch_hp_layers: 2
# close_features_branch_RNN_layer_0_type: SimpleRNN
# close_features_branch_hp_units_at_hp_layer_0: 64
# close_features_branch_recurrent_dropout_0: 0.4
# close_features_branch_RNN_layer_1_type: LSTM
# close_features_branch_hp_units_at_hp_layer_1: 64
# close_features_branch_recurrent_dropout_1: 0.2
# high_low_features_branch_hp_layers: 4
# high_low_features_branch_RNN_layer_0_type: SimpleRNN
# high_low_features_branch_hp_units_at_hp_layer_0: 128
# high_low_features_branch_recurrent_dropout_0: 0.1
# high_low_features_branch_RNN_layer_1_type: LSTM
# high_low_features_branch_hp_units_at_hp_layer_1: 64
# high_low_features_branch_recurrent_dropout_1: 0.1
# volume_features_branch_hp_layers: 2
# volume_features_branch_RNN_layer_0_type: SimpleRNN
# volume_features_branch_hp_units_at_hp_layer_0: 128
# volume_features_branch_recurrent_dropout_0: 0.0
# volume_features_branch_RNN_layer_1_type: SimpleRNN
# volume_features_branch_hp_units_at_hp_layer_1: 128
# volume_features_branch_recurrent_dropout_1: 0.30000000000000004
# optimizer_type: RMSprop
# learning_rate: 0.0005061117544320517
# all_features_branch_RNN_layer_2_type: SimpleRNN
# all_features_branch_hp_units_at_hp_layer_2: 64
# all_features_branch_recurrent_dropout_2: 0.30000000000000004
# all_features_branch_RNN_layer_3_type: GRU
# all_features_branch_hp_units_at_hp_layer_3: 128
# all_features_branch_recurrent_dropout_3: 0.1
# close_features_branch_RNN_layer_2_type: SimpleRNN
# close_features_branch_hp_units_at_hp_layer_2: 128
# close_features_branch_recurrent_dropout_2: 0.1
# close_features_branch_RNN_layer_3_type: SimpleRNN
# close_features_branch_hp_units_at_hp_layer_3: 64
# close_features_branch_recurrent_dropout_3: 0.0
# high_low_features_branch_RNN_layer_2_type: SimpleRNN
# high_low_features_branch_hp_units_at_hp_layer_2: 64
# high_low_features_branch_recurrent_dropout_2: 0.0
# high_low_features_branch_RNN_layer_3_type: SimpleRNN
# high_low_features_branch_hp_units_at_hp_layer_3: 64
# high_low_features_branch_recurrent_dropout_3: 0.0
# volume_features_branch_RNN_layer_2_type: GRU
# volume_features_branch_hp_units_at_hp_layer_2: 64
# volume_features_branch_recurrent_dropout_2: 0.2
# volume_features_branch_RNN_layer_3_type: LSTM
# volume_features_branch_hp_units_at_hp_layer_3: 128
# volume_features_branch_recurrent_dropout_3: 0.0
# batch_size: 64
# base_features_branch_RNN_layer_2_type: LSTM
# base_features_branch_hp_units_at_hp_layer_2: 64
# base_features_branch_recurrent_dropout_2: 0.1
# base_features_branch_RNN_layer_3_type: SimpleRNN
# base_features_branch_hp_units_at_hp_layer_3: 128
# base_features_branch_recurrent_dropout_3: 0.30000000000000004
# tuner/epochs: 10
# tuner/initial_epoch: 0
# tuner/bracket: 0
# tuner/round: 0
# Score: 0.5833333134651184
#
# Trial 0001 summary
# Hyperparameters:
# all_features_branch_hp_layers: 2
# all_features_branch_RNN_layer_0_type: SimpleRNN
# all_features_branch_hp_units_at_hp_layer_0: 128
# all_features_branch_recurrent_dropout_0: 0.2
# all_features_branch_RNN_layer_1_type: LSTM
# all_features_branch_hp_units_at_hp_layer_1: 128
# all_features_branch_recurrent_dropout_1: 0.2
# base_features_branch_hp_layers: 4
# base_features_branch_RNN_layer_0_type: SimpleRNN
# base_features_branch_hp_units_at_hp_layer_0: 128
# base_features_branch_recurrent_dropout_0: 0.2
# base_features_branch_RNN_layer_1_type: SimpleRNN
# base_features_branch_hp_units_at_hp_layer_1: 128
# base_features_branch_recurrent_dropout_1: 0.30000000000000004
# close_features_branch_hp_layers: 4
# close_features_branch_RNN_layer_0_type: GRU
# close_features_branch_hp_units_at_hp_layer_0: 64
# close_features_branch_recurrent_dropout_0: 0.2
# close_features_branch_RNN_layer_1_type: LSTM
# close_features_branch_hp_units_at_hp_layer_1: 128
# close_features_branch_recurrent_dropout_1: 0.30000000000000004
# high_low_features_branch_hp_layers: 2
# high_low_features_branch_RNN_layer_0_type: SimpleRNN
# high_low_features_branch_hp_units_at_hp_layer_0: 128
# high_low_features_branch_recurrent_dropout_0: 0.0
# high_low_features_branch_RNN_layer_1_type: LSTM
# high_low_features_branch_hp_units_at_hp_layer_1: 64
# high_low_features_branch_recurrent_dropout_1: 0.0
# volume_features_branch_hp_layers: 2
# volume_features_branch_RNN_layer_0_type: SimpleRNN
# volume_features_branch_hp_units_at_hp_layer_0: 128
# volume_features_branch_recurrent_dropout_0: 0.1
# volume_features_branch_RNN_layer_1_type: GRU
# volume_features_branch_hp_units_at_hp_layer_1: 128
# volume_features_branch_recurrent_dropout_1: 0.1
# optimizer_type: Adam
# learning_rate: 0.00405701014195834
# all_features_branch_RNN_layer_2_type: LSTM
# all_features_branch_hp_units_at_hp_layer_2: 64
# all_features_branch_recurrent_dropout_2: 0.4
# all_features_branch_RNN_layer_3_type: GRU
# all_features_branch_hp_units_at_hp_layer_3: 128
# all_features_branch_recurrent_dropout_3: 0.0
# close_features_branch_RNN_layer_2_type: LSTM
# close_features_branch_hp_units_at_hp_layer_2: 64
# close_features_branch_recurrent_dropout_2: 0.0
# close_features_branch_RNN_layer_3_type: SimpleRNN
# close_features_branch_hp_units_at_hp_layer_3: 128
# close_features_branch_recurrent_dropout_3: 0.1
# high_low_features_branch_RNN_layer_2_type: LSTM
# high_low_features_branch_hp_units_at_hp_layer_2: 128
# high_low_features_branch_recurrent_dropout_2: 0.2
# high_low_features_branch_RNN_layer_3_type: SimpleRNN
# high_low_features_branch_hp_units_at_hp_layer_3: 128
# high_low_features_branch_recurrent_dropout_3: 0.1
# volume_features_branch_RNN_layer_2_type: LSTM
# volume_features_branch_hp_units_at_hp_layer_2: 128
# volume_features_branch_recurrent_dropout_2: 0.2
# volume_features_branch_RNN_layer_3_type: LSTM
# volume_features_branch_hp_units_at_hp_layer_3: 128
# volume_features_branch_recurrent_dropout_3: 0.0
# batch_size: 32
# tuner/epochs: 2
# tuner/initial_epoch: 0
# tuner/bracket: 2
# tuner/round: 0
# base_features_branch_RNN_layer_2_type: SimpleRNN
# base_features_branch_hp_units_at_hp_layer_2: 64
# base_features_branch_recurrent_dropout_2: 0.0
# base_features_branch_RNN_layer_3_type: SimpleRNN
# base_features_branch_hp_units_at_hp_layer_3: 64
# base_features_branch_recurrent_dropout_3: 0.0
# Score: 0.5729166865348816
# Best epoch: 5
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 8s 4s/step
# training for the INCY model was done in: 2:43:17.772871

# %%
# evaluate the models in the archive
evaluate_models_archive(hp_RNN_inception_models_archive)
# Out:
# Model: "functional_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                  ┃ Output Shape              ┃         Param # ┃ Connected to               ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_2 (InputLayer)    │ (None, 10, 72)            │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ input_spilt_layer_2           │ [(None, 10, 6), (None,    │               0 │ input_layer_2[0][0]        │
# │ (InputSpiltLayer)             │ 10, 30), (None, 10, 31),  │                 │                            │
# │                               │ (None, 10, 5)]            │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ simple_rnn_12 (SimpleRNN)     │ (None, 10, 128)           │          17,280 │ input_spilt_layer_2[0][0]  │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ simple_rnn_13 (SimpleRNN)     │ (None, 10, 64)            │           6,080 │ input_spilt_layer_2[0][1]  │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ gru_6 (GRU)                   │ (None, 10, 128)           │          61,824 │ input_spilt_layer_2[0][2]  │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ lstm_10 (LSTM)                │ (None, 10, 128)           │          68,608 │ input_spilt_layer_2[0][3]  │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ lstm_7 (LSTM)                 │ (None, 10, 64)            │          35,072 │ input_layer_2[0][0]        │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ lstm_8 (LSTM)                 │ (None, 64)                │          49,408 │ simple_rnn_12[0][0]        │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ lstm_9 (LSTM)                 │ (None, 128)               │          98,816 │ simple_rnn_13[0][0]        │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ simple_rnn_14 (SimpleRNN)     │ (None, 64)                │          12,352 │ gru_6[0][0]                │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ simple_rnn_15 (SimpleRNN)     │ (None, 64)                │          12,352 │ lstm_10[0][0]              │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ gru_5 (GRU)                   │ (None, 64)                │          24,960 │ lstm_7[0][0]               │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ concatenate_2 (Concatenate)   │ (None, 384)               │               0 │ lstm_8[0][0],              │
# │                               │                           │                 │ lstm_9[0][0],              │
# │                               │                           │                 │ simple_rnn_14[0][0],       │
# │                               │                           │                 │ simple_rnn_15[0][0],       │
# │                               │                           │                 │ gru_5[0][0]                │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_2 (Dense)               │ (None, 2)                 │             770 │ concatenate_2[0][0]        │
# └───────────────────────────────┴───────────────────────────┴─────────────────┴────────────────────────────┘
#  Total params: 775,046 (2.96 MB)
#  Trainable params: 387,522 (1.48 MB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 387,524 (1.48 MB)
# The PFE Model Classification Metrics:
# Accuracy: 0.48717948717948717
# Precision: 0.48285953177257523
# Recall: 0.48717948717948717
# F-Score: 0.4837515425750719
# --------------------------------------------------------------
# Model: "functional_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                  ┃ Output Shape              ┃         Param # ┃ Connected to               ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_2 (InputLayer)    │ (None, 10, 72)            │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ input_spilt_layer_2           │ [(None, 10, 6), (None,    │               0 │ input_layer_2[0][0]        │
# │ (InputSpiltLayer)             │ 10, 30), (None, 10, 31),  │                 │                            │
# │                               │ (None, 10, 5)]            │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ simple_rnn_11 (SimpleRNN)     │ (None, 10, 128)           │          17,152 │ input_spilt_layer_2[0][3]  │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ gru_10 (GRU)                  │ (None, 10, 128)           │          77,568 │ input_layer_2[0][0]        │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ lstm_11 (LSTM)                │ (None, 10, 64)            │          49,408 │ simple_rnn_11[0][0]        │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ gru_11 (GRU)                  │ (None, 10, 64)            │          37,248 │ gru_10[0][0]               │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ simple_rnn_10 (SimpleRNN)     │ (None, 10, 128)           │          17,280 │ input_spilt_layer_2[0][0]  │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ lstm_9 (LSTM)                 │ (None, 10, 64)            │          24,320 │ input_spilt_layer_2[0][1]  │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ gru_14 (GRU)                  │ (None, 10, 64)            │          18,624 │ input_spilt_layer_2[0][2]  │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ gru_16 (GRU)                  │ (None, 10, 64)            │          24,960 │ lstm_11[0][0]              │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ gru_12 (GRU)                  │ (None, 10, 128)           │          74,496 │ gru_11[0][0]               │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ gru_13 (GRU)                  │ (None, 64)                │          37,248 │ simple_rnn_10[0][0]        │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ lstm_10 (LSTM)                │ (None, 128)               │          98,816 │ lstm_9[0][0]               │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ gru_15 (GRU)                  │ (None, 64)                │          24,960 │ gru_14[0][0]               │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ lstm_12 (LSTM)                │ (None, 128)               │          98,816 │ gru_16[0][0]               │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ lstm_8 (LSTM)                 │ (None, 128)               │         131,584 │ gru_12[0][0]               │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ concatenate_2 (Concatenate)   │ (None, 512)               │               0 │ gru_13[0][0],              │
# │                               │                           │                 │ lstm_10[0][0],             │
# │                               │                           │                 │ gru_15[0][0],              │
# │                               │                           │                 │ lstm_12[0][0],             │
# │                               │                           │                 │ lstm_8[0][0]               │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_2 (Dense)               │ (None, 2)                 │           1,026 │ concatenate_2[0][0]        │
# └───────────────────────────────┴───────────────────────────┴─────────────────┴────────────────────────────┘
#  Total params: 2,200,520 (8.39 MB)
#  Trainable params: 733,506 (2.80 MB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 1,467,014 (5.60 MB)
# The ROP Model Classification Metrics:
# Accuracy: 0.48717948717948717
# Precision: 0.23734385272846809
# Recall: 0.48717948717948717
# F-Score: 0.31918656056587086
# --------------------------------------------------------------
# Model: "functional_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                  ┃ Output Shape              ┃         Param # ┃ Connected to               ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_2 (InputLayer)    │ (None, 10, 72)            │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ input_spilt_layer_2           │ [(None, 10, 6), (None,    │               0 │ input_layer_2[0][0]        │
# │ (InputSpiltLayer)             │ 10, 30), (None, 10, 31),  │                 │                            │
# │                               │ (None, 10, 5)]            │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ simple_rnn_12 (SimpleRNN)     │ (None, 10, 128)           │          17,280 │ input_spilt_layer_2[0][0]  │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ simple_rnn_13 (SimpleRNN)     │ (None, 10, 64)            │           6,080 │ input_spilt_layer_2[0][1]  │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ gru_6 (GRU)                   │ (None, 10, 128)           │          61,824 │ input_spilt_layer_2[0][2]  │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ lstm_10 (LSTM)                │ (None, 10, 128)           │          68,608 │ input_spilt_layer_2[0][3]  │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ lstm_7 (LSTM)                 │ (None, 10, 64)            │          35,072 │ input_layer_2[0][0]        │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ lstm_8 (LSTM)                 │ (None, 64)                │          49,408 │ simple_rnn_12[0][0]        │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ lstm_9 (LSTM)                 │ (None, 128)               │          98,816 │ simple_rnn_13[0][0]        │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ simple_rnn_14 (SimpleRNN)     │ (None, 64)                │          12,352 │ gru_6[0][0]                │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ simple_rnn_15 (SimpleRNN)     │ (None, 64)                │          12,352 │ lstm_10[0][0]              │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ gru_5 (GRU)                   │ (None, 64)                │          24,960 │ lstm_7[0][0]               │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ concatenate_2 (Concatenate)   │ (None, 384)               │               0 │ lstm_8[0][0],              │
# │                               │                           │                 │ lstm_9[0][0],              │
# │                               │                           │                 │ simple_rnn_14[0][0],       │
# │                               │                           │                 │ simple_rnn_15[0][0],       │
# │                               │                           │                 │ gru_5[0][0]                │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_2 (Dense)               │ (None, 2)                 │             770 │ concatenate_2[0][0]        │
# └───────────────────────────────┴───────────────────────────┴─────────────────┴────────────────────────────┘
#  Total params: 775,046 (2.96 MB)
#  Trainable params: 387,522 (1.48 MB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 387,524 (1.48 MB)
# The XYL Model Classification Metrics:
# Accuracy: 0.6153846153846154
# Precision: 0.37869822485207105
# Recall: 0.6153846153846154
# F-Score: 0.46886446886446886
# --------------------------------------------------------------
# Model: "functional_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                  ┃ Output Shape              ┃         Param # ┃ Connected to               ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_2 (InputLayer)    │ (None, 10, 72)            │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ input_spilt_layer_2           │ [(None, 10, 6), (None,    │               0 │ input_layer_2[0][0]        │
# │ (InputSpiltLayer)             │ 10, 30), (None, 10, 31),  │                 │                            │
# │                               │ (None, 10, 5)]            │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ gru_13 (GRU)                  │ (None, 10, 128)           │          61,440 │ input_spilt_layer_2[0][1]  │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ simple_rnn_13 (SimpleRNN)     │ (None, 10, 128)           │          17,152 │ input_spilt_layer_2[0][3]  │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ simple_rnn_11 (SimpleRNN)     │ (None, 10, 64)            │          12,352 │ gru_13[0][0]               │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ lstm_10 (LSTM)                │ (None, 10, 64)            │          49,408 │ simple_rnn_13[0][0]        │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ gru_12 (GRU)                  │ (None, 10, 128)           │          52,224 │ input_spilt_layer_2[0][0]  │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ lstm_8 (LSTM)                 │ (None, 10, 64)            │          33,024 │ simple_rnn_11[0][0]        │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ simple_rnn_12 (SimpleRNN)     │ (None, 10, 128)           │          20,480 │ input_spilt_layer_2[0][2]  │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ gru_15 (GRU)                  │ (None, 10, 128)           │          74,496 │ lstm_10[0][0]              │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ gru_10 (GRU)                  │ (None, 10, 64)            │          26,496 │ input_layer_2[0][0]        │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ lstm_7 (LSTM)                 │ (None, 64)                │          49,408 │ gru_12[0][0]               │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ lstm_9 (LSTM)                 │ (None, 64)                │          33,024 │ lstm_8[0][0]               │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ gru_14 (GRU)                  │ (None, 128)               │          99,072 │ simple_rnn_12[0][0]        │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ gru_16 (GRU)                  │ (None, 128)               │          99,072 │ gru_15[0][0]               │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ gru_11 (GRU)                  │ (None, 64)                │          24,960 │ gru_10[0][0]               │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ concatenate_2 (Concatenate)   │ (None, 448)               │               0 │ lstm_7[0][0],              │
# │                               │                           │                 │ lstm_9[0][0],              │
# │                               │                           │                 │ gru_14[0][0],              │
# │                               │                           │                 │ gru_16[0][0], gru_11[0][0] │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_2 (Dense)               │ (None, 2)                 │             898 │ concatenate_2[0][0]        │
# └───────────────────────────────┴───────────────────────────┴─────────────────┴────────────────────────────┘
#  Total params: 1,960,520 (7.48 MB)
#  Trainable params: 653,506 (2.49 MB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 1,307,014 (4.99 MB)
# The CPAY Model Classification Metrics:
# Accuracy: 0.5128205128205128
# Precision: 0.5236204013377926
# Recall: 0.5128205128205128
# F-Score: 0.5096090461944122
# --------------------------------------------------------------
# Model: "functional_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                  ┃ Output Shape              ┃         Param # ┃ Connected to               ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_2 (InputLayer)    │ (None, 10, 72)            │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ input_spilt_layer_2           │ [(None, 10, 6), (None,    │               0 │ input_layer_2[0][0]        │
# │ (InputSpiltLayer)             │ 10, 30), (None, 10, 31),  │                 │                            │
# │                               │ (None, 10, 5)]            │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ lstm_13 (LSTM)                │ (None, 10, 128)           │          69,120 │ input_spilt_layer_2[0][0]  │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ gru_9 (GRU)                   │ (None, 10, 64)            │          18,432 │ input_spilt_layer_2[0][1]  │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ lstm_17 (LSTM)                │ (None, 10, 128)           │          81,920 │ input_spilt_layer_2[0][2]  │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ simple_rnn_12 (SimpleRNN)     │ (None, 10, 128)           │          25,728 │ input_layer_2[0][0]        │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ lstm_14 (LSTM)                │ (None, 10, 64)            │          49,408 │ lstm_13[0][0]              │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ lstm_16 (LSTM)                │ (None, 10, 128)           │          98,816 │ gru_9[0][0]                │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ lstm_18 (LSTM)                │ (None, 10, 64)            │          49,408 │ lstm_17[0][0]              │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ gru_7 (GRU)                   │ (None, 10, 64)            │          37,248 │ simple_rnn_12[0][0]        │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ gru_8 (GRU)                   │ (None, 10, 128)           │          74,496 │ lstm_14[0][0]              │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ gru_10 (GRU)                  │ (None, 10, 128)           │          99,072 │ lstm_16[0][0]              │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ lstm_19 (LSTM)                │ (None, 10, 128)           │          98,816 │ lstm_18[0][0]              │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ lstm_21 (LSTM)                │ (None, 10, 64)            │          17,920 │ input_spilt_layer_2[0][3]  │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ simple_rnn_13 (SimpleRNN)     │ (None, 10, 64)            │           8,256 │ gru_7[0][0]                │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ lstm_15 (LSTM)                │ (None, 128)               │         131,584 │ gru_8[0][0]                │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ simple_rnn_15 (SimpleRNN)     │ (None, 64)                │          12,352 │ gru_10[0][0]               │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ lstm_20 (LSTM)                │ (None, 64)                │          49,408 │ lstm_19[0][0]              │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ lstm_22 (LSTM)                │ (None, 64)                │          33,024 │ lstm_21[0][0]              │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ simple_rnn_14 (SimpleRNN)     │ (None, 64)                │           8,256 │ simple_rnn_13[0][0]        │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ concatenate_2 (Concatenate)   │ (None, 384)               │               0 │ lstm_15[0][0],             │
# │                               │                           │                 │ simple_rnn_15[0][0],       │
# │                               │                           │                 │ lstm_20[0][0],             │
# │                               │                           │                 │ lstm_22[0][0],             │
# │                               │                           │                 │ simple_rnn_14[0][0]        │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_2 (Dense)               │ (None, 2)                 │             770 │ concatenate_2[0][0]        │
# └───────────────────────────────┴───────────────────────────┴─────────────────┴────────────────────────────┘
#  Total params: 2,892,104 (11.03 MB)
#  Trainable params: 964,034 (3.68 MB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 1,928,070 (7.36 MB)
# The INCY Model Classification Metrics:
# Accuracy: 0.5128205128205128
# Precision: 0.26298487836949375
# Recall: 0.5128205128205128
# F-Score: 0.3476749239461104
# --------------------------------------------------------------
# Average Classification Metrics for All Models:
# Average Accuracy: 0.5230769230769231
# Average Precision: 0.3771013778120801
# Average Recall: 0.5230769230769231
# Average F-Score: 0.4258173084291868

# %%
# source of inspiration: The base Layer class, "class ComputeSum(Layer)", https://keras.io/2.15/api/layers/base_layer/
# create a custom layer to split the features into groups (4 groups)
# TypeError: Could not locate class 'InputSpiltLayer'. Make sure custom classes are decorated with `@keras.saving.register_keras_serializable()
@register_keras_serializable()
class InputSpiltLayer(Layer):
    def __init__(self, split_indices=[6, 36, 67, 72], **kwargs):
        super(InputSpiltLayer, self).__init__(**kwargs)
        
        # set the split indices
        self.split_indices = split_indices
    
    def call(self, inputs): # Defines the computation from inputs to outputs
        
        # initialize a list to store the input branches 
        data_set_branches = []
    
        # set the start index to be 0
        start_index = 0

        # iterates over the split_indices list
        for i in self.split_indices:
            
            # take a slice of the data features that is between the start index and the ith value in the split_indices
            branch = inputs[:, :, start_index:i]

            # add the slice to the data_set_branches list
            data_set_branches.append(branch)

            # update the start_index to be equal to the ith value in the split_indices
            start_index = i

        # return the data_set_branches
        return data_set_branches

class HP_Hollow_RNN_Branch(HyperModel):

    # initialize the model upon creating a class instance
    # using a class structure instead of a function to construct the model will allow us to pass variables to it before passing it to keras tuner
    # source of inspiration on how to pass variables to the model before passing the model to keras tuner: https://github.com/JulieProst/keras-tuner-tutorial/blob/master/hypermodels.py
    def __init__(self, _data_set_branch, _branch_name):
        self.data_set_branch = _data_set_branch
        self.branch_name = _branch_name
    
    # build the model
    def build(self, hp):

        layer = self.data_set_branch
        
        # source: Int method, https://keras.io/api/keras_tuner/hyperparameters/
        # dynamically optimize the number of layers
        hp_layers = hp.Int(name=f'{self.branch_name}_hp_layers', 
                           min_value=2, 
                           max_value=4, 
                           step=2)

        # for each optimized layer
        for i in range(hp_layers):
            
#             # dynamically tune the number of units in each layer, select a value between 32-256
#             hp_units = hp.Choice(f'{self.branch_name}_hp_units_at_hp_layer_{i}', [32, 64, 128, 256])

            # optimize the layer type
            hp_layer_type = hp.Choice(f'{self.branch_name}_RNN_layer_{i}_type', values=['SimpleRNN', 'LSTM', 'GRU'])
            if hp_layer_type == 'SimpleRNN':
                layer_type = SimpleRNN
            elif hp_layer_type == 'LSTM':
                layer_type = LSTM
            else:
                layer_type = GRU
            
            # dynamically tune the number of units in each layer, select a value between 64-128
            hp_units = hp.Int(name=f'{self.branch_name}_hp_units_at_hp_layer_{i}', 
                              min_value=64, 
                              max_value=128, 
                              step=64)

            # source: SimpleRNN layer, https://keras.io/api/layers/recurrent_layers/simple_rnn/
            # return_sequences: Boolean. Whether to return the last output in the output sequence, or the full sequence. Default: False.
            # set the return_sequences parameter to true unless it's the last layer, set it to false
            return_sequences_boolean = i != (hp_layers - 1)

            # source: Float method, https://keras.io/api/keras_tuner/hyperparameters/
            # source: SimpleRNN layer, https://keras.io/api/layers/recurrent_layers/simple_rnn/
            # recurrent_dropout: Float between 0 and 1. Fraction of the units to drop for the linear transformation of the recurrent state.
            # dynamically tune the recurrent_dropout float value
            recurrent_dropout = hp.Float(name=f'{self.branch_name}_recurrent_dropout_{i}', 
                                         min_value=0.0, 
                                         max_value=0.5, 
                                         step=0.1)

            # add a simpleRNN layer and pass the optimized number of unites, recurrent_dropout, and the return_sequences boolean
            layer = layer_type(units=hp_units, 
                              return_sequences=return_sequences_boolean, 
                              recurrent_dropout=recurrent_dropout)(layer)
            
#             layer = BatchNormalization()(layer)
            
            
        return layer
        
        

# source of inspiration: Introduction to the Keras Tuner, https://www.tensorflow.org/tutorials/keras/keras_tuner
# constuct the model which will perform hyperparameter optimization to choose layer type, layers count, neurons counts, recurrent_dropout, optimizer_type, optimizer learning rate
class HP_Hollow_RNN_Inception_Model(HyperModel):

    # initialize the model upon creating a class instance
    # using a class structure instead of a function to construct the model will allow us to pass variables to it before passing it to keras tuner
    # source of inspiration on how to pass variables to the model before passing the model to keras tuner: https://github.com/JulieProst/keras-tuner-tutorial/blob/master/hypermodels.py
    def __init__(self, X_train_shape):
        self.X_train_shape = X_train_shape
    
    # build the model
    def build(self, hp):
        ### add the model layers (Model hyperparameters optimization)
        # input layer
        input_data = Input(shape=(self.X_train_shape[1], self.X_train_shape[2]))

        all_features_branch = HP_Hollow_RNN_Branch(input_data, "all_features_branch").build(hp)
        
        
        # source of inspiration: deep learning with python, 7.1.4. Directed acyclic graphs of layers, Inception modules, https://www.manning.com/books/deep-learning-with-python
        data_set_branches = InputSpiltLayer([6, 36, 67, 72])(input_data)

        base_features_branch = HP_Hollow_RNN_Branch(data_set_branches[0], "base_features_branch").build(hp)
        close_features_branch = HP_Hollow_RNN_Branch(data_set_branches[1], "close_features_branch").build(hp)
        high_low_features_branch = HP_Hollow_RNN_Branch(data_set_branches[2], "high_low_features_branch").build(hp)
#         volume_features_branch = HP_Hollow_RNN_Branch(data_set_branches[3], "volume_features_branch").build(hp)

#         branches_merged = concatenate([base_features_branch, 
#                                        close_features_branch, 
#                                        high_low_features_branch, 
#                                        volume_features_branch, 
#                                        all_features_branch], axis=-1)
        
        branches_merged = concatenate([base_features_branch, 
                                       close_features_branch, 
                                       high_low_features_branch, 
                                       all_features_branch], axis=-1)
    
        
        output = Dense(2, activation='softmax')(branches_merged)
        
        # Define outputs for each branch
#         base_output = Dense(2, activation='softmax', name='base_output')(base_features_branch)
#         close_output = Dense(2, activation='softmax', name='close_output')(close_features_branch)
#         high_low_output = Dense(2, activation='softmax', name='high_low_output')(high_low_features_branch)
#         volume_output = Dense(2, activation='softmax', name='volume_output')(volume_features_branch)

        # create the model
        model = Model(input_data, output)
#         model = Model(inputs=input_data, outputs=[base_output, close_output, high_low_output, volume_output, merged_output])


        ### the model compiler (Algorithm hyperparameters optimization)
        # source: Choice method, https://keras.io/api/keras_tuner/hyperparameters/
        # dynamically optimize the optimizer type
        hp_optimizer_type = hp.Choice('optimizer_type', values=['Adam', 'RMSprop', 'SGD'])
        if hp_optimizer_type == 'Adam':
            optimizer = Adam
        elif hp_optimizer_type == 'RMSprop':
            optimizer = RMSprop
        else:
            optimizer = SGD

        # dynamically tune the learning rate for the optimizer
        # When sampling="log", the step is multiplied between samples.
        hp_lr = hp.Float('learning_rate', 
                         min_value=0.0001, 
                         max_value=0.01, 
                         sampling='LOG')
        hp_optimizer = optimizer(learning_rate=hp_lr)

        # compile the model
        model.compile(optimizer=hp_optimizer, 
                      loss='categorical_crossentropy', # this is the most suitable one for predictions of one-hot encoded labels
                      metrics=['accuracy'])

        # return the model
        return model
    
    # source: omalleyt12, https://github.com/keras-team/keras-tuner/issues/122
    # define a fit function which will allow us to pass an optimized value for batch_size
    # *args and **kwargs are the ones we pass through tuner.search()
    def fit(self, hp, model, *args, **kwargs):
        
        # dynamically optimize the batch_size for the training process
        hp_batch_size = hp.Choice("batch_size", [32, 64])
        return model.fit(
            *args,
            batch_size=hp_batch_size,
            **kwargs,
        )

# %%
# set the model initialization inputs
X_train_shape = data_sets['PFE']['X_train'].shape
model_type='classification'
tuner = Hyperband

# create the model
hp_RNN_inception_model = HP_Hollow_RNN_Inception_Model(X_train_shape)
# hp_RNN_model = hp_RNN_model.build()

# create models archive for simpleRNN classification approach
hp_RNN_inception_models_archive = create_models_archive(hp_RNN_inception_model, 
                                                 data_sets, 
                                                 _model_type=model_type, 
                                                 _tuner=tuner, 
                                                 _epochs=50, 
                                                 _model_name='hp_RNN_inception_model', 
                                                 _project_name='hp_RNN_inception_model_archive2')
# Out:
# Reloading Tuner from keras_tuner_models\hp_RNN_inception_model_archive2/PFE\tuner0.json
# Results summary
# Results in keras_tuner_models\hp_RNN_inception_model_archive2/PFE
# Showing 10 best trials
# Objective(name="val_accuracy", direction="max")
#
# Trial 0017 summary
# Hyperparameters:
# all_features_branch_filters_SeparableConv1D: 32
# all_features_branch_SeparableConv1D_kernel_size: 3
# all_features_branch_hp_layers: 6
# all_features_branch_hp_units_at_hp_layer_0: 128
# all_features_branch_recurrent_dropout_0: 0.4
# all_features_branch_RNN_layer_0_type: GRU
# all_features_branch_hp_units_at_hp_layer_1: 32
# all_features_branch_recurrent_dropout_1: 0.2
# all_features_branch_RNN_layer_1_type: LSTM
# base_features_branch_filters_SeparableConv1D: 64
# base_features_branch_SeparableConv1D_kernel_size: 5
# base_features_branch_hp_layers: 4
# base_features_branch_hp_units_at_hp_layer_0: 32
# base_features_branch_recurrent_dropout_0: 0.2
# base_features_branch_RNN_layer_0_type: SimpleRNN
# base_features_branch_hp_units_at_hp_layer_1: 128
# base_features_branch_recurrent_dropout_1: 0.0
# base_features_branch_RNN_layer_1_type: SimpleRNN
# close_features_branch_filters_SeparableConv1D: 16
# close_features_branch_SeparableConv1D_kernel_size: 3
# close_features_branch_hp_layers: 6
# close_features_branch_hp_units_at_hp_layer_0: 64
# close_features_branch_recurrent_dropout_0: 0.30000000000000004
# close_features_branch_RNN_layer_0_type: GRU
# close_features_branch_hp_units_at_hp_layer_1: 64
# close_features_branch_recurrent_dropout_1: 0.1
# close_features_branch_RNN_layer_1_type: GRU
# high_low_features_branch_filters_SeparableConv1D: 32
# high_low_features_branch_SeparableConv1D_kernel_size: 3
# high_low_features_branch_hp_layers: 6
# high_low_features_branch_hp_units_at_hp_layer_0: 256
# high_low_features_branch_recurrent_dropout_0: 0.4
# high_low_features_branch_RNN_layer_0_type: SimpleRNN
# high_low_features_branch_hp_units_at_hp_layer_1: 128
# high_low_features_branch_recurrent_dropout_1: 0.2
# high_low_features_branch_RNN_layer_1_type: SimpleRNN
# volume_features_branch_filters_SeparableConv1D: 32
# volume_features_branch_SeparableConv1D_kernel_size: 5
# volume_features_branch_hp_layers: 4
# volume_features_branch_hp_units_at_hp_layer_0: 64
# volume_features_branch_recurrent_dropout_0: 0.30000000000000004
# volume_features_branch_RNN_layer_0_type: LSTM
# volume_features_branch_hp_units_at_hp_layer_1: 32
# volume_features_branch_recurrent_dropout_1: 0.30000000000000004
# volume_features_branch_RNN_layer_1_type: LSTM
# optimizer_type: RMSprop
# learning_rate: 0.004263664986805526
# all_features_branch_hp_units_at_hp_layer_2: 128
# all_features_branch_recurrent_dropout_2: 0.30000000000000004
# all_features_branch_RNN_layer_2_type: LSTM
# all_features_branch_hp_units_at_hp_layer_3: 32
# all_features_branch_recurrent_dropout_3: 0.1
# all_features_branch_RNN_layer_3_type: SimpleRNN
# all_features_branch_hp_units_at_hp_layer_4: 32
# all_features_branch_recurrent_dropout_4: 0.30000000000000004
# all_features_branch_RNN_layer_4_type: SimpleRNN
# all_features_branch_hp_units_at_hp_layer_5: 64
# all_features_branch_recurrent_dropout_5: 0.2
# all_features_branch_RNN_layer_5_type: SimpleRNN
# base_features_branch_hp_units_at_hp_layer_2: 128
# base_features_branch_recurrent_dropout_2: 0.1
# base_features_branch_RNN_layer_2_type: LSTM
# base_features_branch_hp_units_at_hp_layer_3: 64
# base_features_branch_recurrent_dropout_3: 0.2
# base_features_branch_RNN_layer_3_type: LSTM
# high_low_features_branch_hp_units_at_hp_layer_2: 32
# high_low_features_branch_recurrent_dropout_2: 0.2
# high_low_features_branch_RNN_layer_2_type: SimpleRNN
# high_low_features_branch_hp_units_at_hp_layer_3: 256
# high_low_features_branch_recurrent_dropout_3: 0.4
# high_low_features_branch_RNN_layer_3_type: SimpleRNN
# batch_size: 64
# tuner/epochs: 10
# tuner/initial_epoch: 4
# tuner/bracket: 2
# tuner/round: 2
# close_features_branch_hp_units_at_hp_layer_2: 32
# close_features_branch_recurrent_dropout_2: 0.0
# close_features_branch_RNN_layer_2_type: SimpleRNN
# close_features_branch_hp_units_at_hp_layer_3: 32
# close_features_branch_recurrent_dropout_3: 0.0
# close_features_branch_RNN_layer_3_type: SimpleRNN
# close_features_branch_hp_units_at_hp_layer_4: 32
# close_features_branch_recurrent_dropout_4: 0.0
# close_features_branch_RNN_layer_4_type: SimpleRNN
# close_features_branch_hp_units_at_hp_layer_5: 32
# close_features_branch_recurrent_dropout_5: 0.0
# close_features_branch_RNN_layer_5_type: SimpleRNN
# high_low_features_branch_hp_units_at_hp_layer_4: 32
# high_low_features_branch_recurrent_dropout_4: 0.0
# high_low_features_branch_RNN_layer_4_type: SimpleRNN
# high_low_features_branch_hp_units_at_hp_layer_5: 32
# high_low_features_branch_recurrent_dropout_5: 0.0
# high_low_features_branch_RNN_layer_5_type: SimpleRNN
# volume_features_branch_hp_units_at_hp_layer_2: 32
# volume_features_branch_recurrent_dropout_2: 0.0
# volume_features_branch_RNN_layer_2_type: SimpleRNN
# volume_features_branch_hp_units_at_hp_layer_3: 32
# volume_features_branch_recurrent_dropout_3: 0.0
# volume_features_branch_RNN_layer_3_type: SimpleRNN
# tuner/trial_id: 0012
# base_features_branch_hp_units_at_hp_layer_4: 256
# base_features_branch_recurrent_dropout_4: 0.4
# base_features_branch_RNN_layer_4_type: LSTM
# base_features_branch_hp_units_at_hp_layer_5: 256
# base_features_branch_recurrent_dropout_5: 0.0
# base_features_branch_RNN_layer_5_type: SimpleRNN
# volume_features_branch_hp_units_at_hp_layer_4: 64
# volume_features_branch_recurrent_dropout_4: 0.0
# volume_features_branch_RNN_layer_4_type: LSTM
# volume_features_branch_hp_units_at_hp_layer_5: 128
# volume_features_branch_recurrent_dropout_5: 0.1
# volume_features_branch_RNN_layer_5_type: GRU
# Score: 0.5491329431533813
#
# Trial 0021 summary
# Hyperparameters:
# all_features_branch_filters_SeparableConv1D: 16
# all_features_branch_SeparableConv1D_kernel_size: 3
# all_features_branch_hp_layers: 6
# all_features_branch_hp_units_at_hp_layer_0: 128
# all_features_branch_recurrent_dropout_0: 0.0
# all_features_branch_RNN_layer_0_type: SimpleRNN
# all_features_branch_hp_units_at_hp_layer_1: 128
# all_features_branch_recurrent_dropout_1: 0.4
# all_features_branch_RNN_layer_1_type: SimpleRNN
# base_features_branch_filters_SeparableConv1D: 128
# base_features_branch_SeparableConv1D_kernel_size: 3
# base_features_branch_hp_layers: 6
# base_features_branch_hp_units_at_hp_layer_0: 32
# base_features_branch_recurrent_dropout_0: 0.1
# base_features_branch_RNN_layer_0_type: SimpleRNN
# base_features_branch_hp_units_at_hp_layer_1: 64
# base_features_branch_recurrent_dropout_1: 0.2
# base_features_branch_RNN_layer_1_type: GRU
# close_features_branch_filters_SeparableConv1D: 64
# close_features_branch_SeparableConv1D_kernel_size: 3
# close_features_branch_hp_layers: 6
# close_features_branch_hp_units_at_hp_layer_0: 32
# close_features_branch_recurrent_dropout_0: 0.2
# close_features_branch_RNN_layer_0_type: GRU
# close_features_branch_hp_units_at_hp_layer_1: 32
# close_features_branch_recurrent_dropout_1: 0.1
# close_features_branch_RNN_layer_1_type: SimpleRNN
# high_low_features_branch_filters_SeparableConv1D: 32
# high_low_features_branch_SeparableConv1D_kernel_size: 3
# high_low_features_branch_hp_layers: 4
# high_low_features_branch_hp_units_at_hp_layer_0: 32
# high_low_features_branch_recurrent_dropout_0: 0.4
# high_low_features_branch_RNN_layer_0_type: SimpleRNN
# high_low_features_branch_hp_units_at_hp_layer_1: 128
# high_low_features_branch_recurrent_dropout_1: 0.30000000000000004
# high_low_features_branch_RNN_layer_1_type: GRU
# volume_features_branch_filters_SeparableConv1D: 128
# volume_features_branch_SeparableConv1D_kernel_size: 5
# volume_features_branch_hp_layers: 6
# volume_features_branch_hp_units_at_hp_layer_0: 32
# volume_features_branch_recurrent_dropout_0: 0.30000000000000004
# volume_features_branch_RNN_layer_0_type: GRU
# volume_features_branch_hp_units_at_hp_layer_1: 256
# volume_features_branch_recurrent_dropout_1: 0.4
# volume_features_branch_RNN_layer_1_type: LSTM
# optimizer_type: SGD
# learning_rate: 0.0006681672318520809
# all_features_branch_hp_units_at_hp_layer_2: 64
# all_features_branch_recurrent_dropout_2: 0.0
# all_features_branch_RNN_layer_2_type: GRU
# all_features_branch_hp_units_at_hp_layer_3: 64
# all_features_branch_recurrent_dropout_3: 0.0
# all_features_branch_RNN_layer_3_type: LSTM
# all_features_branch_hp_units_at_hp_layer_4: 256
# all_features_branch_recurrent_dropout_4: 0.1
# all_features_branch_RNN_layer_4_type: LSTM
# all_features_branch_hp_units_at_hp_layer_5: 256
# all_features_branch_recurrent_dropout_5: 0.30000000000000004
# all_features_branch_RNN_layer_5_type: GRU
# base_features_branch_hp_units_at_hp_layer_2: 64
# base_features_branch_recurrent_dropout_2: 0.30000000000000004
# base_features_branch_RNN_layer_2_type: GRU
# base_features_branch_hp_units_at_hp_layer_3: 128
# base_features_branch_recurrent_dropout_3: 0.30000000000000004
# base_features_branch_RNN_layer_3_type: GRU
# high_low_features_branch_hp_units_at_hp_layer_2: 128
# high_low_features_branch_recurrent_dropout_2: 0.2
# high_low_features_branch_RNN_layer_2_type: GRU
# high_low_features_branch_hp_units_at_hp_layer_3: 128
# high_low_features_branch_recurrent_dropout_3: 0.4
# high_low_features_branch_RNN_layer_3_type: GRU
# batch_size: 16
# close_features_branch_hp_units_at_hp_layer_2: 128
# close_features_branch_recurrent_dropout_2: 0.1
# close_features_branch_RNN_layer_2_type: GRU
# close_features_branch_hp_units_at_hp_layer_3: 64
# close_features_branch_recurrent_dropout_3: 0.0
# close_features_branch_RNN_layer_3_type: GRU
# close_features_branch_hp_units_at_hp_layer_4: 64
# close_features_branch_recurrent_dropout_4: 0.0
# close_features_branch_RNN_layer_4_type: SimpleRNN
# close_features_branch_hp_units_at_hp_layer_5: 64
# close_features_branch_recurrent_dropout_5: 0.1
# close_features_branch_RNN_layer_5_type: GRU
# high_low_features_branch_hp_units_at_hp_layer_4: 64
# high_low_features_branch_recurrent_dropout_4: 0.2
# high_low_features_branch_RNN_layer_4_type: SimpleRNN
# high_low_features_branch_hp_units_at_hp_layer_5: 128
# high_low_features_branch_recurrent_dropout_5: 0.30000000000000004
# high_low_features_branch_RNN_layer_5_type: LSTM
# volume_features_branch_hp_units_at_hp_layer_2: 32
# volume_features_branch_recurrent_dropout_2: 0.1
# volume_features_branch_RNN_layer_2_type: GRU
# volume_features_branch_hp_units_at_hp_layer_3: 256
# volume_features_branch_recurrent_dropout_3: 0.30000000000000004
# volume_features_branch_RNN_layer_3_type: SimpleRNN
# base_features_branch_hp_units_at_hp_layer_4: 32
# base_features_branch_recurrent_dropout_4: 0.30000000000000004
# base_features_branch_RNN_layer_4_type: LSTM
# base_features_branch_hp_units_at_hp_layer_5: 256
# base_features_branch_recurrent_dropout_5: 0.2
# base_features_branch_RNN_layer_5_type: LSTM
# volume_features_branch_hp_units_at_hp_layer_4: 64
# volume_features_branch_recurrent_dropout_4: 0.2
# volume_features_branch_RNN_layer_4_type: LSTM
# volume_features_branch_hp_units_at_hp_layer_5: 128
# volume_features_branch_recurrent_dropout_5: 0.2
# volume_features_branch_RNN_layer_5_type: SimpleRNN
# tuner/epochs: 4
# tuner/initial_epoch: 0
# tuner/bracket: 1
# tuner/round: 0
# Score: 0.5472061634063721
#
# Trial 0016 summary
# Hyperparameters:
# all_features_branch_filters_SeparableConv1D: 128
# all_features_branch_SeparableConv1D_kernel_size: 3
# all_features_branch_hp_layers: 2
# all_features_branch_hp_units_at_hp_layer_0: 256
# all_features_branch_recurrent_dropout_0: 0.1
# all_features_branch_RNN_layer_0_type: GRU
# all_features_branch_hp_units_at_hp_layer_1: 256
# all_features_branch_recurrent_dropout_1: 0.4
# all_features_branch_RNN_layer_1_type: GRU
# base_features_branch_filters_SeparableConv1D: 64
# base_features_branch_SeparableConv1D_kernel_size: 5
# base_features_branch_hp_layers: 6
# base_features_branch_hp_units_at_hp_layer_0: 32
# base_features_branch_recurrent_dropout_0: 0.1
# base_features_branch_RNN_layer_0_type: LSTM
# base_features_branch_hp_units_at_hp_layer_1: 32
# base_features_branch_recurrent_dropout_1: 0.30000000000000004
# base_features_branch_RNN_layer_1_type: GRU
# close_features_branch_filters_SeparableConv1D: 32
# close_features_branch_SeparableConv1D_kernel_size: 3
# close_features_branch_hp_layers: 4
# close_features_branch_hp_units_at_hp_layer_0: 64
# close_features_branch_recurrent_dropout_0: 0.2
# close_features_branch_RNN_layer_0_type: GRU
# close_features_branch_hp_units_at_hp_layer_1: 128
# close_features_branch_recurrent_dropout_1: 0.1
# close_features_branch_RNN_layer_1_type: SimpleRNN
# high_low_features_branch_filters_SeparableConv1D: 16
# high_low_features_branch_SeparableConv1D_kernel_size: 5
# high_low_features_branch_hp_layers: 6
# high_low_features_branch_hp_units_at_hp_layer_0: 256
# high_low_features_branch_recurrent_dropout_0: 0.2
# high_low_features_branch_RNN_layer_0_type: SimpleRNN
# high_low_features_branch_hp_units_at_hp_layer_1: 64
# high_low_features_branch_recurrent_dropout_1: 0.2
# high_low_features_branch_RNN_layer_1_type: SimpleRNN
# volume_features_branch_filters_SeparableConv1D: 64
# volume_features_branch_SeparableConv1D_kernel_size: 3
# volume_features_branch_hp_layers: 6
# volume_features_branch_hp_units_at_hp_layer_0: 32
# volume_features_branch_recurrent_dropout_0: 0.30000000000000004
# volume_features_branch_RNN_layer_0_type: LSTM
# volume_features_branch_hp_units_at_hp_layer_1: 128
# volume_features_branch_recurrent_dropout_1: 0.2
# volume_features_branch_RNN_layer_1_type: GRU
# optimizer_type: SGD
# learning_rate: 0.003921412901411757
# all_features_branch_hp_units_at_hp_layer_2: 32
# all_features_branch_recurrent_dropout_2: 0.0
# all_features_branch_RNN_layer_2_type: LSTM
# all_features_branch_hp_units_at_hp_layer_3: 32
# all_features_branch_recurrent_dropout_3: 0.0
# all_features_branch_RNN_layer_3_type: GRU
# all_features_branch_hp_units_at_hp_layer_4: 128
# all_features_branch_recurrent_dropout_4: 0.1
# all_features_branch_RNN_layer_4_type: SimpleRNN
# all_features_branch_hp_units_at_hp_layer_5: 256
# all_features_branch_recurrent_dropout_5: 0.1
# all_features_branch_RNN_layer_5_type: GRU
# base_features_branch_hp_units_at_hp_layer_2: 64
# base_features_branch_recurrent_dropout_2: 0.2
# base_features_branch_RNN_layer_2_type: GRU
# base_features_branch_hp_units_at_hp_layer_3: 32
# base_features_branch_recurrent_dropout_3: 0.2
# base_features_branch_RNN_layer_3_type: LSTM
# high_low_features_branch_hp_units_at_hp_layer_2: 32
# high_low_features_branch_recurrent_dropout_2: 0.30000000000000004
# high_low_features_branch_RNN_layer_2_type: GRU
# high_low_features_branch_hp_units_at_hp_layer_3: 128
# high_low_features_branch_recurrent_dropout_3: 0.0
# high_low_features_branch_RNN_layer_3_type: SimpleRNN
# batch_size: 32
# close_features_branch_hp_units_at_hp_layer_2: 32
# close_features_branch_recurrent_dropout_2: 0.4
# close_features_branch_RNN_layer_2_type: SimpleRNN
# close_features_branch_hp_units_at_hp_layer_3: 256
# close_features_branch_recurrent_dropout_3: 0.2
# close_features_branch_RNN_layer_3_type: SimpleRNN
# close_features_branch_hp_units_at_hp_layer_4: 256
# close_features_branch_recurrent_dropout_4: 0.30000000000000004
# close_features_branch_RNN_layer_4_type: GRU
# close_features_branch_hp_units_at_hp_layer_5: 32
# close_features_branch_recurrent_dropout_5: 0.2
# close_features_branch_RNN_layer_5_type: SimpleRNN
# high_low_features_branch_hp_units_at_hp_layer_4: 32
# high_low_features_branch_recurrent_dropout_4: 0.0
# high_low_features_branch_RNN_layer_4_type: GRU
# high_low_features_branch_hp_units_at_hp_layer_5: 128
# high_low_features_branch_recurrent_dropout_5: 0.0
# high_low_features_branch_RNN_layer_5_type: LSTM
# volume_features_branch_hp_units_at_hp_layer_2: 64
# volume_features_branch_recurrent_dropout_2: 0.2
# volume_features_branch_RNN_layer_2_type: GRU
# volume_features_branch_hp_units_at_hp_layer_3: 64
# volume_features_branch_recurrent_dropout_3: 0.1
# volume_features_branch_RNN_layer_3_type: SimpleRNN
# base_features_branch_hp_units_at_hp_layer_4: 32
# base_features_branch_recurrent_dropout_4: 0.30000000000000004
# base_features_branch_RNN_layer_4_type: LSTM
# base_features_branch_hp_units_at_hp_layer_5: 128
# base_features_branch_recurrent_dropout_5: 0.1
# base_features_branch_RNN_layer_5_type: SimpleRNN
# volume_features_branch_hp_units_at_hp_layer_4: 64
# volume_features_branch_recurrent_dropout_4: 0.0
# volume_features_branch_RNN_layer_4_type: SimpleRNN
# volume_features_branch_hp_units_at_hp_layer_5: 256
# volume_features_branch_recurrent_dropout_5: 0.1
# volume_features_branch_RNN_layer_5_type: GRU
# tuner/epochs: 10
# tuner/initial_epoch: 4
# tuner/bracket: 2
# tuner/round: 2
# tuner/trial_id: 0013
# Score: 0.5414258241653442
#
# Trial 0025 summary
# Hyperparameters:
# all_features_branch_filters_SeparableConv1D: 32
# all_features_branch_SeparableConv1D_kernel_size: 5
# all_features_branch_hp_layers: 2
# all_features_branch_hp_units_at_hp_layer_0: 256
# all_features_branch_recurrent_dropout_0: 0.0
# all_features_branch_RNN_layer_0_type: LSTM
# all_features_branch_hp_units_at_hp_layer_1: 256
# all_features_branch_recurrent_dropout_1: 0.1
# all_features_branch_RNN_layer_1_type: SimpleRNN
# base_features_branch_filters_SeparableConv1D: 128
# base_features_branch_SeparableConv1D_kernel_size: 5
# base_features_branch_hp_layers: 2
# base_features_branch_hp_units_at_hp_layer_0: 128
# base_features_branch_recurrent_dropout_0: 0.1
# base_features_branch_RNN_layer_0_type: LSTM
# base_features_branch_hp_units_at_hp_layer_1: 128
# base_features_branch_recurrent_dropout_1: 0.2
# base_features_branch_RNN_layer_1_type: GRU
# close_features_branch_filters_SeparableConv1D: 32
# close_features_branch_SeparableConv1D_kernel_size: 5
# close_features_branch_hp_layers: 2
# close_features_branch_hp_units_at_hp_layer_0: 128
# close_features_branch_recurrent_dropout_0: 0.0
# close_features_branch_RNN_layer_0_type: SimpleRNN
# close_features_branch_hp_units_at_hp_layer_1: 256
# close_features_branch_recurrent_dropout_1: 0.30000000000000004
# close_features_branch_RNN_layer_1_type: SimpleRNN
# high_low_features_branch_filters_SeparableConv1D: 32
# high_low_features_branch_SeparableConv1D_kernel_size: 5
# high_low_features_branch_hp_layers: 2
# high_low_features_branch_hp_units_at_hp_layer_0: 256
# high_low_features_branch_recurrent_dropout_0: 0.0
# high_low_features_branch_RNN_layer_0_type: GRU
# high_low_features_branch_hp_units_at_hp_layer_1: 64
# high_low_features_branch_recurrent_dropout_1: 0.30000000000000004
# high_low_features_branch_RNN_layer_1_type: LSTM
# volume_features_branch_filters_SeparableConv1D: 16
# volume_features_branch_SeparableConv1D_kernel_size: 3
# volume_features_branch_hp_layers: 2
# volume_features_branch_hp_units_at_hp_layer_0: 64
# volume_features_branch_recurrent_dropout_0: 0.4
# volume_features_branch_RNN_layer_0_type: GRU
# volume_features_branch_hp_units_at_hp_layer_1: 128
# volume_features_branch_recurrent_dropout_1: 0.30000000000000004
# volume_features_branch_RNN_layer_1_type: GRU
# optimizer_type: SGD
# learning_rate: 0.006684722663543113
# all_features_branch_hp_units_at_hp_layer_2: 64
# all_features_branch_recurrent_dropout_2: 0.0
# all_features_branch_RNN_layer_2_type: GRU
# all_features_branch_hp_units_at_hp_layer_3: 128
# all_features_branch_recurrent_dropout_3: 0.2
# all_features_branch_RNN_layer_3_type: LSTM
# all_features_branch_hp_units_at_hp_layer_4: 256
# all_features_branch_recurrent_dropout_4: 0.1
# all_features_branch_RNN_layer_4_type: LSTM
# all_features_branch_hp_units_at_hp_layer_5: 64
# all_features_branch_recurrent_dropout_5: 0.30000000000000004
# all_features_branch_RNN_layer_5_type: LSTM
# base_features_branch_hp_units_at_hp_layer_2: 32
# base_features_branch_recurrent_dropout_2: 0.4
# base_features_branch_RNN_layer_2_type: SimpleRNN
# base_features_branch_hp_units_at_hp_layer_3: 128
# base_features_branch_recurrent_dropout_3: 0.4
# base_features_branch_RNN_layer_3_type: GRU
# high_low_features_branch_hp_units_at_hp_layer_2: 64
# high_low_features_branch_recurrent_dropout_2: 0.2
# high_low_features_branch_RNN_layer_2_type: GRU
# high_low_features_branch_hp_units_at_hp_layer_3: 256
# high_low_features_branch_recurrent_dropout_3: 0.30000000000000004
# high_low_features_branch_RNN_layer_3_type: SimpleRNN
# batch_size: 32
# close_features_branch_hp_units_at_hp_layer_2: 128
# close_features_branch_recurrent_dropout_2: 0.1
# close_features_branch_RNN_layer_2_type: LSTM
# close_features_branch_hp_units_at_hp_layer_3: 128
# close_features_branch_recurrent_dropout_3: 0.4
# close_features_branch_RNN_layer_3_type: GRU
# close_features_branch_hp_units_at_hp_layer_4: 256
# close_features_branch_recurrent_dropout_4: 0.4
# close_features_branch_RNN_layer_4_type: GRU
# close_features_branch_hp_units_at_hp_layer_5: 256
# close_features_branch_recurrent_dropout_5: 0.1
# close_features_branch_RNN_layer_5_type: SimpleRNN
# high_low_features_branch_hp_units_at_hp_layer_4: 32
# high_low_features_branch_recurrent_dropout_4: 0.2
# high_low_features_branch_RNN_layer_4_type: SimpleRNN
# high_low_features_branch_hp_units_at_hp_layer_5: 128
# high_low_features_branch_recurrent_dropout_5: 0.2
# high_low_features_branch_RNN_layer_5_type: SimpleRNN
# volume_features_branch_hp_units_at_hp_layer_2: 32
# volume_features_branch_recurrent_dropout_2: 0.1
# volume_features_branch_RNN_layer_2_type: SimpleRNN
# volume_features_branch_hp_units_at_hp_layer_3: 64
# volume_features_branch_recurrent_dropout_3: 0.0
# volume_features_branch_RNN_layer_3_type: LSTM
# base_features_branch_hp_units_at_hp_layer_4: 32
# base_features_branch_recurrent_dropout_4: 0.2
# base_features_branch_RNN_layer_4_type: SimpleRNN
# base_features_branch_hp_units_at_hp_layer_5: 128
# base_features_branch_recurrent_dropout_5: 0.0
# base_features_branch_RNN_layer_5_type: SimpleRNN
# volume_features_branch_hp_units_at_hp_layer_4: 32
# volume_features_branch_recurrent_dropout_4: 0.1
# volume_features_branch_RNN_layer_4_type: LSTM
# volume_features_branch_hp_units_at_hp_layer_5: 128
# volume_features_branch_recurrent_dropout_5: 0.0
# volume_features_branch_RNN_layer_5_type: LSTM
# tuner/epochs: 10
# tuner/initial_epoch: 4
# tuner/bracket: 1
# tuner/round: 1
# tuner/trial_id: 0023
# Score: 0.5414258241653442
#
# Trial 0023 summary
# Hyperparameters:
# all_features_branch_filters_SeparableConv1D: 32
# all_features_branch_SeparableConv1D_kernel_size: 5
# all_features_branch_hp_layers: 2
# all_features_branch_hp_units_at_hp_layer_0: 256
# all_features_branch_recurrent_dropout_0: 0.0
# all_features_branch_RNN_layer_0_type: LSTM
# all_features_branch_hp_units_at_hp_layer_1: 256
# all_features_branch_recurrent_dropout_1: 0.1
# all_features_branch_RNN_layer_1_type: SimpleRNN
# base_features_branch_filters_SeparableConv1D: 128
# base_features_branch_SeparableConv1D_kernel_size: 5
# base_features_branch_hp_layers: 2
# base_features_branch_hp_units_at_hp_layer_0: 128
# base_features_branch_recurrent_dropout_0: 0.1
# base_features_branch_RNN_layer_0_type: LSTM
# base_features_branch_hp_units_at_hp_layer_1: 128
# base_features_branch_recurrent_dropout_1: 0.2
# base_features_branch_RNN_layer_1_type: GRU
# close_features_branch_filters_SeparableConv1D: 32
# close_features_branch_SeparableConv1D_kernel_size: 5
# close_features_branch_hp_layers: 2
# close_features_branch_hp_units_at_hp_layer_0: 128
# close_features_branch_recurrent_dropout_0: 0.0
# close_features_branch_RNN_layer_0_type: SimpleRNN
# close_features_branch_hp_units_at_hp_layer_1: 256
# close_features_branch_recurrent_dropout_1: 0.30000000000000004
# close_features_branch_RNN_layer_1_type: SimpleRNN
# high_low_features_branch_filters_SeparableConv1D: 32
# high_low_features_branch_SeparableConv1D_kernel_size: 5
# high_low_features_branch_hp_layers: 2
# high_low_features_branch_hp_units_at_hp_layer_0: 256
# high_low_features_branch_recurrent_dropout_0: 0.0
# high_low_features_branch_RNN_layer_0_type: GRU
# high_low_features_branch_hp_units_at_hp_layer_1: 64
# high_low_features_branch_recurrent_dropout_1: 0.30000000000000004
# high_low_features_branch_RNN_layer_1_type: LSTM
# volume_features_branch_filters_SeparableConv1D: 16
# volume_features_branch_SeparableConv1D_kernel_size: 3
# volume_features_branch_hp_layers: 2
# volume_features_branch_hp_units_at_hp_layer_0: 64
# volume_features_branch_recurrent_dropout_0: 0.4
# volume_features_branch_RNN_layer_0_type: GRU
# volume_features_branch_hp_units_at_hp_layer_1: 128
# volume_features_branch_recurrent_dropout_1: 0.30000000000000004
# volume_features_branch_RNN_layer_1_type: GRU
# optimizer_type: SGD
# learning_rate: 0.006684722663543113
# all_features_branch_hp_units_at_hp_layer_2: 64
# all_features_branch_recurrent_dropout_2: 0.0
# all_features_branch_RNN_layer_2_type: GRU
# all_features_branch_hp_units_at_hp_layer_3: 128
# all_features_branch_recurrent_dropout_3: 0.2
# all_features_branch_RNN_layer_3_type: LSTM
# all_features_branch_hp_units_at_hp_layer_4: 256
# all_features_branch_recurrent_dropout_4: 0.1
# all_features_branch_RNN_layer_4_type: LSTM
# all_features_branch_hp_units_at_hp_layer_5: 64
# all_features_branch_recurrent_dropout_5: 0.30000000000000004
# all_features_branch_RNN_layer_5_type: LSTM
# base_features_branch_hp_units_at_hp_layer_2: 32
# base_features_branch_recurrent_dropout_2: 0.4
# base_features_branch_RNN_layer_2_type: SimpleRNN
# base_features_branch_hp_units_at_hp_layer_3: 128
# base_features_branch_recurrent_dropout_3: 0.4
# base_features_branch_RNN_layer_3_type: GRU
# high_low_features_branch_hp_units_at_hp_layer_2: 64
# high_low_features_branch_recurrent_dropout_2: 0.2
# high_low_features_branch_RNN_layer_2_type: GRU
# high_low_features_branch_hp_units_at_hp_layer_3: 256
# high_low_features_branch_recurrent_dropout_3: 0.30000000000000004
# high_low_features_branch_RNN_layer_3_type: SimpleRNN
# batch_size: 32
# close_features_branch_hp_units_at_hp_layer_2: 128
# close_features_branch_recurrent_dropout_2: 0.1
# close_features_branch_RNN_layer_2_type: LSTM
# close_features_branch_hp_units_at_hp_layer_3: 128
# close_features_branch_recurrent_dropout_3: 0.4
# close_features_branch_RNN_layer_3_type: GRU
# close_features_branch_hp_units_at_hp_layer_4: 256
# close_features_branch_recurrent_dropout_4: 0.4
# close_features_branch_RNN_layer_4_type: GRU
# close_features_branch_hp_units_at_hp_layer_5: 256
# close_features_branch_recurrent_dropout_5: 0.1
# close_features_branch_RNN_layer_5_type: SimpleRNN
# high_low_features_branch_hp_units_at_hp_layer_4: 32
# high_low_features_branch_recurrent_dropout_4: 0.2
# high_low_features_branch_RNN_layer_4_type: SimpleRNN
# high_low_features_branch_hp_units_at_hp_layer_5: 128
# high_low_features_branch_recurrent_dropout_5: 0.2
# high_low_features_branch_RNN_layer_5_type: SimpleRNN
# volume_features_branch_hp_units_at_hp_layer_2: 32
# volume_features_branch_recurrent_dropout_2: 0.1
# volume_features_branch_RNN_layer_2_type: SimpleRNN
# volume_features_branch_hp_units_at_hp_layer_3: 64
# volume_features_branch_recurrent_dropout_3: 0.0
# volume_features_branch_RNN_layer_3_type: LSTM
# base_features_branch_hp_units_at_hp_layer_4: 32
# base_features_branch_recurrent_dropout_4: 0.2
# base_features_branch_RNN_layer_4_type: SimpleRNN
# base_features_branch_hp_units_at_hp_layer_5: 128
# base_features_branch_recurrent_dropout_5: 0.0
# base_features_branch_RNN_layer_5_type: SimpleRNN
# volume_features_branch_hp_units_at_hp_layer_4: 32
# volume_features_branch_recurrent_dropout_4: 0.1
# volume_features_branch_RNN_layer_4_type: LSTM
# volume_features_branch_hp_units_at_hp_layer_5: 128
# volume_features_branch_recurrent_dropout_5: 0.0
# volume_features_branch_RNN_layer_5_type: LSTM
# tuner/epochs: 4
# tuner/initial_epoch: 0
# tuner/bracket: 1
# tuner/round: 0
# Score: 0.539499044418335
#
# Trial 0029 summary
# Hyperparameters:
# all_features_branch_filters_SeparableConv1D: 32
# all_features_branch_SeparableConv1D_kernel_size: 3
# all_features_branch_hp_layers: 4
# all_features_branch_hp_units_at_hp_layer_0: 32
# all_features_branch_recurrent_dropout_0: 0.0
# all_features_branch_RNN_layer_0_type: LSTM
# all_features_branch_hp_units_at_hp_layer_1: 32
# all_features_branch_recurrent_dropout_1: 0.4
# all_features_branch_RNN_layer_1_type: GRU
# base_features_branch_filters_SeparableConv1D: 16
# base_features_branch_SeparableConv1D_kernel_size: 3
# base_features_branch_hp_layers: 2
# base_features_branch_hp_units_at_hp_layer_0: 64
# base_features_branch_recurrent_dropout_0: 0.1
# base_features_branch_RNN_layer_0_type: GRU
# base_features_branch_hp_units_at_hp_layer_1: 32
# base_features_branch_recurrent_dropout_1: 0.4
# base_features_branch_RNN_layer_1_type: SimpleRNN
# close_features_branch_filters_SeparableConv1D: 128
# close_features_branch_SeparableConv1D_kernel_size: 5
# close_features_branch_hp_layers: 2
# close_features_branch_hp_units_at_hp_layer_0: 128
# close_features_branch_recurrent_dropout_0: 0.1
# close_features_branch_RNN_layer_0_type: LSTM
# close_features_branch_hp_units_at_hp_layer_1: 64
# close_features_branch_recurrent_dropout_1: 0.4
# close_features_branch_RNN_layer_1_type: GRU
# high_low_features_branch_filters_SeparableConv1D: 128
# high_low_features_branch_SeparableConv1D_kernel_size: 3
# high_low_features_branch_hp_layers: 4
# high_low_features_branch_hp_units_at_hp_layer_0: 32
# high_low_features_branch_recurrent_dropout_0: 0.2
# high_low_features_branch_RNN_layer_0_type: GRU
# high_low_features_branch_hp_units_at_hp_layer_1: 64
# high_low_features_branch_recurrent_dropout_1: 0.0
# high_low_features_branch_RNN_layer_1_type: SimpleRNN
# volume_features_branch_filters_SeparableConv1D: 32
# volume_features_branch_SeparableConv1D_kernel_size: 5
# volume_features_branch_hp_layers: 4
# volume_features_branch_hp_units_at_hp_layer_0: 128
# volume_features_branch_recurrent_dropout_0: 0.30000000000000004
# volume_features_branch_RNN_layer_0_type: GRU
# volume_features_branch_hp_units_at_hp_layer_1: 128
# volume_features_branch_recurrent_dropout_1: 0.4
# volume_features_branch_RNN_layer_1_type: SimpleRNN
# optimizer_type: RMSprop
# learning_rate: 0.005366151301172358
# all_features_branch_hp_units_at_hp_layer_2: 64
# all_features_branch_recurrent_dropout_2: 0.2
# all_features_branch_RNN_layer_2_type: LSTM
# all_features_branch_hp_units_at_hp_layer_3: 128
# all_features_branch_recurrent_dropout_3: 0.0
# all_features_branch_RNN_layer_3_type: LSTM
# all_features_branch_hp_units_at_hp_layer_4: 256
# all_features_branch_recurrent_dropout_4: 0.4
# all_features_branch_RNN_layer_4_type: SimpleRNN
# all_features_branch_hp_units_at_hp_layer_5: 128
# all_features_branch_recurrent_dropout_5: 0.0
# all_features_branch_RNN_layer_5_type: LSTM
# base_features_branch_hp_units_at_hp_layer_2: 64
# base_features_branch_recurrent_dropout_2: 0.4
# base_features_branch_RNN_layer_2_type: GRU
# base_features_branch_hp_units_at_hp_layer_3: 64
# base_features_branch_recurrent_dropout_3: 0.0
# base_features_branch_RNN_layer_3_type: GRU
# high_low_features_branch_hp_units_at_hp_layer_2: 256
# high_low_features_branch_recurrent_dropout_2: 0.0
# high_low_features_branch_RNN_layer_2_type: GRU
# high_low_features_branch_hp_units_at_hp_layer_3: 256
# high_low_features_branch_recurrent_dropout_3: 0.1
# high_low_features_branch_RNN_layer_3_type: SimpleRNN
# batch_size: 16
# close_features_branch_hp_units_at_hp_layer_2: 64
# close_features_branch_recurrent_dropout_2: 0.1
# close_features_branch_RNN_layer_2_type: GRU
# close_features_branch_hp_units_at_hp_layer_3: 128
# close_features_branch_recurrent_dropout_3: 0.4
# close_features_branch_RNN_layer_3_type: LSTM
# close_features_branch_hp_units_at_hp_layer_4: 64
# close_features_branch_recurrent_dropout_4: 0.0
# close_features_branch_RNN_layer_4_type: SimpleRNN
# close_features_branch_hp_units_at_hp_layer_5: 128
# close_features_branch_recurrent_dropout_5: 0.1
# close_features_branch_RNN_layer_5_type: SimpleRNN
# high_low_features_branch_hp_units_at_hp_layer_4: 32
# high_low_features_branch_recurrent_dropout_4: 0.0
# high_low_features_branch_RNN_layer_4_type: LSTM
# high_low_features_branch_hp_units_at_hp_layer_5: 128
# high_low_features_branch_recurrent_dropout_5: 0.2
# high_low_features_branch_RNN_layer_5_type: LSTM
# volume_features_branch_hp_units_at_hp_layer_2: 128
# volume_features_branch_recurrent_dropout_2: 0.30000000000000004
# volume_features_branch_RNN_layer_2_type: SimpleRNN
# volume_features_branch_hp_units_at_hp_layer_3: 256
# volume_features_branch_recurrent_dropout_3: 0.2
# volume_features_branch_RNN_layer_3_type: LSTM
# base_features_branch_hp_units_at_hp_layer_4: 64
# base_features_branch_recurrent_dropout_4: 0.30000000000000004
# base_features_branch_RNN_layer_4_type: GRU
# base_features_branch_hp_units_at_hp_layer_5: 32
# base_features_branch_recurrent_dropout_5: 0.4
# base_features_branch_RNN_layer_5_type: LSTM
# volume_features_branch_hp_units_at_hp_layer_4: 128
# volume_features_branch_recurrent_dropout_4: 0.2
# volume_features_branch_RNN_layer_4_type: GRU
# volume_features_branch_hp_units_at_hp_layer_5: 256
# volume_features_branch_recurrent_dropout_5: 0.1
# volume_features_branch_RNN_layer_5_type: SimpleRNN
# tuner/epochs: 10
# tuner/initial_epoch: 0
# tuner/bracket: 0
# tuner/round: 0
# Score: 0.539499044418335
#
# Trial 0001 summary
# Hyperparameters:
# all_features_branch_filters_SeparableConv1D: 32
# all_features_branch_SeparableConv1D_kernel_size: 3
# all_features_branch_hp_layers: 6
# all_features_branch_hp_units_at_hp_layer_0: 128
# all_features_branch_recurrent_dropout_0: 0.4
# all_features_branch_RNN_layer_0_type: GRU
# all_features_branch_hp_units_at_hp_layer_1: 32
# all_features_branch_recurrent_dropout_1: 0.2
# all_features_branch_RNN_layer_1_type: LSTM
# base_features_branch_filters_SeparableConv1D: 64
# base_features_branch_SeparableConv1D_kernel_size: 5
# base_features_branch_hp_layers: 4
# base_features_branch_hp_units_at_hp_layer_0: 32
# base_features_branch_recurrent_dropout_0: 0.2
# base_features_branch_RNN_layer_0_type: SimpleRNN
# base_features_branch_hp_units_at_hp_layer_1: 128
# base_features_branch_recurrent_dropout_1: 0.0
# base_features_branch_RNN_layer_1_type: SimpleRNN
# close_features_branch_filters_SeparableConv1D: 16
# close_features_branch_SeparableConv1D_kernel_size: 3
# close_features_branch_hp_layers: 6
# close_features_branch_hp_units_at_hp_layer_0: 64
# close_features_branch_recurrent_dropout_0: 0.30000000000000004
# close_features_branch_RNN_layer_0_type: GRU
# close_features_branch_hp_units_at_hp_layer_1: 64
# close_features_branch_recurrent_dropout_1: 0.1
# close_features_branch_RNN_layer_1_type: GRU
# high_low_features_branch_filters_SeparableConv1D: 32
# high_low_features_branch_SeparableConv1D_kernel_size: 3
# high_low_features_branch_hp_layers: 6
# high_low_features_branch_hp_units_at_hp_layer_0: 256
# high_low_features_branch_recurrent_dropout_0: 0.4
# high_low_features_branch_RNN_layer_0_type: SimpleRNN
# high_low_features_branch_hp_units_at_hp_layer_1: 128
# high_low_features_branch_recurrent_dropout_1: 0.2
# high_low_features_branch_RNN_layer_1_type: SimpleRNN
# volume_features_branch_filters_SeparableConv1D: 32
# volume_features_branch_SeparableConv1D_kernel_size: 5
# volume_features_branch_hp_layers: 4
# volume_features_branch_hp_units_at_hp_layer_0: 64
# volume_features_branch_recurrent_dropout_0: 0.30000000000000004
# volume_features_branch_RNN_layer_0_type: LSTM
# volume_features_branch_hp_units_at_hp_layer_1: 32
# volume_features_branch_recurrent_dropout_1: 0.30000000000000004
# volume_features_branch_RNN_layer_1_type: LSTM
# optimizer_type: RMSprop
# learning_rate: 0.004263664986805526
# all_features_branch_hp_units_at_hp_layer_2: 128
# all_features_branch_recurrent_dropout_2: 0.30000000000000004
# all_features_branch_RNN_layer_2_type: LSTM
# all_features_branch_hp_units_at_hp_layer_3: 32
# all_features_branch_recurrent_dropout_3: 0.1
# all_features_branch_RNN_layer_3_type: SimpleRNN
# all_features_branch_hp_units_at_hp_layer_4: 32
# all_features_branch_recurrent_dropout_4: 0.30000000000000004
# all_features_branch_RNN_layer_4_type: SimpleRNN
# all_features_branch_hp_units_at_hp_layer_5: 64
# all_features_branch_recurrent_dropout_5: 0.2
# all_features_branch_RNN_layer_5_type: SimpleRNN
# base_features_branch_hp_units_at_hp_layer_2: 128
# base_features_branch_recurrent_dropout_2: 0.1
# base_features_branch_RNN_layer_2_type: LSTM
# base_features_branch_hp_units_at_hp_layer_3: 64
# base_features_branch_recurrent_dropout_3: 0.2
# base_features_branch_RNN_layer_3_type: LSTM
# high_low_features_branch_hp_units_at_hp_layer_2: 32
# high_low_features_branch_recurrent_dropout_2: 0.2
# high_low_features_branch_RNN_layer_2_type: SimpleRNN
# high_low_features_branch_hp_units_at_hp_layer_3: 256
# high_low_features_branch_recurrent_dropout_3: 0.4
# high_low_features_branch_RNN_layer_3_type: SimpleRNN
# batch_size: 64
# tuner/epochs: 2
# tuner/initial_epoch: 0
# tuner/bracket: 2
# tuner/round: 0
# close_features_branch_hp_units_at_hp_layer_2: 32
# close_features_branch_recurrent_dropout_2: 0.0
# close_features_branch_RNN_layer_2_type: SimpleRNN
# close_features_branch_hp_units_at_hp_layer_3: 32
# close_features_branch_recurrent_dropout_3: 0.0
# close_features_branch_RNN_layer_3_type: SimpleRNN
# close_features_branch_hp_units_at_hp_layer_4: 32
# close_features_branch_recurrent_dropout_4: 0.0
# close_features_branch_RNN_layer_4_type: SimpleRNN
# close_features_branch_hp_units_at_hp_layer_5: 32
# close_features_branch_recurrent_dropout_5: 0.0
# close_features_branch_RNN_layer_5_type: SimpleRNN
# high_low_features_branch_hp_units_at_hp_layer_4: 32
# high_low_features_branch_recurrent_dropout_4: 0.0
# high_low_features_branch_RNN_layer_4_type: SimpleRNN
# high_low_features_branch_hp_units_at_hp_layer_5: 32
# high_low_features_branch_recurrent_dropout_5: 0.0
# high_low_features_branch_RNN_layer_5_type: SimpleRNN
# volume_features_branch_hp_units_at_hp_layer_2: 32
# volume_features_branch_recurrent_dropout_2: 0.0
# volume_features_branch_RNN_layer_2_type: SimpleRNN
# volume_features_branch_hp_units_at_hp_layer_3: 32
# volume_features_branch_recurrent_dropout_3: 0.0
# volume_features_branch_RNN_layer_3_type: SimpleRNN
# Score: 0.5375722646713257
#
# Trial 0022 summary
# Hyperparameters:
# all_features_branch_filters_SeparableConv1D: 32
# all_features_branch_SeparableConv1D_kernel_size: 5
# all_features_branch_hp_layers: 6
# all_features_branch_hp_units_at_hp_layer_0: 256
# all_features_branch_recurrent_dropout_0: 0.30000000000000004
# all_features_branch_RNN_layer_0_type: GRU
# all_features_branch_hp_units_at_hp_layer_1: 256
# all_features_branch_recurrent_dropout_1: 0.2
# all_features_branch_RNN_layer_1_type: SimpleRNN
# base_features_branch_filters_SeparableConv1D: 128
# base_features_branch_SeparableConv1D_kernel_size: 3
# base_features_branch_hp_layers: 4
# base_features_branch_hp_units_at_hp_layer_0: 64
# base_features_branch_recurrent_dropout_0: 0.4
# base_features_branch_RNN_layer_0_type: GRU
# base_features_branch_hp_units_at_hp_layer_1: 64
# base_features_branch_recurrent_dropout_1: 0.0
# base_features_branch_RNN_layer_1_type: SimpleRNN
# close_features_branch_filters_SeparableConv1D: 16
# close_features_branch_SeparableConv1D_kernel_size: 5
# close_features_branch_hp_layers: 4
# close_features_branch_hp_units_at_hp_layer_0: 256
# close_features_branch_recurrent_dropout_0: 0.0
# close_features_branch_RNN_layer_0_type: LSTM
# close_features_branch_hp_units_at_hp_layer_1: 32
# close_features_branch_recurrent_dropout_1: 0.0
# close_features_branch_RNN_layer_1_type: SimpleRNN
# high_low_features_branch_filters_SeparableConv1D: 128
# high_low_features_branch_SeparableConv1D_kernel_size: 3
# high_low_features_branch_hp_layers: 2
# high_low_features_branch_hp_units_at_hp_layer_0: 128
# high_low_features_branch_recurrent_dropout_0: 0.1
# high_low_features_branch_RNN_layer_0_type: GRU
# high_low_features_branch_hp_units_at_hp_layer_1: 128
# high_low_features_branch_recurrent_dropout_1: 0.0
# high_low_features_branch_RNN_layer_1_type: LSTM
# volume_features_branch_filters_SeparableConv1D: 32
# volume_features_branch_SeparableConv1D_kernel_size: 5
# volume_features_branch_hp_layers: 2
# volume_features_branch_hp_units_at_hp_layer_0: 64
# volume_features_branch_recurrent_dropout_0: 0.4
# volume_features_branch_RNN_layer_0_type: GRU
# volume_features_branch_hp_units_at_hp_layer_1: 64
# volume_features_branch_recurrent_dropout_1: 0.0
# volume_features_branch_RNN_layer_1_type: SimpleRNN
# optimizer_type: SGD
# learning_rate: 0.00023848607337142235
# all_features_branch_hp_units_at_hp_layer_2: 256
# all_features_branch_recurrent_dropout_2: 0.30000000000000004
# all_features_branch_RNN_layer_2_type: GRU
# all_features_branch_hp_units_at_hp_layer_3: 32
# all_features_branch_recurrent_dropout_3: 0.30000000000000004
# all_features_branch_RNN_layer_3_type: LSTM
# all_features_branch_hp_units_at_hp_layer_4: 32
# all_features_branch_recurrent_dropout_4: 0.1
# all_features_branch_RNN_layer_4_type: GRU
# all_features_branch_hp_units_at_hp_layer_5: 256
# all_features_branch_recurrent_dropout_5: 0.1
# all_features_branch_RNN_layer_5_type: SimpleRNN
# base_features_branch_hp_units_at_hp_layer_2: 128
# base_features_branch_recurrent_dropout_2: 0.4
# base_features_branch_RNN_layer_2_type: SimpleRNN
# base_features_branch_hp_units_at_hp_layer_3: 64
# base_features_branch_recurrent_dropout_3: 0.0
# base_features_branch_RNN_layer_3_type: SimpleRNN
# high_low_features_branch_hp_units_at_hp_layer_2: 64
# high_low_features_branch_recurrent_dropout_2: 0.1
# high_low_features_branch_RNN_layer_2_type: LSTM
# high_low_features_branch_hp_units_at_hp_layer_3: 128
# high_low_features_branch_recurrent_dropout_3: 0.2
# high_low_features_branch_RNN_layer_3_type: GRU
# batch_size: 32
# close_features_branch_hp_units_at_hp_layer_2: 128
# close_features_branch_recurrent_dropout_2: 0.0
# close_features_branch_RNN_layer_2_type: LSTM
# close_features_branch_hp_units_at_hp_layer_3: 64
# close_features_branch_recurrent_dropout_3: 0.0
# close_features_branch_RNN_layer_3_type: GRU
# close_features_branch_hp_units_at_hp_layer_4: 128
# close_features_branch_recurrent_dropout_4: 0.0
# close_features_branch_RNN_layer_4_type: GRU
# close_features_branch_hp_units_at_hp_layer_5: 128
# close_features_branch_recurrent_dropout_5: 0.0
# close_features_branch_RNN_layer_5_type: GRU
# high_low_features_branch_hp_units_at_hp_layer_4: 128
# high_low_features_branch_recurrent_dropout_4: 0.0
# high_low_features_branch_RNN_layer_4_type: SimpleRNN
# high_low_features_branch_hp_units_at_hp_layer_5: 256
# high_low_features_branch_recurrent_dropout_5: 0.4
# high_low_features_branch_RNN_layer_5_type: SimpleRNN
# volume_features_branch_hp_units_at_hp_layer_2: 64
# volume_features_branch_recurrent_dropout_2: 0.1
# volume_features_branch_RNN_layer_2_type: LSTM
# volume_features_branch_hp_units_at_hp_layer_3: 32
# volume_features_branch_recurrent_dropout_3: 0.30000000000000004
# volume_features_branch_RNN_layer_3_type: LSTM
# base_features_branch_hp_units_at_hp_layer_4: 128
# base_features_branch_recurrent_dropout_4: 0.4
# base_features_branch_RNN_layer_4_type: SimpleRNN
# base_features_branch_hp_units_at_hp_layer_5: 128
# base_features_branch_recurrent_dropout_5: 0.0
# base_features_branch_RNN_layer_5_type: GRU
# volume_features_branch_hp_units_at_hp_layer_4: 32
# volume_features_branch_recurrent_dropout_4: 0.2
# volume_features_branch_RNN_layer_4_type: LSTM
# volume_features_branch_hp_units_at_hp_layer_5: 64
# volume_features_branch_recurrent_dropout_5: 0.4
# volume_features_branch_RNN_layer_5_type: SimpleRNN
# tuner/epochs: 4
# tuner/initial_epoch: 0
# tuner/bracket: 1
# tuner/round: 0
# Score: 0.5375722646713257
#
# Trial 0020 summary
# Hyperparameters:
# all_features_branch_filters_SeparableConv1D: 128
# all_features_branch_SeparableConv1D_kernel_size: 5
# all_features_branch_hp_layers: 2
# all_features_branch_hp_units_at_hp_layer_0: 64
# all_features_branch_recurrent_dropout_0: 0.4
# all_features_branch_RNN_layer_0_type: SimpleRNN
# all_features_branch_hp_units_at_hp_layer_1: 32
# all_features_branch_recurrent_dropout_1: 0.1
# all_features_branch_RNN_layer_1_type: SimpleRNN
# base_features_branch_filters_SeparableConv1D: 64
# base_features_branch_SeparableConv1D_kernel_size: 3
# base_features_branch_hp_layers: 4
# base_features_branch_hp_units_at_hp_layer_0: 256
# base_features_branch_recurrent_dropout_0: 0.0
# base_features_branch_RNN_layer_0_type: SimpleRNN
# base_features_branch_hp_units_at_hp_layer_1: 32
# base_features_branch_recurrent_dropout_1: 0.1
# base_features_branch_RNN_layer_1_type: GRU
# close_features_branch_filters_SeparableConv1D: 32
# close_features_branch_SeparableConv1D_kernel_size: 3
# close_features_branch_hp_layers: 4
# close_features_branch_hp_units_at_hp_layer_0: 128
# close_features_branch_recurrent_dropout_0: 0.0
# close_features_branch_RNN_layer_0_type: GRU
# close_features_branch_hp_units_at_hp_layer_1: 32
# close_features_branch_recurrent_dropout_1: 0.1
# close_features_branch_RNN_layer_1_type: SimpleRNN
# high_low_features_branch_filters_SeparableConv1D: 16
# high_low_features_branch_SeparableConv1D_kernel_size: 3
# high_low_features_branch_hp_layers: 2
# high_low_features_branch_hp_units_at_hp_layer_0: 128
# high_low_features_branch_recurrent_dropout_0: 0.0
# high_low_features_branch_RNN_layer_0_type: SimpleRNN
# high_low_features_branch_hp_units_at_hp_layer_1: 256
# high_low_features_branch_recurrent_dropout_1: 0.30000000000000004
# high_low_features_branch_RNN_layer_1_type: LSTM
# volume_features_branch_filters_SeparableConv1D: 32
# volume_features_branch_SeparableConv1D_kernel_size: 3
# volume_features_branch_hp_layers: 2
# volume_features_branch_hp_units_at_hp_layer_0: 128
# volume_features_branch_recurrent_dropout_0: 0.4
# volume_features_branch_RNN_layer_0_type: GRU
# volume_features_branch_hp_units_at_hp_layer_1: 64
# volume_features_branch_recurrent_dropout_1: 0.1
# volume_features_branch_RNN_layer_1_type: GRU
# optimizer_type: RMSprop
# learning_rate: 0.00035910093218825
# all_features_branch_hp_units_at_hp_layer_2: 32
# all_features_branch_recurrent_dropout_2: 0.0
# all_features_branch_RNN_layer_2_type: SimpleRNN
# all_features_branch_hp_units_at_hp_layer_3: 64
# all_features_branch_recurrent_dropout_3: 0.0
# all_features_branch_RNN_layer_3_type: SimpleRNN
# all_features_branch_hp_units_at_hp_layer_4: 32
# all_features_branch_recurrent_dropout_4: 0.0
# all_features_branch_RNN_layer_4_type: GRU
# all_features_branch_hp_units_at_hp_layer_5: 32
# all_features_branch_recurrent_dropout_5: 0.2
# all_features_branch_RNN_layer_5_type: LSTM
# base_features_branch_hp_units_at_hp_layer_2: 256
# base_features_branch_recurrent_dropout_2: 0.0
# base_features_branch_RNN_layer_2_type: LSTM
# base_features_branch_hp_units_at_hp_layer_3: 64
# base_features_branch_recurrent_dropout_3: 0.1
# base_features_branch_RNN_layer_3_type: LSTM
# high_low_features_branch_hp_units_at_hp_layer_2: 32
# high_low_features_branch_recurrent_dropout_2: 0.4
# high_low_features_branch_RNN_layer_2_type: GRU
# high_low_features_branch_hp_units_at_hp_layer_3: 256
# high_low_features_branch_recurrent_dropout_3: 0.30000000000000004
# high_low_features_branch_RNN_layer_3_type: LSTM
# batch_size: 64
# close_features_branch_hp_units_at_hp_layer_2: 32
# close_features_branch_recurrent_dropout_2: 0.4
# close_features_branch_RNN_layer_2_type: SimpleRNN
# close_features_branch_hp_units_at_hp_layer_3: 128
# close_features_branch_recurrent_dropout_3: 0.4
# close_features_branch_RNN_layer_3_type: GRU
# close_features_branch_hp_units_at_hp_layer_4: 32
# close_features_branch_recurrent_dropout_4: 0.0
# close_features_branch_RNN_layer_4_type: LSTM
# close_features_branch_hp_units_at_hp_layer_5: 128
# close_features_branch_recurrent_dropout_5: 0.2
# close_features_branch_RNN_layer_5_type: GRU
# high_low_features_branch_hp_units_at_hp_layer_4: 128
# high_low_features_branch_recurrent_dropout_4: 0.30000000000000004
# high_low_features_branch_RNN_layer_4_type: LSTM
# high_low_features_branch_hp_units_at_hp_layer_5: 256
# high_low_features_branch_recurrent_dropout_5: 0.30000000000000004
# high_low_features_branch_RNN_layer_5_type: LSTM
# volume_features_branch_hp_units_at_hp_layer_2: 32
# volume_features_branch_recurrent_dropout_2: 0.2
# volume_features_branch_RNN_layer_2_type: GRU
# volume_features_branch_hp_units_at_hp_layer_3: 128
# volume_features_branch_recurrent_dropout_3: 0.1
# volume_features_branch_RNN_layer_3_type: SimpleRNN
# base_features_branch_hp_units_at_hp_layer_4: 128
# base_features_branch_recurrent_dropout_4: 0.0
# base_features_branch_RNN_layer_4_type: SimpleRNN
# base_features_branch_hp_units_at_hp_layer_5: 128
# base_features_branch_recurrent_dropout_5: 0.1
# base_features_branch_RNN_layer_5_type: LSTM
# volume_features_branch_hp_units_at_hp_layer_4: 256
# volume_features_branch_recurrent_dropout_4: 0.4
# volume_features_branch_RNN_layer_4_type: SimpleRNN
# volume_features_branch_hp_units_at_hp_layer_5: 256
# volume_features_branch_recurrent_dropout_5: 0.4
# volume_features_branch_RNN_layer_5_type: LSTM
# tuner/epochs: 4
# tuner/initial_epoch: 0
# tuner/bracket: 1
# tuner/round: 0
# Score: 0.5356454849243164
#
# Trial 0005 summary
# Hyperparameters:
# all_features_branch_filters_SeparableConv1D: 128
# all_features_branch_SeparableConv1D_kernel_size: 3
# all_features_branch_hp_layers: 2
# all_features_branch_hp_units_at_hp_layer_0: 256
# all_features_branch_recurrent_dropout_0: 0.1
# all_features_branch_RNN_layer_0_type: GRU
# all_features_branch_hp_units_at_hp_layer_1: 256
# all_features_branch_recurrent_dropout_1: 0.4
# all_features_branch_RNN_layer_1_type: GRU
# base_features_branch_filters_SeparableConv1D: 64
# base_features_branch_SeparableConv1D_kernel_size: 5
# base_features_branch_hp_layers: 6
# base_features_branch_hp_units_at_hp_layer_0: 32
# ...
# all_features_branch_filters_SeparableConv1D: 32
# all_features_branch_SeparableConv1D_kernel_size: 5
# all_features_branch_hp_layers: 2
# all_features_branch_hp_units_at_hp_layer_0: 256
# all_features_branch_recurrent_dropout_0: 0.0
# all_features_branch_RNN_layer_0_type: LSTM
# all_features_branch_hp_units_at_hp_layer_1: 256
# all_features_branch_recurrent_dropout_1: 0.1
# all_features_branch_RNN_layer_1_type: SimpleRNN
# base_features_branch_filters_SeparableConv1D: 128
# base_features_branch_SeparableConv1D_kernel_size: 5
# base_features_branch_hp_layers: 2
# base_features_branch_hp_units_at_hp_layer_0: 128
# base_features_branch_recurrent_dropout_0: 0.1
# base_features_branch_RNN_layer_0_type: LSTM
# base_features_branch_hp_units_at_hp_layer_1: 128
# base_features_branch_recurrent_dropout_1: 0.2
# base_features_branch_RNN_layer_1_type: GRU
# close_features_branch_filters_SeparableConv1D: 32
# close_features_branch_SeparableConv1D_kernel_size: 5
# close_features_branch_hp_layers: 2
# close_features_branch_hp_units_at_hp_layer_0: 128
# close_features_branch_recurrent_dropout_0: 0.0
# close_features_branch_RNN_layer_0_type: SimpleRNN
# close_features_branch_hp_units_at_hp_layer_1: 256
# close_features_branch_recurrent_dropout_1: 0.30000000000000004
# close_features_branch_RNN_layer_1_type: SimpleRNN
# high_low_features_branch_filters_SeparableConv1D: 32
# high_low_features_branch_SeparableConv1D_kernel_size: 5
# high_low_features_branch_hp_layers: 2
# high_low_features_branch_hp_units_at_hp_layer_0: 256
# high_low_features_branch_recurrent_dropout_0: 0.0
# high_low_features_branch_RNN_layer_0_type: GRU
# high_low_features_branch_hp_units_at_hp_layer_1: 64
# high_low_features_branch_recurrent_dropout_1: 0.30000000000000004
# high_low_features_branch_RNN_layer_1_type: LSTM
# volume_features_branch_filters_SeparableConv1D: 16
# volume_features_branch_SeparableConv1D_kernel_size: 3
# volume_features_branch_hp_layers: 2
# volume_features_branch_hp_units_at_hp_layer_0: 64
# volume_features_branch_recurrent_dropout_0: 0.4
# volume_features_branch_RNN_layer_0_type: GRU
# volume_features_branch_hp_units_at_hp_layer_1: 128
# volume_features_branch_recurrent_dropout_1: 0.30000000000000004
# volume_features_branch_RNN_layer_1_type: GRU
# optimizer_type: SGD
# learning_rate: 0.006684722663543113
# all_features_branch_hp_units_at_hp_layer_2: 64
# all_features_branch_recurrent_dropout_2: 0.0
# all_features_branch_RNN_layer_2_type: GRU
# all_features_branch_hp_units_at_hp_layer_3: 128
# all_features_branch_recurrent_dropout_3: 0.2
# all_features_branch_RNN_layer_3_type: LSTM
# all_features_branch_hp_units_at_hp_layer_4: 256
# all_features_branch_recurrent_dropout_4: 0.1
# all_features_branch_RNN_layer_4_type: LSTM
# all_features_branch_hp_units_at_hp_layer_5: 64
# all_features_branch_recurrent_dropout_5: 0.30000000000000004
# all_features_branch_RNN_layer_5_type: LSTM
# base_features_branch_hp_units_at_hp_layer_2: 32
# base_features_branch_recurrent_dropout_2: 0.4
# base_features_branch_RNN_layer_2_type: SimpleRNN
# base_features_branch_hp_units_at_hp_layer_3: 128
# base_features_branch_recurrent_dropout_3: 0.4
# base_features_branch_RNN_layer_3_type: GRU
# high_low_features_branch_hp_units_at_hp_layer_2: 64
# high_low_features_branch_recurrent_dropout_2: 0.2
# high_low_features_branch_RNN_layer_2_type: GRU
# high_low_features_branch_hp_units_at_hp_layer_3: 256
# high_low_features_branch_recurrent_dropout_3: 0.30000000000000004
# high_low_features_branch_RNN_layer_3_type: SimpleRNN
# batch_size: 32
# close_features_branch_hp_units_at_hp_layer_2: 128
# close_features_branch_recurrent_dropout_2: 0.1
# close_features_branch_RNN_layer_2_type: LSTM
# close_features_branch_hp_units_at_hp_layer_3: 128
# close_features_branch_recurrent_dropout_3: 0.4
# close_features_branch_RNN_layer_3_type: GRU
# close_features_branch_hp_units_at_hp_layer_4: 256
# close_features_branch_recurrent_dropout_4: 0.4
# close_features_branch_RNN_layer_4_type: GRU
# close_features_branch_hp_units_at_hp_layer_5: 256
# close_features_branch_recurrent_dropout_5: 0.1
# close_features_branch_RNN_layer_5_type: SimpleRNN
# high_low_features_branch_hp_units_at_hp_layer_4: 32
# high_low_features_branch_recurrent_dropout_4: 0.2
# high_low_features_branch_RNN_layer_4_type: SimpleRNN
# high_low_features_branch_hp_units_at_hp_layer_5: 128
# high_low_features_branch_recurrent_dropout_5: 0.2
# high_low_features_branch_RNN_layer_5_type: SimpleRNN
# volume_features_branch_hp_units_at_hp_layer_2: 32
# volume_features_branch_recurrent_dropout_2: 0.1
# volume_features_branch_RNN_layer_2_type: SimpleRNN
# volume_features_branch_hp_units_at_hp_layer_3: 64
# volume_features_branch_recurrent_dropout_3: 0.0
# volume_features_branch_RNN_layer_3_type: LSTM
# base_features_branch_hp_units_at_hp_layer_4: 32
# base_features_branch_recurrent_dropout_4: 0.2
# base_features_branch_RNN_layer_4_type: SimpleRNN
# base_features_branch_hp_units_at_hp_layer_5: 128
# base_features_branch_recurrent_dropout_5: 0.0
# base_features_branch_RNN_layer_5_type: SimpleRNN
# volume_features_branch_hp_units_at_hp_layer_4: 32
# volume_features_branch_recurrent_dropout_4: 0.1
# volume_features_branch_RNN_layer_4_type: LSTM
# volume_features_branch_hp_units_at_hp_layer_5: 128
# volume_features_branch_recurrent_dropout_5: 0.0
# volume_features_branch_RNN_layer_5_type: LSTM
# tuner/epochs: 4
# tuner/initial_epoch: 0
# tuner/bracket: 1
# tuner/round: 0
# Score: 0.5387097001075745
#
# Trial 0014 summary
# Hyperparameters:
# all_features_branch_filters_SeparableConv1D: 32
# all_features_branch_SeparableConv1D_kernel_size: 3
# all_features_branch_hp_layers: 6
# all_features_branch_hp_units_at_hp_layer_0: 32
# all_features_branch_recurrent_dropout_0: 0.2
# all_features_branch_RNN_layer_0_type: SimpleRNN
# all_features_branch_hp_units_at_hp_layer_1: 64
# all_features_branch_recurrent_dropout_1: 0.30000000000000004
# all_features_branch_RNN_layer_1_type: SimpleRNN
# base_features_branch_filters_SeparableConv1D: 16
# base_features_branch_SeparableConv1D_kernel_size: 3
# base_features_branch_hp_layers: 2
# base_features_branch_hp_units_at_hp_layer_0: 32
# base_features_branch_recurrent_dropout_0: 0.30000000000000004
# base_features_branch_RNN_layer_0_type: SimpleRNN
# base_features_branch_hp_units_at_hp_layer_1: 256
# base_features_branch_recurrent_dropout_1: 0.2
# base_features_branch_RNN_layer_1_type: GRU
# close_features_branch_filters_SeparableConv1D: 16
# close_features_branch_SeparableConv1D_kernel_size: 5
# close_features_branch_hp_layers: 4
# close_features_branch_hp_units_at_hp_layer_0: 64
# close_features_branch_recurrent_dropout_0: 0.1
# close_features_branch_RNN_layer_0_type: SimpleRNN
# close_features_branch_hp_units_at_hp_layer_1: 32
# close_features_branch_recurrent_dropout_1: 0.1
# close_features_branch_RNN_layer_1_type: GRU
# high_low_features_branch_filters_SeparableConv1D: 64
# high_low_features_branch_SeparableConv1D_kernel_size: 5
# high_low_features_branch_hp_layers: 2
# high_low_features_branch_hp_units_at_hp_layer_0: 64
# high_low_features_branch_recurrent_dropout_0: 0.4
# high_low_features_branch_RNN_layer_0_type: SimpleRNN
# high_low_features_branch_hp_units_at_hp_layer_1: 32
# high_low_features_branch_recurrent_dropout_1: 0.1
# high_low_features_branch_RNN_layer_1_type: GRU
# volume_features_branch_filters_SeparableConv1D: 16
# volume_features_branch_SeparableConv1D_kernel_size: 3
# volume_features_branch_hp_layers: 2
# volume_features_branch_hp_units_at_hp_layer_0: 64
# volume_features_branch_recurrent_dropout_0: 0.2
# volume_features_branch_RNN_layer_0_type: SimpleRNN
# volume_features_branch_hp_units_at_hp_layer_1: 32
# volume_features_branch_recurrent_dropout_1: 0.2
# volume_features_branch_RNN_layer_1_type: SimpleRNN
# optimizer_type: Adam
# learning_rate: 0.002178803054091246
# all_features_branch_hp_units_at_hp_layer_2: 128
# all_features_branch_recurrent_dropout_2: 0.2
# all_features_branch_RNN_layer_2_type: LSTM
# all_features_branch_hp_units_at_hp_layer_3: 256
# all_features_branch_recurrent_dropout_3: 0.1
# all_features_branch_RNN_layer_3_type: LSTM
# all_features_branch_hp_units_at_hp_layer_4: 64
# all_features_branch_recurrent_dropout_4: 0.30000000000000004
# all_features_branch_RNN_layer_4_type: GRU
# all_features_branch_hp_units_at_hp_layer_5: 128
# all_features_branch_recurrent_dropout_5: 0.30000000000000004
# all_features_branch_RNN_layer_5_type: SimpleRNN
# base_features_branch_hp_units_at_hp_layer_2: 64
# base_features_branch_recurrent_dropout_2: 0.2
# base_features_branch_RNN_layer_2_type: GRU
# base_features_branch_hp_units_at_hp_layer_3: 64
# base_features_branch_recurrent_dropout_3: 0.4
# base_features_branch_RNN_layer_3_type: GRU
# high_low_features_branch_hp_units_at_hp_layer_2: 32
# high_low_features_branch_recurrent_dropout_2: 0.2
# high_low_features_branch_RNN_layer_2_type: SimpleRNN
# high_low_features_branch_hp_units_at_hp_layer_3: 64
# high_low_features_branch_recurrent_dropout_3: 0.2
# high_low_features_branch_RNN_layer_3_type: GRU
# batch_size: 32
# close_features_branch_hp_units_at_hp_layer_2: 64
# close_features_branch_recurrent_dropout_2: 0.0
# close_features_branch_RNN_layer_2_type: GRU
# close_features_branch_hp_units_at_hp_layer_3: 32
# close_features_branch_recurrent_dropout_3: 0.0
# close_features_branch_RNN_layer_3_type: GRU
# close_features_branch_hp_units_at_hp_layer_4: 128
# close_features_branch_recurrent_dropout_4: 0.4
# close_features_branch_RNN_layer_4_type: SimpleRNN
# close_features_branch_hp_units_at_hp_layer_5: 32
# close_features_branch_recurrent_dropout_5: 0.2
# close_features_branch_RNN_layer_5_type: LSTM
# high_low_features_branch_hp_units_at_hp_layer_4: 32
# high_low_features_branch_recurrent_dropout_4: 0.2
# high_low_features_branch_RNN_layer_4_type: GRU
# high_low_features_branch_hp_units_at_hp_layer_5: 64
# high_low_features_branch_recurrent_dropout_5: 0.30000000000000004
# high_low_features_branch_RNN_layer_5_type: SimpleRNN
# volume_features_branch_hp_units_at_hp_layer_2: 128
# volume_features_branch_recurrent_dropout_2: 0.1
# volume_features_branch_RNN_layer_2_type: SimpleRNN
# volume_features_branch_hp_units_at_hp_layer_3: 32
# volume_features_branch_recurrent_dropout_3: 0.0
# volume_features_branch_RNN_layer_3_type: SimpleRNN
# base_features_branch_hp_units_at_hp_layer_4: 128
# base_features_branch_recurrent_dropout_4: 0.2
# base_features_branch_RNN_layer_4_type: SimpleRNN
# base_features_branch_hp_units_at_hp_layer_5: 128
# base_features_branch_recurrent_dropout_5: 0.2
# base_features_branch_RNN_layer_5_type: LSTM
# volume_features_branch_hp_units_at_hp_layer_4: 128
# volume_features_branch_recurrent_dropout_4: 0.30000000000000004
# volume_features_branch_RNN_layer_4_type: SimpleRNN
# volume_features_branch_hp_units_at_hp_layer_5: 128
# volume_features_branch_recurrent_dropout_5: 0.4
# volume_features_branch_RNN_layer_5_type: LSTM
# tuner/epochs: 4
# tuner/initial_epoch: 2
# tuner/bracket: 2
# tuner/round: 1
# tuner/trial_id: 0007
# Score: 0.5322580933570862
#
# Trial 0009 summary
# Hyperparameters:
# all_features_branch_filters_SeparableConv1D: 16
# all_features_branch_SeparableConv1D_kernel_size: 3
# all_features_branch_hp_layers: 2
# all_features_branch_hp_units_at_hp_layer_0: 128
# all_features_branch_recurrent_dropout_0: 0.30000000000000004
# all_features_branch_RNN_layer_0_type: LSTM
# all_features_branch_hp_units_at_hp_layer_1: 64
# all_features_branch_recurrent_dropout_1: 0.2
# all_features_branch_RNN_layer_1_type: LSTM
# base_features_branch_filters_SeparableConv1D: 64
# base_features_branch_SeparableConv1D_kernel_size: 3
# base_features_branch_hp_layers: 6
# base_features_branch_hp_units_at_hp_layer_0: 256
# base_features_branch_recurrent_dropout_0: 0.1
# base_features_branch_RNN_layer_0_type: SimpleRNN
# base_features_branch_hp_units_at_hp_layer_1: 256
# base_features_branch_recurrent_dropout_1: 0.4
# base_features_branch_RNN_layer_1_type: LSTM
# close_features_branch_filters_SeparableConv1D: 128
# close_features_branch_SeparableConv1D_kernel_size: 3
# close_features_branch_hp_layers: 6
# close_features_branch_hp_units_at_hp_layer_0: 32
# close_features_branch_recurrent_dropout_0: 0.4
# close_features_branch_RNN_layer_0_type: LSTM
# close_features_branch_hp_units_at_hp_layer_1: 256
# close_features_branch_recurrent_dropout_1: 0.30000000000000004
# close_features_branch_RNN_layer_1_type: GRU
# high_low_features_branch_filters_SeparableConv1D: 32
# high_low_features_branch_SeparableConv1D_kernel_size: 3
# high_low_features_branch_hp_layers: 6
# high_low_features_branch_hp_units_at_hp_layer_0: 128
# high_low_features_branch_recurrent_dropout_0: 0.30000000000000004
# high_low_features_branch_RNN_layer_0_type: GRU
# high_low_features_branch_hp_units_at_hp_layer_1: 64
# high_low_features_branch_recurrent_dropout_1: 0.0
# high_low_features_branch_RNN_layer_1_type: LSTM
# volume_features_branch_filters_SeparableConv1D: 128
# volume_features_branch_SeparableConv1D_kernel_size: 5
# volume_features_branch_hp_layers: 6
# volume_features_branch_hp_units_at_hp_layer_0: 32
# volume_features_branch_recurrent_dropout_0: 0.4
# volume_features_branch_RNN_layer_0_type: SimpleRNN
# volume_features_branch_hp_units_at_hp_layer_1: 256
# volume_features_branch_recurrent_dropout_1: 0.0
# volume_features_branch_RNN_layer_1_type: GRU
# optimizer_type: RMSprop
# learning_rate: 0.00021363672907531923
# all_features_branch_hp_units_at_hp_layer_2: 256
# all_features_branch_recurrent_dropout_2: 0.30000000000000004
# all_features_branch_RNN_layer_2_type: GRU
# all_features_branch_hp_units_at_hp_layer_3: 128
# all_features_branch_recurrent_dropout_3: 0.2
# all_features_branch_RNN_layer_3_type: LSTM
# all_features_branch_hp_units_at_hp_layer_4: 64
# all_features_branch_recurrent_dropout_4: 0.1
# all_features_branch_RNN_layer_4_type: GRU
# all_features_branch_hp_units_at_hp_layer_5: 128
# all_features_branch_recurrent_dropout_5: 0.0
# all_features_branch_RNN_layer_5_type: GRU
# base_features_branch_hp_units_at_hp_layer_2: 64
# base_features_branch_recurrent_dropout_2: 0.1
# base_features_branch_RNN_layer_2_type: GRU
# base_features_branch_hp_units_at_hp_layer_3: 128
# base_features_branch_recurrent_dropout_3: 0.0
# base_features_branch_RNN_layer_3_type: LSTM
# high_low_features_branch_hp_units_at_hp_layer_2: 64
# high_low_features_branch_recurrent_dropout_2: 0.1
# high_low_features_branch_RNN_layer_2_type: SimpleRNN
# high_low_features_branch_hp_units_at_hp_layer_3: 32
# high_low_features_branch_recurrent_dropout_3: 0.2
# high_low_features_branch_RNN_layer_3_type: SimpleRNN
# batch_size: 32
# close_features_branch_hp_units_at_hp_layer_2: 256
# close_features_branch_recurrent_dropout_2: 0.1
# close_features_branch_RNN_layer_2_type: SimpleRNN
# close_features_branch_hp_units_at_hp_layer_3: 32
# close_features_branch_recurrent_dropout_3: 0.2
# close_features_branch_RNN_layer_3_type: LSTM
# close_features_branch_hp_units_at_hp_layer_4: 256
# close_features_branch_recurrent_dropout_4: 0.30000000000000004
# close_features_branch_RNN_layer_4_type: LSTM
# close_features_branch_hp_units_at_hp_layer_5: 256
# close_features_branch_recurrent_dropout_5: 0.4
# close_features_branch_RNN_layer_5_type: GRU
# high_low_features_branch_hp_units_at_hp_layer_4: 64
# high_low_features_branch_recurrent_dropout_4: 0.0
# high_low_features_branch_RNN_layer_4_type: SimpleRNN
# high_low_features_branch_hp_units_at_hp_layer_5: 128
# high_low_features_branch_recurrent_dropout_5: 0.1
# high_low_features_branch_RNN_layer_5_type: LSTM
# volume_features_branch_hp_units_at_hp_layer_2: 32
# volume_features_branch_recurrent_dropout_2: 0.4
# volume_features_branch_RNN_layer_2_type: GRU
# volume_features_branch_hp_units_at_hp_layer_3: 256
# volume_features_branch_recurrent_dropout_3: 0.2
# volume_features_branch_RNN_layer_3_type: SimpleRNN
# base_features_branch_hp_units_at_hp_layer_4: 64
# base_features_branch_recurrent_dropout_4: 0.4
# base_features_branch_RNN_layer_4_type: SimpleRNN
# base_features_branch_hp_units_at_hp_layer_5: 32
# base_features_branch_recurrent_dropout_5: 0.4
# base_features_branch_RNN_layer_5_type: GRU
# volume_features_branch_hp_units_at_hp_layer_4: 32
# volume_features_branch_recurrent_dropout_4: 0.0
# volume_features_branch_RNN_layer_4_type: SimpleRNN
# volume_features_branch_hp_units_at_hp_layer_5: 256
# volume_features_branch_recurrent_dropout_5: 0.1
# volume_features_branch_RNN_layer_5_type: SimpleRNN
# tuner/epochs: 2
# tuner/initial_epoch: 0
# tuner/bracket: 2
# tuner/round: 0
# Score: 0.5322580933570862
# Best epoch: 1
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 7s 3s/step
# training for the INCY model was done in: 0:09:12.652780

# %%
# evaluate the models in the archive
evaluate_models_archive(hp_RNN_inception_models_archive)
# Out:
# Model: "functional_216"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                  ┃ Output Shape              ┃         Param # ┃ Connected to               ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_38 (InputLayer)   │ (None, 10, 72)            │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ input_spilt_layer_22          │ [(None, 10, 6), (None,    │               0 │ input_layer_38[0][0]       │
# │ (InputSpiltLayer)             │ 10, 30), (None, 10, 31),  │                 │                            │
# │                               │ (None, 10, 5)]            │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ gru_12 (GRU)                  │ (None, 10, 64)            │          18,432 │ input_spilt_layer_22[0][1] │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ simple_rnn_234 (SimpleRNN)    │ (None, 10, 256)           │          73,728 │ input_spilt_layer_22[0][2] │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ gru_11 (GRU)                  │ (None, 10, 128)           │          77,568 │ input_layer_38[0][0]       │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ gru_13 (GRU)                  │ (None, 10, 64)            │          24,960 │ gru_12[0][0]               │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ simple_rnn_235 (SimpleRNN)    │ (None, 10, 128)           │          49,280 │ simple_rnn_234[0][0]       │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ lstm_22 (LSTM)                │ (None, 10, 32)            │          20,608 │ gru_11[0][0]               │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ simple_rnn_228 (SimpleRNN)    │ (None, 10, 32)            │           1,248 │ input_spilt_layer_22[0][0] │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ simple_rnn_230 (SimpleRNN)    │ (None, 10, 32)            │           3,104 │ gru_13[0][0]               │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ simple_rnn_236 (SimpleRNN)    │ (None, 10, 32)            │           5,152 │ simple_rnn_235[0][0]       │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ lstm_23 (LSTM)                │ (None, 10, 128)           │          82,432 │ lstm_22[0][0]              │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ simple_rnn_229 (SimpleRNN)    │ (None, 10, 128)           │          20,608 │ simple_rnn_228[0][0]       │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ simple_rnn_231 (SimpleRNN)    │ (None, 10, 32)            │           2,080 │ simple_rnn_230[0][0]       │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ simple_rnn_237 (SimpleRNN)    │ (None, 10, 256)           │          73,984 │ simple_rnn_236[0][0]       │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ simple_rnn_225 (SimpleRNN)    │ (None, 10, 32)            │           5,152 │ lstm_23[0][0]              │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ lstm_24 (LSTM)                │ (None, 10, 128)           │         131,584 │ simple_rnn_229[0][0]       │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ simple_rnn_232 (SimpleRNN)    │ (None, 10, 32)            │           2,080 │ simple_rnn_231[0][0]       │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ simple_rnn_238 (SimpleRNN)    │ (None, 10, 32)            │           9,248 │ simple_rnn_237[0][0]       │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ simple_rnn_226 (SimpleRNN)    │ (None, 10, 32)            │           2,080 │ simple_rnn_225[0][0]       │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ lstm_25 (LSTM)                │ (None, 64)                │          49,408 │ lstm_24[0][0]              │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ simple_rnn_233 (SimpleRNN)    │ (None, 32)                │           2,080 │ simple_rnn_232[0][0]       │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ simple_rnn_239 (SimpleRNN)    │ (None, 32)                │           2,080 │ simple_rnn_238[0][0]       │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ simple_rnn_227 (SimpleRNN)    │ (None, 64)                │           6,208 │ simple_rnn_226[0][0]       │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ concatenate_22 (Concatenate)  │ (None, 192)               │               0 │ lstm_25[0][0],             │
# │                               │                           │                 │ simple_rnn_233[0][0],      │
# │                               │                           │                 │ simple_rnn_239[0][0],      │
# │                               │                           │                 │ simple_rnn_227[0][0]       │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_37 (Dense)              │ (None, 2)                 │             386 │ concatenate_22[0][0]       │
# └───────────────────────────────┴───────────────────────────┴─────────────────┴────────────────────────────┘
#  Total params: 1,326,982 (5.06 MB)
#  Trainable params: 663,490 (2.53 MB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 663,492 (2.53 MB)
# C:\Users\ammaroAsus\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# The PFE Model Classification Metrics:
# Accuracy: 0.5384615384615384
# Precision: 0.28994082840236685
# Recall: 0.5384615384615384
# F-Score: 0.3769230769230769
# --------------------------------------------------------------
# Model: "functional_220"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                  ┃ Output Shape              ┃         Param # ┃ Connected to               ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_40 (InputLayer)   │ (None, 10, 72)            │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ input_spilt_layer_24          │ [(None, 10, 6), (None,    │               0 │ input_layer_40[0][0]       │
# │ (InputSpiltLayer)             │ 10, 30), (None, 10, 31),  │                 │                            │
# │                               │ (None, 10, 5)]            │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ lstm_27 (LSTM)                │ (None, 10, 32)            │           4,992 │ input_spilt_layer_24[0][0] │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ gru_20 (GRU)                  │ (None, 10, 64)            │          18,432 │ input_spilt_layer_24[0][1] │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ gru_21 (GRU)                  │ (None, 10, 128)           │          61,824 │ input_spilt_layer_24[0][2] │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ simple_rnn_243 (SimpleRNN)    │ (None, 10, 64)            │           8,768 │ input_layer_40[0][0]       │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ gru_19 (GRU)                  │ (None, 128)               │          62,208 │ lstm_27[0][0]              │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ simple_rnn_244 (SimpleRNN)    │ (None, 64)                │           8,256 │ gru_20[0][0]               │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ simple_rnn_245 (SimpleRNN)    │ (None, 32)                │           5,152 │ gru_21[0][0]               │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ gru_18 (GRU)                  │ (None, 256)               │         247,296 │ simple_rnn_243[0][0]       │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ concatenate_24 (Concatenate)  │ (None, 480)               │               0 │ gru_19[0][0],              │
# │                               │                           │                 │ simple_rnn_244[0][0],      │
# │                               │                           │                 │ simple_rnn_245[0][0],      │
# │                               │                           │                 │ gru_18[0][0]               │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_39 (Dense)              │ (None, 2)                 │             962 │ concatenate_24[0][0]       │
# └───────────────────────────────┴───────────────────────────┴─────────────────┴────────────────────────────┘
#  Total params: 835,782 (3.19 MB)
#  Trainable params: 417,890 (1.59 MB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 417,892 (1.59 MB)
# The ROP Model Classification Metrics:
# Accuracy: 0.5128205128205128
# Precision: 0.5077700077700078
# Recall: 0.5128205128205128
# F-Score: 0.4459022738268021
# --------------------------------------------------------------
# Model: "functional_224"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                  ┃ Output Shape              ┃         Param # ┃ Connected to               ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_42 (InputLayer)   │ (None, 10, 72)            │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ input_spilt_layer_26          │ [(None, 10, 6), (None,    │               0 │ input_layer_42[0][0]       │
# │ (InputSpiltLayer)             │ 10, 30), (None, 10, 31),  │                 │                            │
# │                               │ (None, 10, 5)]            │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ gru_30 (GRU)                  │ (None, 10, 32)            │           6,240 │ input_spilt_layer_26[0][2] │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ lstm_32 (LSTM)                │ (None, 10, 32)            │          13,440 │ input_layer_42[0][0]       │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ simple_rnn_250 (SimpleRNN)    │ (None, 10, 64)            │           6,208 │ gru_30[0][0]               │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ gru_27 (GRU)                  │ (None, 10, 32)            │           6,336 │ lstm_32[0][0]              │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ gru_28 (GRU)                  │ (None, 10, 64)            │          13,824 │ input_spilt_layer_26[0][0] │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ lstm_35 (LSTM)                │ (None, 10, 128)           │          81,408 │ input_spilt_layer_26[0][1] │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ gru_31 (GRU)                  │ (None, 10, 256)           │         247,296 │ simple_rnn_250[0][0]       │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ lstm_33 (LSTM)                │ (None, 10, 64)            │          24,832 │ gru_27[0][0]               │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ simple_rnn_249 (SimpleRNN)    │ (None, 32)                │           3,104 │ gru_28[0][0]               │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ gru_29 (GRU)                  │ (None, 64)                │          37,248 │ lstm_35[0][0]              │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ simple_rnn_251 (SimpleRNN)    │ (None, 256)               │         131,328 │ gru_31[0][0]               │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ lstm_34 (LSTM)                │ (None, 128)               │          98,816 │ lstm_33[0][0]              │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ concatenate_26 (Concatenate)  │ (None, 480)               │               0 │ simple_rnn_249[0][0],      │
# │                               │                           │                 │ gru_29[0][0],              │
# │                               │                           │                 │ simple_rnn_251[0][0],      │
# │                               │                           │                 │ lstm_34[0][0]              │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_41 (Dense)              │ (None, 2)                 │             962 │ concatenate_26[0][0]       │
# └───────────────────────────────┴───────────────────────────┴─────────────────┴────────────────────────────┘
#  Total params: 1,342,086 (5.12 MB)
#  Trainable params: 671,042 (2.56 MB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 671,044 (2.56 MB)
# C:\Users\ammaroAsus\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# The XYL Model Classification Metrics:
# Accuracy: 0.6153846153846154
# Precision: 0.37869822485207105
# Recall: 0.6153846153846154
# F-Score: 0.46886446886446886
# --------------------------------------------------------------
# Model: "functional_228"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                  ┃ Output Shape              ┃         Param # ┃ Connected to               ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_44 (InputLayer)   │ (None, 10, 72)            │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ input_spilt_layer_28          │ [(None, 10, 6), (None,    │               0 │ input_layer_44[0][0]       │
# │ (InputSpiltLayer)             │ 10, 30), (None, 10, 31),  │                 │                            │
# │                               │ (None, 10, 5)]            │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ lstm_40 (LSTM)                │ (None, 10, 128)           │          69,120 │ input_spilt_layer_28[0][0] │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ simple_rnn_256 (SimpleRNN)    │ (None, 10, 128)           │          20,352 │ input_spilt_layer_28[0][1] │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ gru_35 (GRU)                  │ (None, 10, 256)           │         221,952 │ input_spilt_layer_28[0][2] │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ lstm_39 (LSTM)                │ (None, 10, 256)           │         336,896 │ input_layer_44[0][0]       │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ gru_34 (GRU)                  │ (None, 128)               │          99,072 │ lstm_40[0][0]              │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ simple_rnn_257 (SimpleRNN)    │ (None, 256)               │          98,560 │ simple_rnn_256[0][0]       │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ lstm_41 (LSTM)                │ (None, 64)                │          82,176 │ gru_35[0][0]               │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ simple_rnn_255 (SimpleRNN)    │ (None, 256)               │         131,328 │ lstm_39[0][0]              │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ concatenate_28 (Concatenate)  │ (None, 704)               │               0 │ gru_34[0][0],              │
# │                               │                           │                 │ simple_rnn_257[0][0],      │
# │                               │                           │                 │ lstm_41[0][0],             │
# │                               │                           │                 │ simple_rnn_255[0][0]       │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_43 (Dense)              │ (None, 2)                 │           1,410 │ concatenate_28[0][0]       │
# └───────────────────────────────┴───────────────────────────┴─────────────────┴────────────────────────────┘
#  Total params: 1,060,868 (4.05 MB)
#  Trainable params: 1,060,866 (4.05 MB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 2 (12.00 B)
# C:\Users\ammaroAsus\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# The CPAY Model Classification Metrics:
# Accuracy: 0.46153846153846156
# Precision: 0.21301775147928995
# Recall: 0.46153846153846156
# F-Score: 0.291497975708502
# --------------------------------------------------------------
# Model: "functional_232"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                  ┃ Output Shape              ┃         Param # ┃ Connected to               ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_46 (InputLayer)   │ (None, 10, 72)            │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ input_spilt_layer_30          │ [(None, 10, 6), (None,    │               0 │ input_layer_46[0][0]       │
# │ (InputSpiltLayer)             │ 10, 30), (None, 10, 31),  │                 │                            │
# │                               │ (None, 10, 5)]            │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ lstm_43 (LSTM)                │ (None, 10, 32)            │           4,992 │ input_spilt_layer_30[0][0] │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ gru_42 (GRU)                  │ (None, 10, 64)            │          18,432 │ input_spilt_layer_30[0][1] │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ gru_43 (GRU)                  │ (None, 10, 128)           │          61,824 │ input_spilt_layer_30[0][2] │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ simple_rnn_261 (SimpleRNN)    │ (None, 10, 64)            │           8,768 │ input_layer_46[0][0]       │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ gru_41 (GRU)                  │ (None, 128)               │          62,208 │ lstm_43[0][0]              │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ simple_rnn_262 (SimpleRNN)    │ (None, 64)                │           8,256 │ gru_42[0][0]               │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ simple_rnn_263 (SimpleRNN)    │ (None, 32)                │           5,152 │ gru_43[0][0]               │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ gru_40 (GRU)                  │ (None, 256)               │         247,296 │ simple_rnn_261[0][0]       │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ concatenate_30 (Concatenate)  │ (None, 480)               │               0 │ gru_41[0][0],              │
# │                               │                           │                 │ simple_rnn_262[0][0],      │
# │                               │                           │                 │ simple_rnn_263[0][0],      │
# │                               │                           │                 │ gru_40[0][0]               │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_45 (Dense)              │ (None, 2)                 │             962 │ concatenate_30[0][0]       │
# └───────────────────────────────┴───────────────────────────┴─────────────────┴────────────────────────────┘
#  Total params: 835,782 (3.19 MB)
#  Trainable params: 417,890 (1.59 MB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 417,892 (1.59 MB)
# C:\Users\ammaroAsus\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# The INCY Model Classification Metrics:
# Accuracy: 0.5128205128205128
# Precision: 0.26298487836949375
# Recall: 0.5128205128205128
# F-Score: 0.3476749239461104
# --------------------------------------------------------------
# Average Classification Metrics for All Models:
# Average Accuracy: 0.5282051282051282
# Average Precision: 0.33048233817464584
# Average Recall: 0.5282051282051282
# Average F-Score: 0.38617254385379207

# %% [markdown]
# ## Different data intervals

# %%
# initialize a MinMaxScaler instance for a range between 0 and 1
min_max_scaler = MinMaxScaler(feature_range=(0, 1))

# initialize a StandardScaler instance
standard_scaler = StandardScaler()

# initialize a RobustScaler instance
robust_scaler = RobustScaler()

# %% [markdown]
# ### 1 Day interval

# %%
# insert the stock symbols into a list
symbols_list = ['PFE', 'ROP', 'XYL', 'CPAY', 'INCY']

# load the stock data for the 5 companies into a dictionary
dfs_1d = loadData(symbols=symbols_list, period='max', interval='1d')

# add the targets and technical indicators to each dataframe in the dictionary
full_dfs_1d = add_targets_and_indicators(dfs_1d.copy())

# get the trend up ratio of all the dataframes in the dictionary to get a sense of how balanced the data is
calculate_data_balance(full_dfs_1d)

# get the common sense baseline for each dataframe in the dictionary
calculate_common_sense_baseline(full_dfs_1d)

# apply the 3 steps of preparing data for training on each dataframe in the dictionary
target = 'classification' # set the target
timesteps = 10 # set the timesteps
data_sets_1d = prepare_data_to_train(full_dfs_1d.copy(), min_max_scaler, target, timesteps)

# set the model initialization inputs
X_train_shape = data_sets_1d['PFE']['X_train'].shape
model_type='classification'
tuner = Hyperband

# create the model
hp_RNN_inception_model_1d = HP_Hollow_RNN_Inception_Model(X_train_shape)

# create models archive for simpleRNN classification approach
hp_RNN_inception_models_archive_1d = create_models_archive(hp_RNN_inception_model_1d, 
                                                 data_sets_1d, 
                                                 _model_type=model_type, 
                                                 _tuner=tuner, 
                                                 _epochs=50, 
                                                 _model_name='hp_RNN_inception_model_1d', 
                                                 _project_name='hp_RNN_inception_model_archive_1d')
# Out:
# There is no max_1d_stocks_data.csv. Data will be downloaded from yfinance.
# [*********************100%%**********************]  5 of 5 completed
# The Trend up ratio of PFE is: 0.49853935397713045
# The Trend up ratio of ROP is: 0.5233549700903652
# The Trend up ratio of XYL is: 0.52059100911663
# The Trend up ratio of CPAY is: 0.5344320188346086
# The Trend up ratio of INCY is: 0.492940863079382
# The Average Trend up ratio is: 0.5139716430196233
# The common sense score of PFE is: 0.5008763876137218
# The common sense score of ROP is: 0.49077255950108184
# The common sense score of XYL is: 0.49324111914492297
# The common sense score of CPAY is: 0.49028840494408477
# The common sense score of INCY is: 0.5077250932338838
# The Average common sense score is: 0.496580712887539
# C:\Users\ammaroAsus\anaconda3\Lib\site-packages\keras\src\saving\saving_lib.py:415: UserWarning: Skipping variable loading for optimizer 'rmsprop', because it has 2 variables whereas the saved optimizer has 40 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# C:\Users\ammaroAsus\anaconda3\Lib\site-packages\keras\src\saving\saving_lib.py:415: UserWarning: Skipping variable loading for optimizer 'rmsprop', because it has 2 variables whereas the saved optimizer has 58 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# C:\Users\ammaroAsus\anaconda3\Lib\site-packages\keras\src\saving\saving_lib.py:415: UserWarning: Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 90 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# C:\Users\ammaroAsus\anaconda3\Lib\site-packages\keras\src\saving\saving_lib.py:415: UserWarning: Skipping variable loading for optimizer 'rmsprop', because it has 2 variables whereas the saved optimizer has 52 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# Results summary
# Results in keras_tuner_models\hp_RNN_inception_model_archive_1d/PFE
# Showing 10 best trials
# Objective(name="val_accuracy", direction="max")
#
# Trial 0029 summary
# Hyperparameters:
# all_features_branch_hp_layers: 4
# all_features_branch_RNN_layer_0_type: GRU
# all_features_branch_hp_units_at_hp_layer_0: 64
# all_features_branch_recurrent_dropout_0: 0.2
# all_features_branch_RNN_layer_1_type: GRU
# all_features_branch_hp_units_at_hp_layer_1: 64
# all_features_branch_recurrent_dropout_1: 0.0
# base_features_branch_hp_layers: 2
# base_features_branch_RNN_layer_0_type: SimpleRNN
# base_features_branch_hp_units_at_hp_layer_0: 128
# base_features_branch_recurrent_dropout_0: 0.0
# base_features_branch_RNN_layer_1_type: LSTM
# base_features_branch_hp_units_at_hp_layer_1: 128
# base_features_branch_recurrent_dropout_1: 0.0
# close_features_branch_hp_layers: 2
# close_features_branch_RNN_layer_0_type: SimpleRNN
# close_features_branch_hp_units_at_hp_layer_0: 64
# close_features_branch_recurrent_dropout_0: 0.4
# close_features_branch_RNN_layer_1_type: LSTM
# close_features_branch_hp_units_at_hp_layer_1: 64
# close_features_branch_recurrent_dropout_1: 0.2
# high_low_features_branch_hp_layers: 4
# high_low_features_branch_RNN_layer_0_type: SimpleRNN
# high_low_features_branch_hp_units_at_hp_layer_0: 128
# high_low_features_branch_recurrent_dropout_0: 0.1
# high_low_features_branch_RNN_layer_1_type: LSTM
# high_low_features_branch_hp_units_at_hp_layer_1: 64
# high_low_features_branch_recurrent_dropout_1: 0.1
# volume_features_branch_hp_layers: 2
# volume_features_branch_RNN_layer_0_type: SimpleRNN
# volume_features_branch_hp_units_at_hp_layer_0: 128
# volume_features_branch_recurrent_dropout_0: 0.0
# volume_features_branch_RNN_layer_1_type: SimpleRNN
# volume_features_branch_hp_units_at_hp_layer_1: 128
# volume_features_branch_recurrent_dropout_1: 0.30000000000000004
# optimizer_type: RMSprop
# learning_rate: 0.0005061117544320517
# all_features_branch_RNN_layer_2_type: SimpleRNN
# all_features_branch_hp_units_at_hp_layer_2: 64
# all_features_branch_recurrent_dropout_2: 0.30000000000000004
# all_features_branch_RNN_layer_3_type: GRU
# all_features_branch_hp_units_at_hp_layer_3: 128
# all_features_branch_recurrent_dropout_3: 0.1
# close_features_branch_RNN_layer_2_type: SimpleRNN
# close_features_branch_hp_units_at_hp_layer_2: 128
# close_features_branch_recurrent_dropout_2: 0.1
# close_features_branch_RNN_layer_3_type: SimpleRNN
# close_features_branch_hp_units_at_hp_layer_3: 64
# close_features_branch_recurrent_dropout_3: 0.0
# high_low_features_branch_RNN_layer_2_type: SimpleRNN
# high_low_features_branch_hp_units_at_hp_layer_2: 64
# high_low_features_branch_recurrent_dropout_2: 0.0
# high_low_features_branch_RNN_layer_3_type: SimpleRNN
# high_low_features_branch_hp_units_at_hp_layer_3: 64
# high_low_features_branch_recurrent_dropout_3: 0.0
# volume_features_branch_RNN_layer_2_type: GRU
# volume_features_branch_hp_units_at_hp_layer_2: 64
# volume_features_branch_recurrent_dropout_2: 0.2
# volume_features_branch_RNN_layer_3_type: LSTM
# volume_features_branch_hp_units_at_hp_layer_3: 128
# volume_features_branch_recurrent_dropout_3: 0.0
# batch_size: 64
# base_features_branch_RNN_layer_2_type: LSTM
# base_features_branch_hp_units_at_hp_layer_2: 64
# base_features_branch_recurrent_dropout_2: 0.1
# base_features_branch_RNN_layer_3_type: SimpleRNN
# base_features_branch_hp_units_at_hp_layer_3: 128
# base_features_branch_recurrent_dropout_3: 0.30000000000000004
# tuner/epochs: 10
# tuner/initial_epoch: 0
# tuner/bracket: 0
# tuner/round: 0
# Score: 0.5179466009140015
#
# Trial 0021 summary
# Hyperparameters:
# all_features_branch_hp_layers: 4
# all_features_branch_RNN_layer_0_type: LSTM
# all_features_branch_hp_units_at_hp_layer_0: 128
# all_features_branch_recurrent_dropout_0: 0.0
# all_features_branch_RNN_layer_1_type: LSTM
# all_features_branch_hp_units_at_hp_layer_1: 64
# all_features_branch_recurrent_dropout_1: 0.2
# base_features_branch_hp_layers: 2
# base_features_branch_RNN_layer_0_type: LSTM
# base_features_branch_hp_units_at_hp_layer_0: 64
# base_features_branch_recurrent_dropout_0: 0.2
# base_features_branch_RNN_layer_1_type: SimpleRNN
# base_features_branch_hp_units_at_hp_layer_1: 128
# base_features_branch_recurrent_dropout_1: 0.2
# close_features_branch_hp_layers: 2
# close_features_branch_RNN_layer_0_type: LSTM
# close_features_branch_hp_units_at_hp_layer_0: 128
# close_features_branch_recurrent_dropout_0: 0.1
# close_features_branch_RNN_layer_1_type: GRU
# close_features_branch_hp_units_at_hp_layer_1: 64
# close_features_branch_recurrent_dropout_1: 0.1
# high_low_features_branch_hp_layers: 4
# high_low_features_branch_RNN_layer_0_type: LSTM
# high_low_features_branch_hp_units_at_hp_layer_0: 128
# high_low_features_branch_recurrent_dropout_0: 0.1
# high_low_features_branch_RNN_layer_1_type: LSTM
# high_low_features_branch_hp_units_at_hp_layer_1: 64
# high_low_features_branch_recurrent_dropout_1: 0.1
# volume_features_branch_hp_layers: 2
# volume_features_branch_RNN_layer_0_type: SimpleRNN
# volume_features_branch_hp_units_at_hp_layer_0: 128
# volume_features_branch_recurrent_dropout_0: 0.1
# volume_features_branch_RNN_layer_1_type: GRU
# volume_features_branch_hp_units_at_hp_layer_1: 64
# volume_features_branch_recurrent_dropout_1: 0.1
# optimizer_type: Adam
# learning_rate: 0.0015603766129866545
# all_features_branch_RNN_layer_2_type: LSTM
# all_features_branch_hp_units_at_hp_layer_2: 64
# all_features_branch_recurrent_dropout_2: 0.1
# all_features_branch_RNN_layer_3_type: GRU
# all_features_branch_hp_units_at_hp_layer_3: 64
# all_features_branch_recurrent_dropout_3: 0.1
# close_features_branch_RNN_layer_2_type: LSTM
# close_features_branch_hp_units_at_hp_layer_2: 64
# close_features_branch_recurrent_dropout_2: 0.4
# close_features_branch_RNN_layer_3_type: LSTM
# close_features_branch_hp_units_at_hp_layer_3: 128
# close_features_branch_recurrent_dropout_3: 0.2
# high_low_features_branch_RNN_layer_2_type: LSTM
# high_low_features_branch_hp_units_at_hp_layer_2: 128
# high_low_features_branch_recurrent_dropout_2: 0.2
# high_low_features_branch_RNN_layer_3_type: SimpleRNN
# high_low_features_branch_hp_units_at_hp_layer_3: 64
# high_low_features_branch_recurrent_dropout_3: 0.1
# volume_features_branch_RNN_layer_2_type: GRU
# volume_features_branch_hp_units_at_hp_layer_2: 128
# volume_features_branch_recurrent_dropout_2: 0.2
# volume_features_branch_RNN_layer_3_type: SimpleRNN
# volume_features_branch_hp_units_at_hp_layer_3: 128
# volume_features_branch_recurrent_dropout_3: 0.2
# batch_size: 32
# base_features_branch_RNN_layer_2_type: GRU
# base_features_branch_hp_units_at_hp_layer_2: 128
# base_features_branch_recurrent_dropout_2: 0.2
# base_features_branch_RNN_layer_3_type: LSTM
# base_features_branch_hp_units_at_hp_layer_3: 64
# base_features_branch_recurrent_dropout_3: 0.0
# tuner/epochs: 4
# tuner/initial_epoch: 0
# tuner/bracket: 1
# tuner/round: 0
# Score: 0.5137729644775391
#
# Trial 0017 summary
# Hyperparameters:
# all_features_branch_hp_layers: 2
# all_features_branch_RNN_layer_0_type: LSTM
# all_features_branch_hp_units_at_hp_layer_0: 64
# all_features_branch_recurrent_dropout_0: 0.4
# all_features_branch_RNN_layer_1_type: LSTM
# all_features_branch_hp_units_at_hp_layer_1: 64
# all_features_branch_recurrent_dropout_1: 0.2
# base_features_branch_hp_layers: 2
# base_features_branch_RNN_layer_0_type: LSTM
# base_features_branch_hp_units_at_hp_layer_0: 64
# base_features_branch_recurrent_dropout_0: 0.4
# base_features_branch_RNN_layer_1_type: LSTM
# base_features_branch_hp_units_at_hp_layer_1: 128
# base_features_branch_recurrent_dropout_1: 0.30000000000000004
# close_features_branch_hp_layers: 2
# close_features_branch_RNN_layer_0_type: GRU
# close_features_branch_hp_units_at_hp_layer_0: 128
# close_features_branch_recurrent_dropout_0: 0.2
# close_features_branch_RNN_layer_1_type: GRU
# close_features_branch_hp_units_at_hp_layer_1: 64
# close_features_branch_recurrent_dropout_1: 0.0
# high_low_features_branch_hp_layers: 2
# high_low_features_branch_RNN_layer_0_type: GRU
# high_low_features_branch_hp_units_at_hp_layer_0: 64
# high_low_features_branch_recurrent_dropout_0: 0.0
# high_low_features_branch_RNN_layer_1_type: GRU
# high_low_features_branch_hp_units_at_hp_layer_1: 128
# high_low_features_branch_recurrent_dropout_1: 0.0
# volume_features_branch_hp_layers: 4
# volume_features_branch_RNN_layer_0_type: GRU
# volume_features_branch_hp_units_at_hp_layer_0: 128
# volume_features_branch_recurrent_dropout_0: 0.0
# volume_features_branch_RNN_layer_1_type: SimpleRNN
# volume_features_branch_hp_units_at_hp_layer_1: 128
# volume_features_branch_recurrent_dropout_1: 0.1
# optimizer_type: RMSprop
# learning_rate: 0.0003828547440527253
# all_features_branch_RNN_layer_2_type: LSTM
# all_features_branch_hp_units_at_hp_layer_2: 128
# all_features_branch_recurrent_dropout_2: 0.2
# all_features_branch_RNN_layer_3_type: SimpleRNN
# all_features_branch_hp_units_at_hp_layer_3: 64
# all_features_branch_recurrent_dropout_3: 0.1
# close_features_branch_RNN_layer_2_type: SimpleRNN
# close_features_branch_hp_units_at_hp_layer_2: 128
# close_features_branch_recurrent_dropout_2: 0.0
# close_features_branch_RNN_layer_3_type: LSTM
# close_features_branch_hp_units_at_hp_layer_3: 128
# close_features_branch_recurrent_dropout_3: 0.4
# high_low_features_branch_RNN_layer_2_type: SimpleRNN
# high_low_features_branch_hp_units_at_hp_layer_2: 64
# high_low_features_branch_recurrent_dropout_2: 0.4
# high_low_features_branch_RNN_layer_3_type: GRU
# high_low_features_branch_hp_units_at_hp_layer_3: 128
# high_low_features_branch_recurrent_dropout_3: 0.1
# volume_features_branch_RNN_layer_2_type: GRU
# volume_features_branch_hp_units_at_hp_layer_2: 128
# volume_features_branch_recurrent_dropout_2: 0.2
# volume_features_branch_RNN_layer_3_type: GRU
# volume_features_branch_hp_units_at_hp_layer_3: 64
# volume_features_branch_recurrent_dropout_3: 0.1
# batch_size: 32
# base_features_branch_RNN_layer_2_type: GRU
# base_features_branch_hp_units_at_hp_layer_2: 64
# base_features_branch_recurrent_dropout_2: 0.2
# base_features_branch_RNN_layer_3_type: SimpleRNN
# base_features_branch_hp_units_at_hp_layer_3: 64
# base_features_branch_recurrent_dropout_3: 0.30000000000000004
# tuner/epochs: 10
# tuner/initial_epoch: 4
# tuner/bracket: 2
# tuner/round: 2
# tuner/trial_id: 0012
# Score: 0.5125208497047424
#
# Trial 0019 summary
# Hyperparameters:
# all_features_branch_hp_layers: 4
# all_features_branch_RNN_layer_0_type: LSTM
# all_features_branch_hp_units_at_hp_layer_0: 64
# all_features_branch_recurrent_dropout_0: 0.30000000000000004
# all_features_branch_RNN_layer_1_type: SimpleRNN
# all_features_branch_hp_units_at_hp_layer_1: 64
# all_features_branch_recurrent_dropout_1: 0.0
# base_features_branch_hp_layers: 4
# base_features_branch_RNN_layer_0_type: GRU
# base_features_branch_hp_units_at_hp_layer_0: 64
# base_features_branch_recurrent_dropout_0: 0.1
# base_features_branch_RNN_layer_1_type: LSTM
# base_features_branch_hp_units_at_hp_layer_1: 64
# base_features_branch_recurrent_dropout_1: 0.30000000000000004
# close_features_branch_hp_layers: 2
# close_features_branch_RNN_layer_0_type: GRU
# close_features_branch_hp_units_at_hp_layer_0: 128
# close_features_branch_recurrent_dropout_0: 0.1
# close_features_branch_RNN_layer_1_type: SimpleRNN
# close_features_branch_hp_units_at_hp_layer_1: 128
# close_features_branch_recurrent_dropout_1: 0.4
# high_low_features_branch_hp_layers: 2
# high_low_features_branch_RNN_layer_0_type: GRU
# high_low_features_branch_hp_units_at_hp_layer_0: 64
# high_low_features_branch_recurrent_dropout_0: 0.30000000000000004
# high_low_features_branch_RNN_layer_1_type: SimpleRNN
# high_low_features_branch_hp_units_at_hp_layer_1: 128
# high_low_features_branch_recurrent_dropout_1: 0.2
# volume_features_branch_hp_layers: 4
# volume_features_branch_RNN_layer_0_type: LSTM
# volume_features_branch_hp_units_at_hp_layer_0: 128
# volume_features_branch_recurrent_dropout_0: 0.2
# volume_features_branch_RNN_layer_1_type: LSTM
# volume_features_branch_hp_units_at_hp_layer_1: 128
# volume_features_branch_recurrent_dropout_1: 0.2
# optimizer_type: RMSprop
# learning_rate: 0.00392551860940815
# all_features_branch_RNN_layer_2_type: SimpleRNN
# all_features_branch_hp_units_at_hp_layer_2: 64
# all_features_branch_recurrent_dropout_2: 0.2
# all_features_branch_RNN_layer_3_type: GRU
# all_features_branch_hp_units_at_hp_layer_3: 128
# all_features_branch_recurrent_dropout_3: 0.4
# close_features_branch_RNN_layer_2_type: SimpleRNN
# close_features_branch_hp_units_at_hp_layer_2: 128
# close_features_branch_recurrent_dropout_2: 0.0
# close_features_branch_RNN_layer_3_type: GRU
# close_features_branch_hp_units_at_hp_layer_3: 64
# close_features_branch_recurrent_dropout_3: 0.4
# high_low_features_branch_RNN_layer_2_type: LSTM
# high_low_features_branch_hp_units_at_hp_layer_2: 64
# high_low_features_branch_recurrent_dropout_2: 0.30000000000000004
# high_low_features_branch_RNN_layer_3_type: GRU
# high_low_features_branch_hp_units_at_hp_layer_3: 128
# high_low_features_branch_recurrent_dropout_3: 0.2
# volume_features_branch_RNN_layer_2_type: LSTM
# volume_features_branch_hp_units_at_hp_layer_2: 64
# volume_features_branch_recurrent_dropout_2: 0.2
# volume_features_branch_RNN_layer_3_type: LSTM
# volume_features_branch_hp_units_at_hp_layer_3: 128
# volume_features_branch_recurrent_dropout_3: 0.2
# batch_size: 32
# base_features_branch_RNN_layer_2_type: GRU
# base_features_branch_hp_units_at_hp_layer_2: 64
# base_features_branch_recurrent_dropout_2: 0.1
# base_features_branch_RNN_layer_3_type: GRU
# base_features_branch_hp_units_at_hp_layer_3: 128
# base_features_branch_recurrent_dropout_3: 0.0
# tuner/epochs: 4
# tuner/initial_epoch: 0
# tuner/bracket: 1
# tuner/round: 0
# Score: 0.5121034979820251
#
# Trial 0009 summary
# Hyperparameters:
# all_features_branch_hp_layers: 2
# all_features_branch_RNN_layer_0_type: LSTM
# all_features_branch_hp_units_at_hp_layer_0: 64
# all_features_branch_recurrent_dropout_0: 0.4
# all_features_branch_RNN_layer_1_type: LSTM
# all_features_branch_hp_units_at_hp_layer_1: 64
# all_features_branch_recurrent_dropout_1: 0.2
# base_features_branch_hp_layers: 2
# base_features_branch_RNN_layer_0_type: LSTM
# base_features_branch_hp_units_at_hp_layer_0: 64
# base_features_branch_recurrent_dropout_0: 0.4
# base_features_branch_RNN_layer_1_type: LSTM
# base_features_branch_hp_units_at_hp_layer_1: 128
# base_features_branch_recurrent_dropout_1: 0.30000000000000004
# close_features_branch_hp_layers: 2
# close_features_branch_RNN_layer_0_type: GRU
# close_features_branch_hp_units_at_hp_layer_0: 128
# close_features_branch_recurrent_dropout_0: 0.2
# close_features_branch_RNN_layer_1_type: GRU
# close_features_branch_hp_units_at_hp_layer_1: 64
# close_features_branch_recurrent_dropout_1: 0.0
# high_low_features_branch_hp_layers: 2
# high_low_features_branch_RNN_layer_0_type: GRU
# high_low_features_branch_hp_units_at_hp_layer_0: 64
# high_low_features_branch_recurrent_dropout_0: 0.0
# high_low_features_branch_RNN_layer_1_type: GRU
# high_low_features_branch_hp_units_at_hp_layer_1: 128
# high_low_features_branch_recurrent_dropout_1: 0.0
# volume_features_branch_hp_layers: 4
# volume_features_branch_RNN_layer_0_type: GRU
# volume_features_branch_hp_units_at_hp_layer_0: 128
# volume_features_branch_recurrent_dropout_0: 0.0
# volume_features_branch_RNN_layer_1_type: SimpleRNN
# volume_features_branch_hp_units_at_hp_layer_1: 128
# volume_features_branch_recurrent_dropout_1: 0.1
# optimizer_type: RMSprop
# learning_rate: 0.0003828547440527253
# all_features_branch_RNN_layer_2_type: LSTM
# all_features_branch_hp_units_at_hp_layer_2: 128
# all_features_branch_recurrent_dropout_2: 0.2
# all_features_branch_RNN_layer_3_type: SimpleRNN
# all_features_branch_hp_units_at_hp_layer_3: 64
# all_features_branch_recurrent_dropout_3: 0.1
# close_features_branch_RNN_layer_2_type: SimpleRNN
# close_features_branch_hp_units_at_hp_layer_2: 128
# close_features_branch_recurrent_dropout_2: 0.0
# close_features_branch_RNN_layer_3_type: LSTM
# close_features_branch_hp_units_at_hp_layer_3: 128
# close_features_branch_recurrent_dropout_3: 0.4
# high_low_features_branch_RNN_layer_2_type: SimpleRNN
# high_low_features_branch_hp_units_at_hp_layer_2: 64
# high_low_features_branch_recurrent_dropout_2: 0.4
# high_low_features_branch_RNN_layer_3_type: GRU
# high_low_features_branch_hp_units_at_hp_layer_3: 128
# high_low_features_branch_recurrent_dropout_3: 0.1
# volume_features_branch_RNN_layer_2_type: GRU
# volume_features_branch_hp_units_at_hp_layer_2: 128
# volume_features_branch_recurrent_dropout_2: 0.2
# volume_features_branch_RNN_layer_3_type: GRU
# volume_features_branch_hp_units_at_hp_layer_3: 64
# volume_features_branch_recurrent_dropout_3: 0.1
# batch_size: 32
# base_features_branch_RNN_layer_2_type: GRU
# base_features_branch_hp_units_at_hp_layer_2: 64
# base_features_branch_recurrent_dropout_2: 0.2
# base_features_branch_RNN_layer_3_type: SimpleRNN
# base_features_branch_hp_units_at_hp_layer_3: 64
# base_features_branch_recurrent_dropout_3: 0.30000000000000004
# tuner/epochs: 2
# tuner/initial_epoch: 0
# tuner/bracket: 2
# tuner/round: 0
# Score: 0.5108514428138733
#
# Trial 0022 summary
# Hyperparameters:
# all_features_branch_hp_layers: 4
# all_features_branch_RNN_layer_0_type: SimpleRNN
# all_features_branch_hp_units_at_hp_layer_0: 128
# all_features_branch_recurrent_dropout_0: 0.0
# all_features_branch_RNN_layer_1_type: LSTM
# all_features_branch_hp_units_at_hp_layer_1: 128
# all_features_branch_recurrent_dropout_1: 0.30000000000000004
# base_features_branch_hp_layers: 2
# base_features_branch_RNN_layer_0_type: LSTM
# base_features_branch_hp_units_at_hp_layer_0: 128
# base_features_branch_recurrent_dropout_0: 0.2
# base_features_branch_RNN_layer_1_type: SimpleRNN
# base_features_branch_hp_units_at_hp_layer_1: 64
# base_features_branch_recurrent_dropout_1: 0.4
# close_features_branch_hp_layers: 4
# close_features_branch_RNN_layer_0_type: GRU
# close_features_branch_hp_units_at_hp_layer_0: 128
# close_features_branch_recurrent_dropout_0: 0.4
# close_features_branch_RNN_layer_1_type: SimpleRNN
# close_features_branch_hp_units_at_hp_layer_1: 128
# close_features_branch_recurrent_dropout_1: 0.2
# high_low_features_branch_hp_layers: 2
# high_low_features_branch_RNN_layer_0_type: SimpleRNN
# high_low_features_branch_hp_units_at_hp_layer_0: 64
# high_low_features_branch_recurrent_dropout_0: 0.30000000000000004
# high_low_features_branch_RNN_layer_1_type: LSTM
# high_low_features_branch_hp_units_at_hp_layer_1: 128
# high_low_features_branch_recurrent_dropout_1: 0.2
# volume_features_branch_hp_layers: 2
# volume_features_branch_RNN_layer_0_type: LSTM
# volume_features_branch_hp_units_at_hp_layer_0: 128
# volume_features_branch_recurrent_dropout_0: 0.1
# volume_features_branch_RNN_layer_1_type: LSTM
# volume_features_branch_hp_units_at_hp_layer_1: 64
# volume_features_branch_recurrent_dropout_1: 0.1
# optimizer_type: SGD
# learning_rate: 0.0014635819274432475
# all_features_branch_RNN_layer_2_type: LSTM
# all_features_branch_hp_units_at_hp_layer_2: 64
# all_features_branch_recurrent_dropout_2: 0.2
# all_features_branch_RNN_layer_3_type: GRU
# all_features_branch_hp_units_at_hp_layer_3: 64
# all_features_branch_recurrent_dropout_3: 0.30000000000000004
# close_features_branch_RNN_layer_2_type: SimpleRNN
# close_features_branch_hp_units_at_hp_layer_2: 64
# close_features_branch_recurrent_dropout_2: 0.4
# close_features_branch_RNN_layer_3_type: SimpleRNN
# close_features_branch_hp_units_at_hp_layer_3: 128
# close_features_branch_recurrent_dropout_3: 0.4
# high_low_features_branch_RNN_layer_2_type: SimpleRNN
# high_low_features_branch_hp_units_at_hp_layer_2: 64
# high_low_features_branch_recurrent_dropout_2: 0.4
# high_low_features_branch_RNN_layer_3_type: LSTM
# high_low_features_branch_hp_units_at_hp_layer_3: 128
# high_low_features_branch_recurrent_dropout_3: 0.1
# volume_features_branch_RNN_layer_2_type: GRU
# volume_features_branch_hp_units_at_hp_layer_2: 64
# volume_features_branch_recurrent_dropout_2: 0.4
# volume_features_branch_RNN_layer_3_type: SimpleRNN
# volume_features_branch_hp_units_at_hp_layer_3: 64
# volume_features_branch_recurrent_dropout_3: 0.30000000000000004
# batch_size: 64
# base_features_branch_RNN_layer_2_type: GRU
# base_features_branch_hp_units_at_hp_layer_2: 64
# base_features_branch_recurrent_dropout_2: 0.2
# base_features_branch_RNN_layer_3_type: GRU
# base_features_branch_hp_units_at_hp_layer_3: 128
# base_features_branch_recurrent_dropout_3: 0.4
# tuner/epochs: 4
# tuner/initial_epoch: 0
# tuner/bracket: 1
# tuner/round: 0
# Score: 0.5108514428138733
#
# Trial 0016 summary
# Hyperparameters:
# all_features_branch_hp_layers: 4
# all_features_branch_RNN_layer_0_type: SimpleRNN
# all_features_branch_hp_units_at_hp_layer_0: 128
# all_features_branch_recurrent_dropout_0: 0.4
# all_features_branch_RNN_layer_1_type: GRU
# all_features_branch_hp_units_at_hp_layer_1: 128
# all_features_branch_recurrent_dropout_1: 0.1
# base_features_branch_hp_layers: 2
# base_features_branch_RNN_layer_0_type: SimpleRNN
# base_features_branch_hp_units_at_hp_layer_0: 128
# base_features_branch_recurrent_dropout_0: 0.4
# base_features_branch_RNN_layer_1_type: LSTM
# base_features_branch_hp_units_at_hp_layer_1: 64
# base_features_branch_recurrent_dropout_1: 0.1
# close_features_branch_hp_layers: 4
# close_features_branch_RNN_layer_0_type: GRU
# close_features_branch_hp_units_at_hp_layer_0: 64
# close_features_branch_recurrent_dropout_0: 0.30000000000000004
# close_features_branch_RNN_layer_1_type: GRU
# close_features_branch_hp_units_at_hp_layer_1: 128
# close_features_branch_recurrent_dropout_1: 0.0
# high_low_features_branch_hp_layers: 4
# high_low_features_branch_RNN_layer_0_type: SimpleRNN
# high_low_features_branch_hp_units_at_hp_layer_0: 128
# high_low_features_branch_recurrent_dropout_0: 0.4
# high_low_features_branch_RNN_layer_1_type: LSTM
# high_low_features_branch_hp_units_at_hp_layer_1: 64
# high_low_features_branch_recurrent_dropout_1: 0.4
# volume_features_branch_hp_layers: 4
# volume_features_branch_RNN_layer_0_type: LSTM
# volume_features_branch_hp_units_at_hp_layer_0: 64
# volume_features_branch_recurrent_dropout_0: 0.2
# volume_features_branch_RNN_layer_1_type: LSTM
# volume_features_branch_hp_units_at_hp_layer_1: 64
# volume_features_branch_recurrent_dropout_1: 0.30000000000000004
# optimizer_type: RMSprop
# learning_rate: 0.0001395510628578222
# tuner/epochs: 10
# tuner/initial_epoch: 4
# tuner/bracket: 2
# tuner/round: 2
# all_features_branch_RNN_layer_2_type: SimpleRNN
# all_features_branch_hp_units_at_hp_layer_2: 64
# all_features_branch_recurrent_dropout_2: 0.0
# all_features_branch_RNN_layer_3_type: SimpleRNN
# all_features_branch_hp_units_at_hp_layer_3: 64
# all_features_branch_recurrent_dropout_3: 0.0
# close_features_branch_RNN_layer_2_type: SimpleRNN
# close_features_branch_hp_units_at_hp_layer_2: 64
# close_features_branch_recurrent_dropout_2: 0.0
# close_features_branch_RNN_layer_3_type: SimpleRNN
# close_features_branch_hp_units_at_hp_layer_3: 64
# close_features_branch_recurrent_dropout_3: 0.0
# high_low_features_branch_RNN_layer_2_type: SimpleRNN
# high_low_features_branch_hp_units_at_hp_layer_2: 64
# high_low_features_branch_recurrent_dropout_2: 0.0
# high_low_features_branch_RNN_layer_3_type: SimpleRNN
# high_low_features_branch_hp_units_at_hp_layer_3: 64
# high_low_features_branch_recurrent_dropout_3: 0.0
# volume_features_branch_RNN_layer_2_type: SimpleRNN
# volume_features_branch_hp_units_at_hp_layer_2: 64
# volume_features_branch_recurrent_dropout_2: 0.0
# volume_features_branch_RNN_layer_3_type: SimpleRNN
# volume_features_branch_hp_units_at_hp_layer_3: 64
# volume_features_branch_recurrent_dropout_3: 0.0
# batch_size: 32
# tuner/trial_id: 0013
# base_features_branch_RNN_layer_2_type: GRU
# base_features_branch_hp_units_at_hp_layer_2: 64
# base_features_branch_recurrent_dropout_2: 0.1
# base_features_branch_RNN_layer_3_type: SimpleRNN
# base_features_branch_hp_units_at_hp_layer_3: 128
# base_features_branch_recurrent_dropout_3: 0.30000000000000004
# Score: 0.510016679763794
#
# Trial 0000 summary
# Hyperparameters:
# all_features_branch_hp_layers: 4
# all_features_branch_RNN_layer_0_type: SimpleRNN
# all_features_branch_hp_units_at_hp_layer_0: 128
# all_features_branch_recurrent_dropout_0: 0.4
# all_features_branch_RNN_layer_1_type: GRU
# all_features_branch_hp_units_at_hp_layer_1: 128
# all_features_branch_recurrent_dropout_1: 0.1
# base_features_branch_hp_layers: 2
# base_features_branch_RNN_layer_0_type: SimpleRNN
# base_features_branch_hp_units_at_hp_layer_0: 128
# base_features_branch_recurrent_dropout_0: 0.4
# base_features_branch_RNN_layer_1_type: LSTM
# base_features_branch_hp_units_at_hp_layer_1: 64
# base_features_branch_recurrent_dropout_1: 0.1
# close_features_branch_hp_layers: 4
# close_features_branch_RNN_layer_0_type: GRU
# close_features_branch_hp_units_at_hp_layer_0: 64
# close_features_branch_recurrent_dropout_0: 0.30000000000000004
# close_features_branch_RNN_layer_1_type: GRU
# close_features_branch_hp_units_at_hp_layer_1: 128
# close_features_branch_recurrent_dropout_1: 0.0
# high_low_features_branch_hp_layers: 4
# high_low_features_branch_RNN_layer_0_type: SimpleRNN
# high_low_features_branch_hp_units_at_hp_layer_0: 128
# high_low_features_branch_recurrent_dropout_0: 0.4
# high_low_features_branch_RNN_layer_1_type: LSTM
# high_low_features_branch_hp_units_at_hp_layer_1: 64
# high_low_features_branch_recurrent_dropout_1: 0.4
# volume_features_branch_hp_layers: 4
# volume_features_branch_RNN_layer_0_type: LSTM
# volume_features_branch_hp_units_at_hp_layer_0: 64
# volume_features_branch_recurrent_dropout_0: 0.2
# volume_features_branch_RNN_layer_1_type: LSTM
# volume_features_branch_hp_units_at_hp_layer_1: 64
# volume_features_branch_recurrent_dropout_1: 0.30000000000000004
# optimizer_type: RMSprop
# learning_rate: 0.0001395510628578222
# tuner/epochs: 2
# tuner/initial_epoch: 0
# tuner/bracket: 2
# tuner/round: 0
# all_features_branch_RNN_layer_2_type: SimpleRNN
# all_features_branch_hp_units_at_hp_layer_2: 64
# all_features_branch_recurrent_dropout_2: 0.0
# all_features_branch_RNN_layer_3_type: SimpleRNN
# all_features_branch_hp_units_at_hp_layer_3: 64
# all_features_branch_recurrent_dropout_3: 0.0
# close_features_branch_RNN_layer_2_type: SimpleRNN
# close_features_branch_hp_units_at_hp_layer_2: 64
# close_features_branch_recurrent_dropout_2: 0.0
# close_features_branch_RNN_layer_3_type: SimpleRNN
# close_features_branch_hp_units_at_hp_layer_3: 64
# close_features_branch_recurrent_dropout_3: 0.0
# high_low_features_branch_RNN_layer_2_type: SimpleRNN
# high_low_features_branch_hp_units_at_hp_layer_2: 64
# high_low_features_branch_recurrent_dropout_2: 0.0
# high_low_features_branch_RNN_layer_3_type: SimpleRNN
# high_low_features_branch_hp_units_at_hp_layer_3: 64
# high_low_features_branch_recurrent_dropout_3: 0.0
# volume_features_branch_RNN_layer_2_type: SimpleRNN
# volume_features_branch_hp_units_at_hp_layer_2: 64
# volume_features_branch_recurrent_dropout_2: 0.0
# volume_features_branch_RNN_layer_3_type: SimpleRNN
# volume_features_branch_hp_units_at_hp_layer_3: 64
# volume_features_branch_recurrent_dropout_3: 0.0
# batch_size: 32
# Score: 0.5091819763183594
#
# Trial 0001 summary
# Hyperparameters:
# all_features_branch_hp_layers: 2
# all_features_branch_RNN_layer_0_type: SimpleRNN
# all_features_branch_hp_units_at_hp_layer_0: 128
# all_features_branch_recurrent_dropout_0: 0.2
# all_features_branch_RNN_layer_1_type: LSTM
# all_features_branch_hp_units_at_hp_layer_1: 128
# all_features_branch_recurrent_dropout_1: 0.2
# base_features_branch_hp_layers: 4
# base_features_branch_RNN_layer_0_type: SimpleRNN
# base_features_branch_hp_units_at_hp_layer_0: 128
# base_features_branch_recurrent_dropout_0: 0.2
# base_features_branch_RNN_layer_1_type: SimpleRNN
# base_features_branch_hp_units_at_hp_layer_1: 128
# base_features_branch_recurrent_dropout_1: 0.30000000000000004
# close_features_branch_hp_layers: 4
# close_features_branch_RNN_layer_0_type: GRU
# close_features_branch_hp_units_at_hp_layer_0: 64
# close_features_branch_recurrent_dropout_0: 0.2
# close_features_branch_RNN_layer_1_type: LSTM
# close_features_branch_hp_units_at_hp_layer_1: 128
# close_features_branch_recurrent_dropout_1: 0.30000000000000004
# high_low_features_branch_hp_layers: 2
# high_low_features_branch_RNN_layer_0_type: SimpleRNN
# high_low_features_branch_hp_units_at_hp_layer_0: 128
# high_low_features_branch_recurrent_dropout_0: 0.0
# high_low_features_branch_RNN_layer_1_type: LSTM
# high_low_features_branch_hp_units_at_hp_layer_1: 64
# high_low_features_branch_recurrent_dropout_1: 0.0
# volume_features_branch_hp_layers: 2
# volume_features_branch_RNN_layer_0_type: SimpleRNN
# volume_features_branch_hp_units_at_hp_layer_0: 128
# volume_features_branch_recurrent_dropout_0: 0.1
# volume_features_branch_RNN_layer_1_type: GRU
# volume_features_branch_hp_units_at_hp_layer_1: 128
# volume_features_branch_recurrent_dropout_1: 0.1
# optimizer_type: Adam
# learning_rate: 0.00405701014195834
# all_features_branch_RNN_layer_2_type: LSTM
# all_features_branch_hp_units_at_hp_layer_2: 64
# all_features_branch_recurrent_dropout_2: 0.4
# all_features_branch_RNN_layer_3_type: GRU
# all_features_branch_hp_units_at_hp_layer_3: 128
# all_features_branch_recurrent_dropout_3: 0.0
# close_features_branch_RNN_layer_2_type: LSTM
# close_features_branch_hp_units_at_hp_layer_2: 64
# close_features_branch_recurrent_dropout_2: 0.0
# close_features_branch_RNN_layer_3_type: SimpleRNN
# close_features_branch_hp_units_at_hp_layer_3: 128
# close_features_branch_recurrent_dropout_3: 0.1
# high_low_features_branch_RNN_layer_2_type: LSTM
# high_low_features_branch_hp_units_at_hp_layer_2: 128
# high_low_features_branch_recurrent_dropout_2: 0.2
# high_low_features_branch_RNN_layer_3_type: SimpleRNN
# high_low_features_branch_hp_units_at_hp_layer_3: 128
# high_low_features_branch_recurrent_dropout_3: 0.1
# volume_features_branch_RNN_layer_2_type: LSTM
# volume_features_branch_hp_units_at_hp_layer_2: 128
# volume_features_branch_recurrent_dropout_2: 0.2
# volume_features_branch_RNN_layer_3_type: LSTM
# volume_features_branch_hp_units_at_hp_layer_3: 128
# volume_features_branch_recurrent_dropout_3: 0.0
# batch_size: 32
# tuner/epochs: 2
# tuner/initial_epoch: 0
# tuner/bracket: 2
# tuner/round: 0
# base_features_branch_RNN_layer_2_type: SimpleRNN
# base_features_branch_hp_units_at_hp_layer_2: 64
# base_features_branch_recurrent_dropout_2: 0.0
# base_features_branch_RNN_layer_3_type: SimpleRNN
# base_features_branch_hp_units_at_hp_layer_3: 64
# base_features_branch_recurrent_dropout_3: 0.0
# Score: 0.5091819763183594
#
# Trial 0002 summary
# Hyperparameters:
# all_features_branch_hp_layers: 2
# all_features_branch_RNN_layer_0_type: SimpleRNN
# all_features_branch_hp_units_at_hp_layer_0: 128
# all_features_branch_recurrent_dropout_0: 0.0
# all_features_branch_RNN_layer_1_type: LSTM
# all_features_branch_hp_units_at_hp_layer_1: 64
# all_features_branch_recurrent_dropout_1: 0.0
# base_features_branch_hp_layers: 4
# base_features_branch_RNN_layer_0_type: SimpleRNN
# base_features_branch_hp_units_at_hp_layer_0: 128
# base_features_branch_recurrent_dropout_0: 0.1
# base_features_branch_RNN_layer_1_type: LSTM
# base_features_branch_hp_units_at_hp_layer_1: 64
# base_features_branch_recurrent_dropout_1: 0.0
# close_features_branch_hp_layers: 4
# close_features_branch_RNN_layer_0_type: SimpleRNN
# close_features_branch_hp_units_at_hp_layer_0: 128
# close_features_branch_recurrent_dropout_0: 0.4
# close_features_branch_RNN_layer_1_type: SimpleRNN
# close_features_branch_hp_units_at_hp_layer_1: 128
# close_features_branch_recurrent_dropout_1: 0.30000000000000004
# high_low_features_branch_hp_layers: 2
# high_low_features_branch_RNN_layer_0_type: GRU
# high_low_features_branch_hp_units_at_hp_layer_0: 64
# high_low_features_branch_recurrent_dropout_0: 0.0
# high_low_features_branch_RNN_layer_1_type: GRU
# high_low_features_branch_hp_units_at_hp_layer_1: 64
# high_low_features_branch_recurrent_dropout_1: 0.1
# volume_features_branch_hp_layers: 4
# volume_features_branch_RNN_layer_0_type: LSTM
# volume_features_branch_hp_units_at_hp_layer_0: 128
# volume_features_branch_recurrent_dropout_0: 0.4
# volume_features_branch_RNN_layer_1_type: SimpleRNN
# volume_features_branch_hp_units_at_hp_layer_1: 128
# volume_features_branch_recurrent_dropout_1: 0.1
# optimizer_type: RMSprop
# learning_rate: 0.002220709089529535
# all_features_branch_RNN_layer_2_type: LSTM
# all_features_branch_hp_units_at_hp_layer_2: 128
# all_features_branch_recurrent_dropout_2: 0.0
# all_features_branch_RNN_layer_3_type: GRU
# all_features_branch_hp_units_at_hp_layer_3: 128
# all_features_branch_recurrent_dropout_3: 0.1
# close_features_branch_RNN_layer_2_type: GRU
# close_features_branch_hp_units_at_hp_layer_2: 128
# close_features_branch_recurrent_dropout_2: 0.0
# close_features_branch_RNN_layer_3_type: GRU
# close_features_branch_hp_units_at_hp_layer_3: 64
# close_features_branch_recurrent_dropout_3: 0.4
# high_low_features_branch_RNN_layer_2_type: SimpleRNN
# high_low_features_branch_hp_units_at_hp_layer_2: 64
# high_low_features_branch_recurrent_dropout_2: 0.2
# high_low_features_branch_RNN_layer_3_type: GRU
# high_low_features_branch_hp_units_at_hp_layer_3: 128
# high_low_features_branch_recurrent_dropout_3: 0.1
# volume_features_branch_RNN_layer_2_type: SimpleRNN
# volume_features_branch_hp_units_at_hp_layer_2: 64
# volume_features_branch_recurrent_dropout_2: 0.1
# volume_features_branch_RNN_layer_3_type: LSTM
# volume_features_branch_hp_units_at_hp_layer_3: 64
# volume_features_branch_recurrent_dropout_3: 0.1
# batch_size: 32
# base_features_branch_RNN_layer_2_type: SimpleRNN
# base_features_branch_hp_units_at_hp_layer_2: 128
# base_features_branch_recurrent_dropout_2: 0.30000000000000004
# base_features_branch_RNN_layer_3_type: GRU
# base_features_branch_hp_units_at_hp_layer_3: 128
# base_features_branch_recurrent_dropout_3: 0.0
# tuner/epochs: 2
# tuner/initial_epoch: 0
# tuner/bracket: 2
# tuner/round: 0
# Score: 0.5091819763183594
# Best epoch: 12
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 14s 284ms/step
# training for the PFE model was done in: 7:31:29.666766
# Results summary
# Results in keras_tuner_models\hp_RNN_inception_model_archive_1d/ROP
# Showing 10 best trials
# Objective(name="val_accuracy", direction="max")
#
# Trial 0021 summary
# Hyperparameters:
# all_features_branch_hp_layers: 4
# all_features_branch_RNN_layer_0_type: LSTM
# all_features_branch_hp_units_at_hp_layer_0: 128
# all_features_branch_recurrent_dropout_0: 0.0
# all_features_branch_RNN_layer_1_type: LSTM
# all_features_branch_hp_units_at_hp_layer_1: 64
# all_features_branch_recurrent_dropout_1: 0.2
# base_features_branch_hp_layers: 2
# base_features_branch_RNN_layer_0_type: LSTM
# base_features_branch_hp_units_at_hp_layer_0: 64
# base_features_branch_recurrent_dropout_0: 0.2
# base_features_branch_RNN_layer_1_type: SimpleRNN
# base_features_branch_hp_units_at_hp_layer_1: 128
# base_features_branch_recurrent_dropout_1: 0.2
# close_features_branch_hp_layers: 2
# close_features_branch_RNN_layer_0_type: LSTM
# close_features_branch_hp_units_at_hp_layer_0: 128
# close_features_branch_recurrent_dropout_0: 0.1
# close_features_branch_RNN_layer_1_type: GRU
# close_features_branch_hp_units_at_hp_layer_1: 64
# close_features_branch_recurrent_dropout_1: 0.1
# high_low_features_branch_hp_layers: 4
# high_low_features_branch_RNN_layer_0_type: LSTM
# high_low_features_branch_hp_units_at_hp_layer_0: 128
# high_low_features_branch_recurrent_dropout_0: 0.1
# high_low_features_branch_RNN_layer_1_type: LSTM
# high_low_features_branch_hp_units_at_hp_layer_1: 64
# high_low_features_branch_recurrent_dropout_1: 0.1
# volume_features_branch_hp_layers: 2
# volume_features_branch_RNN_layer_0_type: SimpleRNN
# volume_features_branch_hp_units_at_hp_layer_0: 128
# volume_features_branch_recurrent_dropout_0: 0.1
# volume_features_branch_RNN_layer_1_type: GRU
# volume_features_branch_hp_units_at_hp_layer_1: 64
# volume_features_branch_recurrent_dropout_1: 0.1
# optimizer_type: Adam
# learning_rate: 0.0015603766129866545
# all_features_branch_RNN_layer_2_type: LSTM
# all_features_branch_hp_units_at_hp_layer_2: 64
# all_features_branch_recurrent_dropout_2: 0.1
# all_features_branch_RNN_layer_3_type: GRU
# all_features_branch_hp_units_at_hp_layer_3: 64
# all_features_branch_recurrent_dropout_3: 0.1
# close_features_branch_RNN_layer_2_type: LSTM
# close_features_branch_hp_units_at_hp_layer_2: 64
# close_features_branch_recurrent_dropout_2: 0.4
# close_features_branch_RNN_layer_3_type: LSTM
# close_features_branch_hp_units_at_hp_layer_3: 128
# close_features_branch_recurrent_dropout_3: 0.2
# high_low_features_branch_RNN_layer_2_type: LSTM
# high_low_features_branch_hp_units_at_hp_layer_2: 128
# high_low_features_branch_recurrent_dropout_2: 0.2
# high_low_features_branch_RNN_layer_3_type: SimpleRNN
# high_low_features_branch_hp_units_at_hp_layer_3: 64
# high_low_features_branch_recurrent_dropout_3: 0.1
# volume_features_branch_RNN_layer_2_type: GRU
# volume_features_branch_hp_units_at_hp_layer_2: 128
# volume_features_branch_recurrent_dropout_2: 0.2
# volume_features_branch_RNN_layer_3_type: SimpleRNN
# volume_features_branch_hp_units_at_hp_layer_3: 128
# volume_features_branch_recurrent_dropout_3: 0.2
# batch_size: 32
# base_features_branch_RNN_layer_2_type: GRU
# base_features_branch_hp_units_at_hp_layer_2: 128
# base_features_branch_recurrent_dropout_2: 0.2
# base_features_branch_RNN_layer_3_type: LSTM
# base_features_branch_hp_units_at_hp_layer_3: 64
# base_features_branch_recurrent_dropout_3: 0.0
# tuner/epochs: 4
# tuner/initial_epoch: 0
# tuner/bracket: 1
# tuner/round: 0
# Score: 0.5607892870903015
#
# Trial 0000 summary
# Hyperparameters:
# all_features_branch_hp_layers: 4
# all_features_branch_RNN_layer_0_type: SimpleRNN
# all_features_branch_hp_units_at_hp_layer_0: 128
# all_features_branch_recurrent_dropout_0: 0.4
# all_features_branch_RNN_layer_1_type: GRU
# all_features_branch_hp_units_at_hp_layer_1: 128
# all_features_branch_recurrent_dropout_1: 0.1
# base_features_branch_hp_layers: 2
# base_features_branch_RNN_layer_0_type: SimpleRNN
# base_features_branch_hp_units_at_hp_layer_0: 128
# base_features_branch_recurrent_dropout_0: 0.4
# base_features_branch_RNN_layer_1_type: LSTM
# base_features_branch_hp_units_at_hp_layer_1: 64
# base_features_branch_recurrent_dropout_1: 0.1
# close_features_branch_hp_layers: 4
# close_features_branch_RNN_layer_0_type: GRU
# close_features_branch_hp_units_at_hp_layer_0: 64
# close_features_branch_recurrent_dropout_0: 0.30000000000000004
# close_features_branch_RNN_layer_1_type: GRU
# close_features_branch_hp_units_at_hp_layer_1: 128
# close_features_branch_recurrent_dropout_1: 0.0
# high_low_features_branch_hp_layers: 4
# high_low_features_branch_RNN_layer_0_type: SimpleRNN
# high_low_features_branch_hp_units_at_hp_layer_0: 128
# high_low_features_branch_recurrent_dropout_0: 0.4
# high_low_features_branch_RNN_layer_1_type: LSTM
# high_low_features_branch_hp_units_at_hp_layer_1: 64
# high_low_features_branch_recurrent_dropout_1: 0.4
# volume_features_branch_hp_layers: 4
# volume_features_branch_RNN_layer_0_type: LSTM
# volume_features_branch_hp_units_at_hp_layer_0: 64
# volume_features_branch_recurrent_dropout_0: 0.2
# volume_features_branch_RNN_layer_1_type: LSTM
# volume_features_branch_hp_units_at_hp_layer_1: 64
# volume_features_branch_recurrent_dropout_1: 0.30000000000000004
# optimizer_type: RMSprop
# learning_rate: 0.0001395510628578222
# tuner/epochs: 2
# tuner/initial_epoch: 0
# tuner/bracket: 2
# tuner/round: 0
# all_features_branch_RNN_layer_2_type: SimpleRNN
# all_features_branch_hp_units_at_hp_layer_2: 64
# all_features_branch_recurrent_dropout_2: 0.0
# all_features_branch_RNN_layer_3_type: SimpleRNN
# all_features_branch_hp_units_at_hp_layer_3: 64
# all_features_branch_recurrent_dropout_3: 0.0
# close_features_branch_RNN_layer_2_type: SimpleRNN
# close_features_branch_hp_units_at_hp_layer_2: 64
# close_features_branch_recurrent_dropout_2: 0.0
# close_features_branch_RNN_layer_3_type: SimpleRNN
# close_features_branch_hp_units_at_hp_layer_3: 64
# close_features_branch_recurrent_dropout_3: 0.0
# high_low_features_branch_RNN_layer_2_type: SimpleRNN
# high_low_features_branch_hp_units_at_hp_layer_2: 64
# high_low_features_branch_recurrent_dropout_2: 0.0
# high_low_features_branch_RNN_layer_3_type: SimpleRNN
# high_low_features_branch_hp_units_at_hp_layer_3: 64
# high_low_features_branch_recurrent_dropout_3: 0.0
# volume_features_branch_RNN_layer_2_type: SimpleRNN
# volume_features_branch_hp_units_at_hp_layer_2: 64
# volume_features_branch_recurrent_dropout_2: 0.0
# volume_features_branch_RNN_layer_3_type: SimpleRNN
# volume_features_branch_hp_units_at_hp_layer_3: 64
# volume_features_branch_recurrent_dropout_3: 0.0
# batch_size: 32
# Score: 0.5601527690887451
#
# Trial 0002 summary
# Hyperparameters:
# all_features_branch_hp_layers: 2
# all_features_branch_RNN_layer_0_type: SimpleRNN
# all_features_branch_hp_units_at_hp_layer_0: 128
# all_features_branch_recurrent_dropout_0: 0.0
# all_features_branch_RNN_layer_1_type: LSTM
# all_features_branch_hp_units_at_hp_layer_1: 64
# all_features_branch_recurrent_dropout_1: 0.0
# base_features_branch_hp_layers: 4
# base_features_branch_RNN_layer_0_type: SimpleRNN
# base_features_branch_hp_units_at_hp_layer_0: 128
# base_features_branch_recurrent_dropout_0: 0.1
# base_features_branch_RNN_layer_1_type: LSTM
# base_features_branch_hp_units_at_hp_layer_1: 64
# base_features_branch_recurrent_dropout_1: 0.0
# close_features_branch_hp_layers: 4
# close_features_branch_RNN_layer_0_type: SimpleRNN
# close_features_branch_hp_units_at_hp_layer_0: 128
# close_features_branch_recurrent_dropout_0: 0.4
# close_features_branch_RNN_layer_1_type: SimpleRNN
# close_features_branch_hp_units_at_hp_layer_1: 128
# close_features_branch_recurrent_dropout_1: 0.30000000000000004
# high_low_features_branch_hp_layers: 2
# high_low_features_branch_RNN_layer_0_type: GRU
# high_low_features_branch_hp_units_at_hp_layer_0: 64
# high_low_features_branch_recurrent_dropout_0: 0.0
# high_low_features_branch_RNN_layer_1_type: GRU
# high_low_features_branch_hp_units_at_hp_layer_1: 64
# high_low_features_branch_recurrent_dropout_1: 0.1
# volume_features_branch_hp_layers: 4
# volume_features_branch_RNN_layer_0_type: LSTM
# volume_features_branch_hp_units_at_hp_layer_0: 128
# volume_features_branch_recurrent_dropout_0: 0.4
# volume_features_branch_RNN_layer_1_type: SimpleRNN
# volume_features_branch_hp_units_at_hp_layer_1: 128
# volume_features_branch_recurrent_dropout_1: 0.1
# optimizer_type: RMSprop
# learning_rate: 0.002220709089529535
# all_features_branch_RNN_layer_2_type: LSTM
# all_features_branch_hp_units_at_hp_layer_2: 128
# all_features_branch_recurrent_dropout_2: 0.0
# all_features_branch_RNN_layer_3_type: GRU
# all_features_branch_hp_units_at_hp_layer_3: 128
# all_features_branch_recurrent_dropout_3: 0.1
# close_features_branch_RNN_layer_2_type: GRU
# close_features_branch_hp_units_at_hp_layer_2: 128
# close_features_branch_recurrent_dropout_2: 0.0
# close_features_branch_RNN_layer_3_type: GRU
# close_features_branch_hp_units_at_hp_layer_3: 64
# close_features_branch_recurrent_dropout_3: 0.4
# high_low_features_branch_RNN_layer_2_type: SimpleRNN
# high_low_features_branch_hp_units_at_hp_layer_2: 64
# high_low_features_branch_recurrent_dropout_2: 0.2
# high_low_features_branch_RNN_layer_3_type: GRU
# high_low_features_branch_hp_units_at_hp_layer_3: 128
# high_low_features_branch_recurrent_dropout_3: 0.1
# volume_features_branch_RNN_layer_2_type: SimpleRNN
# volume_features_branch_hp_units_at_hp_layer_2: 64
# volume_features_branch_recurrent_dropout_2: 0.1
# volume_features_branch_RNN_layer_3_type: LSTM
# volume_features_branch_hp_units_at_hp_layer_3: 64
# volume_features_branch_recurrent_dropout_3: 0.1
# batch_size: 32
# base_features_branch_RNN_layer_2_type: SimpleRNN
# base_features_branch_hp_units_at_hp_layer_2: 128
# base_features_branch_recurrent_dropout_2: 0.30000000000000004
# base_features_branch_RNN_layer_3_type: GRU
# base_features_branch_hp_units_at_hp_layer_3: 128
# base_features_branch_recurrent_dropout_3: 0.0
# tuner/epochs: 2
# tuner/initial_epoch: 0
# tuner/bracket: 2
# tuner/round: 0
# Score: 0.5595162510871887
#
# Trial 0004 summary
# Hyperparameters:
# all_features_branch_hp_layers: 2
# all_features_branch_RNN_layer_0_type: SimpleRNN
# all_features_branch_hp_units_at_hp_layer_0: 64
# all_features_branch_recurrent_dropout_0: 0.0
# all_features_branch_RNN_layer_1_type: LSTM
# all_features_branch_hp_units_at_hp_layer_1: 128
# all_features_branch_recurrent_dropout_1: 0.0
# base_features_branch_hp_layers: 2
# base_features_branch_RNN_layer_0_type: LSTM
# base_features_branch_hp_units_at_hp_layer_0: 128
# base_features_branch_recurrent_dropout_0: 0.2
# base_features_branch_RNN_layer_1_type: LSTM
# base_features_branch_hp_units_at_hp_layer_1: 128
# base_features_branch_recurrent_dropout_1: 0.2
# close_features_branch_hp_layers: 4
# close_features_branch_RNN_layer_0_type: GRU
# close_features_branch_hp_units_at_hp_layer_0: 128
# close_features_branch_recurrent_dropout_0: 0.0
# close_features_branch_RNN_layer_1_type: SimpleRNN
# close_features_branch_hp_units_at_hp_layer_1: 64
# close_features_branch_recurrent_dropout_1: 0.30000000000000004
# high_low_features_branch_hp_layers: 2
# high_low_features_branch_RNN_layer_0_type: GRU
# high_low_features_branch_hp_units_at_hp_layer_0: 64
# high_low_features_branch_recurrent_dropout_0: 0.4
# high_low_features_branch_RNN_layer_1_type: GRU
# high_low_features_branch_hp_units_at_hp_layer_1: 128
# high_low_features_branch_recurrent_dropout_1: 0.30000000000000004
# volume_features_branch_hp_layers: 4
# volume_features_branch_RNN_layer_0_type: GRU
# volume_features_branch_hp_units_at_hp_layer_0: 64
# volume_features_branch_recurrent_dropout_0: 0.0
# volume_features_branch_RNN_layer_1_type: GRU
# volume_features_branch_hp_units_at_hp_layer_1: 128
# volume_features_branch_recurrent_dropout_1: 0.0
# optimizer_type: Adam
# learning_rate: 0.00017156481353511826
# all_features_branch_RNN_layer_2_type: SimpleRNN
# all_features_branch_hp_units_at_hp_layer_2: 64
# all_features_branch_recurrent_dropout_2: 0.1
# all_features_branch_RNN_layer_3_type: GRU
# all_features_branch_hp_units_at_hp_layer_3: 64
# all_features_branch_recurrent_dropout_3: 0.0
# close_features_branch_RNN_layer_2_type: SimpleRNN
# close_features_branch_hp_units_at_hp_layer_2: 128
# close_features_branch_recurrent_dropout_2: 0.2
# close_features_branch_RNN_layer_3_type: SimpleRNN
# close_features_branch_hp_units_at_hp_layer_3: 128
# close_features_branch_recurrent_dropout_3: 0.30000000000000004
# high_low_features_branch_RNN_layer_2_type: GRU
# high_low_features_branch_hp_units_at_hp_layer_2: 128
# high_low_features_branch_recurrent_dropout_2: 0.2
# high_low_features_branch_RNN_layer_3_type: GRU
# high_low_features_branch_hp_units_at_hp_layer_3: 128
# high_low_features_branch_recurrent_dropout_3: 0.2
# volume_features_branch_RNN_layer_2_type: LSTM
# volume_features_branch_hp_units_at_hp_layer_2: 128
# volume_features_branch_recurrent_dropout_2: 0.1
# volume_features_branch_RNN_layer_3_type: GRU
# volume_features_branch_hp_units_at_hp_layer_3: 64
# volume_features_branch_recurrent_dropout_3: 0.0
# batch_size: 32
# base_features_branch_RNN_layer_2_type: GRU
# base_features_branch_hp_units_at_hp_layer_2: 64
# base_features_branch_recurrent_dropout_2: 0.1
# base_features_branch_RNN_layer_3_type: LSTM
# base_features_branch_hp_units_at_hp_layer_3: 128
# base_features_branch_recurrent_dropout_3: 0.1
# tuner/epochs: 2
# tuner/initial_epoch: 0
# tuner/bracket: 2
# tuner/round: 0
# Score: 0.5595162510871887
#
# Trial 0006 summary
# Hyperparameters:
# all_features_branch_hp_layers: 4
# ...
# high_low_features_branch_hp_units_at_hp_layer_2: 64
# high_low_features_branch_recurrent_dropout_2: 0.2
# high_low_features_branch_RNN_layer_3_type: GRU
# high_low_features_branch_hp_units_at_hp_layer_3: 128
# high_low_features_branch_recurrent_dropout_3: 0.1
# volume_features_branch_RNN_layer_2_type: SimpleRNN
# volume_features_branch_hp_units_at_hp_layer_2: 64
# volume_features_branch_recurrent_dropout_2: 0.1
# volume_features_branch_RNN_layer_3_type: LSTM
# volume_features_branch_hp_units_at_hp_layer_3: 64
# volume_features_branch_recurrent_dropout_3: 0.1
# batch_size: 32
# base_features_branch_RNN_layer_2_type: SimpleRNN
# base_features_branch_hp_units_at_hp_layer_2: 128
# base_features_branch_recurrent_dropout_2: 0.30000000000000004
# base_features_branch_RNN_layer_3_type: GRU
# base_features_branch_hp_units_at_hp_layer_3: 128
# base_features_branch_recurrent_dropout_3: 0.0
# tuner/epochs: 4
# tuner/initial_epoch: 2
# tuner/bracket: 2
# tuner/round: 1
# tuner/trial_id: 0002
# Score: 0.5595162510871887
#
# Trial 0014 summary
# Hyperparameters:
# all_features_branch_hp_layers: 2
# all_features_branch_RNN_layer_0_type: SimpleRNN
# all_features_branch_hp_units_at_hp_layer_0: 64
# all_features_branch_recurrent_dropout_0: 0.0
# all_features_branch_RNN_layer_1_type: LSTM
# all_features_branch_hp_units_at_hp_layer_1: 128
# all_features_branch_recurrent_dropout_1: 0.0
# base_features_branch_hp_layers: 2
# base_features_branch_RNN_layer_0_type: LSTM
# base_features_branch_hp_units_at_hp_layer_0: 128
# base_features_branch_recurrent_dropout_0: 0.2
# base_features_branch_RNN_layer_1_type: LSTM
# base_features_branch_hp_units_at_hp_layer_1: 128
# base_features_branch_recurrent_dropout_1: 0.2
# close_features_branch_hp_layers: 4
# close_features_branch_RNN_layer_0_type: GRU
# close_features_branch_hp_units_at_hp_layer_0: 128
# close_features_branch_recurrent_dropout_0: 0.0
# close_features_branch_RNN_layer_1_type: SimpleRNN
# close_features_branch_hp_units_at_hp_layer_1: 64
# close_features_branch_recurrent_dropout_1: 0.30000000000000004
# high_low_features_branch_hp_layers: 2
# high_low_features_branch_RNN_layer_0_type: GRU
# high_low_features_branch_hp_units_at_hp_layer_0: 64
# high_low_features_branch_recurrent_dropout_0: 0.4
# high_low_features_branch_RNN_layer_1_type: GRU
# high_low_features_branch_hp_units_at_hp_layer_1: 128
# high_low_features_branch_recurrent_dropout_1: 0.30000000000000004
# volume_features_branch_hp_layers: 4
# volume_features_branch_RNN_layer_0_type: GRU
# volume_features_branch_hp_units_at_hp_layer_0: 64
# volume_features_branch_recurrent_dropout_0: 0.0
# volume_features_branch_RNN_layer_1_type: GRU
# volume_features_branch_hp_units_at_hp_layer_1: 128
# volume_features_branch_recurrent_dropout_1: 0.0
# optimizer_type: Adam
# learning_rate: 0.00017156481353511826
# all_features_branch_RNN_layer_2_type: SimpleRNN
# all_features_branch_hp_units_at_hp_layer_2: 64
# all_features_branch_recurrent_dropout_2: 0.1
# all_features_branch_RNN_layer_3_type: GRU
# all_features_branch_hp_units_at_hp_layer_3: 64
# all_features_branch_recurrent_dropout_3: 0.0
# close_features_branch_RNN_layer_2_type: SimpleRNN
# close_features_branch_hp_units_at_hp_layer_2: 128
# close_features_branch_recurrent_dropout_2: 0.2
# close_features_branch_RNN_layer_3_type: SimpleRNN
# close_features_branch_hp_units_at_hp_layer_3: 128
# close_features_branch_recurrent_dropout_3: 0.30000000000000004
# high_low_features_branch_RNN_layer_2_type: GRU
# high_low_features_branch_hp_units_at_hp_layer_2: 128
# high_low_features_branch_recurrent_dropout_2: 0.2
# high_low_features_branch_RNN_layer_3_type: GRU
# high_low_features_branch_hp_units_at_hp_layer_3: 128
# high_low_features_branch_recurrent_dropout_3: 0.2
# volume_features_branch_RNN_layer_2_type: LSTM
# volume_features_branch_hp_units_at_hp_layer_2: 128
# volume_features_branch_recurrent_dropout_2: 0.1
# volume_features_branch_RNN_layer_3_type: GRU
# volume_features_branch_hp_units_at_hp_layer_3: 64
# volume_features_branch_recurrent_dropout_3: 0.0
# batch_size: 32
# base_features_branch_RNN_layer_2_type: GRU
# base_features_branch_hp_units_at_hp_layer_2: 64
# base_features_branch_recurrent_dropout_2: 0.1
# base_features_branch_RNN_layer_3_type: LSTM
# base_features_branch_hp_units_at_hp_layer_3: 128
# base_features_branch_recurrent_dropout_3: 0.1
# tuner/epochs: 4
# tuner/initial_epoch: 2
# tuner/bracket: 2
# tuner/round: 1
# tuner/trial_id: 0004
# Score: 0.5595162510871887
#
# Trial 0016 summary
# Hyperparameters:
# all_features_branch_hp_layers: 2
# all_features_branch_RNN_layer_0_type: SimpleRNN
# all_features_branch_hp_units_at_hp_layer_0: 128
# all_features_branch_recurrent_dropout_0: 0.0
# all_features_branch_RNN_layer_1_type: LSTM
# all_features_branch_hp_units_at_hp_layer_1: 64
# all_features_branch_recurrent_dropout_1: 0.0
# base_features_branch_hp_layers: 4
# base_features_branch_RNN_layer_0_type: SimpleRNN
# base_features_branch_hp_units_at_hp_layer_0: 128
# base_features_branch_recurrent_dropout_0: 0.1
# base_features_branch_RNN_layer_1_type: LSTM
# base_features_branch_hp_units_at_hp_layer_1: 64
# base_features_branch_recurrent_dropout_1: 0.0
# close_features_branch_hp_layers: 4
# close_features_branch_RNN_layer_0_type: SimpleRNN
# close_features_branch_hp_units_at_hp_layer_0: 128
# close_features_branch_recurrent_dropout_0: 0.4
# close_features_branch_RNN_layer_1_type: SimpleRNN
# close_features_branch_hp_units_at_hp_layer_1: 128
# close_features_branch_recurrent_dropout_1: 0.30000000000000004
# high_low_features_branch_hp_layers: 2
# high_low_features_branch_RNN_layer_0_type: GRU
# high_low_features_branch_hp_units_at_hp_layer_0: 64
# high_low_features_branch_recurrent_dropout_0: 0.0
# high_low_features_branch_RNN_layer_1_type: GRU
# high_low_features_branch_hp_units_at_hp_layer_1: 64
# high_low_features_branch_recurrent_dropout_1: 0.1
# volume_features_branch_hp_layers: 4
# volume_features_branch_RNN_layer_0_type: LSTM
# volume_features_branch_hp_units_at_hp_layer_0: 128
# volume_features_branch_recurrent_dropout_0: 0.4
# volume_features_branch_RNN_layer_1_type: SimpleRNN
# volume_features_branch_hp_units_at_hp_layer_1: 128
# volume_features_branch_recurrent_dropout_1: 0.1
# optimizer_type: RMSprop
# learning_rate: 0.002220709089529535
# all_features_branch_RNN_layer_2_type: LSTM
# all_features_branch_hp_units_at_hp_layer_2: 128
# all_features_branch_recurrent_dropout_2: 0.0
# all_features_branch_RNN_layer_3_type: GRU
# all_features_branch_hp_units_at_hp_layer_3: 128
# all_features_branch_recurrent_dropout_3: 0.1
# close_features_branch_RNN_layer_2_type: GRU
# close_features_branch_hp_units_at_hp_layer_2: 128
# close_features_branch_recurrent_dropout_2: 0.0
# close_features_branch_RNN_layer_3_type: GRU
# close_features_branch_hp_units_at_hp_layer_3: 64
# close_features_branch_recurrent_dropout_3: 0.4
# high_low_features_branch_RNN_layer_2_type: SimpleRNN
# high_low_features_branch_hp_units_at_hp_layer_2: 64
# high_low_features_branch_recurrent_dropout_2: 0.2
# high_low_features_branch_RNN_layer_3_type: GRU
# high_low_features_branch_hp_units_at_hp_layer_3: 128
# high_low_features_branch_recurrent_dropout_3: 0.1
# volume_features_branch_RNN_layer_2_type: SimpleRNN
# volume_features_branch_hp_units_at_hp_layer_2: 64
# volume_features_branch_recurrent_dropout_2: 0.1
# volume_features_branch_RNN_layer_3_type: LSTM
# volume_features_branch_hp_units_at_hp_layer_3: 64
# volume_features_branch_recurrent_dropout_3: 0.1
# batch_size: 32
# base_features_branch_RNN_layer_2_type: SimpleRNN
# base_features_branch_hp_units_at_hp_layer_2: 128
# base_features_branch_recurrent_dropout_2: 0.30000000000000004
# base_features_branch_RNN_layer_3_type: GRU
# base_features_branch_hp_units_at_hp_layer_3: 128
# base_features_branch_recurrent_dropout_3: 0.0
# tuner/epochs: 10
# tuner/initial_epoch: 4
# tuner/bracket: 2
# tuner/round: 2
# tuner/trial_id: 0013
# Score: 0.5595162510871887
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[62], line 30
#      27 hp_RNN_inception_model_1d = HP_Hollow_RNN_Inception_Model(X_train_shape)
#      29 # create models archive for simpleRNN classification approach
# ---> 30 hp_RNN_inception_models_archive_1d = create_models_archive(hp_RNN_inception_model_1d,
#      31                                                  data_sets_1d,
#      32                                                  _model_type=model_type,
#      33                                                  _tuner=tuner,
#      34                                                  _epochs=50,
#      35                                                  _model_name='hp_RNN_inception_model_1d',
#      36                                                  _project_name='hp_RNN_inception_model_archive_1d')
#
# Cell In[24], line 85, in create_models_archive(_create_model, _datasets_dict, _model_type, _tuner, _epochs, _model_name, _project_name)
#      81     model = tuner.hypermodel.build(best_hps)
#      84 # fit the model
# ---> 85 history = model.fit(X_train, y_train,
#      86                     epochs=_epochs,
#      87                     batch_size=32,
#      88                     validation_data=(X_vald, y_vald),
#      89                     callbacks=[stop_early, reduce_lr],
#      90                     verbose=0)
#      92 # get the history of accuracy during training as a list
#      93 if _model_type == "classification":
#
# File ~\anaconda3\Lib\site-packages\keras\src\utils\traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\anaconda3\Lib\site-packages\keras\src\backend\tensorflow\trainer.py:339, in TensorFlowTrainer.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     328 if getattr(self, "_eval_epoch_iterator", None) is None:
#     329     self._eval_epoch_iterator = TFEpochIterator(
#     330         x=val_x,
#     331         y=val_y,
#    (...)
#     337         shuffle=False,
#     338     )
# --> 339 val_logs = self.evaluate(
#     340     x=val_x,
#     341     y=val_y,
#     342     sample_weight=val_sample_weight,
#     343     batch_size=validation_batch_size or batch_size,
#     344     steps=validation_steps,
#     345     callbacks=callbacks,
#     346     return_dict=True,
#     347     _use_cached_eval_dataset=True,
#     348 )
#     349 val_logs = {
#     350     "val_" + name: val for name, val in val_logs.items()
#     351 }
#     352 epoch_logs.update(val_logs)
#
# File ~\anaconda3\Lib\site-packages\keras\src\utils\traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\anaconda3\Lib\site-packages\keras\src\backend\tensorflow\trainer.py:425, in TensorFlowTrainer.evaluate(self, x, y, batch_size, verbose, sample_weight, steps, callbacks, return_dict, **kwargs)
#     423 for step, iterator in epoch_iterator.enumerate_epoch():
#     424     callbacks.on_test_batch_begin(step)
# --> 425     logs = self.test_function(iterator)
#     426     logs = self._pythonify_logs(logs)
#     427     callbacks.on_test_batch_end(step, logs)
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:833, in Function.__call__(self, *args, **kwds)
#     830 compiler = "xla" if self._jit_compile else "nonXla"
#     832 with OptionalXlaContext(self._jit_compile):
# --> 833   result = self._call(*args, **kwds)
#     835 new_tracing_count = self.experimental_get_tracing_count()
#     836 without_tracing = (tracing_count == new_tracing_count)
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:878, in Function._call(self, *args, **kwds)
#     875 self._lock.release()
#     876 # In this case we have not created variables on the first call. So we can
#     877 # run the first trace but we should fail if variables are created.
# --> 878 results = tracing_compilation.call_function(
#     879     args, kwds, self._variable_creation_config
#     880 )
#     881 if self._created_variables:
#     882   raise ValueError("Creating variables on a non-first call to a function"
#     883                    " decorated with tf.function.")
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compilation.py:139, in call_function(args, kwargs, tracing_options)
#     137 bound_args = function.function_type.bind(*args, **kwargs)
#     138 flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139 return function._call_flat(  # pylint: disable=protected-access
#     140     flat_inputs, captured_inputs=function.captured_inputs
#     141 )
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\concrete_function.py:1322, in ConcreteFunction._call_flat(self, tensor_inputs, captured_inputs)
#    1318 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1319 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1320     and executing_eagerly):
#    1321   # No tape is watching; skip to running the function.
# -> 1322   return self._inference_function.call_preflattened(args)
#    1323 forward_backward = self._select_forward_and_backward_functions(
#    1324     args,
#    1325     possible_gradient_type,
#    1326     executing_eagerly)
#    1327 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:216, in AtomicFunction.call_preflattened(self, args)
#     214 def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215   """Calls with flattened tensor inputs and returns the structured output."""
# --> 216   flat_outputs = self.call_flat(*args)
#     217   return self.function_type.pack_output(flat_outputs)
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:251, in AtomicFunction.call_flat(self, *args)
#     249 with record.stop_recording():
#     250   if self._bound_context.executing_eagerly():
# --> 251     outputs = self._bound_context.call_function(
#     252         self.name,
#     253         list(args),
#     254         len(self.function_type.flat_outputs),
#     255     )
#     256   else:
#     257     outputs = make_call_op_in_graph(
#     258         self,
#     259         list(args),
#     260         self._bound_context.function_call_options.as_attrs(),
#     261     )
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\eager\context.py:1500, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1498 cancellation_context = cancellation.context()
#    1499 if cancellation_context is None:
# -> 1500   outputs = execute.execute(
#    1501       name.decode("utf-8"),
#    1502       num_outputs=num_outputs,
#    1503       inputs=tensor_inputs,
#    1504       attrs=attrs,
#    1505       ctx=self,
#    1506   )
#    1507 else:
#    1508   outputs = execute.execute_with_cancellation(
#    1509       name.decode("utf-8"),
#    1510       num_outputs=num_outputs,
#    (...)
#    1514       cancellation_manager=cancellation_context,
#    1515   )
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\eager\execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:

# %% [markdown]
# ### 1 Hour interval

# %%
# insert the stock symbols into a list
symbols_list = ['PFE', 'ROP', 'XYL', 'CPAY', 'INCY']

# load the stock data for the 5 companies into a dictionary
dfs_1h = loadData(symbols=symbols_list, period='max', interval='1h')

# add the targets and technical indicators to each dataframe in the dictionary
full_dfs_1h = add_targets_and_indicators(dfs_1h.copy())

# get the trend up ratio of all the dataframes in the dictionary to get a sense of how balanced the data is
calculate_data_balance(full_dfs_1h)

# get the common sense baseline for each dataframe in the dictionary
calculate_common_sense_baseline(full_dfs_1h)

# apply the 3 steps of preparing data for training on each dataframe in the dictionary
target = 'classification' # set the target
timesteps = 10 # set the timesteps
data_sets_1h = prepare_data_to_train(full_dfs_1h.copy(), min_max_scaler, target, timesteps)

# set the model initialization inputs
X_train_shape = data_sets_1h['PFE']['X_train'].shape
model_type='classification'
tuner = Hyperband

# create the model
hp_RNN_inception_model_1h = HP_Hollow_RNN_Inception_Model(X_train_shape)

# create models archive for simpleRNN classification approach
hp_RNN_inception_models_archive_1d = create_models_archive(hp_RNN_inception_model_1h, 
                                                 data_sets_1h, 
                                                 _model_type=model_type, 
                                                 _tuner=tuner, 
                                                 _epochs=50, 
                                                 _model_name='hp_RNN_inception_model_1h', 
                                                 _project_name='hp_RNN_inception_model_archive_1h')

# %% [markdown]
# ### 5 Minutes intreval

# %%
# insert the stock symbols into a list
symbols_list = ['PFE', 'ROP', 'XYL', 'CPAY', 'INCY']

# load the stock data for the 5 companies into a dictionary
dfs_5m = loadData(symbols=symbols_list, period='max', interval='5m')

# add the targets and technical indicators to each dataframe in the dictionary
full_dfs_5m = add_targets_and_indicators(dfs_5m.copy())

# get the trend up ratio of all the dataframes in the dictionary to get a sense of how balanced the data is
calculate_data_balance(full_dfs_5m)

# get the common sense baseline for each dataframe in the dictionary
calculate_common_sense_baseline(full_dfs_5m)

# apply the 3 steps of preparing data for training on each dataframe in the dictionary
target = 'classification' # set the target
timesteps = 10 # set the timesteps
data_sets_5m = prepare_data_to_train(full_dfs_5m.copy(), min_max_scaler, target, timesteps)

# set the model initialization inputs
X_train_shape = data_sets_5m['PFE']['X_train'].shape
model_type='classification'
tuner = Hyperband

# create the model
hp_RNN_inception_model_5m = HP_Hollow_RNN_Inception_Model(X_train_shape)

# create models archive for simpleRNN classification approach
hp_RNN_inception_models_archive_1d = create_models_archive(hp_RNN_inception_model_5m, 
                                                 data_sets_5m, 
                                                 _model_type=model_type, 
                                                 _tuner=tuner, 
                                                 _epochs=50, 
                                                 _model_name='hp_RNN_inception_model_5m', 
                                                 _project_name='hp_RNN_inception_model_archive_5m')

# %% [markdown]
# List of things to try:
# month intrevals
# longer timesteps for lower intrevals
# BatchNormalization
# convolution layer before lstm
# inception with only one hyperparameter optimization branch
# multi model outputs
# less features and set clode = adj close
